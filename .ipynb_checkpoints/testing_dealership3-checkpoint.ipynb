# %%
import requests
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
from datetime import datetime
import sqlite3
import re


################################################
# Helper functions #
################################################

# Parse a specific tag + class
def parseColumn(soup, html_tag, html_class):
    dataColumn = soup.find_all(html_tag, class_=html_class)
    new_col_list = []
    
    for i in range(0, len(dataColumn)):
        new_col_list.append(dataColumn[i].get_text())
        
    return new_col_list

# Add new column to data frame
def addColumnDF(df, arr, col_name):
    df_tmp = pd.DataFrame(arr, columns = [col_name])
    df[col_name] = df_tmp[col_name]

# Grab vehicle manufacture year
def get_valid_year(soup, html_tag, html_class):
    models = parseColumn(soup, html_tag, html_class)
    new_col_list = []
    
    for model in models:
        new_col_list.append(model[0:4])
        
    return new_col_list

def fix_vehicle_type(df):
    # Check van & cargo
    for idx, row in df.iterrows():
        if 'van' in row['title'].lower() and 'cargo' in row['title'].lower() :
            row['vehicle_type'] = 'Cargo Van'

# Make & Model & Vehicle Type
def get_car_make_model_type(soup, html_tag, html_class):
    full_titles = parseColumn(soup, html_tag, html_class)
    makes = []
    models = []
    vehicle_types = []
    valid_makes = ['BMW', 'Audi', 'Toyota', 'Lexus', 'Ford', 'Honda'
                   , 'Hyundai', 'Kia', 'Chevrolet', 'Jeep', 'Nissan', 'Volkswagen'
                   , 'Mitsubishi', 'Mazda', 'GMC', 'Cadillac', 'Land Rover', 'Dodge'           
                   , 'Subaru', 'Ram', 'Chrysler', 'Acura', 'Mercedes-Benz', 'Infiniti']
    
    valid_vehicle_type = ['Sedan', 'SUV', 'Coupe', 'Wagon', 'Hatchback', 'Truck', 'Cargo Van', 'Van']
    
    # Remove years
    for idx in range(len(full_titles)):
        full_titles[idx] = full_titles[idx][5:]
        
    for model in full_titles:
        clean_model = ''
        stripped_make = ''
        stripped_type = ''
        for make in valid_makes:
            if make.lower() in model.lower():
                stripped_make = make
                clean_model = model.replace(make, '')
        
        for vt in valid_vehicle_type:
            if vt.lower() in clean_model.lower():
                stripped_type = vt
                clean_model = clean_model.replace(vt, '')
                
        if (stripped_make != ''):
            makes.append(stripped_make.strip())
        else:
            makes.append(None) # if none matches add a none
        
        if (stripped_type != ''):
            vehicle_types.append(stripped_type.strip())
        else:
            vehicle_types.append(None) # if none matches add a none
        
        models.append(clean_model.strip()) 

    return makes, models, vehicle_types

# def get_numeric_vehicle_data(html_tag, html_class):
#     scraped_mileages = parseColumn(html_tag, html_class)
#     mileages = []
    
#     for mileage in scraped_mileages:
#         mileages.append(int(re.sub("[^0-9]", "", mileage)))
    
#     return mileages

def get_numeric_vehicle_data(soup, html_tag, html_class):
    scraped_data = parseColumn(soup, html_tag, html_class)
    parsed_data = []
    numeric_data = []
    
    for el in scraped_data:
        parsed_data.append(re.sub("[^0-9]", "", el))
        
    for data in parsed_data:
        if data == '':
            numeric_data.append(np.nan)
        else:
            numeric_data.append(int(data))
    
    return numeric_data

# Use for when vehicle data doesn't have specific class names
def get_misc_vehicle_data(soup, html_tag, html_class, vehicle_data_type):
    misc_vehicle_data = parseColumn(soup, html_tag, html_class)
    vehicle_data_list = []
    for row in misc_vehicle_data:
        for el in row.split('\n'):
            if vehicle_data_type.lower() in el.lower():
                vehicle_data_list.append(el.split(':')[1].strip())
    return vehicle_data_list

# %%
# Dealership Info Dictionary
dealerships = {
    'Bostonyan Auto Group': {
        'url': 'https://www.bostonyanautogroup.com/view-inventory',
        'pagination_url': '',
        'dealership_name': 'Bostonyan Auto Group',
        'address': '119 Worcester St',
        'zipcode': '01760',
        'city': 'Natick',
        'state': 'MA'
    },
    'Direct Auto Mecca': {
        'url': 'https://www.directautomecca.com/view-inventory.aspx',
        'pagination_url': 'https://www.directautomecca.com/inventory.aspx?_new=true&_used=true&_page=2',
        'dealership_name': 'Direct Auto Mecca',
        'address': '154 Waverly Street',
        'zipcode': '01760',
        'city': 'Natick',
        'state': 'MA'
    },
    'Fafama Auto Sales': {
        'url': 'https://www.fafama.com/used-cars.aspx',
        'pagination_url': 'https://www.fafama.com/inventory.aspx?_used=true&_page=2',
        'dealership_name': 'Fafama Auto Sales',
        'address': '5 Cape Road',
        'zipcode': '01757',
        'city': 'Milford',
        'state': 'MA'
    }    
}

# %%
headers = {
    'user-agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/56.0.2924.87 Safari/537.36',
}

URL = 'https://www.fafama.com/used-cars.aspx'
response = requests.get(URL, headers = headers)

soup = BeautifulSoup(response.text, "html.parser")

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en-US">
#  <head>
#   <title>
#    Used Car Inventory &amp; Prices - Boston, Milford, &amp; Framingham, MA | Fafama Auto Sales
#   </title>
#   <meta content="Serving Boston, Milford, and Framingham, MA, Fafama Auto Sales is the best place to purchase your next used car. Check out our car deals today!" name="description"/>
#   <meta content="Boston Used Cars, used cars for sale in Boston, Used Cars Natick, Used cars Worcester MA, used cars boston, used cars providence" name="keywords"/>
#   <meta content="text/html; charset=utf-8" http-equiv="content-type">
#    <meta content="Fafama Auto Sales" name="author">
#     <meta content="width=device-width, initial-scale=1" name="viewport"/>
#     <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#     <meta content="Used Car Inventory &amp; Prices - Boston, Milford, &amp; Framingham, MA | Fafama Auto Sales" name="og:title"/>
#     <meta content="website" name="og:type"/>
#     <meta content="Fafama Auto Sales" property="og:site_name"/>
#     <meta content="http://www.fafama.com/used-cars.aspx" name="og:url"/>
#     <meta content="Serving Boston, Milford, and Framingham, MA, Fafama Auto Sales is the best place to purchase your next used car. Check out our car deals today!" name="og:description"/>
#     <meta content="https://images.ebizautos.media/Foundation/Sites/10730/AccountTemplate/images/dealership-photo.jpg" property="og:image"/>
#     <link href="https://www.fafama.com/used-cars.aspx" rel="canonical"/>
#     <link href="//images.ebizautos.media/sites/10730/favicon.ico" rel="icon" type="image/x-icon"/>
#     <link crossorigin="" href="https://images.ebizautos.media" rel="preconnect"/>
#     <link crossorigin="" href="https://cdn.ebizautos.media" rel="preconnect"/>
#     <link crossorigin="" href="https://stockphotos.ebizautos.media" rel="preconnect"/>
#     <link as="font" crossorigin="" href="https://images.ebizautos.media/fonts/foundation-icons/font-icons.woff" rel="preload" type="font/woff"/>
#     <link as="font" crossorigin="" href="https://images.ebizautos.media/fonts/foundation-icons/font-icons.woff2" rel="preload" type="font/woff2"/>
#     <link as="font" crossorigin="" href="https://images.ebizautos.media/fonts/foundation-icons/font-icons-2.woff" rel="preload" type="font/woff"/>
#     <link as="font" crossorigin="" href="https://images.ebizautos.media/fonts/foundation-icons/font-icons-2.woff2" rel="preload" type="font/woff2"/>
#     <link as="font" crossorigin="" href="https://images.ebizautos.media/fonts/foundation-icons/font-icons-3.woff" rel="preload" type="font/woff"/>
#     <link as="font" crossorigin="" href="https://images.ebizautos.media/fonts/foundation-icons/font-icons-3.woff2" rel="preload" type="font/woff2"/>
#     <link as="font" crossorigin="" href="https://images.ebizautos.media/fonts/foundation-icons/font-icons-4.woff" rel="preload" type="font/woff"/>
#     <link as="font" crossorigin="" href="https://images.ebizautos.media/fonts/foundation-icons/font-icons-4.woff2" rel="preload" type="font/woff2"/>
#     <link as="font" crossorigin="" href="https://images.ebizautos.media/fonts/foundation-icons/lined-icons.woff" rel="preload" type="font/woff"/>
#     <link as="font" crossorigin="" href="https://images.ebizautos.media/fonts/foundation-icons/lined-icons.woff2" rel="preload" type="font/woff2"/>
#     <link as="font" crossorigin="" href="https://images.ebizautos.media/fonts/foundation-icons/Simple-Line-Icons.woff" rel="preload" type="font/woff"/>
#     <link as="font" crossorigin="" href="https://images.ebizautos.media/fonts/foundation-icons/Simple-Line-Icons.woff2" rel="preload" type="font/woff2"/>
#     <link as="font" crossorigin="" href="https://images.ebizautos.media/fonts/foundation-icons/font-vehicles.woff" rel="preload" type="font/woff"/>
#     <link as="font" crossorigin="" href="https://images.ebizautos.media/fonts/foundation-icons/font-vehicles.woff2" rel="preload" type="font/woff2"/>
#     <link as="font" crossorigin="" href="https://images.ebizautos.media/fonts/foundation-icons/font-features.woff" rel="preload" type="font/woff"/>
#     <link as="font" crossorigin="" href="https://images.ebizautos.media/fonts/foundation-icons/font-features.woff2" rel="preload" type="font/woff2"/>
#     <link href="https://images.ebizautos.media/Foundation/Controls/-2147483583/css/foundation.css" rel="stylesheet" type="text/css">
#      <link href="https://images.ebizautos.media/Foundation/Controls/-2147483583/css/font-icons.css" rel="stylesheet" type="text/css">
#       <link href="https://images.ebizautos.media/Foundation/Templates/-2147483603/css/fonts.css" rel="stylesheet" type="text/css">
#        <link href="https://images.ebizautos.media/Foundation/Templates/-2147483603/css/foundation-theme.css" rel="stylesheet" type="text/css">
#         <link href="https://images.ebizautos.media/Foundation/Templates/-2147483603/css/responsive.css" rel="stylesheet" type="text/css">
#          <link href="https://images.ebizautos.media/Foundation/Sites/10730/AccountTemplate/css/custom.css" rel="stylesheet" type="text/css">
#           <style type="text/css">
#            .vehicle-title-wrapper .specials, #srp-vehicle-list .specials{background: #f0b405;}
# .ebiz-carfax-link img, #HistoryInfo img {width:102px; -webkit-backface-visibility: hidden;   -ms-transform: translateZ(0); /* IE 9 */  -webkit-transform: translateZ(0); /* Chrome, Safari, Opera */ transform: translateZ(0);}
#           </style>
#           <!--[if lt IE 9]>
#   <script src="//css3-mediaqueries-js.googlecode.com/svn/trunk/css3-mediaqueries.js"></script>
# <![endif]-->
#           <!-- HeaderContents_Foundation_jQuery_v1.12.0 -->
#           <script src="https://images.ebizautos.media/Foundation/Templates/-2147483646/js/jquery.min.js">
#           </script>
#           <script src="https://images.ebizautos.media/Foundation/Templates/-2147483646/js/jquery.cookie.min.js">
#           </script>
#           <script language="javascript" type="text/javascript">
#            var _leadJSParams = {
# 		14 : 'https://secure-leads.motorcar.com/leads/?siteguid=b35869c5-da4c-409f-9f56-46c10819fc71&leadsource=ebizautos&leadtype=scheduleappointmentrequest&contactid=23355&pageid=21859&pagetypeid=2&campaignid=9&campaignsitetypeid=1&segmentdefaultcampaignid=9&initialrefer=&initialurl=&initialtarget=http%3A%2F%2Fwww.fafama.com%2Fused-cars.aspx&sourcepage=http%3A%2F%2Fwww.fafama.com%2Fused-cars.aspx&hastoincludetransferfee=false&campaigntypeid=10&sitebox=sitebox_vip',
# 29 : 'https://secure-leads.motorcar.com/leads/?siteguid=b35869c5-da4c-409f-9f56-46c10819fc71&leadsource=ebizautos&leadtype=partsrequest&contactid=23355&pageid=21859&pagetypeid=2&campaignid=9&campaignsitetypeid=1&segmentdefaultcampaignid=9&initialrefer=&initialurl=&initialtarget=http%3A%2F%2Fwww.fafama.com%2Fused-cars.aspx&sourcepage=http%3A%2F%2Fwww.fafama.com%2Fused-cars.aspx&hastoincludetransferfee=false&campaigntypeid=10&sitebox=sitebox_vip',
# 13 : 'https://secure-leads.motorcar.com/leads/?siteguid=b35869c5-da4c-409f-9f56-46c10819fc71&leadsource=ebizautos&leadtype=vehiclefinder&contactid=23133&pageid=21859&pagetypeid=2&campaignid=9&campaignsitetypeid=1&segmentdefaultcampaignid=9&initialrefer=&initialurl=&initialtarget=http%3A%2F%2Fwww.fafama.com%2Fused-cars.aspx&sourcepage=http%3A%2F%2Fwww.fafama.com%2Fused-cars.aspx&hastoincludetransferfee=false&campaigntypeid=10&sitebox=sitebox_vip',
# 40 : 'https://secure-leads.motorcar.com/leads/?siteguid=b35869c5-da4c-409f-9f56-46c10819fc71&leadsource=ebizautos&leadtype=contactus&contactid=23133&pageid=21859&pagetypeid=2&campaignid=9&campaignsitetypeid=1&segmentdefaultcampaignid=9&initialrefer=&initialurl=&initialtarget=http%3A%2F%2Fwww.fafama.com%2Fused-cars.aspx&sourcepage=http%3A%2F%2Fwww.fafama.com%2Fused-cars.aspx&hastoincludetransferfee=false&campaigntypeid=10&sitebox=sitebox_vip',
# 1 : 'https://secure-leads.motorcar.com/leads/?siteguid=b35869c5-da4c-409f-9f56-46c10819fc71&leadsource=ebizautos&leadtype=email&pageid=21859&pagetypeid=2&campaignid=9&campaignsitetypeid=1&segmentdefaultcampaignid=9&initialrefer=&initialurl=&initialtarget=http%3A%2F%2Fwww.fafama.com%2Fused-cars.aspx&sourcepage=http%3A%2F%2Fwww.fafama.com%2Fused-cars.aspx&hastoincludetransferfee=false&campaigntypeid=10&sitebox=sitebox_vip',
# 45 : 'https://secure-leads.motorcar.com/leads/?siteguid=b35869c5-da4c-409f-9f56-46c10819fc71&leadsource=ebizautos&leadtype=textrequest&pageid=21859&pagetypeid=2&campaignid=9&campaignsitetypeid=1&segmentdefaultcampaignid=9&initialrefer=&initialurl=&initialtarget=http%3A%2F%2Fwww.fafama.com%2Fused-cars.aspx&sourcepage=http%3A%2F%2Fwww.fafama.com%2Fused-cars.aspx&hastoincludetransferfee=false&campaigntypeid=10&sitebox=sitebox_vip',
# 9 : 'https://secure-leads.motorcar.com/leads/?siteguid=b35869c5-da4c-409f-9f56-46c10819fc71&leadsource=ebizautos&leadtype=tradeappraisal&contactid=23133&pageid=21859&pagetypeid=2&campaignid=9&campaignsitetypeid=1&segmentdefaultcampaignid=9&initialrefer=&initialurl=&initialtarget=http%3A%2F%2Fwww.fafama.com%2Fused-cars.aspx&sourcepage=http%3A%2F%2Fwww.fafama.com%2Fused-cars.aspx&hastoincludetransferfee=false&campaigntypeid=10&sitebox=sitebox_vip',
# 27 : 'https://secure-leads.motorcar.com/leads/?siteguid=b35869c5-da4c-409f-9f56-46c10819fc71&leadsource=ebizautos&leadtype=requestatestdrive&contactid=23133&pageid=21859&pagetypeid=2&campaignid=9&campaignsitetypeid=1&segmentdefaultcampaignid=9&initialrefer=&initialurl=&initialtarget=http%3A%2F%2Fwww.fafama.com%2Fused-cars.aspx&sourcepage=http%3A%2F%2Fwww.fafama.com%2Fused-cars.aspx&hastoincludetransferfee=false&campaigntypeid=10&sitebox=sitebox_vip',
#
# 	};
# 	var _commonJSParams = {
# 		DealerName: 'Fafama Auto Sales',
# 		DealerState: 'Massachusetts',
# 		DealerStateCode: 'MA',
# 		DealerZip: '01757',
# 		LexusDealerId: '',
# 		DealerDomain: '//www.fafama.com/',
# 		DefaultProxyUrl: '//www.fafama.com/',
# 		HostWithoutTLD: 'fafama',
# 		SiteId: '10730',
# 		SiteGuid: 'b35869c5-da4c-409f-9f56-46c10819fc71',
# 		PageName: 'used-cars',
# 		PageType: 2,
# 		Title: 'Used Car Inventory & Prices - Boston, Milford, & Framingham, MA | Fafama Auto Sales',
# 		TrafficType: 'Typed/Bookmarked',
# 		Language: 'en',
# 		SecureSharedLocation: 'https://secure-leads.motorcar.com/',
# 		PASLocation: '//pas.motorcar.com/api/gallery/',
# 		ReferrerPage: '',
# 		SiteboxName: 'sitebox_vip'
# 	};
# 	var _trackingParams = {
# 		IsBmwTrackingOn: false,
# 		IsMiniTrackingOn: false,
# 		IsGoogleEventTrackingOn: true,
# 		IsConversionTrackingOn: true,
# 		IsToyotaTrackingOn: false,
# 		IsPorscheTrackingOn: false,
# 		IsVolkswagenTrackingOn: false,
# 		IsNTPageTrackingOn: false,
# 		GaTrackerNames: 'eBizReports',
# 		IsBmwFranchise: false,
# 		IsMiniFranchise: false,
# 		IsVolkswagenFranchise: false,
# 		VehicleId: '',
# 		VinNumberParam: '',
# 		InventoryYearParam: 'no value',
# 		InventoryTrimParam: 'no value',
# 		InventoryMakeParam: 'no value',
# 		InventoryModelParam: 'no value',
# 		InventoryTypeParam: 'used',
# 		InventoryTransmissionParam: '',
# 		InventoryIntColorTypeParam: '',
# 		InventoryIntColorParam: '',
# 		InventoryExtColorParam: '',
# 		InventoryEngineParam: '',
# 		InventoryPriceFromParam: '0',
# 		InventoryPriceToParam: '0',
# 		InventoryMultipleMakesParam: '',
# 		InventoryMultipleModelsParam: '',
# 		InventoryMultipleTrimsParam: '',
# 		InventoryMultipleExtColorsParam: '',
# 		InventoryMultipleBodyStylesParam: '',
# 		InventoryMultipleYearsParam: '',
# 		InventorySearchPhraseParam: '',
# 		InventorySearchStatusParam: 'used',
# 		LowestPriceValueParam: '0',
# 		MsrpParam: '0',
# 		LowestPrice: '',
# 		SpecialType: '',
# 		SpecialInventoryType: '',
# 		SearchInventoryResult: '144',
# 		SearchPhrases: '',
# 		SearchInventoryTypeResult: 'used',
# 		LeadTypeId: 0,
# 		IsFormSubmited: false,
# 		IsLeadForm: false,
# 		IsFormError: false,
# 		prop1: '',
# 		eVar8: '',
# 		channel: '',
# 		customToyotaPageName: '',
# 	};
# 	var _socialMediaBarParams = {
# 		YouTubeUserName: 'UC81HWN3UydflRBpaSK7h9uQ'
# 	};
#           </script>
#           <script language="javascript" type="text/javascript">
#           </script>
#           <script>
#            (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#     (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#     m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#     })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
# 	ga('create', 'UA-7364301-1', 'auto', {'allowLinker': true});
# 	ga('require', 'linker');
# 	ga('linker:autoLink', ['.ebizautos.com']);
#     ga('send', 'pageview');
#           </script>
#           <script language="javascript" type="text/javascript">
#           </script>
#           <script language="javascript" src="https://images.ebizautos.media/foundation/gallery/js/global.js?18" type="text/javascript">
#           </script>
#           <script language="javascript" src="https://images.ebizautos.media/foundation/gallery/js/gallery.js?20" type="text/javascript">
#           </script>
#           <meta content="F8VLJi8nLOFdFujAJ8rUi5ZpHMwNo6ezVSwCXcs6n-s" name="google-site-verification"/>
#           <meta content="664CEBF35A860F95EF56981A34B13D3F" name="msvalidate.01"/>
#           <script>
#            (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
# 	ga('eBizReports.send', 'pageview');
#           </script>
#           <!-- VIN360 GTM -->
#           <script>
#            (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src='https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);})(window,document,'script','dataLayer','GTM-NFTX3XB');
#           </script>
#           <!-- End VIN360 GTM -->
#           <script src="https://maps.googleapis.com/maps/api/js?key=AIzaSyA1qom5im0_SykXCJ57FmVthVbmUeQEADs&amp;extension=.js">
#           </script>
#          </link>
#         </link>
#        </link>
#       </link>
#      </link>
#     </link>
#    </meta>
#   </meta>
#  </head>
#  <body class="stretched no-transition side-panel-left pageType-Inventory pageName-used-cars">
#   <!-- Body_Inventory_Filters -->
#   <input id="siteDefaultUrl" type="hidden" value="//www.fafama.com/"/>
#   <input id="filtersActionUrl" type="hidden" value="//www.fafama.com/inventory.aspx?_used=true"/>
#   <input id="paginationActionUrl" type="hidden" value="http://www.fafama.com/used-cars.aspx"/>
#   <!-- Body_CustomCodeBodyTop -->
#   <!-- VIN360 GTM (noscript) -->
#   <noscript>
#    <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-NFTX3XB" style="display:none;visibility:hidden" width="0">
#    </iframe>
#   </noscript>
#   <!-- End VIN360 GTM (noscript) -->
#   <!-- Google Tag Manager (noscript) -->
#   <noscript>
#    <iframe height="0" src="
# https://www.googletagmanager.com/ns.html?id=GTM-M6KHQD9" style="display:none;visibility:hidden" width="0">
#    </iframe>
#   </noscript>
#   <!-- End Google Tag Manager (noscript) -->
#   <div class="clearfix" id="wrapper">
#    <div role="banner">
#     <!-- Skip to main content for ADA compliance -->
#     <a class="skip-main button button-small" href="#content">
#      Skip to main content
#     </a>
#     <!-- Skip to main content for ADA compliance -->
#     <!-- Body_SidePanelNav -->
#     <div class="body-overlay d-none">
#     </div>
#     <div class="d-none" id="side-panel">
#      <div class="side-panel-trigger" id="side-panel-trigger-close">
#       <a aria-label="Close" href="#">
#        <i class="icon-line-cross">
#        </i>
#       </a>
#      </div>
#      <div class="side-panel-wrap">
#       <div id="mobile-custom-area-1">
#       </div>
#       <nav aria-label="Mobile Menu" id="mobile-menu" role="navigation">
#        <ul aria-label="Mobile Menu" role="menubar">
#         <li id="mobile-navID-21864" role="menuitem">
#          <a href="//www.fafama.com/">
#           Home
#          </a>
#         </li>
#         <li aria-haspopup="true" class="current" id="mobile-navID-21865" role="menuitem">
#          <a href="//www.fafama.com/used-cars.aspx">
#           Shop Now »
#          </a>
#          <ul aria-label="Shop Now »" role="menu">
#           <li class="current" id="mobile-navID-21865-sub" role="menuitem">
#            <a href="//www.fafama.com/used-cars.aspx">
#             Shop Now »
#            </a>
#           </li>
#           <li id="mobile-navID-21866" role="menuitem">
#            <a href="//www.fafama.com/inventory-1-195144.aspx">
#             View All Cars
#            </a>
#           </li>
#           <li id="mobile-navID-21867" role="menuitem">
#            <a href="https://www.fafama.com/inventory.aspx?_used=true&amp;_bodystyle=1,2,3,4,8&amp;_sort=priceasc">
#             All Sedans
#            </a>
#           </li>
#           <li id="mobile-navID-21868" role="menuitem">
#            <a href="https://www.fafama.com/inventory.aspx?_used=true&amp;_bodystyle=6&amp;_sort=priceasc">
#             All Trucks
#            </a>
#           </li>
#           <li id="mobile-navID-21869" role="menuitem">
#            <a href="https://www.fafama.com/inventory.aspx?_used=true&amp;_bodystyle=5,10&amp;_sort=priceasc">
#             All SUVs
#            </a>
#           </li>
#           <li id="mobile-navID-21870" role="menuitem">
#            <a href="https://www.fafama.com/inventory.aspx?_used=true&amp;_bodystyle=7&amp;_sort=priceasc">
#             All Vans
#            </a>
#           </li>
#           <li id="mobile-navID-21881" role="menuitem">
#            <a href="//www.fafama.com/we-buy-cars.aspx">
#             We Buy Cars
#            </a>
#           </li>
#           <li id="mobile-navID-21882" role="menuitem">
#            <a href="https://www.fafama.com/inventory.aspx?_new=true&amp;_used=true&amp;_cpodealer=true&amp;_daysto=60&amp;_sort=instockdesc">
#             New Arrivals
#            </a>
#           </li>
#           <li id="mobile-navID-21883" role="menuitem">
#            <a href="https://www.fafama.com/inventory.aspx?_new=true&amp;_used=true&amp;_cpodealer=true&amp;_daysfrom=60&amp;_sort=instockasc">
#             "Price Drop"
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li aria-haspopup="true" id="mobile-navID-21886" role="menuitem">
#          <a href="//www.fafama.com/financing.aspx">
#           Finance »
#          </a>
#          <ul aria-label="Finance »" role="menu">
#           <li id="mobile-navID-21886-sub" role="menuitem">
#            <a href="//www.fafama.com/financing.aspx">
#             Finance »
#            </a>
#           </li>
#           <li id="mobile-navID-21887" role="menuitem">
#            <a href="https://secure-leads.motorcar.com/leads/?siteguid=b35869c5-da4c-409f-9f56-46c10819fc71&amp;leadsource=ebiz&amp;leadtype=creaditapp&amp;sitebox=sitebox_vip" rel="noopener" target="_blank">
#             Finance Application
#            </a>
#           </li>
#           <li id="mobile-navID-21888" role="menuitem">
#            <a href="//www.fafama.com/finance-calculator.aspx">
#             Finance Calculator
#            </a>
#           </li>
#           <li id="mobile-navID-21889" role="menuitem">
#            <a href="http://www.fafama.com/trade-in-value.aspx">
#             Trade In Value
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li aria-haspopup="true" id="mobile-navID-21892" role="menuitem">
#          <a href="//www.fafama.com/service-center.aspx">
#           Service »
#          </a>
#          <ul aria-label="Service »" role="menu">
#           <li id="mobile-navID-21892-sub" role="menuitem">
#            <a href="//www.fafama.com/service-center.aspx">
#             Service »
#            </a>
#           </li>
#           <li id="mobile-navID-21893" role="menuitem">
#            <a href="//www.fafama.com/service-department-1.aspx">
#             Schedule A Service
#            </a>
#           </li>
#           <li id="mobile-navID-21896" role="menuitem">
#            <a href="//www.fafama.com/free-form-241103.aspx">
#             About Our Service
#            </a>
#           </li>
#           <li id="mobile-navID-21897" role="menuitem">
#            <a href="//www.fafama.com/dealer-warranty.aspx">
#             Dealer Warranty
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li aria-haspopup="true" id="mobile-navID-21903" role="menuitem">
#          <a href="//www.fafama.com/about-us.aspx">
#           About Us »
#          </a>
#          <ul aria-label="About Us »" role="menu">
#           <li id="mobile-navID-21903-sub" role="menuitem">
#            <a href="//www.fafama.com/about-us.aspx">
#             About Us »
#            </a>
#           </li>
#           <li id="mobile-navID-21904" role="menuitem">
#            <a href="//www.fafama.com/contact-us.aspx">
#             Contact Us
#            </a>
#           </li>
#           <li id="mobile-navID-21905" role="menuitem">
#            <a href="http://www.fafama.com/reviews.aspx">
#             Our Reviews
#            </a>
#           </li>
#           <li id="mobile-navID-21906" role="menuitem">
#            <a href="//www.fafama.com/directions.aspx">
#             Map &amp; Hours
#            </a>
#           </li>
#           <li id="mobile-navID-21907" role="menuitem">
#            <a href="//www.fafama.com/contact-us-3-239111.aspx">
#             Now Hiring
#            </a>
#           </li>
#           <li id="mobile-navID-21908" role="menuitem">
#            <a href="http://www.fafama.com/about-us.aspx">
#             Our History
#            </a>
#           </li>
#           <li id="mobile-navID-21914" role="menuitem">
#            <a href="//www.fafama.com/free-form-240994.aspx">
#             Home Delivery
#            </a>
#           </li>
#           <li id="mobile-navID-21915" role="menuitem">
#            <a href="//www.fafama.com/free-form-240793.aspx">
#             The Fafama Way
#            </a>
#           </li>
#          </ul>
#         </li>
#        </ul>
#       </nav>
#       <div id="mobil-custom-area-2">
#       </div>
#       <!-- Body_SidePanelSocial -->
#       <div class="clearfix" id="mobile-social-media">
#        <a aria-label="View our Facebook Page" class="social-icon si-colored si-facebook" href="https://www.facebook.com/fafamaauto" onclick="return confirm('Are you sure you want to leave this page?')" rel="noopener" target="_blank">
#         <i class="icon-facebook">
#         </i>
#        </a>
#        <a aria-label="View Our Twitter Page" class="social-icon si-colored si-twitter" href="https://www.twitter.com/FafamaCars" onclick="return confirm('Are you sure you want to leave this page?')" rel="noopener" target="_blank">
#         <i class="icon-twitter">
#         </i>
#        </a>
#        <a aria-label="View Our Instagram Page" class="social-icon si-colored si-instagram" href="https://www.instagram.com/fafama.cars" onclick="return confirm('Are you sure you want to leave this page?')" rel="noopener" target="_blank">
#         <i class="icon-instagram2">
#         </i>
#        </a>
#        <a aria-label="View Our YouTube Page" class="social-icon si-colored si-youtube" href="https://www.youtube.com/channel/UC81HWN3UydflRBpaSK7h9uQ" onclick="return confirm('Are you sure you want to leave this page?')" rel="noopener" target="_blank">
#         <i class="icon-youtube">
#         </i>
#        </a>
#       </div>
#       <!-- Body_SidePanelSocialClose -->
#       <div id="mobile-custom-area-3">
#       </div>
#      </div>
#     </div>
#     <!-- Body_SearchFlyout -->
#     <div aria-labelledby="search-flyout-label" id="search-flyout" role="dialog" tabindex="-1">
#      <div class="wrapper">
#       <a aria-label="Close Search Flyout" class="search-flyout-close" href="#" id="search-flyout-close">
#        <i class="icon-line-cross">
#        </i>
#       </a>
#       <div class="container clearfix">
#        <div class="text-center">
#         <h2 id="search-flyout-label">
#          Search Inventory
#         </h2>
#        </div>
#        <div class="search-wrapper">
#         <form action="/inventory.aspx" autocomplete="on" class="ebiz-search-inventory-form" method="get">
#          <div class="row">
#           <div class="col-md-10">
#            <div class="input">
#             <input aria-label="Search Our Inventory" class="search-flyout-input" name="_search" placeholder="Search Inventory" type="text" value=""/>
#            </div>
#           </div>
#           <div class="col-md-2">
#            <button class="button btn-block m-0 ebiz-search-submit" id="submit-button" name="submit">
#             GO
#            </button>
#           </div>
#          </div>
#         </form>
#        </div>
#       </div>
#      </div>
#     </div>
#     <!-- Body_HeaderStyle1_NoSearch -->
#     <header class="mobile-left" id="header">
#      <div id="header-wrap">
#       <div class="container-fullwidth clearfix">
#        <div class="side-panel-trigger d-block d-md-none" id="side-panel-trigger">
#         <a aria-label="Menu" href="javascript:void(0);">
#          <i class="icon-line-menu">
#          </i>
#         </a>
#        </div>
#        <div id="logo">
#         <a aria-label="Fafama Auto Sales" class="standard-logo" href="//www.fafama.com/">
#          <img alt="Dealership Logo" src="https://images.ebizautos.media/Foundation/Sites/10730/AccountTemplate/images/logo-fafama@mobile-2x.png"/>
#          <div class="logo-dealership-name">
#           Fafama Auto Sales
#          </div>
#         </a>
#         <a class="retina-logo" href="//www.fafama.com/">
#          <img alt="Dealership Logo" src="https://images.ebizautos.media/Foundation/Sites/10730/AccountTemplate/images/logo-fafama@mobile-2x.png"/>
#          <div class="logo-dealership-name">
#           Fafama Auto Sales
#          </div>
#         </a>
#         <a class="retina-mobile-logo" href="//www.fafama.com/">
#          <img alt="Dealership Logo" src="https://images.ebizautos.media/Foundation/Sites/10730/AccountTemplate/images/logo-fafama@mobile-2x.png"/>
#          <div class="logo-dealership-name">
#           Fafama Auto Sales
#          </div>
#         </a>
#        </div>
#        <nav aria-label="Primary Menu" class="style-1 d-print-none" id="primary-menu" role="navigation">
#         <ul aria-label="Primary Menu" role="menubar">
#          <li id="navID-21864" role="menuitem">
#           <a href="//www.fafama.com/">
#            <div>
#             Home
#            </div>
#           </a>
#          </li>
#          <li aria-haspopup="true" class="current" id="navID-21865" role="menuitem">
#           <a href="//www.fafama.com/used-cars.aspx">
#            <div>
#             Shop Now »
#            </div>
#           </a>
#           <ul aria-label="Shop Now »" role="menu">
#            <li id="navID-21866" role="menuitem">
#             <a href="//www.fafama.com/inventory-1-195144.aspx">
#              <div>
#               View All Cars
#              </div>
#             </a>
#            </li>
#            <li id="navID-21867" role="menuitem">
#             <a href="https://www.fafama.com/inventory.aspx?_used=true&amp;_bodystyle=1,2,3,4,8&amp;_sort=priceasc">
#              <div>
#               All Sedans
#              </div>
#             </a>
#            </li>
#            <li id="navID-21868" role="menuitem">
#             <a href="https://www.fafama.com/inventory.aspx?_used=true&amp;_bodystyle=6&amp;_sort=priceasc">
#              <div>
#               All Trucks
#              </div>
#             </a>
#            </li>
#            <li id="navID-21869" role="menuitem">
#             <a href="https://www.fafama.com/inventory.aspx?_used=true&amp;_bodystyle=5,10&amp;_sort=priceasc">
#              <div>
#               All SUVs
#              </div>
#             </a>
#            </li>
#            <li id="navID-21870" role="menuitem">
#             <a href="https://www.fafama.com/inventory.aspx?_used=true&amp;_bodystyle=7&amp;_sort=priceasc">
#              <div>
#               All Vans
#              </div>
#             </a>
#            </li>
#            <li id="navID-21881" role="menuitem">
#             <a href="//www.fafama.com/we-buy-cars.aspx">
#              <div>
#               We Buy Cars
#              </div>
#             </a>
#            </li>
#            <li id="navID-21882" role="menuitem">
#             <a href="https://www.fafama.com/inventory.aspx?_new=true&amp;_used=true&amp;_cpodealer=true&amp;_daysto=60&amp;_sort=instockdesc">
#              <div>
#               New Arrivals
#              </div>
#             </a>
#            </li>
#            <li id="navID-21883" role="menuitem">
#             <a href="https://www.fafama.com/inventory.aspx?_new=true&amp;_used=true&amp;_cpodealer=true&amp;_daysfrom=60&amp;_sort=instockasc">
#              <div>
#               "Price Drop"
#              </div>
#             </a>
#            </li>
#           </ul>
#          </li>
#          <li aria-haspopup="true" id="navID-21886" role="menuitem">
#           <a href="//www.fafama.com/financing.aspx">
#            <div>
#             Finance »
#            </div>
#           </a>
#           <ul aria-label="Finance »" role="menu">
#            <li id="navID-21887" role="menuitem">
#             <a href="https://secure-leads.motorcar.com/leads/?siteguid=b35869c5-da4c-409f-9f56-46c10819fc71&amp;leadsource=ebiz&amp;leadtype=creaditapp&amp;sitebox=sitebox_vip" rel="noopener" target="_blank">
#              <div>
#               Finance Application
#              </div>
#             </a>
#            </li>
#            <li id="navID-21888" role="menuitem">
#             <a href="//www.fafama.com/finance-calculator.aspx">
#              <div>
#               Finance Calculator
#              </div>
#             </a>
#            </li>
#            <li id="navID-21889" role="menuitem">
#             <a href="http://www.fafama.com/trade-in-value.aspx">
#              <div>
#               Trade In Value
#              </div>
#             </a>
#            </li>
#           </ul>
#          </li>
#          <li aria-haspopup="true" id="navID-21892" role="menuitem">
#           <a href="//www.fafama.com/service-center.aspx">
#            <div>
#             Service »
#            </div>
#           </a>
#           <ul aria-label="Service »" role="menu">
#            <li id="navID-21893" role="menuitem">
#             <a href="//www.fafama.com/service-department-1.aspx">
#              <div>
#               Schedule A Service
#              </div>
#             </a>
#            </li>
#            <li id="navID-21896" role="menuitem">
#             <a href="//www.fafama.com/free-form-241103.aspx">
#              <div>
#               About Our Service
#              </div>
#             </a>
#            </li>
#            <li id="navID-21897" role="menuitem">
#             <a href="//www.fafama.com/dealer-warranty.aspx">
#              <div>
#               Dealer Warranty
#              </div>
#             </a>
#            </li>
#           </ul>
#          </li>
#          <li aria-haspopup="true" id="navID-21903" role="menuitem">
#           <a href="//www.fafama.com/about-us.aspx">
#            <div>
#             About Us »
#            </div>
#           </a>
#           <ul aria-label="About Us »" role="menu">
#            <li id="navID-21904" role="menuitem">
#             <a href="//www.fafama.com/contact-us.aspx">
#              <div>
#               Contact Us
#              </div>
#             </a>
#            </li>
#            <li id="navID-21905" role="menuitem">
#             <a href="http://www.fafama.com/reviews.aspx">
#              <div>
#               Our Reviews
#              </div>
#             </a>
#            </li>
#            <li id="navID-21906" role="menuitem">
#             <a href="//www.fafama.com/directions.aspx">
#              <div>
#               Map &amp; Hours
#              </div>
#             </a>
#            </li>
#            <li id="navID-21907" role="menuitem">
#             <a href="//www.fafama.com/contact-us-3-239111.aspx">
#              <div>
#               Now Hiring
#              </div>
#             </a>
#            </li>
#            <li id="navID-21908" role="menuitem">
#             <a href="http://www.fafama.com/about-us.aspx">
#              <div>
#               Our History
#              </div>
#             </a>
#            </li>
#            <li id="navID-21914" role="menuitem">
#             <a href="//www.fafama.com/free-form-240994.aspx">
#              <div>
#               Home Delivery
#              </div>
#             </a>
#            </li>
#            <li id="navID-21915" role="menuitem">
#             <a href="//www.fafama.com/free-form-240793.aspx">
#              <div>
#               The Fafama Way
#              </div>
#             </a>
#            </li>
#           </ul>
#          </li>
#         </ul>
#         <div class="d-none d-md-block" id="top-search">
#          <a aria-label="Search Toggle" href="#" id="top-search-trigger">
#           <i class="icon-search3">
#           </i>
#           <i class="icon-line-cross">
#           </i>
#          </a>
#          <form action="/inventory.aspx" class="ebiz-search-inventory-form row d-none d-md-flex align-items-center with-search" method="get">
#           <input aria-label="_search" class="form-control justify-content-start" name="_search" placeholder="Type &amp; Hit Enter.." type="text" value=""/>
#           <button aria-label="Search" class="button justify-content-end" type="submit">
#            <i class="icon-search3 my-0 mr-1">
#            </i>
#            Search
#           </button>
#          </form>
#         </div>
#        </nav>
#       </div>
#      </div>
#     </header>
#     <div class="clear">
#     </div>
#     <!-- Body_MobileHeaderStart -->
#     <div class="clearfix d-block d-md-none" id="bottom-mobile-header">
#      <!-- Body_MobileHeaderLinks_Custom -->
#      <ul>
#       <li>
#        <a href="/used-cars.aspx">
#         <i class="icon-vehicle-car">
#         </i>
#         Inventory
#        </a>
#       </li>
#       <li class="mobile-header-trigger">
#        <div data-mobile-section="#mobile-header-section--search">
#         <i class="icon-search3">
#         </i>
#         Search
#        </div>
#       </li>
#       <li>
#        <a href="/directions.aspx">
#         <i class="icon-map-marker2">
#         </i>
#         Map
#        </a>
#       </li>
#       <li class="mobile-header-trigger">
#        <div data-mobile-section="#mobile-header-section--call-us">
#         <i class="icon-phone3">
#         </i>
#         Call Us
#        </div>
#       </li>
#      </ul>
#      <!-- Body_MobileHeaderLinksEnd -->
#     </div>
#     <!-- Body_MobileHeaderEnd -->
#     <!-- Body_MobileHeaderSearch -->
#     <div class="mobile-header-section" id="mobile-header-section--call-us">
#      <div class="mobile-bar-row clearfix d-flex align-items-center">
#       <div class="col-xs-5">
#        <div class="tleft">
#         Sales Dept.
#        </div>
#       </div>
#       <div class="col-xs-7">
#        <div class="tright">
#         <a class="ebiz-calltoday-button ebiz-clicktocall-button button button-small" href="tel:508-381-6070">
#          <i class="icon-phone3">
#          </i>
#          508-381-6070
#         </a>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="mobile-header-section" id="mobile-header-section--search">
#      <form action="/inventory.aspx" autocomplete="on" class="ebiz-search-inventory-form m-0" method="get">
#       <div class="wrapper clearfix">
#        <div class="col-xs-10 col-sm-10">
#         <div class="input m-0">
#          <input aria-label="Search Inventory" class="form-control" name="_search" placeholder="Search Inventory" type="text"/>
#         </div>
#        </div>
#        <div class="col-xs-2 col-sm-2 pl-0">
#         <button class="button btn-block m-0 p-0" type="submit">
#          Go
#         </button>
#        </div>
#       </div>
#      </form>
#     </div>
#     <!-- Body_BottomBar_Start -->
#     <div class="hidden-sm hidden-xs" id="bottom-bar">
#      <div class="container-fullwidth clearfix">
#       <div class="row">
#        <!-- Body_BottomBar_Content_Franchise -->
#        <div class="col-md-12">
#         <div class="address fleft">
#          5 Cape Road, Milford, MA 01757
#          <a class="map-link ebiz-view-google-map" href="https://www.google.com/maps?q=5 Cape Road+,Milford,MA+01757&amp;spn=0.023888,0.039669&amp;t=h&amp;hl=en" rel="noopener" target="_blank">
#           Map
#           <i class="icon-map-marker2 mr-0 ml-1">
#           </i>
#          </a>
#         </div>
#         <div class="phone fright">
#          <ul>
#           <li>
#            <span class="phone-label">
#             Sales:
#            </span>
#            508-381-6070
#           </li>
#           <li>
#            <span class="phone-label">
#             Service:
#            </span>
#            508-381-6072
#           </li>
#           <li>
#            <span class="phone-label">
#             Parts:
#            </span>
#            508-381-6072
#           </li>
#          </ul>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#     <!-- Body_BottomBar_End -->
#    </div>
#    <!-- role="banner" end -->
#    <!-- Inventory_GEOPageTitle -->
#    <section class="page-title-center" id="page-title">
#     <div class="container clearfix">
#      <h1>
#       144 Used Vehicles For Sale
#       <span>
#        Serving Boston, Milford, Framingham, MA
#       </span>
#      </h1>
#      <ol aria-label="Breadcrumb Links" class="breadcrumb">
#       <li id="breadcrumb-0">
#        <a href="//www.fafama.com/" title="Home">
#         Home
#        </a>
#       </li>
#       <li aria-hidden="true" class="active" id="breadcrumb-1">
#        Used  Cars
#       </li>
#      </ol>
#     </div>
#    </section>
#    <!-- Inventory_TopSort -->
#    <section id="content" role="main">
#     <div class="container bg1 clearfix">
#      <div class="py-4 border-bottom d-none d-sm-block">
#       <div class="row mb-3">
#        <div class="col-md-12">
#         <div id="srp-promo-content">
#          <center>
#           <div class="row my-5">
#            <div class="col-xs-12 col-sm-10 col-sm-offset-1">
#             <a href="/reviews.aspx" target="_self">
#              <img alt="DealerRater" class="responsive" src="https://images.ebizautos.media/Foundation/Sites/10730/AccountTemplate/images/logo-dealer-rater.jpg"/>
#             </a>
#            </div>
#           </div>
#          </center>
#         </div>
#        </div>
#       </div>
#       <div class="row py-2">
#        <div class="col-xs-12 col-sm-4 col-md-6">
#         <div class="pagination-wrapper">
#          <div class="pagination-control">
#           <ul aria-label="List of Pages" class="list-unstyled list-inline m-0 p-0 text-center text-sm-left">
#            <li aria-hidden="true" class="px-0">
#             Page:
#            </li>
#            <li class="active px-2 font-weight-bold">
#             1
#            </li>
#            <li class="px-2 underline">
#             <a href="//www.fafama.com/inventory.aspx?_used=true&amp;_page=2" rel="nofollow">
#              2
#             </a>
#            </li>
#            <li class="px-2 underline">
#             <a href="//www.fafama.com/inventory.aspx?_used=true&amp;_page=3" rel="nofollow">
#              3
#             </a>
#            </li>
#           </ul>
#          </div>
#         </div>
#        </div>
#        <div class="col-xs-12 col-sm-8 col-md-6 d-none d-sm-block">
#         <div class="row">
#          <div class="col-sm-6 col-md-5 col-lg-6 text-right">
#           <label for="pageSize">
#            Vehicles Per Page:
#           </label>
#          </div>
#          <div class="col-sm-6 col-md-7 col-lg-6">
#           <div class="input-wrapper">
#            <div class="select small">
#             <select aria-label="Vehicles Per Page" id="pageSize" name="pageSize" role="listbox">
#              <option value="10">
#               Show 10 Vehicles
#              </option>
#              <option value="25">
#               Show 25 Vehicles
#              </option>
#              <option selected="selected" value="50">
#               Show 50 Vehicles
#              </option>
#              <option value="100">
#               Show 100 Vehicles
#              </option>
#             </select>
#             <i class="icon-angle-down">
#             </i>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div id="srp-top-sort">
#       <div class="row">
#        <div class="col-xs-6 col-md-6 d-block d-md-none">
#         <a class="button" data-target="#srp-modal-refine-search" data-toggle="modal" href="#" id="srp-refine-search-mobile">
#          <i class="icon-filter">
#          </i>
#          Refine Search
#         </a>
#        </div>
#        <div class="col-xs-6 col-md-6 d-block d-md-none">
#         <button class="button fright" data-target="#srp-modal-sortby" data-toggle="modal">
#          <i class="icon-sort">
#          </i>
#          Sort By
#         </button>
#        </div>
#        <div class="col-md-6 d-none d-md-block">
#         <div class="clearfix" id="srp-sortby">
#          <ul class="sortby">
#           <li class="title">
#            Sort By:
#           </li>
#           <li>
#            <a class="ebiz-sort-link" href="//www.fafama.com/inventory.aspx?_used=true&amp;_sort=yearasc" rel="nofollow">
#             Year
#            </a>
#            |
#           </li>
#           <li>
#            <a class="ebiz-sort-link" href="//www.fafama.com/inventory.aspx?_used=true&amp;_sort=makeasc" rel="nofollow">
#             Make
#            </a>
#            |
#           </li>
#           <li>
#            <a class="ebiz-sort-link" href="//www.fafama.com/inventory.aspx?_used=true&amp;_sort=modelasc" rel="nofollow">
#             Model
#            </a>
#            |
#           </li>
#           <li>
#            <a class="ebiz-sort-link" href="//www.fafama.com/inventory.aspx?_used=true&amp;_sort=mileageasc" rel="nofollow">
#             Mileage
#            </a>
#            |
#           </li>
#           <li>
#            <a class="ebiz-sort-link" href="//www.fafama.com/inventory.aspx?_used=true&amp;_sort=priceasc" rel="nofollow">
#             Price
#            </a>
#            |
#           </li>
#           <li>
#            <a class="ebiz-sort-link" href="//www.fafama.com/inventory.aspx?_used=true&amp;_sort=photoasc" rel="nofollow">
#             Photos
#            </a>
#           </li>
#          </ul>
#         </div>
#        </div>
#        <div class="col-md-6 d-none d-md-block">
#         <div class="clearfix" id="srp-vehicle-comparison">
#          <div class="srp-vehicle-comparison-wrapper">
#           <div class="row">
#            <div class="col-md-5 col-md-offset-2 p-0 srp-vehicle-comparison-images d-flex align-items-stretch h-100">
#             <div class="col-md-4 p-0">
#              <div class="VehicleComparingImage h-100 SelectedVehicle1">
#               <img alt="" class="VehiclePhoto responsive" src=""/>
#               <i aria-label="Remove Vehicle" class="icon icon-line2-close remove-car" onclick="javascript:removeItemFromCompareBar(0);" role="button" style="display: none;" tabindex="0">
#               </i>
#              </div>
#             </div>
#             <div class="col-md-4 p-0">
#              <div class="VehicleComparingImage h-100 SelectedVehicle2">
#               <img alt="" class="VehiclePhoto responsive" src=""/>
#               <i aria-label="Remove Vehicle" class="icon icon-line2-close remove-car" onclick="javascript:removeItemFromCompareBar(0);" role="button" style="display: none;" tabindex="0">
#               </i>
#              </div>
#             </div>
#             <div class="col-md-4 p-0">
#              <div class="VehicleComparingImage h-100 SelectedVehicle3">
#               <img alt="" class="VehiclePhoto responsive" src=""/>
#               <i aria-label="Remove Vehicle" class="icon icon-line2-close remove-car" onclick="javascript:removeItemFromCompareBar(0);" role="button" style="display: none;" tabindex="0">
#               </i>
#              </div>
#             </div>
#            </div>
#            <div class="col-md-5 center">
#             <div class="srp-vehicle-comparison-button">
#              <a class="button button-alt btn-block m-0 py-0 px-2 fright" href="#" id="srp-button-compare" onclick="showVehicleCompare()" rel="nofollow">
#               Compare Vehicles
#               <i class="icon-caret-right ml-1 mr-0">
#               </i>
#              </a>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div class="py-4 border-bottom d-block d-sm-none">
#       <div class="row mb-3">
#        <div class="col-md-12">
#         <div id="srp-promo-content-mobile">
#          <center>
#           <div class="row my-5">
#            <div class="col-xs-12 col-sm-10 col-sm-offset-1">
#             <a href="/reviews.aspx" target="_self">
#              <img alt="DealerRater" class="responsive" src="https://images.ebizautos.media/Foundation/Sites/10730/AccountTemplate/images/logo-dealer-rater.jpg"/>
#             </a>
#            </div>
#           </div>
#          </center>
#         </div>
#        </div>
#       </div>
#       <div class="row py-2">
#        <div class="col-xs-4 d-sm-none">
#        </div>
#        <div class="col-xs-4 d-sm-none text-center">
#         <div class="d-inline-block p-0">
#          Page:
#          <br/>
#          1 of 3
#         </div>
#        </div>
#        <div class="col-xs-4 d-sm-none text-right">
#         <a class="button button-small" href="//www.fafama.com/inventory.aspx?_used=true&amp;_page=2" rel="nofollow" title="Next Page">
#          Next
#          <i class="icon-chevron-right ml-2 mr-0">
#          </i>
#         </a>
#        </div>
#       </div>
#      </div>
#      <!-- Inventory_LeftSearchFilter_Sliders -->
#      <div class="clearfix" id="srp">
#       <div class="col-md-3 col-lg-3 d-none d-md-block p-0">
#        <div class="pt-4 pb-3 srp-search-title">
#         <h2 class="h4 body-font text-center">
#          Your Current Search
#         </h2>
#        </div>
#        <div class="srp-current-search-wrapper" id="srp-current-search">
#         <div class="current-search-item clearfix">
#          <div class="current-search-group clearfix">
#           <div class="item-title">
#            Condition
#           </div>
#           <div class="remove-group clearfix">
#            <div class="item-detail fleft">
#             Used
#            </div>
#            <div class="item-clear fright">
#             <a aria-label="Remove Used" class="ebiz-filter-link" href="//www.fafama.com/inventory.aspx" rel="nofollow">
#              <i class="icon-line-cross">
#              </i>
#             </a>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#        <div id="srp-search-filter">
#         <div class="srp-search-filter-wrapper">
#          <div class="pt-4 pb-3 srp-search-title">
#           <h2 class="h4 body-font text-center">
#            Refine Your Search
#           </h2>
#          </div>
#          <div class="toggle" data-state="open" id="srp-make-toggle">
#           <!-- All Other Sections-->
#           <div class="togglet">
#            Make
#            <i class="toggle-closed icon-angle-down">
#            </i>
#            <i class="toggle-open icon-angle-up">
#            </i>
#           </div>
#           <div class="togglec">
#            <div class="filter-element clearfix">
#             <a class="ebiz-filter-link" href="//www.fafama.com/used-acura/" rel="nofollow">
#              Acura
#             </a>
#             <span class="label label-default">
#              5
#             </span>
#            </div>
#            <div class="filter-element clearfix">
#             <a class="ebiz-filter-link" href="//www.fafama.com/used-audi/" rel="nofollow">
#              Audi
#             </a>
#             <span class="label label-default">
#              1
#             </span>
#            </div>
#            <div class="filter-element clearfix">
#             <a class="ebiz-filter-link" href="//www.fafama.com/used-bmw/" rel="nofollow">
#              BMW
#             </a>
#             <span class="label label-default">
#              4
#             </span>
#            </div>
#            <div class="filter-element clearfix">
#             <a class="ebiz-filter-link" href="//www.fafama.com/used-chevrolet/" rel="nofollow">
#              Chevrolet
#             </a>
#             <span class="label label-default">
#              12
#             </span>
#            </div>
#            <div class="filter-element clearfix">
#             <a class="ebiz-filter-link" href="//www.fafama.com/used-chrysler/" rel="nofollow">
#              Chrysler
#             </a>
#             <span class="label label-default">
#              3
#             </span>
#            </div>
#            <div class="filter-element clearfix">
#             <a class="ebiz-filter-link" href="//www.fafama.com/used-dodge/" rel="nofollow">
#              Dodge
#             </a>
#             <span class="label label-default">
#              1
# ...
#             },
#
#             {
#                 "@type": "ListItem",
#                 "position": 15,
#                 "name": "2019 Chevrolet Malibu LT",
#                 "image": "//cdn.ebizautos.media/used-2019-chevrolet-malibu-lt-10730-21038703-1-640.jpg",
#                 "url": "//www.fafama.com/details-2019-chevrolet-malibu-lt-used-1g1zd5stxkf168284.html"
#             },
#
#             {
#                 "@type": "ListItem",
#                 "position": 16,
#                 "name": "2018 Chevrolet Malibu LT",
#                 "image": "//cdn.ebizautos.media/used-2018-chevrolet-malibu-lt-10730-21060512-1-640.jpg",
#                 "url": "//www.fafama.com/details-2018-chevrolet-malibu-lt-used-1g1zd5st9jf248609.html"
#             },
#
#             {
#                 "@type": "ListItem",
#                 "position": 17,
#                 "name": "2020 Chevrolet Silverado 1500 Custom Crew Cab 4WD",
#                 "image": "//stockphotos.ebizautos.media/ebizstockphotos/vehiclestyles/101690/1.jpg",
#                 "url": "//www.fafama.com/details-2020-chevrolet-silverado_1500-custom_crew_cab_4wd-used-1gcuybef1lz148922.html"
#             },
#
#             {
#                 "@type": "ListItem",
#                 "position": 18,
#                 "name": "2020 Chevrolet Silverado 1500 Custom Crew Cab 4WD",
#                 "image": "//cdn.ebizautos.media/used-2020-chevrolet-silverado_1500-customcrewcab4wd-10730-21255419-1-640.jpg",
#                 "url": "//www.fafama.com/details-2020-chevrolet-silverado_1500-custom_crew_cab_4wd-used-1gcuybef3lz212233.html"
#             },
#
#             {
#                 "@type": "ListItem",
#                 "position": 19,
#                 "name": "2020 Chevrolet Silverado 1500 Custom Z71 Crew Cab 4WD ",
#                 "image": "//images.ebizautos.media/ebizstockphoto.jpg",
#                 "url": "//www.fafama.com/details-2020-chevrolet-silverado_1500-custom_z71_crew_cab_4wd_-used-1gcuybef2lz364813.html"
#             },
#
#             {
#                 "@type": "ListItem",
#                 "position": 20,
#                 "name": "2019 Chevrolet Silverado 1500 LT Double Cab 4WD Z71",
#                 "image": "//cdn.ebizautos.media/used-2019-chevrolet-silverado_1500-ltdoublecab4wdz71-10730-21199610-1-640.jpg",
#                 "url": "//www.fafama.com/details-2019-chevrolet-silverado_1500-lt_double_cab_4wd_z71-used-1gcryded0kz245110.html"
#             },
#
#             {
#                 "@type": "ListItem",
#                 "position": 21,
#                 "name": "2019 Chevrolet Silverado 1500 Trail Boss Z71 Crew Cab 4WD",
#                 "image": "//images.ebizautos.media/ebizstockphoto.jpg",
#                 "url": "//www.fafama.com/details-2019-chevrolet-silverado_1500-trail_boss_z71_crew_cab_4wd-used-1gcpycef5kz261015.html"
#             },
#
#             {
#                 "@type": "ListItem",
#                 "position": 22,
#                 "name": "2018 Chrysler Pacifica Touring L",
#                 "image": "//cdn.ebizautos.media/used-2018-chrysler-pacifica-touringl-10730-21210547-1-640.jpg",
#                 "url": "//www.fafama.com/details-2018-chrysler-pacifica-touring_l-used-2c4rc1bg5jr353873.html"
#             },
#
#             {
#                 "@type": "ListItem",
#                 "position":
html"
#             },
#
#             {
#                 "@type": "ListItem",
#                 "position": 44,
#                 "name": "2020 Honda Accord Sedan Sport",
#                 "image": "//cdn.ebizautos.media/used-2020-honda-accord_sedan-sport-10730-21101914-1-640.jpg",
#                 "url": "//www.fafama.com/details-2020-honda-accord_sedan-sport-used-1hgcv1f3xla152678.html"
#             },
#
#             {
#                 "@type": "ListItem",
#                 "position": 45,
#                 "name": "2018 Honda Accord Sedan EX-L",
#                 "image": "//cdn.ebizautos.media/used-2018-honda-accord_sedan-exl-10730-21138198-1-640.jpg",
#                 "url": "//www.fafama.com/details-2018-honda-accord_sedan-ex~l-used-1hgcv1f5xja231864.html"
#             },
#
#             {
#                 "@type": "ListItem",
#                 "position": 46,
#                 "name": "2018 Honda Accord Sedan Sport",
#                 "image": "//cdn.ebizautos.media/used-2018-honda-accord_sedan-sport-10730-21144005-1-640.jpg",
#                 "url": "//www.fafama.com/details-2018-honda-accord_sedan-sport-used-1hgcv1f35ja215344.html"
#             },
#
#             {
#                 "@type": "ListItem",
#                 "position": 47,
#                 "name": "2017 Honda Accord Sedan LX",
#                 "image": "//cdn.ebizautos.media/used-2017-honda-accord_sedan-lx-10730-21220118-1-640.jpg",
#                 "url": "//www.fafama.com/details-2017-honda-accord_sedan-lx-used-1hgcr2f36ha243593.html"
#             },
#
#             {
#                 "@type": "ListItem",
#                 "position": 48,
#                 "name": "2019 Honda Civic Sedan LX",
#                 "image": "//cdn.ebizautos.media/used-2019-honda-civic_sedan-lx-10730-21199606-1-640.jpg",
#                 "url": "//www.fafama.com/details-2019-honda-civic_sedan-lx-used-2hgfc2f6xkh549519.html"
#             },
#
#             {
#                 "@type": "ListItem",
#                 "position": 49,
#                 "name": "2019 Honda Civic Sedan LX ",
#                 "image": "//cdn.ebizautos.media/used-2019-honda-civic_sedan-lx-10730-21189295-1-640.jpg",
#                 "url": "//www.fafama.com/details-2019-honda-civic_sedan-lx_-used-2hgfc2f68kh575729.html"
#             }
#
#         ]
#     }
#   </script>
#   <!-- Footer_Breadcrumb_Schema_org -->
#   <script type="application/ld+json">
#    {
#   "@context": "http://schema.org",
#   "@type": "BreadcrumbList",
#   "itemListElement": [
#     {
#     "@type": "ListItem",
#     "position": 1,
#     "item": {
#       "@id": "//www.fafama.com/",
#       "name": "Home"
#     }
#   },
#
#     {
#     "@type": "ListItem",
#     "position": 2,
#     "item": {
#       "@id": "https://www.fafama.com/used-cars.aspx",
#       "name": "Used  Cars"
#     }
#   }
#   ]
# }
#   </script>
#   <!-- HTML_End -->
#   <script type="application/ld+json">
#    {
# 	  "@context": "http://www.schema.org",
# 	  "@type": "AutoDealer",
# 	  "name": "Fafama Auto Sales",
# 	  "url": "http://www.fafama.com/",
# 	  "logo": "https://images.ebizautos.media/Foundation/Sites/10730/AccountTemplate/images/logo-fafama@mobile-2x.png",
# 	  "image": "https://images.ebizautos.media/Foundation/Sites/10730/AccountTemplate/images/dealership-photo.jpg",
# 	  "telephone": "+1 508-381-6070",
# 	  "address": {
# 		"@type": "PostalAddress",
# 		"streetAddress": "5 Cape Road ",
# 		"addressLocality": "Milford",
# 		"addressRegion": "MA",
# 		"postalCode": "01757",
# 		"addressCountry": "USA"
# 	  },
# 	  "priceRange": "$$",
# 	  "geo": {
# 		"@type": "GeoCoordinates",
# 		"latitude": "42.130057",
# 		"longitude": "-71.5233998"
# 	  },
# 	  "contactPoint": {
# 		"@type": "ContactPoint",
# 		"telephone": "+1 508-381-6070",
# 		"contactType": "sales"
# 	  },
# 	  "sameAs": [
#         "https://www.facebook.com/fafamaauto",
#         "https://www.twitter.com/FafamaCars",
#         "https://www.youtube.com/channel/UC81HWN3UydflRBpaSK7h9uQ",
#         "https://www.instagram.com/fafama.cars",
#         "",
#         ""
#       ]
# 	}
#   </script>
#   <script>
#    $(document).ready(function() {
#     setTimeout(function() {
#         if (window.SpinCarLeadReportUrl) {
#             $('.ebiz-leadform-button').each(function() {
#                 $(this).attr("data-source", $(this).attr("data-source") + "&spurl=" + window.SpinCarLeadReportUrl);
#             });
#             $('.spin-frame').attr("title","Vehicle Spins and Images")
#         } else {
#             console.log("SpinCar not installed.")
#         }
#     }, 1900);
# });
#   </script>
#  </body>
# </html>

# %%
def get_fafama_inventory_data(soup, dealership_info):
    # Initialize empty data frame
    cars = pd.DataFrame()
    
    # Add title
    title = parseColumn(soup, 'h2', 'color m-0 ebiz-vdp-title')    
    addColumnDF(cars, title, 'title')

    # Add vehicle manufacture date
    years = get_valid_year(soup, 'h2', 'color m-0 ebiz-vdp-title')
    addColumnDF(cars, years, 'year')

    # Add make, models, and vehicle type
    makes, models, vtypes = get_car_make_model_type(soup, 'h2', 'color m-0 ebiz-vdp-title')
    addColumnDF(cars, makes, 'make')
    addColumnDF(cars, models, 'models')
    addColumnDF(cars, vtypes, 'vehicle_type')
    
    # Clean up vehicle type
    fix_vehicle_type(cars)

    # Add mileage col
    miles = get_numeric_vehicle_data(soup, 'li', 'mileage-units')
    addColumnDF(cars, miles, 'vehicle_mileage')

    # Add price
    car_prices = get_numeric_vehicle_data(soup, 'div', 'price-item active mt-3 mt-md-0')
    addColumnDF(cars, car_prices, 'price')

    # Add Colors & transmission & other cols
    addColumnDF(cars, get_misc_vehicle_data(soup, 'ul', 'small list-unstyled mb-0', 'exterior'), 'exterior_color')
    addColumnDF(cars, get_misc_vehicle_data(soup, 'ul', 'small list-unstyled mb-0', 'interior'), 'interior_color')
    addColumnDF(cars, get_misc_vehicle_data(soup, 'ul', 'small list-unstyled mb-0', 'transmission'), 'transmission')
    addColumnDF(cars, get_misc_vehicle_data(soup, 'ul', 'small list-unstyled mb-0', 'engine'), 'engine')
    addColumnDF(cars, parseColumn(soup, 'li', 'vin'), 'vin')
    cars['vin'] = cars['vin'].str.replace('VIN #: ', '')
    
    # Add dealership info + scrape date
    cars['dealership_name'] = dealership_info['dealership_name']
    cars['dealership_address'] = dealership_info['address']
    cars['dealership_zipcode'] = dealership_info['zipcode']
    cars['dealership_city'] = dealership_info['city']
    cars['dealership_state'] = dealership_info['state']
    cars['inventory_url'] = dealership_info['url']
    cars['scraped_date'] = datetime.now(tz = None)
    
    return cars
    
    # Add data to a SQLite database
#     conn = sqlite3.connect('cars.db')
#     cars.to_sql('inventory', conn, if_exists='append', index=False)

# %%
c = get_fafama_inventory_data(soup, dealerships['Fafama Auto Sales'])

# %%
c
# Out:
#                                                 title  year       make  \
# 0                                2019 Acura ILX Sedan  2019      Acura
# 1                 2019 Acura ILX Technology Pkg Sedan  2019      Acura
# 2                2018 Acura ILX Special Edition Sedan  2018      Acura
# 3                                2017 Acura ILX Sedan  2017      Acura
# 48                          2019 Honda Civic Sedan LX  2019      Honda
# 49                         2019 Honda Civic Sedan LX   2019      Honda
#
#                                         models vehicle_type  vehicle_mileage  \
# 0                                          ILX        Sedan            36721
# 1                           ILX Technology Pkg        Sedan            21018
# 2                          ILX Special Edition        Sedan            30104
# 3                                          ILX        Sedan            39649
# 4                                          TLX        Sedan            43790
# 5                   A4 Premium Plus S Line AWD        Sedan            50165
# 6                              X1 sDrive28 SAV         None            27326
# 7                             X1 xDrive28i SAV         None            36183
# 8                             X1 xDrive28i SAV         None            30371
# 9                             X5 xDrive35i SAV         None            32113
# 10                                    CRUZE LT        Sedan            19085
# 11                                    CRUZE LT        Sedan            57151
# 12                             CRUZE LT RS Pkg    Hatchback            18604
# 13                                    CRUZE LT        Sedan            64271
# 14                          Express  2500 135"    Cargo Van            35060
# 15                                   Malibu LT        Sedan            54916
# 16                                   Malibu LT        Sedan            59372
# 17          Silverado 1500 Custom Crew Cab 4WD        Truck            30037
# 18          Silverado 1500 Custom Crew Cab 4WD        Truck            28369
# 19      Silverado 1500 Custom Z71 Crew Cab 4WD        Truck            13250
# 20        Silverado 1500 LT Double Cab 4WD Z71        Truck            32612
# 21  Silverado 1500 Trail Boss Z71 Crew Cab 4WD        Truck            30265
# 22                          Pacifica Touring L          Van            39845
# 23                          Pacifica Touring L          Van            24248
# 24                          Pacifica Touring L          Van            24328
# 25                              Challenger SXT        Coupe            23495
# 26                            EcoSport SES 4WD          SUV            24248
# 27                           Edge Titanium AWD          SUV            23741
# 28                         Escape Titanium 4WD          SUV           132155
# 29                  Explorer XLT 4WD Sport Pkg          SUV            48501
# 30                  Explorer XLT 4WD Sport Pkg          SUV            41372
# 31                  Explorer XLT 4WD Sport Pkg          SUV            30784
# 32              F-150 XL SuperCrew 4WD STX Pkg        Truck            38575
# 33             F-150 XLT SuperCrew 4WD XTR Pkg        Truck            36650
# 34             F-150 XLT SuperCrew 4WD XTR Pkg        Truck            51573
# 35                         Fusion Titanium AWD        Sedan            73264
# 36                                   Fusion SE        Sedan            25476
# 37                                   Fusion SE        Sedan            78197
# 38                                   Fusion SE        Sedan            81346
# 39                   Transit  Cargo T-250 130"    Cargo Van            18342
# 40                   Transit  T-250 148" Cargo    Cargo Van            13364
# 41                           Savana  2500 135"    Cargo Van            27634
# 42            Sierra 1500 Crew Cab 4WD X31 Pkg        Truck            16674
# 43                               Accord  Sport        Sedan            39805
# 44                               Accord  Sport        Sedan            17430
# 45                                Accord  EX-L        Sedan            31754
# 46                               Accord  Sport        Sedan            32707
# 47                                  Accord  LX        Sedan            77702
# 48                                   Civic  LX        Sedan            36652
# 49                                   Civic  LX        Sedan            28107
#
#       price                      exterior_color     interior_color  \
# 0   26790.0                Majestic Black Pearl              Ebony
# 1   28390.0                Majestic Black Pearl              Ebony
# 2   25190.0               Lunar Silver Metallic              Ebony
# 3   23190.0               Bellanova White Pearl              Ebony
# 4   29790.0                Majestic Black Pearl              Ebony
# 5   29790.0               Monsoon Gray Metallic       S Line Black
# 6   29390.0                           Jet Black              Black
# 7   30990.0                        Alpine White              Black
# 12  6 Spd Automatic           1.4L 4 CYLINDER  3G1BE6SM3HS583559
# 13  6 Spd Automatic           1.4L 4 CYLINDER  1G1BE5SM5G7255941
# 14  8 Spd Automatic          4.3L V6 CYLINDER  1GCWGAFP5J1287847
# 15        Automatic           1.5L 4 CYLINDER  1G1ZD5STXKF168284
# 16  6 Spd Automatic           1.5L 4 CYLINDER  1G1ZD5ST9JF248609
# 17  6 Spd Automatic           5.3L 8 CYLINDER  1GCUYBEF1LZ148922
# 18  6 Spd Automatic           5.3L 8 CYLINDER  1GCUYBEF3LZ212233
# 19  6 Spd Automatic           5.3L 8 CYLINDER  1GCUYBEF2LZ364813
# 20  8 Spd Automatic           5.3L 8 CYLINDER  1GCRYDED0KZ245110
# 21  6 Spd Automatic           5.3L 8 CYLINDER  1GCPYCEF5KZ261015
# 22  9 Spd Automatic          3.6L V6 CYLINDER  2C4RC1BG5JR353873
# 23  9 Spd Automatic          3.6L V6 CYLINDER  2C4RC1BG0JR323048
# 24  9 Spd Automatic          3.6L V6 CYLINDER  2C4RC1BGXJR331237
# 25  8 Spd Automatic          3.6L V6 CYLINDER  2C3CDZAGXGH300124
# 26  6 Spd Automatic           2.0L 4 CYLINDER  MAJ6P1CL4JC173849
# 27  8 Spd Automatic           2.0L 4 CYLINDER  2FMPK4K91KBB77715
# 28        Automatic           2.0L 4 CYLINDER  1FMCU9J90EUA96274
# 29  6 Spd Automatic           2.3L 4 CYLINDER  1FM5K8DH9JGC59797
# 30  6 Spd Automatic          3.5L V6 CYLINDER  1FM5K8D89JGB95566
# 31  6 Spd Automatic          3.5L V6 CYLINDER  1FM5K8D88JGC61430
# 32        Automatic          2.7L V6 CYLINDER  1FTEW1EP4KFD47671
# 33        Automatic          2.7L V6 CYLINDER  1FTEW1EP5KFA24486
# 34        Automatic          2.7L V6 CYLINDER  1FTEW1EP4HFB93911
# 35  6 Spd Automatic           2.0L 4 CYLINDER  3FA6P0D93KR120334
# 36  6 Spd Automatic           2.5L 4 CYLINDER  3FA6P0H78JR215740
# 37  6 Spd Automatic           2.5L 4 CYLINDER  3FA6P0H77HR331165
# 38  6 Spd Automatic           2.5L 4 CYLINDER  1FA6P0H79E5382326
# 39  6 Spd Automatic          3.7L V6 CYLINDER  1FTYR1ZM7KKB49176
# 40  6 Spd Automatic          3.7L V6 CYLINDER  1FTYR2YM3JKA97082
# 41  8 Spd Automatic           6.0L 8 CYLINDER  1GTW7AFG8L1247121
# 42  6 Spd Automatic           5.3L 8 CYLINDER  1GTU9AEF0LZ145422
# 43        Automatic           1.5L 4 CYLINDER  1HGCV1F38LA025377
# 44        Automatic           1.5L 4 CYLINDER  1HGCV1F3XLA152678
# 45        Automatic           1.5L 4 CYLINDER  1HGCV1F5XJA231864
# 46        Automatic           1.5L 4 CYLINDER  1HGCV1F35JA215344
# 47        Automatic           2.4L 4 CYLINDER  1HGCR2F36HA243593
# 48        Automatic           2.0L 4 CYLINDER  2HGFC2F6XKH549519
# 49        Automatic           2.0L 4 CYLINDER  2HGFC2F68KH575729
#
# 171                     Odyssey EX-L          Van            39482  36390.0
# ..                               ...          ...              ...      ...
# 257                   Jetta 1.4T SEL        Sedan            21528      NaN
# 258      Passat R-Line w/Comfort Pkg        Sedan            57382      NaN
# 259  Tiguan SE 4MOTION w/Premium Pkg          SUV            34481      NaN
# 260  Tiguan SE 4MOTION w/Premium Pkg          SUV            34161  28790.0
# 261              S90 T5 AWD Momentum        Sedan            36349  34190.0
#
#             exterior_color    interior_color     transmission  \
# 167  Lunar Silver Metallic              Gray        Automatic
# 168   Radiant Red Metallic              Gray        Automatic
# 169    Obsidian Blue Pearl              Gray        Automatic
# 170    Crystal Black Pearl             Black        Automatic
# 171    Crystal Black Pearl             Black  9 Spd Automatic
# ..                     ...               ...              ...
# 257             Pure White             Black  8 Spd Automatic
# 258             Pure White    Cornsilk Beige  6 Spd Automatic
# 259             Pure White  Saffrano & Black  8 Spd Automatic
# 260             Pure White  Saffrano & Black  8 Spd Automatic
# 261    Onyx Black Metallic          Charcoal  8 Spd Automatic
#
#                engine                vin    dealership_name  \
# 167   2.0L 4 CYLINDER  2HGFC2F51HH519003  Fafama Auto Sales
# 168   1.5L 4 CYLINDER  5J6RW2H27LA012081  Fafama Auto Sales
# 169   2.4L 4 CYLINDER  5J6RW6H30KL003385  Fafama Auto Sales
# 170   1.5L 4 CYLINDER  2HKRW2H89KH101751  Fafama Auto Sales
# 171  3.5L V6 CYLINDER  5FNRL6H73JB078889  Fafama Auto Sales
# ..                ...                ...                ...
# 257   1.4L 4 CYLINDER  3VWE57BU3KM251768  Fafama Auto Sales
# 258   1.8L 4 CYLINDER  1VWDT7A31HC052402  Fafama Auto Sales
# 259   2.0L 4 CYLINDER  3VV2B7AX6JM193763  Fafama Auto Sales
# 260   2.0L 4 CYLINDER  3VV2B7AX2JM103007  Fafama Auto Sales
# 261   2.0L 4 CYLINDER  LVY982MK8JP032610  Fafama Auto Sales
#
#     dealership_address dealership_zipcode dealership_city dealership_state  \
# 167        5 Cape Road              01757         Milford               MA
# 168        5 Cape Road              01757         Milford               MA
# 169        5 Cape Road              01757         Milford               MA
# 170        5 Cape Road              01757         Milford               MA
# 171        5 Cape Road              01757         Milford               MA
# ..                 ...                ...             ...              ...
# 257        5 Cape Road              01757         Milford               MA
# 258        5 Cape Road              01757         Milford               MA
# 259        5 Cape Road              01757         Milford               MA
# 260        5 Cape Road              01757         Milford               MA
# 261        5 Cape Road              01757         Milford               MA
#
#                              inventory_url                scraped_date
# 167  https://www.fafama.com/used-cars.aspx  2022-03-08 22:41:11.615053
# 168  https://www.fafama.com/used-cars.aspx  2022-03-08 22:41:11.615053
# 169  https://www.fafama.com/used-cars.aspx  2022-03-08 22:41:11.615053
# 170  https://www.fafama.com/used-cars.aspx  2022-03-08 22:41:11.615053
# 171  https://www.fafama.com/used-cars.aspx  2022-03-08 22:41:11.615053
# ..                                     ...                         ...
# 257  https://www.fafama.com/used-cars.aspx  2022-03-08 22:41:12.548816
# 258  https://www.fafama.com/used-cars.aspx  2022-03-08 22:41:12.548816
# 259  https://www.fafama.com/used-cars.aspx  2022-03-08 22:41:12.548816
# 260  https://www.fafama.com/used-cars.aspx  2022-03-08 22:41:12.548816
# 261  https://www.fafama.com/used-cars.aspx  2022-03-08 22:41:12.548816
#
# [95 rows x 19 columns]

# %%
df.loc[df['dealership_name'] == 'Fafama Auto Sales', :].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 95 entries, 167 to 261
# Data columns (total 19 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   title               95 non-null     object
#  1   year                95 non-null     object
#  2   make                95 non-null     object
#  3   models              95 non-null     object
#  4   vehicle_type        95 non-null     object
#  5   vehicle_mileage     95 non-null     int64
#  6   price               81 non-null     float64
#  7   exterior_color      95 non-null     object
#  8   interior_color      95 non-null     object
#  9   transmission        95 non-null     object
#  10  engine              94 non-null     object
#  11  vin                 95 non-null     object
#  12  dealership_name     95 non-null     object
#  13  dealership_address  95 non-null     object
#  14  dealership_zipcode  95 non-null     object
#  15  dealership_city     95 non-null     object
#  16  dealership_state    95 non-null     object
#  17  inventory_url       95 non-null     object
#  18  scraped_date        95 non-null     object
# dtypes: float64(1), int64(1), object(17)
# memory usage: 14.8+ KB

# %%
df.loc[df['dealership_name'] == 'Fafama Auto Sales', :].isnull().sum()
# Out:
# title                  0
# year                   0
# make                   0
# models                 0
# vehicle_type           0
# vehicle_mileage        0
# price                 12
# exterior_color         0
# interior_color         0
# transmission           0
# engine                 1
# vin                    0
# dealership_name        0
# dealership_address     0
# dealership_zipcode     0
# dealership_city        0
# dealership_state       0
# inventory_url          0
# scraped_date           0
# dtype: int64

# %%
df.loc[(df['dealership_name'] == 'Fafama Auto Sales') & (df['make'].isnull()), :]
# Out:
#                                     title  year  make models vehicle_type  \
# 246      2018 Jaguar XE Premium AWD Sedan  2018  None                None
# 320  2018 Volvo S90 T5 AWD Momentum Sedan  2018  None                None
#
#      vehicle_mileage    price       exterior_color interior_color  \
# 246            29866  28790.0          Corris Grey    Ebony/Ebony
# 320            36349  34190.0  Onyx Black Metallic       Charcoal
#
#         transmission           engine                vin    dealership_name  \
# 246  8 Spd Automatic  2.0L 4 CYLINDER  SAJAJ4FX4JCP21579  Fafama Auto Sales
# 320  8 Spd Automatic  2.0L 4 CYLINDER  LVY982MK8JP032610  Fafama Auto Sales
#
#     dealership_address dealership_zipcode dealership_city dealership_state  \
# 246        5 Cape Road              01757         Milford               MA
# 320        5 Cape Road              01757         Milford               MA
#
#                              inventory_url                scraped_date
# 246  https://www.fafama.com/used-cars.aspx  2022-03-06 01:19:52.864160
# 320  https://www.fafama.com/used-cars.aspx  2022-03-06 01:19:53.555042

# %%
df.loc[(df['dealership_name'] == 'Fafama Auto Sales') & (df['engine'].isnull()), :]
# Out:
#                         title  year make     models vehicle_type  \
# 262  2019 Kia Forte LXS Sedan  2019  Kia  Forte LXS        Sedan
#
#      vehicle_mileage    price exterior_color interior_color transmission  \
# 262            35478  19790.0           None           None         None
#
#     engine                vin    dealership_name dealership_address  \
# 262   None  3KPF24AD1KE103127  Fafama Auto Sales        5 Cape Road
#
#     dealership_zipcode dealership_city dealership_state  \
# 262              01757         Milford               MA
#
#                              inventory_url                scraped_date
# 262  https://www.fafama.com/used-cars.aspx  2022-03-06 01:38:12.684829

# %%
df.loc[(df['dealership_name'] == 'Fafama Auto Sales') & (df['exterior_color'].isnull()), :]
# Out:
#                         title  year make     models vehicle_type  \
# 262  2019 Kia Forte LXS Sedan  2019  Kia  Forte LXS        Sedan
#
#      vehicle_mileage    price exterior_color interior_color transmission  \
# 262            35478  19790.0           None           None         None
#
#     engine                vin    dealership_name dealership_address  \
# 262   None  3KPF24AD1KE103127  Fafama Auto Sales        5 Cape Road
#
#     dealership_zipcode dealership_city dealership_state  \
# 262              01757         Milford               MA
#
#                              inventory_url                scraped_date
# 262  https://www.fafama.com/used-cars.aspx  2022-03-06 01:38:12.684829

# %%
df.loc[(df['dealership_name'] == 'Fafama Auto Sales') & (df['price'].isnull()), :]
# Out:
#                                                  title  year        make  \
# 202                    2016 Dodge Challenger SXT Coupe  2016       Dodge
# 211    2017 Ford F-150 XLT SuperCrew 4WD XTR Pkg Truck  2017        Ford
# 215                          2014 Ford Fusion SE Sedan  2014        Ford
# 233                       2017 Hyundai Accent SE Sedan  2017     Hyundai
# 242             2018 INFINITI Q50 3.0t SPORT AWD Sedan  2018    Infiniti
# 254       2018 Jeep Compass Limited 4x4 Luxury Pkg SUV  2018        Jeep
# 257       2018 Jeep Compass Limited 4x4 Luxury Pkg SUV  2018        Jeep
# 271                        2018 Lexus IS 300 AWD Sedan  2018       Lexus
# 274              2018 Mazda CX-9 Grand Touring AWD SUV  2018       Mazda
# 291  2019 Ram 1500 Big Horn/Lone Star Crew Cab 4x4 ...  2019         Ram
# 297                         2019 Toyota Camry SE Sedan  2019      Toyota
# 317  2017 Volkswagen Passat R-Line w/Comfort Pkg Sedan  2017  Volkswagen
#
#                                    models vehicle_type  vehicle_mileage  \
# 202                        Challenger SXT        Coupe            23495
# 211       F-150 XLT SuperCrew 4WD XTR Pkg        Truck            51573
# 215                             Fusion SE        Sedan            81346
# 233                             Accent SE        Sedan            67743
# 242           INFINITI Q50 3.0t SPORT AWD        Sedan            11124
# 254        Compass Limited 4x4 Luxury Pkg          SUV            28823
# 257        Compass Limited 4x4 Luxury Pkg          SUV            21475
# 271                            IS 300 AWD        Sedan            28924
# 274                CX-9 Grand Touring AWD          SUV            22768
# 291  1500 Big Horn/Lone Star Crew Cab 4x4        Truck            33190
# 297                              Camry SE        Sedan            18096
# 317           Passat R-Line w/Comfort Pkg        Sedan            57382
#
#      price                      exterior_color     interior_color  \
# 202    NaN              Bright White Clearcoat              Black
# 211    NaN                        Shadow Black  Medium Earth Gray
# 215    NaN                        Ingot Silver     Charcoal Black
# 233    NaN                       Century White               Gray
# 242    NaN                     Graphite Shadow           Graphite
# 254    NaN  Granite Crystal Metallic Clearcoat              Black
# 257    NaN                Pearl White Tri-Coat              Black
# 271    NaN                       Atomic Silver              Black
# 274    NaN                      Jet Black Mica              Black
# 291    NaN     Diamond Black Crystal Pearlcoat              Black
# 297    NaN           Celestial Silver Metallic              Black
# 317    NaN                          Pure White     Cornsilk Beige
#
#         transmission            engine                vin    dealership_name  \
# 202  8 Spd Automatic  3.6L V6 CYLINDER  2C3CDZAGXGH300124  Fafama Auto Sales
# 211        Automatic  2.7L V6 CYLINDER  1FTEW1EP4HFB93911  Fafama Auto Sales
# 215  6 Spd Automatic   2.5L 4 CYLINDER  1FA6P0H79E5382326  Fafama Auto Sales
# 233        Automatic   1.6L 4 CYLINDER  KMHCT4AE5HU307864  Fafama Auto Sales
# 242  7 Spd Automatic  3.0L V6 CYLINDER  JN1EV7AR4JM434481  Fafama Auto Sales
# 254  9 Spd Automatic   2.4L 4 CYLINDER  3C4NJDCBXJT234299  Fafama Auto Sales
# 257  9 Spd Automatic   2.4L 4 CYLINDER  3C4NJDCB1JT434570  Fafama Auto Sales
# 271  6 Spd Automatic  3.5L V6 CYLINDER  JTHC81D21J5033390  Fafama Auto Sales
# 274  6 Spd Automatic   2.5L 4 CYLINDER  JM3TCBDY2J0226825  Fafama Auto Sales
# 291  8 Spd Automatic  3.6L V6 CYLINDER  1C6RRFFG4KN825234  Fafama Auto Sales
# 297  8 Spd Automatic   2.5L 4 CYLINDER  4T1B11HK0KU776573  Fafama Auto Sales
# 317  6 Spd Automatic   1.8L 4 CYLINDER  1VWDT7A31HC052402  Fafama Auto Sales
#
#     dealership_address dealership_zipcode dealership_city dealership_state  \
# 202        5 Cape Road              01757         Milford               MA
# 211        5 Cape Road              01757         Milford               MA
# 215        5 Cape Road              01757         Milford               MA
# 233        5 Cape Road              01757         Milford               MA
# 242        5 Cape Road              01757         Milford               MA
# 254        5 Cape Road              01757         Milford               MA
# 257        5 Cape Road              01757         Milford               MA
# 271        5 Cape Road              01757         Milford               MA
# 274        5 Cape Road              01757         Milford               MA
# 291        5 Cape Road              01757         Milford               MA
# 297        5 Cape Road              01757         Milford               MA
# 317        5 Cape Road              01757         Milford               MA
#
#                              inventory_url                scraped_date
# 202  https://www.fafama.com/used-cars.aspx  2022-03-06 01:19:51.677114
# 211  https://www.fafama.com/used-cars.aspx  2022-03-06 01:19:51.677114
# 215  https://www.fafama.com/used-cars.aspx  2022-03-06 01:19:51.677114
# 233  https://www.fafama.com/used-cars.aspx  2022-03-06 01:19:52.864160
# 242  https://www.fafama.com/used-cars.aspx  2022-03-06 01:19:52.864160
# 254  https://www.fafama.com/used-cars.aspx  2022-03-06 01:19:52.864160
# 257  https://www.fafama.com/used-cars.aspx  2022-03-06 01:19:52.864160
# 271  https://www.fafama.com/used-cars.aspx  2022-03-06 01:19:52.864160
# 274  https://www.fafama.com/used-cars.aspx  2022-03-06 01:19:52.864160
# 291  https://www.fafama.com/used-cars.aspx  2022-03-06 01:19:53.555042
# 297  https://www.fafama.com/used-cars.aspx  2022-03-06 01:19:53.555042
# 317  https://www.fafama.com/used-cars.aspx  2022-03-06 01:19:53.555042

# %%
conn = sqlite3.connect('cars.db')

#Creating a cursor object using the cursor() method
cursor = conn.cursor()

#Doping EMPLOYEE table if already exists
cursor.execute("DROP TABLE inventory_staging.db")

#Commit your changes in the database
conn.commit()

#Closing the connection
conn.close()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /var/folders/xb/kngqrs1n3n5474zrpfc02thc0000gn/T/ipykernel_36533/776986524.py in <module>
#       5
#       6 #Doping EMPLOYEE table if already exists
# ----> 7 cursor.execute("DROP TABLE inventory_staging.db")
#       8
#       9 #Commit your changes in the database
#
# OperationalError: no such table: inventory_staging.db

# %%
pagination_url.replace('page=[0-9+]', f'page={page_counter}')
# Out:
# 'https://www.fafama.com/inventory.aspx?_used=true&_page=3'

# %%
pagination_url = re.sub('page=[0-9+]', f'page={page_counter}', pagination_url)

# %%
print(pagination_url)
# Out:
# https://www.fafama.com/inventory.aspx?_used=true&_page=4

# %%
pagination_url = 'https://www.fafama.com/inventory.aspx?_used=true&_page=2'

response = requests.get(pagination_url, headers = headers)
soup_pagination = BeautifulSoup(response.text, "html.parser")

# %%
len(get_misc_vehicle_data(soup_pagination, 'ul', 'small list-unstyled mb-0', 'engine'))
# Out:
# 49

# %%
misc_vehicle_data = parseColumn(soup_pagination, 'ul', 'small list-unstyled mb-0')
misc_vehicle_data[0]
# Out:
# '\nEngine: 1.5L 4 CYLINDER\nTransmission: Automatic\nMiles: 32,368\nExterior: Radiant Red Metallic\nInterior: Gray\nStock #: 12673\nVIN #: 5J6RW2H27LA012081\n\n37 Photos\n\n'

# %%
for row in misc_vehicle_data[0]:
    print(row)
# Out:
# E
# n
# g
# i
# n
# e
# :
#
# 1
# .
# 5
# L
#
# 4
#
# C
# Y
# L
# I
# N
# D
# E
# R
#
#
# T
# r
# a
# n
# s
# m
# i
# s
# s
# i
# o
# n
# :
#
# A
# u
# t
# o
# m
# a
# t
# i
# c
#
#
# M
# i
# l
# e
# s
# :
#
# 3
# 2
# ,
# 3
# 6
# 8
#
#
# E
# x
# t
# e
# r
# i
# o
# r
# :
#
# R
# a
# d
# i
# a
# n
# t
#
# R
# e
# d
#
# M
# e
# t
# a
# l
# l
# i
# c
#
#
# I
# n
# t
# e
# r
# i
# o
# r
# :
#
# G
# r
# a
# y
#
#
# S
# t
# o
# c
# k
#
# #
# :
#
# 1
# 2
# 6
# 7
# 3
#
#
# V
# I
# N
#
# #
# :
#
# 5
# J
# 6
# R
# W
# 2
# H
# 2
# 7
# L
# A
# 0
# 1
# 2
# 0
# 8
# 1
#
#
#
#
# 3
# 7
#
# P
# h
# o
# t
# o
# s

# %%
vehicle_data_list = []
for row in misc_vehicle_data:
    if 'engine' not in row.lower():
        vehicle_data_list.append(None)
        continue
    for el in row.split('\n'):
        if 'engine' in el.lower():
            vehicle_data_list.append(el.split(':')[1].strip())
            print(el)
# Out:
# Engine: 1.5L 4 CYLINDER
# Engine: 2.4L 4 CYLINDER
# Engine: 1.5L 4 CYLINDER
# Engine: 3.5L V6 CYLINDER
# Engine: 3.5L V6 CYLINDER
# Engine: 3.5L V6 CYLINDER
# Engine: 1.6L 4 CYLINDER
# Engine: 2.0L 4 CYLINDER
# Engine: 2.0L 4 CYLINDER
# Engine: 2.5L 4 CYLINDER
# Engine: 2.5L 4 CYLINDER
# Engine: 2.4L 4 CYLINDER
# Engine: 2.4L 4 CYLINDER
# Engine: 2.4L 4 CYLINDER
# Engine: 3.0L V6 CYLINDER
# Engine: 3.0L V6 CYLINDER
# Engine: 3.5L V6 CYLINDER
# Engine: 3.5L V6 CYLINDER
# Engine: 3.5L V6 CYLINDER
# Engine: 2.0L 4 CYLINDER
# Engine: 2.4L 4 CYLINDER
# Engine: 2.0L 4 CYLINDER
# Engine: 2.4L 4 CYLINDER
# Engine: 2.4L 4 CYLINDER
# Engine: 2.4L 4 CYLINDER
# Engine: 2.4L 4 CYLINDER
# Engine: 2.4L 4 CYLINDER
# Engine: 2.4L 4 CYLINDER
# Engine: 2.4L 4 CYLINDER
# Engine: 2.4L 4 CYLINDER
# Engine: 2.4L 4 CYLINDER
# Engine: 3.6L V6 CYLINDER
# Engine: 3.6L V6 CYLINDER
# Engine: 3.6L V6 CYLINDER
# Engine: 2.4L 4 CYLINDER
# Engine: 2.0L 4 CYLINDER
# Engine: 2.0L 4 CYLINDER
# Engine: 2.0L 4 CYLINDER
# Engine: 1.6L 4 CYLINDER
# Engine: 2.4L 4 CYLINDER
# Engine: 2.4L 4 CYLINDER
# Engine: 2.0L 4 CYLINDER
# Engine: 3.5L V6 CYLINDER
# Engine: 3.5L V6 CYLINDER
# Engine: 3.5L V6 CYLINDER
# Engine: 2.0L 4 CYLINDER
# Engine: 2.5L 4 CYLINDER
# Engine: 2.5L 4 CYLINDER
# Engine: 1.6L 4 CYLINDER

# %%
vehicle_data_list
# Out:
# ['1.5L 4 CYLINDER',
#  '2.4L 4 CYLINDER',
#  '1.5L 4 CYLINDER',
#  '3.5L V6 CYLINDER',
#  '3.5L V6 CYLINDER',
#  '3.5L V6 CYLINDER',
#  '1.6L 4 CYLINDER',
#  '2.0L 4 CYLINDER',
#  '2.0L 4 CYLINDER',
#  '2.5L 4 CYLINDER',
#  '2.5L 4 CYLINDER',
#  '2.4L 4 CYLINDER',
#  '2.4L 4 CYLINDER',
#  '2.4L 4 CYLINDER',
#  '3.0L V6 CYLINDER',
#  '3.0L V6 CYLINDER',
#  '3.5L V6 CYLINDER',
#  '3.5L V6 CYLINDER',
#  '3.5L V6 CYLINDER',
#  '2.0L 4 CYLINDER',
#  '2.4L 4 CYLINDER',
#  '2.0L 4 CYLINDER',
#  '2.4L 4 CYLINDER',
#  '2.4L 4 CYLINDER',
#  '2.4L 4 CYLINDER',
#  '2.4L 4 CYLINDER',
#  '2.4L 4 CYLINDER',
#  '2.4L 4 CYLINDER',
#  '2.4L 4 CYLINDER',
#  '2.4L 4 CYLINDER',
#  '2.4L 4 CYLINDER',
#  '3.6L V6 CYLINDER',
#  '3.6L V6 CYLINDER',
#  '3.6L V6 CYLINDER',
#  '2.4L 4 CYLINDER',
#  None,
#  '2.0L 4 CYLINDER',
#  '2.0L 4 CYLINDER',
#  '2.0L 4 CYLINDER',
#  '1.6L 4 CYLINDER',
#  '2.4L 4 CYLINDER',
#  '2.4L 4 CYLINDER',
#  '2.0L 4 CYLINDER',
#  '3.5L V6 CYLINDER',
#  '3.5L V6 CYLINDER',
#  '3.5L V6 CYLINDER',
#  '2.0L 4 CYLINDER',
#  '2.5L 4 CYLINDER',
#  '2.5L 4 CYLINDER',
#  '1.6L 4 CYLINDER']
