# %%
import parse_inventory as pi
import parse_dealership
import requests
import re
from bs4 import BeautifulSoup
import pandas as pd
from datetime import datetime
import sqlite3
import numpy as np

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %%
# Dealership Info Dictionary
dealerships = {
    'Bostonyan Auto Group': {
        'url': 'https://www.bostonyanautogroup.com/view-inventory',
        'pagination_url': '',
        'dealership_name': 'Bostonyan Auto Group',
        'address': '119 Worcester St',
        'zipcode': '01760',
        'city': 'Natick',
        'state': 'MA'
    },
    'Direct Auto Mecca': {
        'url': 'https://www.directautomecca.com/view-inventory.aspx',
        'pagination_url': 'https://www.directautomecca.com/inventory.aspx?_new=true&_used=true&_page=2',
        'dealership_name': 'Direct Auto Mecca',
        'address': '154 Waverly Street',
        'zipcode': '01760',
        'city': 'Natick',
        'state': 'MA'
    },
    'Fafama Auto Sales': {
        'url': 'https://www.fafama.com/used-cars.aspx',
        'pagination_url': 'https://www.fafama.com/inventory.aspx?_used=true&_page=2',
        'dealership_name': 'Fafama Auto Sales',
        'address': '5 Cape Road',
        'zipcode': '01757',
        'city': 'Milford',
        'state': 'MA'
    },
    'Newton Automotive Sales': {
        'url': 'https://www.newtonautoandsales.com/cars-for-sale',
        'pagination_url': 'https://www.newtonautoandsales.com/cars-for-sale?PageNumber=2&Sort=MakeAsc&StockNumber=&Condition=&BodyStyle=&Make=&MaxPrice=&Mileage=&SoldStatus=AllVehicles&StockNumber=',
        'dealership_name': 'Newton Automotive Sales',
        'address': '249 Centre Street',
        'zipcode': '02458',
        'city': 'Newton',
        'state': 'MA'
    },
    'Blasius Boston': {
        'url': 'https://www.blasiusboston.com/used-cars-holliston-ma',
        'pagination_url': 'https://www.blasiusboston.com/used-cars-holliston-ma?page=2',
        'dealership_name': 'Blasius Boston',
        'address': '1286 Washington Street',
        'zipcode': '01746',
        'city': 'Holliston',
        'state': 'MA'
    },
    'Avon Auto Brokers': {
        'url': 'https://avonautobrokers.com/newandusedcars?clearall=1',
        'pagination_url': 'https://avonautobrokers.com/newandusedcars?page=2',
        'dealership_name': 'Avon Auto Brokers',
        'address': '159 Memorial Drive',
        'zipcode': '02322',
        'city': 'Avon',
        'state': 'MA'
    }, 
    'Johns Auto Sales': {
        'url': 'https://johnsautosales.com/newandusedcars?clearall=1',
        'pagination_url': 'https://johnsautosales.com/newandusedcars?page=2',
        'dealership_name': "John's Auto Sales",
        'address': '181 Somerville Avenue',
        'zipcode': '02143',
        'city': 'Somerville',
        'state': 'MA'
    },
    'JM Automotive': {
        'url': 'https://www.jmautomotive.com/cars-for-sale-in-Naugatuck-CT-Hartford-New-Haven/used_cars',
        'pagination_url': 'https://www.jmautomotive.com/inventory.aspx?pg=2&sort=12&limit=50&vstatus=1&status=6',
        'dealership_name': 'J&M Automotive',
        'address': '756/820 New Haven Road',
        'zipcode': '06770',
        'city': 'Naugatuck',
        'state': 'CT'
    }
}

# %% [markdown]
# ## Test Connection
#
# Check that the html for the page is being pulled in correctly

# %%
headers = {
    'user-agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/56.0.2924.87 Safari/537.36',
}

URL = 'https://www.jmautomotive.com/cars-for-sale-in-Naugatuck-CT-Hartford-New-Haven/used_cars'
#URL = 'https://www.jmautomotive.com/inventory.aspx?pg=11&sort=12&limit=50&vstatus=1&status=6'
response = requests.get(URL, headers = headers)
soup = BeautifulSoup(response.text, "html.parser")

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en-us">
#  <head>
#   <title>
#    Used cars for sale in Naugatuck, Waterbury, Hartford, New Haven, CT | J&amp;M Automotive Sls&amp;Svc LLC
#   </title>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="black" name="apple-mobile-web-app-status-bar-style"/>
#   <meta content="width=device-width, user-scalable=yes, initial-scale=1.0, minimum-scale=1.0, maximum-scale=9.0" name="viewport"/>
#   <meta content="index, follow" name="robots"/>
#   <meta content="J&amp;M Automotive Sls&amp;Svc LLC, used cars for sale, used car dealer, Connecticut, CT, Naugatuck, Waterbury, Hartford, New Haven, New Haven County, Waterbury CT, Hartford CT, Prospect CT, Oxford CT, Seymour CT, Cheshire CT, Southbury CT, Wolcott CT, Watertown CT, Woodbury CT, Woodbridge CT, Ansonia CT, Hamden CT, Derby CT, North Haven CT and Shelton CT,  used cars, used suv, used trucks, used pickups, used minivans, car financing, service and repair center in Naugatuck, CT" name="keywords"/>
#   <meta content="Used cars for sale in Naugatuck, Waterbury, Hartford, New Haven, Connecticut | J&amp;M Automotive Sls&amp;Svc LLC | Cars in New Haven County, Waterbury CT, Hartford CT, Prospect CT, Oxford CT, Seymour CT, Cheshire CT, Southbury CT, Wolcott CT, Watertown CT, Woodbury CT, Woodbridge CT, Ansonia CT, Hamden CT, Derby CT, North Haven CT and Shelton CT" name="description"/>
#   <meta content="Copyright J&amp;M Automotive Sls&amp;Svc LLC - Naugatuck, CT. All rights reserved." name="copyright"/>
#   <meta content="J&amp;M Automotive Sls&amp;Svc LLC - Naugatuck, CT" name="author"/>
#   <meta content="General" name="rating"/>
#   <meta content="DB59462BDEB106B04DA73EABB07F4A23" name="msvalidate.01"/>
#   <meta content="46C0DFC6DF57F09BF0F60B1C94E05B75" name="msvalidate.01"/>
#   <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
#   <meta content="telephone=no" name="format-detection"/>
#   <meta content="https://www.jmautomotive.com/cars-for-sale-in-Naugatuck-CT-Hartford-New-Haven/used_cars" property="og:url">
#    <meta content="J&amp;M Automotive Sls&amp;Svc LLC" property="og:site_name">
#     <meta content="Used cars for sale in Naugatuck, Waterbury, Hartford, New Haven, CT | J&amp;M Automotive Sls&amp;Svc LLC" property="og:title"/>
#     <meta content="Used cars for sale in Naugatuck, Waterbury, Hartford, New Haven, Connecticut | J&amp;M Automotive Sls&amp;Svc LLC | Cars in New Haven County, Waterbury CT, Hartford CT, Prospect CT, Oxford CT, Seymour CT, Cheshire CT, Southbury CT, Wolcott CT, Watertown CT, Woodbury CT, Woodbridge CT, Ansonia CT, Hamden CT, Derby CT, North Haven CT and Shelton CT" property="og:description"/>
#     <meta content="website" property="og:type"/>
#     <meta content="https://www.jmautomotive.com/Dealer-Websites/J+Mautomotive/images/sharingLogoImg_11.png" property="og:image"/>
#     <meta content="summary" name="twitter:card"/>
#     <meta content="Used cars for sale in Naugatuck, Waterbury, Hartford, New Haven, CT | J&amp;M Automotive Sls&amp;Svc LLC" name="twitter:title"/>
#     <meta content="Used cars for sale in Naugatuck, Waterbury, Hartford, New Haven, Connecticut | J&amp;M Automotive Sls&amp;Svc LLC | Cars in New Haven County, Waterbury CT, Hartford CT, Prospect CT, Oxford CT, Seymour CT, Cheshire CT, Southbury CT, Wolcott CT, Watertown CT, Woodbury CT, Woodbridge CT, Ansonia CT, Hamden CT, Derby CT, North Haven CT and Shelton CT" name="twitter:description"/>
#     <meta content="J&amp;M Automotive Sls&amp;Svc LLC" name="twitter:site"/>
#     <meta content="https://www.jmautomotive.com/Dealer-Websites/J+Mautomotive/images/sharingLogoImg_11.png" name="twitter:image"/>
#     <link href="https://www.jmautomotive.com/cars-for-sale-in-Naugatuck-CT-Waterbury-Hartford/used_cars" rel="canonical"/>
#     <link href="https://www.jmautomotive.com/inventory.aspx?pg=2&amp;sort=12&amp;limit=50&amp;vstatus=1&amp;status=6" rel="next"/>
#     <link href="/HttpCombiner.ashx?s=DW_Common-CSS-min&amp;t=text/css&amp;v=2022.03.28.A&amp;d=467" rel="stylesheet" type="text/css">
#      <link href="/Dealer-Websites/J+Mautomotive/stylesheet/theme.css?v=2022.03.28.A" rel="stylesheet" type="text/css"/>
#      <link href="https://www.jmautomotive.com/Dealer-Websites/J+Mautomotive/images/favicon.ico?v=2022.03.28.A" rel="shortcut icon" type="image/x-icon">
#      </link>
#     </link>
#    </meta>
#   </meta>
#  </head>
#  <body class="SearchBarEnabled ChatDisabled DesktopCss FBChatChatDisabled body_CaptchaCodeEnabled" id="body_inventory">
#   <noscript>
#    <iframe class="DwNoDisplay" height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-K6T6T3V" title="Google Tag Manager" width="0">
#    </iframe>
#   </noscript>
#   <noscript>
#    <img alt="" class="DwNoDisplay" height="1" src="https://www.facebook.com/tr?id=171808093741209&amp;ev=PageView&amp;noscript=1" width="1"/>
#    <img alt="" class="DwNoDisplay" height="1" src="https://www.facebook.com/tr?id=599518190591013&amp;ev=PageView&amp;noscript=1" width="1"/>
#    <img alt="" class="DwNoDisplay" height="1" src="https://www.facebook.com/tr?id=149383822442668&amp;ev=PageView&amp;noscript=1" width="1"/>
#   </noscript>
#   <div class="dw-container-1" id="dw-container">
#    <div id="skip-content">
#     <a href="#DWnavigation">
#      Skip to main content
#     </a>
#    </div>
#    <div class="dw-block" id="dw-topbar-container" itemref="dw-dealership dw-logo DW_StoreHours" itemscope="" itemtype="http://schema.org/AutoDealer">
#     <div id="dw-append-address">
#      <span class="dw-top-addr" itemprop="address" itemscope="" itemtype="http://schema.org/PostalAddress">
#       <span class="dw-block" itemprop="streetAddress">
#        756/820 New Haven Road
#       </span>
#       <span>
#        <span itemprop="addressLocality">
#         Naugatuck
#        </span>
#        ,
#       </span>
#       <span itemprop="addressRegion" title="Connecticut">
#        CT
#       </span>
#       <span class="nbspL" itemprop="postalCode">
#        06770
#       </span>
#      </span>
#      <span>
#       <span class="nbspR dw-hide-dd">
#        |
#       </span>
#       <a aria-label="Driving Directions(opens in a new tab)" class="dw-hide-dd" href="https://maps.google.com/maps?f=q&amp;hl=en&amp;q=J%26M+Automotive+Sls%26Svc+LLC,756/820+New+Haven+Road,Naugatuck,CT+06770&amp;ie=UTF8&amp;om=1&amp;maptype=terrain" id="aGoogleLink1" itemprop="hasMap" target="_blank">
#        Driving Directions
#       </a>
#      </span>
#     </div>
#     <div id="dw-append-fb">
#      <a aria-label="fb recommend (opens ina new tab)" href="https://www.facebook.com/pages/JM-Automotive-SlsSvc-LLC/159851630780993" target="_blank">
#       <img alt="fb" height="19" src="/2/images/fb_rec.png" title="fb recommend" width="99"/>
#      </a>
#     </div>
#     <div id="dw-topbar-info">
#      <div class="dw-fr" id="DWSocialContainer">
#       <div class="dw-social" id="divInstagram">
#        <a aria-label="Instagram" class="dw-top-social" href="https://www.instagram.com/jmautomotivenaugatuck/" id="IconInstagram" itemprop="sameAs" target="_blank">
#         <i class="fa fa-instagram">
#         </i>
#        </a>
#       </div>
#       <div class="dw-social" id="divFacebook">
#        <a aria-label="Facebook" class="dw-top-social" href="https://www.facebook.com/pages/JM-Automotive-SlsSvc-LLC/159851630780993" id="IconFacebook" itemprop="sameAs" target="_blank">
#         <i class="fa fa-facebook">
#         </i>
#        </a>
#       </div>
#       <div class="dw-social" id="divRSS">
#        <a aria-label="Rss" class="dw-top-social" href="https://www.jmautomotive.com/rss.aspx" id="IconRss" target="_blank">
#         <i class="fa fa-rss">
#         </i>
#        </a>
#       </div>
#      </div>
#      <div class="dw-fr" id="dw-append-dealerinfo">
#       <span class="dw-block dw-top-dname" itemprop="name">
#        J&amp;M Automotive Sls&amp;Svc LLC
#       </span>
#       <span class="dw-top-website">
#        <a href="https://www.jmautomotive.com" rel="home">
#         www.jmautomotive.com
#        </a>
#       </span>
#       <span class="dw-pipe">
#        |
#       </span>
#       <span>
#        <a href="tel:2037235666">
#         <span itemprop="telephone">
#          (203) 723-5666
#         </span>
#        </a>
#       </span>
#      </div>
#     </div>
#    </div>
#    <div id="dw-searchbar-append">
#     <div class="dw-block" id="dw-searchbar-c">
#      <div class="dw-searchbar">
#       <div class="dw-searchbox-c">
#        <input aria-label="Search our inventory" autocomplete="off" class="dw-searchbox" id="dw-searchbox" placeholder="Search our inventory" title="Search our inventory" type="text" value=""/>
#       </div>
#       <div id="dw-searchbox-btn" role="button" tabindex="0">
#        <i class="material-icons">
#         search
#        </i>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="dw-block" id="dw-affix-container">
#     <div class="dw-top-header">
#      <div class="dw-table" id="dw-top-DRB">
#       <div class="dw-row">
#        <div class="dw-cell-c dw-cell-3 dw-m-hide">
#         <div class="dwc-cell-1">
#          <img alt="over 550 pre-owned automobiles in stock" class="pre_ownedBanner" id="pre_ownedBanner" src="/Dealer-Websites/J+Mautomotive/images/550.gif" title="over 550 pre-owned automobiles in stock">
#           <br/>
#           <a href="https://www.jmautomotive.com/Dealer-Websites/J+Mautomotive/Get-Financing.aspx?IsGeneric=0&amp;">
#            <img alt="Nosotras Financianos La Identificacion Fiscal" class="tax_Banner" id="tax_Banner" src="/Dealer-Websites/J+Mautomotive/images/getFinancing.png" title="Nosotras Financianos La Identificacion Fiscal"/>
#           </a>
#          </img>
#         </div>
#        </div>
#        <div class="dw-cell dw-cell-2" id="dw-logo">
#         <a href="https://www.jmautomotive.com">
#          <img alt="J&amp;M Automotive Sls&amp;Svc LLC, Naugatuck, CT" class="logoImg" itemprop="logo" src="/Dealer-Websites/J+Mautomotive/images/logo.png" title="J&amp;M Automotive Sls&amp;Svc LLC, Naugatuck, CT"/>
#         </a>
#         <div class="dwc-cell-2">
#          <img alt="OPEN 7 DAYS A WEEK" id="dealerRaterimg" src="/Dealer-Websites/J+Mautomotive/images/OPEN-7-DAYS-A-WEEK.png" title="OPEN 7 DAYS A WEEK"/>
#         </div>
#        </div>
#        <div class="dw-cell-c dw-cell-1 dw-m-hide">
#         <div>
#          <span class="dw-cell-4">
#           <a href="/Dealer-Websites/J+Mautomotive/Sell-You-Car.aspx">
#            <img alt="click here to sell your car and get paid on the spot" class="pre_ownedBanner" src="/Dealer-Websites/J+Mautomotive/images/sellYourCar.jpg" title="click here to sell your car and get paid on the spot"/>
#           </a>
#          </span>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="dw-block" id="dw-scroll-header">
#     </div>
#     <div class="dw-top-menu menu">
#      <nav class="navbar navbar-inverse samp">
#       <div class="container-fluid">
#        <div class="navbar-header">
#         <span id="divIconShare">
#          <a aria-label="share(opens in a new tab)" href="javascript:void(0)" id="aIconShare" role="button">
#           <i class="material-icons">
#            share
#           </i>
#          </a>
#         </span>
#         <span id="divIconDirection">
#          <a aria-label="place(opens in a new tab)" href="https://maps.google.com/maps?f=q&amp;hl=en&amp;q=J%26M+Automotive+Sls%26Svc+LLC,756/820+New+Haven+Road,Naugatuck,CT+06770&amp;ie=UTF8&amp;om=1&amp;maptype=terrain" id="aIconDirection" target="_blank">
#           <i class="material-icons">
#            place
#           </i>
#          </a>
#         </span>
#         <span id="divIconCall">
#          <a aria-label="call(opens in a new tab)" href="tel:2037235666" id="aIconCall">
#           <i class="material-icons">
#            call
#           </i>
#          </a>
#         </span>
#         <div class="navbar-toggle" id="divMenuButton">
#          <i class="material-icons">
#           menu
#          </i>
#         </div>
#        </div>
#        <div class="collapse navbar-collapse" id="DWnavigation">
#         <ul class="main_menu nav navbar-nav" id="main_menu">
#          <li class="dropdown" id="main_menu_1">
#           <a aria-label="HOME" class="dropdown-toggle" data-hover="dropdown" href="https://www.jmautomotive.com" rel="home">
#            HOME
#           </a>
#          </li>
#          <li class="dropdown" id="main_menu_2">
#           <a aria-expanded="false" aria-haspopup="true" aria-label="INVENTORY" class="dropdown-toggle haschildren" data-hover="dropdown" href="https://www.jmautomotive.com/cars-for-sale-in-Naugatuck-CT-Hartford-New-Haven/used_cars">
#            INVENTORY
#           </a>
#           <span class="droparrow">
#            <span class="caretfont">
#             <i aria-hidden="true" class="fa fa-caret-down">
#             </i>
#            </span>
#           </span>
#           <ul class="sub_menu dropdown-menu">
#            <li>
#             <a aria-label="View used cars" class="dropdown-toggle" data-hover="dropdown" href="https://www.jmautomotive.com/cars-for-sale-in-Naugatuck-CT-Hartford-New-Haven/used_cars">
#              View used cars
#             </a>
#            </li>
#            <li>
#             <a aria-label="Featured used cars" class="dropdown-toggle" data-hover="dropdown" href="https://www.jmautomotive.com/search-cars/featured-used-cars-JandM-Automotive-SlsandSvc-LLC">
#              Featured used cars
#             </a>
#            </li>
#            <li>
#             <a aria-label="Used car finder" class="dropdown-toggle" data-hover="dropdown" href="https://www.jmautomotive.com/find-car-for-me">
#              Used car finder
#             </a>
#            </li>
#            <li>
#             <a aria-label="Used cars under $10,000" class="dropdown-toggle" data-hover="dropdown" href="https://www.jmautomotive.com/search-cars/cheap-cars-under-10000-dollars-Naugatuck-Hartford-New-Haven-CT">
#              Used cars under $10,000
#             </a>
#            </li>
#            <li>
#             <a aria-label="$10,000 to $15,000" class="dropdown-toggle" data-hover="dropdown" href="https://www.jmautomotive.com/search-cars/deals-on-cars-under-15000-dollars">
#              $10,000 to $15,000
#             </a>
#            </li>
#            <li>
#             <a aria-label="$15,000 to $20,000" class="dropdown-toggle" data-hover="dropdown" href="https://www.jmautomotive.com/search-cars/deals-on-cars-under-20000-dollars">
#              $15,000 to $20,000
#             </a>
#            </li>
#            <li>
#             <a aria-label="Used cars over $20,000" class="dropdown-toggle" data-hover="dropdown" href="https://www.jmautomotive.com/search-cars/deals-on-cars-over-20000-dollars">
#              Used cars over $20,000
#             </a>
#            </li>
#           </ul>
#          </li>
#          <li class="dropdown" id="main_menu_3">
#           <a aria-expanded="false" aria-haspopup="true" aria-label="SERVICE DEPARTMENT" class="dropdown-toggle haschildren" data-hover="dropdown" href="#">
#            SERVICE DEPARTMENT
#           </a>
#           <span class="droparrow">
#            <span class="caretfont">
#             <i aria-hidden="true" class="fa fa-caret-down">
#             </i>
#            </span>
#           </span>
#           <ul class="sub_menu dropdown-menu">
#            <li>
#             <a aria-label="J&amp;M Service Department" class="dropdown-toggle" data-hover="dropdown" href="https://www.jmautomotive.com/Dealer-Websites/J+Mautomotive/servicedepartment.aspx">
#              J&amp;M Service Department
#             </a>
#            </li>
#           </ul>
#          </li>
#          <li class="dropdown" id="main_menu_4">
#           <a aria-label="VIDEO TOUR" class="dropdown-toggle" data-hover="dropdown" href="javascript:dwmaHdVideoShow()">
#            VIDEO TOUR
#           </a>
#          </li>
#          <li class="dropdown" id="main_menu_5">
#           <a aria-label="FINANCE" class="dropdown-toggle" data-hover="dropdown" href="https://www.jmautomotive.com/Dealer-Websites/J+Mautomotive/Get-Financing.aspx">
#            FINANCE
#           </a>
#          </li>
#          <li class="dropdown" id="main_menu_6">
#           <a aria-expanded="false" aria-haspopup="true" aria-label="ABOUT US" class="dropdown-toggle haschildren" data-hover="dropdown" href="https://www.jmautomotive.com/Dealer-Websites/J+Mautomotive/aboutus.aspx">
#            ABOUT US
#           </a>
#           <span class="droparrow">
#            <span class="caretfont">
#             <i aria-hidden="true" class="fa fa-caret-down">
#             </i>
#            </span>
#           </span>
#           <ul class="sub_menu dropdown-menu">
#            <li>
#             <a aria-label="Our staff" class="dropdown-toggle" data-hover="dropdown" href="https://www.jmautomotive.com/our-staff">
#              Our staff
#             </a>
#            </li>
#            <li>
#             <a aria-label="Contact us" class="dropdown-toggle" data-hover="dropdown" href="https://www.jmautomotive.com/contact-JandM-Automotive-SlsandSvc-LLC">
#              Contact us
#             </a>
#            </li>
#            <li>
#             <a aria-label="Driving directions" class="dropdown-toggle" data-hover="dropdown" href="https://www.jmautomotive.com/driving-directions-to-JandM-Automotive-SlsandSvc-LLC">
#              Driving directions
#             </a>
#            </li>
#            <li>
#             <a aria-label="Our warranties" class="dropdown-toggle" data-hover="dropdown" href="https://www.jmautomotive.com/used-car-warranty-service-contracts-Naugatuck-CT">
#              Our warranties
#             </a>
#            </li>
#            <li>
#             <a aria-label="Remote Purchase Process" class="dropdown-toggle" data-hover="dropdown" href="https://www.jmautomotive.com/Dealer-Websites/J+Mautomotive/remotePurchase.aspx">
#              Remote Purchase Process
#             </a>
#            </li>
#           </ul>
#          </li>
#          <li class="dropdown" id="main_menu_7">
#           <a aria-expanded="false" aria-haspopup="true" aria-label="REVIEWS" class="dropdown-toggle haschildren" data-hover="dropdown" href="https://www.jmautomotive.com/JandM-Automotive-SlsandSvc-LLC-reviews-testimonials">
#            REVIEWS
#           </a>
#           <span class="droparrow">
#            <span class="caretfont">
#             <i aria-hidden="true" class="fa fa-caret-down">
#             </i>
#            </span>
#           </span>
#           <ul class="sub_menu dropdown-menu">
#            <li>
#             <a aria-label="View reviews" class="dropdown-toggle" data-hover="dropdown" href="https://www.jmautomotive.com/JandM-Automotive-SlsandSvc-LLC-reviews-testimonials">
#              View reviews
#             </a>
#            </li>
#            <li>
#             <a aria-label="Submit one" class="dropdown-toggle" data-hover="dropdown" href='javascript:GE_DW_Set_myPopup_invoked_function("myPopup_Testimonial_Show");' role="button">
#              Submit one
#             </a>
#            </li>
#           </ul>
#          </li>
#          <li class="dropdown" id="main_menu_8">
#           <a aria-expanded="false" aria-haspopup="true" class="dropdown-toggle haschildren" data-hover="dropdown" href="javascript:void(0)">
#            <img alt="Google Transilator" id="Transilator" src="/Dealer-Websites/J+Mautomotive/images/language.gif"/>
#           </a>
#           <span class="droparrow">
#            <span class="caretfont">
#             <i aria-hidden="true" class="fa fa-caret-down">
#             </i>
#            </span>
#           </span>
#           <ul class="sub_menu dropdown-menu">
#            <li>
#             <a class="dropdown-toggle" data-hover="dropdown" href="javascript:void(0)">
#              <span id="Transilator_top">
#               Transilator
#              </span>
#             </a>
#            </li>
#           </ul>
#          </li>
#          <li class="dropdown" id="main_menu_end">
#           <a class="dropdown-toggle" data-hover="dropdown" href="javascript:void(0)">
#            <img alt="car fax" src="/Dealer-Websites/J+Mautomotive/images/topcarfaxmenu.png" title="car fax"/>
#           </a>
#          </li>
#         </ul>
#         <div class="dw-desk-hide">
#          <div class="dw-mob-contact-m">
#           <div class="dw-block">
#            756/820 New Haven Road
#           </div>
#           <div class="dw-block">
#            Naugatuck,
#            <span class="nbsp">
#            </span>
#            CT
#            <span class="nbsp" role="presentation">
#            </span>
#            06770
#           </div>
#           <div class="dw-block">
#            <a href="tel:2037235666" id="contactAdd_Phone">
#             (203) 723-5666
#            </a>
#           </div>
#           <div class="dw-block dw-hide-dd">
#            <a aria-label="Driving Directions(opens in a new tab)" href="https://maps.google.com/maps?f=q&amp;hl=en&amp;q=J%26M+Automotive+Sls%26Svc+LLC,756/820+New+Haven+Road,Naugatuck,CT+06770&amp;ie=UTF8&amp;om=1&amp;maptype=terrain" id="contactAdd_Direction" target="_blank">
#             Driving Directions
#            </a>
#           </div>
#          </div>
#          <div id="Mob_ExtraDiv">
#          </div>
#          <div class="googletransMob" id="google_translate_element_mob">
#          </div>
#         </div>
#        </div>
#       </div>
#      </nav>
#     </div>
#    </div>
#    <form action="Dealer-Websites/J+Mautomotive/inventory.aspx?key=vstatus%3d1&amp;status=6" aria-label="inventory" id="searchform" method="post" name="searchform">
#     <div>
#      <input id="__VIEWSTATE" name="__VIEWSTATE" type="hidden" value="AOlDJca7B0tWcTpDYiqGQ8DAt2Gh4BVdFA/XTRySpbLS1NsMbuH4YziCScbezFQCQsZeeYhCl4H07yEURCVyxSPALXqTw2sSlQVbeWp6GcM="/>
#     </div>
#     <div>
#      <input id="__VIEWSTATEGENERATOR" name="__VIEWSTATEGENERATOR" type="hidden" value="4D9B6F97"/>
#     </div>
#     <div aria-hidden="true" class="modal fade" id="div_myPopup_AFDWVideo" role="dialog" tabindex="-1">
#      <div class="modal-dialog" id="div-modal-dialog">
#       <div class="modal-content">
#        <div class="modal-header">
#         <button aria-hidden="true" class="close" data-dismiss="modal" id="dw-video-close" tabindex="-1" type="button">
#          ×
#         </button>
#         <h4>
#          Watch Video
#         </h4>
#        </div>
#        <div class="modal-body video-container" id="div_myPopup_AFDWVideoCnt">
#        </div>
#       </div>
#      </div>
#     </div>
#     <div aria-hidden="true" class="modal fade" id="div_myPopup_AFDWPhoto" role="dialog" tabindex="-1">
#      <div class="modal-dialog dw-modal-dialog-photo">
#       <div class="modal-content">
#        <div class="modal-header">
#         <button aria-hidden="true" class="close" data-dismiss="modal" tabindex="-1" type="button">
#          ×
#         </button>
#         <h4>
#          Inventory Images
#         </h4>
#        </div>
#        <div class="modal-body" id="div_myPopup_AFDWPhotoCnt">
#        </div>
#       </div>
#      </div>
#     </div>
#     <div aria-hidden="true" class="modal fade" id="myPopup_AdvanceSearch_Show" role="dialog" tabindex="-1">
#      <div class="modal-dialog modal-dialog-adv">
#       <div class="modal-content">
#        <div class="modal-header">
#         <button aria-hidden="true" class="close" data-dismiss="modal" tabindex="-1" type="button">
#          ×
#         </button>
#         <h4 id="div_Popup_AdvanceSearch_Title">
#          ADVANCED SEARCH
#         </h4>
#        </div>
#        <div class="modal-body" id="myPopup_AdvanceSearch_Body">
#         <div class="row">
#          <div class="col-lg-12">
#           <div class="ExpandColapaseAll" id="ExpandColapaseAll">
#            <a href="javascript:void(0)" id="expandAll" onclick="inventoryShowMore('-1')">
#             <span>
#              Expand All
#             </span>
#            </a>
#            <span class="nbsp">
#            </span>
#            |
#            <span class="nbspR">
#            </span>
#            <a href="javascript:void(0)" id="collapseAll" onclick="inventoryShowMore('-2')">
#             <span>
#              Collapse All
#             </span>
#            </a>
#           </div>
#           <div class="adv_RangeSlider">
#            <div class="col-sm-12 advSearchSlider">
#             <div class="wpas-range_1 wpas-generic-field wpas-field" id="wpas-range_1">
#              <div class="label-container">
#               <label for="range_1">
#                By Price
#                <i class="icon-help-circled-1 tooltip hide-on-change">
#                </i>
#               </label>
#              </div>
#              <input id="range_1" name="range_1" type="text" value="0;80000"/>
#             </div>
#            </div>
#            <div class="col-sm-12 advSearchSlider">
#             <div class="wpas-range_1 wpas-generic-field wpas-field" id="wpas-range_2">
#              <div class="label-container">
#               <label for="range_2">
#                By Year
#                <i class="icon-help-circled-1 tooltip hide-on-change">
#                </i>
#               </label>
#              </div>
#              <input id="range_2" name="range_2" type="text" value="2000;2016"/>
#             </div>
#            </div>
#            <div class="col-sm-12 advSearchSlider">
#             <div class="wpas-range_1 wpas-generic-field wpas-field" id="wpas-range_3">
#              <div class="label-container">
#               <label for="range_3">
#                By Mileage
#                <i class="icon-help-circled-1 tooltip hide-on-change">
#                </i>
#               </label>
#              </div>
#              <input id="range_3" name="range_3" type="text" value="0;80000"/>
#             </div>
#            </div>
#           </div>
#           <div class="adv_searchType">
#            <div class="col-sm-12 advSearchColorType">
#             <div class="SR_boder">
#              <div class="addSearch">
#               <div>
#                <h5>
#                 By Color
#                </h5>
#               </div>
#               <div class="chkbox">
#                <label>
#                 <input checked="checked" class="CB_AdvSearchPopup" id="chkcolor" name="chkcolor" onclick="setColorBodyAll('chkcolor')" type="checkbox" value="C_All"/>
#                 <strong class="p">
#                  Select all
#                 </strong>
#                </label>
#               </div>
#              </div>
#              <div class="addSearchR" id="adSearchColor">
#              </div>
#             </div>
#            </div>
#            <div class="col-sm-12 advSearchBodyType">
#             <div class="SR_boder">
#              <div class="addSearch">
#               <div>
#                <h5>
#                 By Body Types
#                </h5>
#               </div>
#               <div class="chkbox">
#                <label>
#                 <input checked="checked" class="CB_AdvSearchPopup" id="chkbodyt" name="chkbodyt" onclick="setColorBodyAll('chkbodyt')" type="checkbox" value="B_All"/>
#                 <strong class="p">
#                  Select all
#                 </strong>
#                </label>
#               </div>
#              </div>
#              <div class="addSearchR" id="addSearchRBodyType">
#              </div>
#             </div>
#            </div>
#           </div>
#           <div class="dw-cseachbtn" id="div_addsearchSend">
#            <div class="dw-addDW_send01">
#             <a class="btn btn-primary pull-right" href="javascript:void(0)" id="addbtnSend" onclick="showVechicle()">
#              <i class="fa fa-send fa-btn">
#              </i>
#              Submit
#             </a>
#            </div>
#           </div>
#           <div class="col-sm-12 wpas-field" id="dw-adsfilterlist">
#            <div class="addSearch dw-addSearch">
#            </div>
#            <div class="addSearchR">
#             <div id="divsearch">
#              <table role="presentation">
#               <tbody>
#                <tr>
#                 <td class="valignTop240">
#                  <div class="valignTop240" id="MakeSearch1">
#                  </div>
#                 </td>
#                 <td class="valignTop240">
#                  <div class="valignTop240" id="MakeSearch2">
#                  </div>
#                 </td>
#                 <td class="valignTop240">
#                  <div class="valignTop240" id="MakeSearch3">
#                  </div>
#                 </td>
#                </tr>
#               </tbody>
#              </table>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div aria-hidden="true" class="modal fade" id="myPopup_Vehicle_History" role="dialog" tabindex="-1">
#      <div class="modal-dialog" id="vehicle-history-modal-dialog">
#       <div class="modal-content">
#        <div class="modal-header">
#         <button aria-hidden="true" class="close" data-dismiss="modal" tabindex="-1" type="button">
#          ×
#         </button>
#         <h4>
#          Vehicle History
#         </h4>
#        </div>
#        <div class="modal-body" id="myPopup_Vehicle_History_Body">
#        </div>
#       </div>
#      </div>
#     </div>
#     <div aria-hidden="true" class="modal fade" id="div_myPopup_AFDWUrlImage360" role="dialog" tabindex="-1">
#      <div class="modal-dialog" id="div-modal-dialog-UrlImage360">
#       <div class="modal-content">
#        <div class="modal-header">
#         <button aria-hidden="true" class="close" data-dismiss="modal" id="dw-UrlImage360-close" tabindex="-1" type="button">
#          ×
#         </button>
#         <h4>
#          360° view of the exterior
#         </h4>
#        </div>
#        <div class="modal-body UrlImage360-container" id="div_myPopup_AFDWUrlImage360Cnt">
#        </div>
#       </div>
#      </div>
#     </div>
#     <div aria-hidden="true" class="modal fade" id="myPopup_Request_ConfirmAvail" role="dialog" tabindex="-1">
#      <div class="modal-dialog">
#       <div class="modal-content">
#        <div class="modal-header" id="myPopup_Request_ConfirmAvail_header">
#         <button aria-hidden="true" class="close" data-dismiss="modal" tabindex="-1" type="button">
#          ×
#         </button>
#         <h4>
#          CONFIRM AVAILABILITY
#         </h4>
#        </div>
#        <div class="modal-body" id="myPopup_Request_ConfirmAvail_body">
#         <div id="loader">
#          <img alt="loader" src="/1/images/ajax-loader.gif"/>
#         </div>
#         <div class="myPopup_bodyHead" id="myPopup_bodyHead">
#          <b>
#           INTERESTED VEHICLE
#          </b>
#         </div>
#         <div id="myPopup_Request_ConfirmAvail_bodyText">
#         </div>
#         <div id="myPopup_ConfirmAvail_body">
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="contentbg make_False model_False" id="divcontentinv">
#      <div class="contentbg0">
#       <div class="container cover002">
#        <div class="panel panel-primary ClsMobile_False" id="divInvMakeContainer">
#         <div class="panel-heading" id="divInvHeading">
#          <div class="panel-title bdr-btm1" id="MidH1Text">
#           INVENTORY
#          </div>
#         </div>
#         <div class="panel-body" id="divMakeListing">
#          <div class="MakesDiv">
#           <a href="https://www.jmautomotive.com/used/make/Acura/Naugatuck/CT/Waterbury/Hartford/New-Haven/NEW-HAVEN" title="6 Acura for sale in Naugatuck, CT 06770 | J&amp;M Automotive Sls&amp;Svc LLC. Naugatuck, Connecticut">
#            <div class="Lst-car">
#             <strong class="badge">
#              6
#             </strong>
#             <span class="dw-makes">
#              Acura
#             </span>
#            </div>
#           </a>
#          </div>
#          <div class="MakesDiv">
#           <a href="https://www.jmautomotive.com/used/make/Audi/Naugatuck/CT/Waterbury/Hartford/New-Haven/NEW-HAVEN" title="23 Audi for sale in Naugatuck, CT 06770 | J&amp;M Automotive Sls&amp;Svc LLC. Naugatuck, Connecticut">
#            <div class="Lst-car">
#             <strong class="badge">
#              23
#             </strong>
#             <span class="dw-makes">
#              Audi
#             </span>
#            </div>
#           </a>
#          </div>
#          <div class="MakesDiv">
#           <a href="https://www.jmautomotive.com/used/make/BMW/Naugatuck/CT/Waterbury/Hartford/New-Haven/NEW-HAVEN" title="15 BMW for sale in Naugatuck, CT 06770 | J&amp;M Automotive Sls&amp;Svc LLC. Naugatuck, Connecticut">
#            <div class="Lst-car">
#             <strong class="badge">
#              15
#             </strong>
#             <span class="dw-makes">
#              BMW
#             </span>
#            </div>
#           </a>
#          </div>
#          <div class="MakesDiv">
#           <a href="https://www.jmautomotive.com/used/make/Buick/Naugatuck/CT/Waterbury/Hartford/New-Haven/NEW-HAVEN" title="5 Buick for sale in Naugatuck, CT 06770 | J&amp;M Automotive Sls&amp;Svc LLC. Naugatuck, Connecticut">
#            <div class="Lst-car">
#             <strong class="badge">
#              5
#             </strong>
#             <span class="dw-makes">
#              Buick
#             </span>
#            </div>
#           </a>
#          </div>
#          <div class="MakesDiv">
#           <a href="https://www.jmautomotive.com/used/make/Cadillac/Naugatuck/CT/Waterbury/Hartford/New-Haven/NEW-HAVEN" title="7 Cadillac for sale in Naugatuck, CT 06770 | J&amp;M Automotive Sls&amp;Svc LLC. Naugatuck, Connecticut">
#            <div class="Lst-car">
#             <strong class="badge">
#              7
#             </strong>
#             <span class="dw-makes">
#              Cadillac
#             </span>
#            </div>
#           </a>
#          </div>
#          <div class="MakesDiv">
#           <a href="https://www.jmautomotive.com/used/make/Chevrolet/Naugatuck/CT/Waterbury/Hartford/New-Haven/NEW-HAVEN" title="26 Chevrolet for sale in Naugatuck, CT 06770 | J&amp;M Automotive Sls&amp;Svc LLC. Naugatuck, Connecticut">
#            <div class="Lst-car">
#             <strong class="badge">
#              26
#             </strong>
#             <span class="dw-makes">
#              Chevrolet
#             </span>
#            </div>
#           </a>
#          </div>
#          <div class="MakesDiv">
#           <a href="https://www.jmautomotive.com/used/make/Chrysler/Naugatuck/CT/Waterbury/Hartford/New-Haven/NEW-HAVEN" title="7 Chrysler for sale in Naugatuck, CT 06770 | J&amp;M Automotive Sls&amp;Svc LLC. Naugatuck, Connecticut">
#            <div class="Lst-car">
#             <strong class="badge">
#              7
#             </strong>
#             <span class="dw-makes">
#              Chrysler
#             </span>
#            </div>
#           </a>
#          </div>
#          <div class="MakesDiv">
#           <a href="https://www.jmautomotive.com/used/make/Dodge/Naugatuck/CT/Waterbury/Hartford/New-Haven/NEW-HAVEN" title="12 Dodge for sale in Naugatuck, CT 06770 | J&amp;M Automotive Sls&amp;Svc LLC. Naugatuck, Connecticut">
#            <div class="Lst-car">
#             <strong class="badge">
#              12
#             </strong>
#             <span class="dw-makes">
#              Dodge
#             </span>
#            </div>
#           </a>
#          </div>
#          <div class="MakesDiv">
#           <a href="https://www.jmautomotive.com/used/make/Fiat/Naugatuck/CT/Waterbury/Hartford/New-Haven/NEW-HAVEN" title="5 Fiat for sale in Naugatuck, CT 06770 | J&amp;M Automotive Sls&amp;Svc LLC. Naugatuck, Connecticut">
#            <div class="Lst-car">
#             <strong class="badge">
#              5
#             </strong>
#             <span class="dw-makes">
#              Fiat
#             </span>
#            </div>
#           </a>
#          </div>
#          <div class="MakesDiv">
#           <a href="https://www.jmautomotive.com/used/make/Ford/Naugatuck/CT/Waterbury/Hartford/New-Haven/NEW-HAVEN" title="45 Ford for sale in Naugatuck, CT 06770 | J&amp;M Automotive Sls&amp;Svc LLC. Naugatuck, Connecticut">
#            <div class="Lst-car">
#             <strong class="badge">
#              45
#             </strong>
#             <span class="dw-makes">
#              Ford
#             </span>
#            </div>
#           </a>
#          </div>
#          <div class="MakesDiv">
#           <a href="https://www.jmautomotive.com/used/make/GMC/Naugatuck/CT/Waterbury/Hartford/New-Haven/NEW-HAVEN" title="12 GMC for sale in Naugatuck, CT 06770 | J&amp;M Automotive Sls&amp;Svc LLC. Naugatuck, Connecticut">
#            <div class="Lst-car">
#             <strong class="badge">
#              12
#             </strong>
#             <span class="dw-makes">
#              GMC
#             </span>
#            </div>
#           </a>
#          </div>
#          <div class="MakesDiv">
#           <a href="https://www.jmautomotive.com/used/make/Honda/Naugatuck/CT/Waterbury/Hartford/New-Haven/NEW-HAVEN" title="37 Honda for sale in Naugatuck, CT 06770 | J&amp;M Automotive Sls&amp;Svc LLC. Naugatuck, Connecticut">
#            <div class="Lst-car">
#             <strong class="badge">
#              37
#             </strong>
#             <span class="dw-makes">
#              Honda
#             </span>
#            </div>
#           </a>
#          </div>
#          <div class="MakesDiv">
#           <a href="https://www.jmautomotive.com/used/make/Hyundai/Naugatuck/CT/Waterbury/Hartford/New-Haven/NEW-HAVEN" title="19 Hyundai for sale in Naugatuck, CT 06770 | J&amp;M Automotive Sls&amp;Svc LLC. Naugatuck, Connecticut">
#            <div class="Lst-car">
#             <strong class="badge">
#              19
#             </strong>
#             <span class="dw-makes">
#              Hyundai
#             </span>
#            </div>
#           </a>
#          </div>
#          <div class="MakesDiv">
#           <a href="https://www.jmautomotive.com/used/make/Infiniti/Naugatuck/CT/Waterbury/Hartford/New-Haven/NEW-HAVEN" title="11 Infiniti for sale in Naugatuck, CT 06770 | J&amp;M Automotive Sls&amp;Svc LLC. Naugatuck, Connecticut">
#            <div class="Lst-car">
#             <strong class="badge">
#              11
#             </strong>
#             <span class="dw-makes">
#              Infiniti
#             </span>
#            </div>
#           </a>
#          </div>
#          <div class="MakesDiv">
#           <a href="https://www.jmautomotive.com/used/make/Jeep/Naugatuck/CT/Waterbury/Hartford/New-Haven/NEW-HAVEN" title="26 Jeep for sale in Naugatuck, CT 06770 | J&amp;M Automotive Sls&amp;Svc LLC. Naugatuck, Connecticut">
#            <div class="Lst-car">
#             <strong class="badge">
#              26
#             </strong>
#             <span class="dw-makes">
#              Jeep
#             </span>
#            </div>
#           </a>
#          </div>
#          <div class="MakesDiv">
#           <a href="https://www.jmautomotive.com/used/make/Kia/Naugatuck/CT/Waterbury/Hartford/New-Haven/NEW-HAVEN" title="7 Kia for sale in Naugatuck, CT 06770 | J&amp;M Automotive Sls&amp;Svc LLC. Naugatuck, Connecticut">
#            <div class="Lst-car">
#             <strong class="badge">
#              7
#             </strong>
#             <span class="dw-makes">
#              Kia
#             </span>
#            </div>
#           </a>
#          </div>
#          <div class="MakesDiv">
#           <a href="https://www.jmautomotive.com/used/make/Land+Rover/Naugatuck/CT/Waterbury/Hartford/New-Haven/NEW-HAVEN" title="1 Land Rover for sale in Naugatuck, CT 06770 | J&amp;M Automotive Sls&amp;Svc LLC. Naugatuck, Connecticut">
#            <div class="Lst-car">
#             <strong class="badge">
#              1
#             </strong>
#             <span class="dw-makes">
#              Land Rover
#             </span>
#            </div>
#           </a>
#          </div>
#          <div class="MakesDiv">
#           <a href="https://www.jmautomotive.com/used/make/Lexus/Naugatuck/CT/Waterbury/Hartford/New-Haven/NEW-HAVEN" title="15 Lexus for sale in Naugatuck, CT 06770 | J&amp;M Automotive Sls&amp;Svc LLC. Naugatuck, Connecticut">
#            <div class="Lst-car">
#             <strong class="badge">
#              15
#             </strong>
#             <span class="dw-makes">
#              Lexus
#             </span>
#            </div>
#           </a>
#          </div>
#          <div class="MakesDiv">
#           <a href="https://www.jmautomotive.com/used/make/Lincoln/Naugatuck/CT/Waterbury/Hartford/New-Haven/NEW-HAVEN" title="7 Lincoln for sale in Naugatuck, CT 06770 | J&amp;M Automotive Sls&amp;Svc LLC. Naugatuck, Connecticut">
#            <div class="Lst-car">
#             <strong class="badge">
#              7
#             </strong>
#             <span class="dw-makes">
#              Lincoln
#             </span>
#            </div>
#           </a>
#          </div>
#          <div class="MakesDiv">
#           <a href="https://www.jmautomotive.com/used/make/Mazda/Naugatuck/CT/Waterbury/Hartford/New-Haven/NEW-HAVEN" title="14 Mazda for sale in Naugatuck, CT 06770 | J&amp;M Automotive Sls&amp;Svc LLC. Naugatuck, Connecticut">
#            <div class="Lst-car">
#             <strong class="badge">
#              14
#             </strong>
#             <span class="dw-makes">
#              Mazda
#             </span>
#            </div>
#           </a>
#          </div>
#          <div class="MakesDiv">
#           <a href="https://www.jmautomotive.com/used/make/Mercedes-benz/Naugatuck/CT/Waterbury/Hartford/New-Haven/NEW-HAVEN" title="11 Mercedes-benz for sale in Naugatuck, CT 06770 | J&amp;M Automotive Sls&amp;Svc LLC. Naugatuck, Connecticut">
#            <div class="Lst-car">
#             <strong class="badge">
#              11
#             </strong>
#             <span class="dw-makes">
#              Mercedes-benz
#             </span>
#            </div>
#           </a>
#          </div>
#          <div class="MakesDiv">
#           <a href="https://www.jmautomotive.com/used/make/Mini/Naugatuck/CT/Waterbury/Hartford/New-Haven/NEW-HAVEN" title="7 Mini for sale in Naugatuck, CT 06770 | J&amp;M Automotive Sls&amp;Svc LLC. Naugatuck, Connecticut">
#            <div class="Lst-car">
#             <strong class="badge">
#              7
#             </strong>
#             <span class="dw-makes">
#              Mini
#             </span>
#            </div>
#           </a>
#          </div>
#          <div class="MakesDiv">
#           <a href="https://www.jmautomotive.com/used/make/Mitsubishi/Naugatuck/CT/Waterbury/Hartford/New-Haven/NEW-HAVEN" title="3 Mitsubishi for sale in Naugatuck, CT 06770 | J&amp;M Automotive Sls&amp;Svc LLC. Naugatuck, Connecticut">
#            <div class="Lst-car">
#             <strong class="badge">
#              3
#             </strong>
#             <span class="dw-makes">
#              Mitsubishi
#             </span>
#            </div>
#           </a>
#          </div>
#          <div class="MakesDiv">
#           <a href="https://www.jmautomotive.com/used/make/Nissan/Naugatuck/CT/Waterbury/Hartford/New-Haven/NEW-HAVEN" title="21 Nissan for sale in Naugatuck, CT 06770 | J&amp;M Automotive Sls&amp;Svc LLC. Naugatuck, Connecticut">
#            <div class="Lst-car">
#             <strong class="badge">
#              21
#             </strong>
#             <span class="dw-makes">
#              Nissan
#             </span>
#            </div>
#           </a>
#          </div>
#          <div class="MakesDiv">
#           <a href="https://www.jmautomotive.com/used/make/Ram/Naugatuck/CT/Waterbury/Hartford/New-Haven/NEW-HAVEN" title="12 Ram for sale in Naugatuck, CT 06770 | J&amp;M Automotive Sls&amp;Svc LLC. Naugatuck, Connecticut">
#            <div class="Lst-car">
#             <strong class="badge">
#              12
#             </strong>
#             <span class="dw-makes">
#              Ram
#             </span>
#            </div>
#           </a>
#          </div>
#          <div class="MakesDiv">
#           <a href="https://www.jmautomotive.com/used/make/Scion/Naugatuck/CT/Waterbury/Hartford/New-Haven/NEW-HAVEN" title="1 Scion for sale in Naugatuck, CT 06770 | J&amp;M Automotive Sls&amp;Svc LLC. Naugatuck, Connecticut">
#            <div class="Lst-car">
#             <strong class="badge">
#              1
#             </strong>
#             <span class="dw-makes">
#              Scion
#             </span>
#            </div>
#           </a>
#          </div>
#          <div class="MakesDiv">
#           <a href="https://www.jmautomotive.com/used/make/Subaru/Naugatuck/CT/Waterbury/Hartford/New-Haven/NEW-HAVEN" title="21 Subaru for sale in Naugatuck, CT 06770 | J&amp;M Automotive Sls&amp;Svc LLC. Naugatuck, Connecticut">
#            <div class="Lst-car">
#             <strong class="badge">
#              21
#             </strong>
#             <span class="dw-makes">
#              Subaru
#             </span>
#            </div>
#           </a>
#          </div>
#          <div class="MakesDiv">
#           <a href="https://www.jmautomotive.com/used/make/Tesla/Naugatuck/CT/Waterbury/Hartford/New-Haven/NEW-HAVEN" title="1 Tesla for sale in Naugatuck, CT 06770 | J&amp;M Automotive Sls&amp;Svc LLC. Naugatuck, Connecticut">
#            <div class="Lst-car">
#             <strong class="badge">
#              1
#             </strong>
#             <span class="dw-makes">
#              Tesla
#             </span>
#            </div>
#           </a>
#          </div>
#          <div class="MakesDiv">
#           <a href="https://www.jmautomotive.com/used/make/Toyota/Naugatuck/CT/Waterbury/Hartford/New-Haven/NEW-HAVEN" title="35 Toyota for sale in Naugatuck, CT 06770 | J&amp;M Automotive Sls&amp;Svc LLC. Naugatuck, Connecticut">
#            <div class="Lst-car">
#             <strong class="badge">
#              35
#             </strong>
#             <span class="dw-makes">
#              Toyota
#             </span>
#            </div>
#           </a>
#          </div>
#          <div class="MakesDiv">
#           <a href="https://www.jmautomotive.com/used/make/Volkswagen/Naugatuck/CT/Waterbury/Hartford/New-Haven/NEW-HAVEN" title="29 Volkswagen for sale in Naugatuck, CT 06770 | J&amp;M Automotive Sls&amp;Svc LLC. Naugatuck, Connecticut">
#            <div class="Lst-car">
#             <strong class="badge">
#              29
#             </strong>
#             <span class="dw-makes">
#              Volkswagen
#             </span>
#            </div>
#           </a>
#          </div>
#          <div class="MakesDiv">
#           <a href="https://www.jmautomotive.com/used/make/Volvo/Naugatuck/CT/Waterbury/Hartford/New-Haven/NEW-HAVEN" title="6 Volvo for sale in Naugatuck, CT 06770 | J&amp;M Automotive Sls&amp;Svc LLC. Naugatuck, Connecticut">
#            <div class="Lst-car">
#             <strong class="badge">
#              6
#             </strong>
#             <span class="dw-makes">
#              Volvo
#             </span>
#            </div>
#           </a>
#          </div>
#         </div>
#        </div>
#        <div class="navbar-inverse" id="divFilterButton">
#         FILTER
#         <i class="fa fa-filter">
#         </i>
#        </div>
#        <div class="invpaging ClsMobile_False" id="invpaging">
#         <div id="ipages">
#          <div class="dwfloatL">
#           <strong>
#            Now viewing: Vehicle Status » Used
#           </strong>
#           <span>
#            |
#           </span>
#           <strong>
#            1 - 50
#           </strong>
#           <span>
#            of
#           </span>
#           <strong id="inv_maxCount">
#            447
#           </strong>
#           <span>
#            |
#           </span>
#           <a href="https://www.jmautomotive.com/inventory.aspx?pg=2&amp;sort=12&amp;limit=50&amp;vstatus=1&amp;status=6">
#            Next
#           </a>
#           <span>
#            |
#           </span>
#           <span>
#            Page(s)
#           </span>
#           <a class="pageLinkActive" href="https://www.jmautomotive.com/inventory.aspx?pg=1&amp;sort=12&amp;limit=50&amp;vstatus=1&amp;status=6" id="ipg1">
#            1
#           </a>
#           <a class="pageLink" href="https://www.jmautomotive.com/inventory.aspx?pg=2&amp;sort=12&amp;limit=50&amp;vstatus=1&amp;status=6" id="ipg2">
#            2
#           </a>
#           <a class="pageLink" href="https://www.jmautomotive.com/inventory.aspx?pg=3&amp;sort=12&amp;limit=50&amp;vstatus=1&amp;status=6" id="ipg3">
#            3
#           </a>
#           <a class="pageLink" href="https://www.jmautomotive.com/inventory.aspx?pg=4&amp;sort=12&amp;limit=50&amp;vstatus=1&amp;status=6" id="ipg4">
#            4
#           </a>
#           <a class="pageLink" href="https://www.jmautomotive.com/inventory.aspx?pg=5&amp;sort=12&amp;limit=50&amp;vstatus=1&amp;status=6" id="ipg5">
#            5
#           </a>
#           <a class="pageLink" href="https://www.jmautomotive.com/inventory.aspx?pg=6&amp;sort=12&amp;limit=50&amp;vstatus=1&amp;status=6" id="ipg6">
#            6
#           </a>
#           <a class="pageLink" href="https://www.jmautomotive.com/inventory.aspx?pg=7&amp;sort=12&amp;limit=50&amp;vstatus=1&amp;status=6" id="ipg7">
#            7
#           </a>
# ...
#     </div>
#    </div>
#    <div aria-label="footer" class="dw-block dw-footer" id="dw-footer01" role="contentinfo">
#     <div class="col-lg-3 col-md-3 dw-col-1 dw-p0 dw-m-hide">
#      <h2>
#       About J&amp;M Automotive Sls&amp;Svc LLC
#      </h2>
#      <ul>
#       <li>
#        <a aria-label="Our staff" class="dropdown-toggle" data-hover="dropdown" href="https://www.jmautomotive.com/our-staff">
#         Our staff
#        </a>
#       </li>
#       <li>
#        <a aria-label="Contact us" class="dropdown-toggle" data-hover="dropdown" href="https://www.jmautomotive.com/contact-JandM-Automotive-SlsandSvc-LLC">
#         Contact us
#        </a>
#       </li>
#       <li>
#        <a aria-label="Driving directions" class="dropdown-toggle" data-hover="dropdown" href="https://www.jmautomotive.com/driving-directions-to-JandM-Automotive-SlsandSvc-LLC">
#         Driving directions
#        </a>
#       </li>
#       <li>
#        <a aria-label="Our warranties" class="dropdown-toggle" data-hover="dropdown" href="https://www.jmautomotive.com/used-car-warranty-service-contracts-Naugatuck-CT">
#         Our warranties
#        </a>
#       </li>
#       <li>
#        <a aria-label="Remote Purchase Process" class="dropdown-toggle" data-hover="dropdown" href="https://www.jmautomotive.com/Dealer-Websites/J+Mautomotive/remotePurchase.aspx">
#         Remote Purchase Process
#        </a>
#       </li>
#      </ul>
#     </div>
#     <div class="col-lg-3 col-md-3 dw-col-2 dw-p0 dw-m-hide">
#      <h2>
#       J&amp;M Automotive Sls&amp;Svc LLC Inventory tools
#      </h2>
#      <ul>
#       <li>
#        <a aria-label="View used cars" class="dropdown-toggle" data-hover="dropdown" href="https://www.jmautomotive.com/cars-for-sale-in-Naugatuck-CT-Hartford-New-Haven/used_cars">
#         View used cars
#        </a>
#       </li>
#       <li>
#        <a aria-label="Featured used cars" class="dropdown-toggle" data-hover="dropdown" href="https://www.jmautomotive.com/search-cars/featured-used-cars-JandM-Automotive-SlsandSvc-LLC">
#         Featured used cars
#        </a>
#       </li>
#       <li>
#        <a aria-label="Used car finder" class="dropdown-toggle" data-hover="dropdown" href="https://www.jmautomotive.com/find-car-for-me">
#         Used car finder
#        </a>
#       </li>
#       <li>
#        <a aria-label="Used cars under $10,000" class="dropdown-toggle" data-hover="dropdown" href="https://www.jmautomotive.com/search-cars/cheap-cars-under-10000-dollars-Naugatuck-Hartford-New-Haven-CT">
#         Used cars under $10,000
#        </a>
#       </li>
#       <li>
#        <a aria-label="$10,000 to $15,000" class="dropdown-toggle" data-hover="dropdown" href="https://www.jmautomotive.com/search-cars/deals-on-cars-under-15000-dollars">
#         $10,000 to $15,000
#        </a>
#       </li>
#       <li>
#        <a aria-label="$15,000 to $20,000" class="dropdown-toggle" data-hover="dropdown" href="https://www.jmautomotive.com/search-cars/deals-on-cars-under-20000-dollars">
#         $15,000 to $20,000
#        </a>
#       </li>
#       <li>
#        <a aria-label="Used cars over $20,000" class="dropdown-toggle" data-hover="dropdown" href="https://www.jmautomotive.com/search-cars/deals-on-cars-over-20000-dollars">
#         Used cars over $20,000
#        </a>
#       </li>
#      </ul>
#     </div>
#     <div class="col-lg-3 col-md-3 dw-col-3 dw-p0 dw-m-hide">
#      <h2>
#       <a href="https://www.jmautomotive.com">
#        www.jmautomotive.com
#       </a>
#      </h2>
#      <ul>
#       <li>
#        <a href="https://www.jmautomotive.com/cars-for-sale-in-Naugatuck-CT-Waterbury-Hartford/used_cars">
#         Vehicle inventory
#        </a>
#       </li>
#       <li>
#        <a href="https://www.jmautomotive.com/sitemap.aspx">
#         Sitemap
#        </a>
#       </li>
#       <li>
#        <a href="https://www.jmautomotive.com/privacy-policy" rel="nofollow">
#         Privacy policy
#        </a>
#       </li>
#      </ul>
#     </div>
#     <div class="col-lg-3 col-md-3 dw-col-4 dw-p0 dw-m-hide">
#      <h2>
#       J&amp;M Automotive Sls&amp;Svc LLC
#      </h2>
#      <ul id="dw-address">
#       <li class="l1">
#        <p>
#         756/820 New Haven Road
#        </p>
#       </li>
#       <li class="l2">
#        Naugatuck,
#        <span class="nbsp" role="presentation">
#        </span>
#        CT
#        <span class="nbsp" role="presentation">
#        </span>
#        06770
#        <span class="nbsp" role="presentation">
#        </span>
#        <span class="dw-hide-dd">
#         |
#        </span>
#        <span class="nbsp" role="presentation">
#        </span>
#        <a aria-label="Driving Directions(opens in a new tab)" class="dw-hide-dd" href="https://maps.google.com/maps?f=q&amp;hl=en&amp;q=J%26M+Automotive+Sls%26Svc+LLC,756/820+New+Haven+Road,Naugatuck,CT+06770&amp;ie=UTF8&amp;om=1&amp;maptype=terrain" id="dw-contGoogLinkFoot01" target="_blank">
#         Driving Directions
#        </a>
#       </li>
#       <li class="l3">
#        <p>
#         <i class="fa-lg fa fa-phone-square" role="presentation">
#         </i>
#         <span>
#          <span class="nbsp" role="presentation">
#          </span>
#          <span class="nbsp" role="presentation">
#          </span>
#          Tel:
#         </span>
#         <a href="tel:2037235666">
#          (203) 723-5666
#         </a>
#        </p>
#       </li>
#       <li class="l4">
#        <p>
#         <i class="fa-lg fa fa-fax" role="presentation">
#         </i>
#         <span>
#          <span class="nbsp" role="presentation">
#          </span>
#          <span class="nbsp" role="presentation">
#          </span>
#          Fax:
#         </span>
#         <a href="tel:2037231937">
#          (203) 723-1937
#         </a>
#        </p>
#       </li>
#      </ul>
#      <div class="dw-block">
#       <a aria-label="Rss" href="https://www.jmautomotive.com/rss.aspx" id="IconRssF" target="_blank">
#        <i class="fa-lg fa dw-icon fa-rss">
#        </i>
#       </a>
#       <a aria-label="Facebook" href="https://www.facebook.com/pages/JM-Automotive-SlsSvc-LLC/159851630780993" id="IconFacebookF" target="_blank">
#        <i class="fa-lg fa dw-icon fa-facebook">
#        </i>
#       </a>
#       <a aria-label="Instagram" href="https://www.instagram.com/jmautomotivenaugatuck/" id="IconInstagramF" target="_blank">
#        <i class="fa-lg fa dw-icon fa-instagram">
#        </i>
#       </a>
#      </div>
#     </div>
#     <div class="dw-block dw-sub-footer">
#      <h4 class="dw-copyright">
#       <span>
#        All rights reserved. © 2003-2022
#       </span>
#       <span>
#        <a href="https://www.jmautomotive.com" title="Used car dealer in Naugatuck | J&amp;M Automotive Sls&amp;Svc LLC. Naugatuck Connecticut">
#         J&amp;M Automotive Sls&amp;Svc LLC
#        </a>
#       </span>
#       <span>
#        <a aria-label="Autofunds - Dealership Management Software(opens in new tab)" href="//www.autofunds.com" target="_blank">
#         Autofunds - Dealership Management Software
#        </a>
#       </span>
#      </h4>
#     </div>
#    </div>
#    <div class="dw-block dw-bottom-bar dw-m-hide">
#     <div class="dw-recent">
#      <span class="dw-recent-c" id="dw-recently-bar" role="button" tabindex="0">
#       Recently viewed
#       <span>
#        (0)
#       </span>
#      </span>
#      <span class="dw-bot-translate" id="google_translate_element" role="presentation">
#      </span>
#     </div>
#     <div id="dw-recently-bar-outer-cont">
#      <div id="dw-recently-bar-cont">
#      </div>
#     </div>
#    </div>
#    <div class="dw-none dw-dealership-info" id="dw-dealership">
#     <input id="hdnDealerID" type="hidden" value="467"/>
#     <input id="hdnDealerName" type="hidden" value="J&amp;M Automotive Sls&amp;Svc LLC"/>
#     <input id="hdnDealersiteFolder" type="hidden" value="Dealer-Websites/J+Mautomotive"/>
#     <input id="hdnDealerSiteUrl" type="hidden" value="https://www.jmautomotive.com"/>
#     <input id="hdnInventoryUrl" type="hidden" value="https://www.jmautomotive.com/cars-for-sale-in-Naugatuck-CT-Waterbury-Hartford/used_cars"/>
#     <input id="hdnFinanceUrl" type="hidden" value="https://www.jmautomotive.com/Dealer-Websites/J+Mautomotive/Get-Financing.aspx?IsGeneric=0&amp;"/>
#     <input id="hdnDealerCity" type="hidden" value="Naugatuck"/>
#     <input id="hdnDealerState" type="hidden" value="CT"/>
#     <input id="hdnDealerPhone" type="hidden" value="(203) 723-5666"/>
#     <input id="hdnIsMobile" type="hidden" value="false"/>
#     <input id="hdnRegion1" type="hidden" value="Waterbury"/>
#     <input id="hdnRegion2" type="hidden" value="Hartford"/>
#     <input id="hdnRegion3" type="hidden" value="New Haven"/>
#     <input id="hdnCounty" type="hidden" value="NEW HAVEN"/>
#     <input id="hdnCountry" type="hidden" value="USA"/>
#     <input id="hdnIsSecureURL" type="hidden" value="true"/>
#     <input id="hdnHidePrices" type="hidden" value="false"/>
#     <input id="hdnInventoryUrlType" type="hidden" value="1"/>
#     <input id="hdnContactReferralSetting" type="hidden" value="0"/>
#     <input id="hdnCurrentPN" type="hidden" value="inventory"/>
#     <input id="hdnDirectionsEmbedurl" type="hidden" value="https://www.google.com/maps/embed/v1/place?key=AIzaSyDLzPWMvwGmTYXNk0aZuHUAVq9luEpGAiI&amp;q=J%26M+Automotive+Sls%26Svc+LLC,756/820+New+Haven+Road,Naugatuck,CT+06770&amp;zoom=15"/>
#     <input id="hdnPixelID" type="hidden" value="599518190591013,149383822442668"/>
#     <input id="hdnGoogleTagManagerID" type="hidden" value="GTM-K6T6T3V"/>
#     <input id="hdnGoogleTrackingID" type="hidden" value=""/>
#     <input id="hdnIsDebug" type="hidden" value="false"/>
#     <input id="hdnUserWayWidgetCode" type="hidden" value="mhqa48d5HX"/>
#     <input id="hdnIsChatActive" type="hidden" value="false"/>
#     <input id="hdnChatEncryptedID" type="hidden" value="j8l9fpWVa8k="/>
#     <input id="hdnIsFBChatActive" type="hidden" value="false"/>
#     <input id="hdnFacebookPageID" type="hidden" value="159851630780993"/>
#     <input id="hdnFBChatSkinColor" type="hidden" value=""/>
#     <input id="hdnShowCaptchaCode" type="hidden" value="true"/>
#     <input id="hdnContactFieldSetting" type="hidden" value="0"/>
#     <input id="hdnAFTagProductionURL" type="hidden" value="https://cctags.com"/>
#     <input id="hdnAFTagVersion" type="hidden" value="1.1.3"/>
#     <input id="hdnAFTagDecryptedId" type="hidden" value="Y0RyYmRDRFZqTTA9"/>
#     <input id="hdnOverlayURL" type="hidden" value=""/>
#     <input id="hdnOverlayOnFirstImageOnly" type="hidden" value="false"/>
#     <input id="hdnSoldLotId" type="hidden" value="-1"/>
#     <input id="hdnDealerEmail" type="hidden" value="sales@jmautomotive.com"/>
#     <input id="hdnFinanceURLTarget" type="hidden" value=""/>
#     <input id="hdnShowReducedPrice" type="hidden" value="true"/>
#     <input id="hdnDealerAddress1" type="hidden" value="756/820 New Haven Road"/>
#     <input id="hdnDealerStateFull" type="hidden" value="Connecticut"/>
#     <input id="hdnDealerZip" type="hidden" value="06770"/>
#     <input id="hdnDirectionsurl" type="hidden" value="https://maps.google.com/maps?f=q&amp;hl=en&amp;q=J%26M+Automotive+Sls%26Svc+LLC,756/820+New+Haven+Road,Naugatuck,CT+06770&amp;ie=UTF8&amp;om=1&amp;maptype=terrain"/>
#     <input id="hdnDealerAPR" type="hidden" value=""/>
#     <input id="hdnContactusUrl" type="hidden" value="https://www.jmautomotive.com/contact-JandM-Automotive-SlsandSvc-LLC"/>
#     <input id="hdnCCProductionDomain" type="hidden" value="chatchasers.com"/>
#     <input id="hdnGCLID" type="hidden" value=""/>
#     <input id="hdnDealerFax" type="hidden" value="(203) 723-1937"/>
#     <input id="hdnInventoryNoImageURL" type="hidden" value="https://invimg2.autofunds.com/InventoryNoImages"/>
#     <input id="hdnInventoryOverlayImageURL" type="hidden" value="https://invimg2.autofunds.com/OverlayImages"/>
#     <input id="hdnDealerAddress2" type="hidden" value=""/>
#     <div itemprop="geo" itemscope="" itemtype="http://schema.org/GeoCoordinates">
#      <meta content="41.4737946" itemprop="latitude"/>
#      <meta content="-73.0430881" itemprop="longitude"/>
#     </div>
#     <meta content="https://www.jmautomotive.com/cars-for-sale-in-Naugatuck-CT-Hartford-New-Haven/used_cars" itemprop="url"/>
#     <meta content="(203) 723-1937" itemprop="faxNumber"/>
#     <meta content="sales@jmautomotive.com" itemprop="email"/>
#     <meta content="https://www.jmautomotive.com/Dealer-Websites/J+Mautomotive/images/sharingLogoImg_11.png" itemprop="image"/>
#    </div>
#    <div id="disablingDiv">
#    </div>
#    <div aria-hidden="true" class="modal fade" id="myPopup_Testimonial_Show" role="dialog" tabindex="-1">
#     <div class="modal-dialog">
#      <div class="modal-content">
#       <div class="modal-header">
#        <button aria-hidden="true" class="close" data-dismiss="modal" tabindex="-1" type="button">
#         ×
#        </button>
#        <h4 id="div_Popup_NewTestimonial_Title">
#         Write a review
#        </h4>
#       </div>
#       <p class="review_headtxt">
#        Tell us about your experience at J&amp;M Automotive Sls&amp;Svc LLC.
#       </p>
#       <div class="modal-body" id="myPopup_Testimonial_Body">
#       </div>
#      </div>
#     </div>
#    </div>
#    <div aria-hidden="true" class="modal fade" id="myPopup_Book_TestDrive" role="dialog" tabindex="-1">
#     <div class="modal-dialog">
#      <div class="modal-content">
#       <div class="modal-header">
#        <button aria-hidden="true" class="close" data-dismiss="modal" tabindex="-1" type="button">
#         ×
#        </button>
#        <h4>
#         Book a test drive
#        </h4>
#       </div>
#       <div class="modal-body" id="myPopup_Book_TestDrive_Body">
#       </div>
#      </div>
#     </div>
#    </div>
#    <div aria-hidden="true" class="modal fade" id="myPopup_Shedule_Appointment" role="dialog" tabindex="-1">
#     <div class="modal-dialog">
#      <div class="modal-content">
#       <div class="modal-header">
#        <button aria-hidden="true" class="close" data-dismiss="modal" tabindex="-1" type="button">
#         ×
#        </button>
#        <h4>
#         Schedule appointment
#        </h4>
#       </div>
#       <div class="modal-body" id="myPopup_Shedule_Appointment_Body">
#       </div>
#      </div>
#     </div>
#    </div>
#    <div aria-hidden="true" class="modal fade" id="myPopup_Shedule_Service_Appointment" role="dialog" tabindex="-1">
#     <div class="modal-dialog">
#      <div class="modal-content">
#       <div class="modal-header">
#        <button aria-hidden="true" class="close" data-dismiss="modal" tabindex="-1" type="button">
#         ×
#        </button>
#        <h4>
#         Schedule appointment
#        </h4>
#       </div>
#       <div class="modal-body" id="myPopup_Shedule_Service_Appointment_Body">
#       </div>
#      </div>
#     </div>
#    </div>
#    <div aria-hidden="true" class="modal fade" id="myPopup_Shedule_Lease_Appointment" role="dialog" tabindex="-1">
#     <div class="modal-dialog">
#      <div class="modal-content">
#       <div class="modal-header">
#        <button aria-hidden="true" class="close" data-dismiss="modal" tabindex="-1" type="button">
#         ×
#        </button>
#        <h4>
#         Schedule appointment
#        </h4>
#       </div>
#       <div class="modal-body" id="myPopup_Shedule_Lease_Appointment_Body">
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="modal-box" id="DivAlertPopup">
#     <div aria-label="Missing information" id="DivHeader" role="main">
#      <a class="js-modal-close errclose" href="javascript:void(0)" role="button">
#       ×
#      </a>
#      <div class="error-head" role="heading">
#       Missing information
#      </div>
#     </div>
#     <div class="modal-body" id="DivAlertPopup_body">
#      <div id="modal-item">
#      </div>
#     </div>
#     <div id="DivFooter">
#      <a class="js-modal-close btn btn-primary pull-right" href="javascript:void(0)" role="button">
#       OK
#      </a>
#     </div>
#    </div>
#    <a aria-label="Back to top" class="overlayST" href="javascript:void(0)" id="dw-back-to-top" role="button" title="Back to top">
#     <i class="fa fa-arrow-circle-up" role="presentation">
#     </i>
#    </a>
#   </div>
#   <input id="hdnASP_NET_SessionID" type="hidden" value="fpdgnys1mihqo2vqeg05bpxx"/>
#   <script async="" defer="" src="/HttpCombiner.ashx?s=DW_Common-Scripts-min&amp;t=text/javascript&amp;v=2022.03.28.A&amp;d=467">
#   </script>
#   <script async="" defer="" src="https://cctags.com/get/tag-1.1.3.min.js?Y0RyYmRDRFZqTTA9">
#   </script>
#  </body>
# </html>

# %% [markdown]
# ## Test Extracting Columns

# %% [markdown]
# ### Title

# %%
pi.parse_subsection_attr(soup, 'title','div', 'a', 'thumbnail', 'listitemlink')
# Out:
# ['Used 2016 Ford F-150 4WD SuperCrew 145 XLT for sale in Naugatuck, CT',
#  'Used 2016 Ford Super Duty F-350 Srw 4WD Crew Cab 156 Platinum for sale in Naugatuck, CT',
#  'Used 2017 Mini Countryman Cooper ALL4 for sale in Naugatuck, CT',
#  'Used 2015 Ford Expedition 4WD 4dr Platinum for sale in Naugatuck, CT',
#  'Used 2017 Infiniti Q50 3.0t Premium AWD for sale in Naugatuck, CT',
#  'Used 2015 Ford Super Duty F-250 Srw 4WD Crew Cab 156 XL for sale in Naugatuck, CT',
#  'Used 2018 Volkswagen Jetta 1.4T SE Auto for sale in Naugatuck, CT',
#  'Used 2015 Toyota Tundra Double Cab 5.7L V8 6-Spd AT SR for sale in Naugatuck, CT',
#  'Used 2013 Audi Tts 2dr Cpe S tronic quattro 2.0T Prest for sale in Naugatuck, CT',
#  'Used 2015 GMC Yukon 4WD 4dr Denali for sale in Naugatuck, CT',
#  'Used 2013 Jeep Wrangler Unlimited 4WD 4dr Sport for sale in Naugatuck, CT',
#  'Used 2015 Lexus Is 250 4dr Sport Sdn AWD for sale in Naugatuck, CT',
#  'Used 2014 Audi S4 4dr Sdn S Tronic Prestige for sale in Naugatuck, CT',
#  'Used 1993 Chevrolet Corvette 2dr Convertible for sale in Naugatuck, CT',
#  'Used 2014 Mercedes-benz E-class 2dr Cpe E 350 4MATIC for sale in Naugatuck, CT',
#  'Used 2004 Chevrolet Ssr Reg Cab 116.0 WB LS for sale in Naugatuck, CT',
#  'Used 2009 Honda Ridgeline 4WD Crew Cab RTL for sale in Naugatuck, CT',
#  'Used 2016 Lexus Rx 350 AWD 4dr for sale in Naugatuck, CT',
#  'Used 2014 Toyota Fj Cruiser 4WD 4dr Auto for sale in Naugatuck, CT',
#  'Used 2016 Hyundai Genesis 4dr Sdn V6 3.8L AWD for sale in Naugatuck, CT',
#  'Used 2017 Nissan Titan 4x4 Crew Cab SV for sale in Naugatuck, CT',
#  'Used 2018 Volvo S60 T5 AWD Dynamic for sale in Naugatuck, CT',
#  'Used 2012 Honda Accord 4dr I4 Auto LX for sale in Naugatuck, CT',
#  'Used 2020 Acura Tlx 3.5L SH-AWD w/Technology Pkg for sale in Naugatuck, CT',
#  'Used 2018 Dodge Challenger GT AWD for sale in Naugatuck, CT',
#  'Used 2019 Dodge Challenger SXT AWD for sale in Naugatuck, CT',
#  'Used 2016 Chrysler Town & Country 4dr Wgn Touring for sale in Naugatuck, CT',
#  'Used 2014 Audi S4 4dr Sdn Man Premium Plus for sale in Naugatuck, CT',
#  'Used 2013 Cadillac Xts 4dr Sdn Platinum AWD for sale in Naugatuck, CT',
#  'Used 2012 Nissan Maxima 4dr Sdn V6 CVT 3.5 SV for sale in Naugatuck, CT',
#  'Used 2014 Ford Fusion 4dr Sdn SE FWD for sale in Naugatuck, CT',
#  'Used 2016 Nissan Maxima 4dr Sdn 3.5 Platinum for sale in Naugatuck, CT',
#  'Used 2016 Honda Pilot AWD 4dr EX for sale in Naugatuck, CT',
#  'Used 2015 Kia Optima 4dr Sdn LX for sale in Naugatuck, CT',
#  'Used 2018 Infiniti Q50 3.0t LUXE AWD for sale in Naugatuck, CT',
#  'Used 2015 Toyota 4runner 4WD 4dr V6 Limited for sale in Naugatuck, CT',
#  'Used 2014 Lexus Es 350 4dr Sdn for sale in Naugatuck, CT',
#  'Used 2015 GMC Sierra 1500 4WD Crew Cab 143.5 SLE for sale in Naugatuck, CT',
#  'Used 2018 Toyota Sienna LE FWD 8-Passenger for sale in Naugatuck, CT',
#  'Used 2020 Mazda Cx-5 Grand Touring AWD for sale in Naugatuck, CT',
#  'Used 2016 Chevrolet Silverado 1500 4WD Double Cab 143.5 LTZ w/1LZ for sale in Naugatuck, CT',
#  'Used 2019 Chevrolet Colorado 4WD Crew Cab 128.3 LT for sale in Naugatuck, CT',
#  'Used 2018 Chevrolet Volt 5dr HB LT for sale in Naugatuck, CT',
#  'Used 2013 Ford F-150 4WD SuperCrew 145 XLT for sale in Naugatuck, CT',
#  'Used 2018 Toyota Rav4 XLE AWD for sale in Naugatuck, CT',
#  'Used 2017 Honda Cr-v EX-L AWD w/Navi for sale in Naugatuck, CT',
#  'Used 2015 Ford Taurus 4dr Sdn SEL FWD for sale in Naugatuck, CT',
#  'Used 2015 Audi Q7 quattro 4dr 3.0T Premium Plus for sale in Naugatuck, CT',
#  'Used 2019 Acura Tlx 3.5L FWD for sale in Naugatuck, CT',
#  'Used 2013 Fiat 500 2dr HB Pop for sale in Naugatuck, CT']

# %% [markdown]
# ### Year

# %%
col_data = []
main = soup.findAll('div', 'thumbnail')
sub_section_attr_parse_key = 'itemprop'
sub_section_attr_parse_value = 'vehicleInteriorColor'
for el in main:
    sub_data = el.findAll()
    appendedData = False
    for sd in sub_data:
        if sub_section_attr_parse_key is not None and sub_section_attr_parse_value is not None:
            if sd.get(sub_section_attr_parse_key) == sub_section_attr_parse_value:
                col_data.append(sd.getText())
                appendedData = True
        else:
            col_data.append(sd.getText())
            appendedData = True
        
    if (appendedData == False):
        col_data.append(None)

col_data
# Out:
# ['Medium Earth Gray  ',
#  'Pecan  ',
#  'Satellite Grey  ',
#  'Brunell W/black  ',
#  'Graphite  ',
#  'Steel  ',
#  'Titan Black  ',
#  'Graphite  ',
#  'Black  ',
#  'Cocoa/dark Atmosphe  ',
#  'Black Interior  ',
#  'Black  ',
#  'Black/red  ',
#  None,
#  'Silk Beige/espresso  ',
#  'Ebony  ',
#  'Beige  ',
#  'Black  ',
#  'Dark Charcoal  ',
#  'Beige  ',
#  'Black  ',
#  'Off-black  ',
#  'Ivory  ',
#  'Ebony  ',
#  'Black  ',
#  'Black  ',
#  'Black/light Graysto  ',
#  'Black  ',
#  'Jet Black/light Whe  ',
#  'Cafe Latte  ',
#  'Charcoal Black  ',
#  'Charcoal  ',
#  'Gray  ',
#  'Beige  ',
#  'Wheat  ',
#  'Redwood  ',
#  'Black  ',
#  'Jet Black  ',
#  'Ash  ',
#  'Black  ',
#  'Jet Black  ',
#  'Jet Black  ',
#  'Jet Black/jet Black  ',
#  'Pale Adobe  ',
#  'Black  ',
#  'Gray  ',
#  'Charcoal Black  ',
#  'Cardamom  ',
#  'Ebony  ',
#  'Black Interior  ']

# %%
pi.parse_main_section_attr_text_all(soup, 'div', 'thumbnail', 'itemprop', 'vehicleModelDate')
# Out:
# ['2016',
#  '2016',
#  '2017',
#  '2015',
#  '2017',
#  '2015',
#  '2018',
#  '2015',
#  '2013',
#  '2015',
#  '2013',
#  '2015',
#  '2014',
#  '1993',
#  '2014',
#  '2004',
#  '2009',
#  '2016',
#  '2014',
#  '2016',
#  '2017',
#  '2018',
#  '2012',
#  '2020',
#  '2018',
#  '2019',
#  '2016',
#  '2014',
#  '2013',
#  '2012',
#  '2014',
#  '2016',
#  '2016',
#  '2015',
#  '2018',
#  '2015',
#  '2014',
#  '2015',
#  '2018',
#  '2020',
#  '2016',
#  '2019',
#  '2018',
#  '2013',
#  '2018',
#  '2017',
#  '2015',
#  '2015',
#  '2019',
#  '2013']

# %% [markdown]
# ### Make

# %%
pi.parse_main_section_attr_text_all(soup, 'div', 'thumbnail', 'itemprop', 'manufacturer')
# Out:
# ['Ford',
#  'Ford',
#  'Mini',
#  'Ford',
#  'Infiniti',
#  'Ford',
#  'Volkswagen',
#  'Toyota',
#  'Audi',
#  'GMC',
#  'Jeep',
#  'Lexus',
#  'Audi',
#  'Chevrolet',
#  'Mercedes-benz',
#  'Chevrolet',
#  'Honda',
#  'Lexus',
#  'Toyota',
#  'Hyundai',
#  'Nissan',
#  'Volvo',
#  'Honda',
#  'Acura',
#  'Dodge',
#  'Dodge',
#  'Chrysler',
#  'Audi',
#  'Cadillac',
#  'Nissan',
#  'Ford',
#  'Nissan',
#  'Honda',
#  'Kia',
#  'Infiniti',
#  'Toyota',
#  'Lexus',
#  'GMC',
#  'Toyota',
#  'Mazda',
#  'Chevrolet',
#  'Chevrolet',
#  'Chevrolet',
#  'Ford',
#  'Toyota',
#  'Honda',
#  'Ford',
#  'Audi',
#  'Acura',
#  'Fiat']

# %% [markdown]
# ### Model

# %%
pi.parse_main_section_attr_text_all(soup, 'div', 'thumbnail', 'itemprop', 'model')
# Out:
# ['F-150',
#  'Super Duty F-350 Srw',
#  'Countryman',
#  'Expedition',
#  'Q50',
#  'Super Duty F-250 Srw',
#  'Jetta',
#  'Tundra',
#  'Tts',
#  'Yukon',
#  'Wrangler Unlimited',
#  'Is 250',
#  'S4',
#  'Corvette',
#  'E-class',
#  'Ssr',
#  'Ridgeline',
#  'Rx 350',
#  'Fj Cruiser',
#  'Genesis',
#  'Titan',
#  'S60',
#  'Accord',
#  'Tlx',
#  'Challenger',
#  'Challenger',
#  'Town & Country',
#  'S4',
#  'Xts',
#  'Maxima',
#  'Fusion',
#  'Maxima',
#  'Pilot',
#  'Optima',
#  'Q50',
#  '4runner',
#  'Es 350',
#  'Sierra 1500',
#  'Sienna',
#  'Cx-5',
#  'Silverado 1500',
#  'Colorado',
#  'Volt',
#  'F-150',
#  'Rav4',
#  'Cr-v',
#  'Taurus',
#  'Q7',
#  'Tlx',
#  '500']

# %% [markdown]
# ### Trim

# %%
pi.parse_main_section_attr_text_all(soup, 'div', 'thumbnail', 'itemprop', 'vehicleConfiguration')
# Out:
# ['4WD SuperCrew 145 XLT',
#  '4WD Crew Cab 156 Platinum',
#  'Cooper ALL4',
#  '4WD 4dr Platinum',
#  '3.0t Premium AWD',
#  '4WD Crew Cab 156 XL',
#  '1.4T SE Auto',
#  'Double Cab 5.7L V8 6-Spd AT SR',
#  '2dr Cpe S tronic quattro 2.0T Prest',
#  '4WD 4dr Denali',
#  '4WD 4dr Sport',
#  '4dr Sport Sdn AWD',
#  '4dr Sdn S Tronic Prestige',
#  '2dr Convertible',
#  '2dr Cpe E 350 4MATIC',
#  'Reg Cab 116.0 WB LS',
#  '4WD Crew Cab RTL',
#  'AWD 4dr',
#  '4WD 4dr Auto',
#  '4dr Sdn V6 3.8L AWD',
#  '4x4 Crew Cab SV',
#  'T5 AWD Dynamic',
#  '4dr I4 Auto LX',
#  '3.5L SH-AWD w/Technology Pkg',
#  'GT AWD',
#  'SXT AWD',
#  '4dr Wgn Touring',
#  '4dr Sdn Man Premium Plus',
#  '4dr Sdn Platinum AWD',
#  '4dr Sdn V6 CVT 3.5 SV',
#  '4dr Sdn SE FWD',
#  '4dr Sdn 3.5 Platinum',
#  'AWD 4dr EX',
#  '4dr Sdn LX',
#  '3.0t LUXE AWD',
#  '4WD 4dr V6 Limited',
#  '4dr Sdn',
#  '4WD Crew Cab 143.5 SLE',
#  'LE FWD 8-Passenger',
#  'Grand Touring AWD',
#  '4WD Double Cab 143.5 LTZ w/1LZ',
#  '4WD Crew Cab 128.3 LT',
#  '5dr HB LT',
#  '4WD SuperCrew 145 XLT',
#  'XLE AWD',
#  'EX-L AWD w/Navi',
#  '4dr Sdn SEL FWD',
#  'quattro 4dr 3.0T Premium Plus',
#  '3.5L FWD',
#  '2dr HB Pop']

# %% [markdown]
# ### Mileage

# %%
pi.convert_to_numeric_type(
pi.parse_subsection(soup, 'div', 'li', 'thumbnail', 'list-group-item mileage', 'get_text'))
# Out:
# [89305,
#  24752,
#  77144,
#  87901,
#  49387,
#  59080,
#  37612,
#  82527,
#  89390,
#  75993,
#  67146,
#  94198,
#  95490,
#  38420,
#  68064,
#  64413,
#  72027,
#  27063,
#  63318,
#  78040,
#  76087,
#  31413,
#  76673,
#  12393,
#  34654,
#  28332,
#  74716,
#  81623,
#  82281,
#  52336,
#  76848,
#  82178,
#  59209,
#  74167,
#  39641,
#  76652,
#  78813,
#  89543,
#  93842,
#  23256,
#  63285,
#  44214,
#  29971,
#  99811,
#  64455,
#  94402,
#  87013,
#  84066,
#  23110,
#  67502]

# %% [markdown]
# ### Car Prices

# %%
pi.convert_to_numeric_type(pi.parse_subsection(soup, 'div', 'div', 'thumbnail', 'pricetag', 'get_text'))
# Out:
# [28995,
#  53995,
#  18995,
#  31995,
#  29995,
#  45995,
#  20995,
#  32995,
#  24995,
#  39995,
#  25995,
#  23995,
#  26995,
#  15995,
#  25995,
#  21995,
#  23995,
#  36995,
#  38995,
#  24995,
#  32995,
#  28995,
#  15995,
#  37995,
#  32995,
#  31995,
#  18995,
#  30995,
#  22995,
#  17995,
#  14995,
#  22995,
#  28995,
#  15995,
#  30995,
#  35995,
#  22995,
#  30995,
#  25995,
#  32995,
#  36995,
#  35995,
#  23995,
#  24995,
#  26995,
#  24995,
#  15995,
#  26995,
#  31995,
#  9995]

# %% [markdown]
# ### Exterior Color

# %%
pi.clean_text_data(
    pi.parse_subsection(soup, 'div', 'li', 'thumbnail', 'list-group-item InvExteriorcolor', 'get_text'), 'Exterior')
# Out:
# ['Ingot Silver Metallic',
#  'Shadow Black',
#  'Moonwalk Gray Metallic',
#  'Ruby Red Metallic Tinted Clearcoat',
#  'Majestic White',
#  'Oxford White',
#  'White Silver Metallic',
#  'Black',
#  'Scuba Blue Metallic',
#  'Crystal Red Tintcoat',
#  'Billet Silver Metallic',
#  'Obsidian',
#  'Brilliant Black',
#  'Green',
#  'Polar White',
#  'Redline Red',
#  'Nighthawk Black Pearl',
#  'Nightfall Mica',
#  'Quicksand',
#  'Pamplona Red',
#  'Magnetic Black',
#  'Passion Red',
#  'Dark Amber Metallic',
#  'Platinum White Pearl',
#  'White Knuckle Clearcoat',
#  'Octane Red Pearlcoat',
#  'Deep Cherry Red Crystal Pearlcoat',
#  'Glacier White Metallic',
#  'Black Raven',
#  'Navy Blue Metallic',
#  'Tuxedo Black Metallic',
#  'Forged Bronze',
#  'Obsidian Blue Pearl',
#  'Dark Cherry',
#  'Majestic White',
#  'Blizzard Pearl',
#  'Obsidian',
#  'Stone Blue Metallic',
#  'Midnight Black Metallic',
#  'Deep Crystal Blue Mica',
#  'Black',
#  'Silver Ice Metallic',
#  'Summit White',
#  'Pale Adobe Metallic',
#  'Black',
#  'Gunmetal Metallic',
#  'Tuxedo Black Metallic',
#  'Atlantis Blue Metallic',
#  'Lunar Silver Metallic',
#  'Rosso (red)']

# %% [markdown]
# ### Interior Color

# %%
pi.clean_text_data(pi.parse_subsection(soup, 'div', 'li', 'thumbnail', 'list-group-item InvInteriorcolor', 'get_text'), 'Interior')
# Out:
# ['Medium Earth Gray',
#  'Pecan',
#  'Satellite Grey',
#  'Brunell W/black',
#  'Graphite',
#  'Steel',
#  'Titan Black',
#  'Graphite',
#  'Black',
#  'Cocoa/dark Atmosphe',
#  'Black Interior',
#  'Black',
#  'Black/red',
#  None,
#  'Silk Beige/espresso',
#  'Ebony',
#  'Beige',
#  'Black',
#  'Dark Charcoal',
#  'Beige',
#  'Black',
#  'Off-black',
#  'Ivory',
#  'Ebony',
#  'Black',
#  'Black',
#  'Black/light Graysto',
#  'Black',
#  'Jet Black/light Whe',
#  'Cafe Latte',
#  'Charcoal Black',
#  'Charcoal',
#  'Gray',
#  'Beige',
#  'Wheat',
#  'Redwood',
#  'Black',
#  'Jet Black',
#  'Ash',
#  'Black',
#  'Jet Black',
#  'Jet Black',
#  'Jet Black/jet Black',
#  'Pale Adobe',
#  'Black',
#  'Gray',
#  'Charcoal Black',
#  'Cardamom',
#  'Ebony',
#  'Black Interior']

# %%
pi.clean_text_data(
    pi.parse_main_section_attr_text_all(soup, 'div', 'thumbnail', 'itemprop', 'vehicleInteriorColor'))
# Out:
# ['Medium Earth Gray',
#  'Pecan',
#  'Satellite Grey',
#  'Brunell W/black',
#  'Graphite',
#  'Steel',
#  'Titan Black',
#  'Graphite',
#  'Black',
#  'Cocoa/dark Atmosphe',
#  'Black Interior',
#  'Black',
#  'Black/red',
#  None,
#  'Silk Beige/espresso',
#  'Ebony',
#  'Beige',
#  'Black',
#  'Dark Charcoal',
#  'Beige',
#  'Black',
#  'Off-black',
#  'Ivory',
#  'Ebony',
#  'Black',
#  'Black',
#  'Black/light Graysto',
#  'Black',
#  'Jet Black/light Whe',
#  'Cafe Latte',
#  'Charcoal Black',
#  'Charcoal',
#  'Gray',
#  'Beige',
#  'Wheat',
#  'Redwood',
#  'Black',
#  'Jet Black',
#  'Ash',
#  'Black',
#  'Jet Black',
#  'Jet Black',
#  'Jet Black/jet Black',
#  'Pale Adobe',
#  'Black',
#  'Gray',
#  'Charcoal Black',
#  'Cardamom',
#  'Ebony',
#  'Black Interior']

# %% [markdown]
# ### Transmission

# %%
pi.clean_text_data(
    pi.parse_subsection(soup, 'div', 'li', 'thumbnail', 'list-group-item InvTransmissiontype', 'get_text'), 'Transmission')
# Out:
# ['Automatic',
#  'Automatic',
#  'Manual',
#  'Automatic',
#  'Automatic',
#  'Automatic',
#  'Automatic',
#  'Automatic',
#  'Automatic',
#  'Automatic',
#  'Automatic',
#  'Automatic',
#  'Automatic',
#  'Manual',
#  'Automatic',
#  'Automatic',
#  'Automatic',
#  'Automatic',
#  'Automatic',
#  'Automatic',
#  'Automatic',
#  'Automatic',
#  'Automatic',
#  'Automatic',
#  'Automatic',
#  'Automatic',
#  'Automatic',
#  'Manual',
#  'Automatic',
#  'Automatic',
#  'Automatic',
#  'Automatic',
#  'Automatic',
#  'Automatic',
#  'Automatic',
#  'Automatic',
#  'Automatic',
#  'Automatic',
#  'Automatic',
#  'Automatic',
#  'Automatic',
#  'Automatic',
#  'Automatic',
#  'Automatic',
#  'Automatic',
#  'Automatic',
#  'Automatic',
#  'Automatic',
#  'Automatic',
#  'Manual']

# %% [markdown]
# ### Engine

# %%
pi.clean_text_data(
    pi.parse_subsection(soup, 'div', 'li', 'thumbnail', 'list-group-item InvEnginetype', 'get_text'), 'Engine')
# Out:
# ['3.5L V6 Cylinder Engine',
#  '6.2L 8 Cylinder Engine',
#  '1.5L 3 Cylinder Engine',
#  '3.5L V6 Cylinder Engine',
#  '3.0L V6 Cylinder Engine',
#  '6.7L 8 Cylinder Engine',
#  '1.4L 4 Cylinder Engine',
#  '5.7L 8 Cylinder Engine',
#  '2.0L 4 Cylinder Engine',
#  '6.2L 8 Cylinder Engine',
#  '3.6L V6 Cylinder Engine',
#  '2.5L V6 Cylinder Engine',
#  '3.0L V6 Cylinder Engine',
#  '5.7L 8 Cylinder Engine',
#  '3.5L V6 Cylinder Engine',
#  '5.3L 8 Cylinder Engine',
#  '3.5L V6 Cylinder Engine',
#  '3.5L V6 Cylinder Engine',
#  '4.0L V6 Cylinder Engine',
#  '3.8L V6 Cylinder Engine',
#  '5.6L 8 Cylinder Engine',
#  '2.0L 4 Cylinder Engine',
#  '2.4L 4 Cylinder Engine',
#  '3.5L V6 Cylinder Engine',
#  '3.6L V6 Cylinder Engine',
#  '3.6L V6 Cylinder Engine',
#  '3.6L V6 Cylinder Engine',
#  '3.0L V6 Cylinder Engine',
#  '3.6L V6 Cylinder Engine',
#  '3.5L V6 Cylinder Engine',
#  '2.5L 4 Cylinder Engine',
#  '3.5L V6 Cylinder Engine',
#  '3.5L V6 Cylinder Engine',
#  '2.4L 4 Cylinder Engine',
#  '3.0L V6 Cylinder Engine',
#  '4.0L V6 Cylinder Engine',
#  '3.5L V6 Cylinder Engine',
#  '5.3L 8 Cylinder Engine',
#  '3.5L V6 Cylinder Engine',
#  '2.5L 4 Cylinder Engine',
#  '5.3L 8 Cylinder Engine',
#  '3.6L V6 Cylinder Engine',
#  '1.5L 4 Cylinder Engine',
#  '3.5L V6 Cylinder Engine',
#  '2.5L 4 Cylinder Engine',
#  '1.5L 4 Cylinder Engine',
#  '3.5L V6 Cylinder Engine',
#  '3.0L V6 Cylinder Engine',
#  '3.5L V6 Cylinder Engine',
#  '1.4L 4 Cylinder Engine']

# %% [markdown]
# ### Drivetrain

# %%
pi.clean_text_data(
    pi.parse_subsection(soup, 'div', 'li', 'thumbnail', 'list-group-item drivetrain-item', 'get_text'), 'Drivetrain')
# Out:
# ['Four Wheel Drive',
#  'Four Wheel Drive',
#  'All Wheel Drive',
#  'Four Wheel Drive',
#  'All Wheel Drive',
#  'Four Wheel Drive',
#  'Front Wheel Drive',
#  'Four Wheel Drive',
#  'All Wheel Drive',
#  'Four Wheel Drive',
#  'Four Wheel Drive',
#  'All Wheel Drive',
#  'All Wheel Drive',
#  'Rear Wheel Drive',
#  'All Wheel Drive',
#  'Rear Wheel Drive',
#  'Four Wheel Drive',
#  'All Wheel Drive',
#  'Four Wheel Drive',
#  'All Wheel Drive',
#  'Four Wheel Drive',
#  'All Wheel Drive',
#  'Front Wheel Drive',
#  'All Wheel Drive',
#  'All Wheel Drive',
#  'All Wheel Drive',
#  'Front Wheel Drive',
#  'All Wheel Drive',
#  'All Wheel Drive',
#  'Front Wheel Drive',
#  'Front Wheel Drive',
#  'Front Wheel Drive',
#  'All Wheel Drive',
#  'Front Wheel Drive',
#  'All Wheel Drive',
#  'Four Wheel Drive',
#  'Front Wheel Drive',
#  'Four Wheel Drive',
#  'Front Wheel Drive',
#  'All Wheel Drive',
#  'Four Wheel Drive',
#  'Four Wheel Drive',
#  'Front Wheel Drive',
#  'Four Wheel Drive',
#  'All Wheel Drive',
#  'All Wheel Drive',
#  'Front Wheel Drive',
#  'All Wheel Drive',
#  'Front Wheel Drive',
#  'Front Wheel Drive']

# %% [markdown]
# ### VIN

# %%
pi.clean_text_data(
    pi.parse_subsection(soup, 'div', 'li', 'thumbnail', 'list-group-item InvVin', 'get_text'), 'VIN')
# Out:
# ['1FTEW1EG5GKD26164',
#  '1FT8W3B60GEC37377',
#  'WMZYV5C35H3B75526',
#  '1FMJU1MT2FEF15902',
#  'JN1EV7AR1HM840101',
#  '1FT7W2BT0FED48828',
#  '3VWDB7AJ9JM260615',
#  '5TFUY5F10FX423622',
#  'TRUK1AFK8D1001374',
#  '1GKS2CKJ1FR654928',
#  '1C4BJWDG2DL671450',
#  'JTHCF1D22F5028809',
#  'WAUKGAFLXEA021268',
#  '1G1YY33P7P5101290',
#  'WDDKJ8JB6EF282191',
#  '1GCES14P74B107165',
#  '5FPYK16579B101645',
#  '2T2BZMCA4GC042676',
#  'JTEBU4BF7EK205134',
#  'KMHGN4JE1GU141742',
#  '1N6AA1E50HN538088',
#  'YV140MTL1J2462274',
#  '1HGCP2F35CA075928',
#  '19UUB3F48LA001789',
#  '2C3CDZGG9JH289051',
#  '2C3CDZGG3KH690340',
#  '2C4RC1BG4GR110760',
#  'WAUDGAFL2EA139517',
#  '2G61V5S36D9130888',
#  '1N4AA5AP0CC827645',
#  '1FA6P0H70E5365477',
#  '1N4AA6AP7GC379917',
#  '5FNYF6H31GB089558',
#  '5XXGM4A78FG460844',
#  'JN1EV7ARXJM443430',
#  'JTEBU5JR4F5241848',
#  'JTHBK1GG5E2127042',
#  '3GTU2UEC0FG341344',
#  '5TDKZ3DCXJS949090',
#  'JM3KFBDM1L0723903',
#  '1GCVKSEC9GZ238434',
#  '1GCGTCEN3K1145395',
#  '1G1RC6S51JU142077',
#  '1FTFW1ET5DKE48455',
#  '2T3RFREV1JW811818',
#  '5J6RW2H89HL024538',
#  '1FAHP2E85FG187802',
#  'WA1LGAFE8FD004486',
#  '19UUB2F35KA005881',
#  '3C3CFFARXDT512860']

# %% [markdown]
# ## Check Full Script

# %%
error_df = pd.DataFrame()
error_df.at[0, 'error'] = 'Data Validation'
error_df.at[0, 'dealership'] = 'Blah'
error_df.at[0, 'date'] = datetime.now(tz = None)  
error_df.at[0, 'url'] = URL

# %%
error_df
# Out:
#              error dealership                       date                                                url
# 0  Data Validation       Blah 2022-03-28 20:59:36.836848  https://www.jmautomotive.com/cars-for-sale-in-...

# %%
error_df.columns
# Out:
# Index(['error', 'dealership', 'date', 'url'], dtype='object')

# %%
'error' in error_df.columns
# Out:
# False

# %% [markdown]
# ### Check Data

# %%
c = parse_dealership.get_jm_auto_inventory_data(soup, dealerships['JM Automotive'])

# %%
c.head()
# Out:
#                                                title  year    make                                      model_trim vehicle_type                 model                       trim  vehicle_mileage  price                      exterior_color     interior_color transmission                   engine        drivetrain                vin dealership_name      dealership_address dealership_zipcode dealership_city dealership_state                                      inventory_url               scraped_date
# 0              2016 Ford F-150 4WD SuperCrew 145 XLT  2016    Ford                     F-150 4WD SuperCrew 145 XLT         None                 F-150      4WD SuperCrew 145 XLT            89305  28995               Ingot Silver Metallic  Medium Earth Gray    Automatic  3.5L V6 Cylinder Engine  Four Wheel Drive  1FTEW1EG5GKD26164  J&M Automotive  756/820 New Haven Road              06770       Naugatuck               CT  https://www.jmautomotive.com/cars-for-sale-in-... 2022-03-27 22:19:45.868625
# 1  2016 Ford Super Duty F-350 Srw 4WD Crew Cab 15...  2016    Ford  Super Duty F-350 Srw 4WD Crew Cab 156 Platinum         None  Super Duty F-350 Srw  4WD Crew Cab 156 Platinum            24752  53995                        Shadow Black              Pecan    Automatic   6.2L 8 Cylinder Engine  Four Wheel Drive  1FT8W3B60GEC37377  J&M Automotive  756/820 New Haven Road              06770       Naugatuck               CT  https://www.jmautomotive.com/cars-for-sale-in-... 2022-03-27 22:19:45.868625
# 2                   2017 Mini Countryman Cooper ALL4  2017    Mini                          Countryman Cooper ALL4         None            Countryman                Cooper ALL4            77144  18995              Moonwalk Gray Metallic     Satellite Grey       Manual   1.5L 3 Cylinder Engine   All Wheel Drive  WMZYV5C35H3B75526  J&M Automotive  756/820 New Haven Road              06770       Naugatuck               CT  https://www.jmautomotive.com/cars-for-sale-in-... 2022-03-27 22:19:45.868625
# 3                2012 Toyota Fj Cruiser 4WD 4dr Auto  2012  Toyota                         Fj Cruiser 4WD 4dr Auto         None            Fj Cruiser               4WD 4dr Auto            92465  30995                             Iceberg      Dark Charcoal    Automatic  4.0L V6 Cylinder Engine  Four Wheel Drive  JTEBU4BF6CK123246  J&M Automotive  756/820 New Haven Road              06770       Naugatuck               CT  https://www.jmautomotive.com/cars-for-sale-in-... 2022-03-27 22:19:45.868625
# 4              2015 Ford Expedition 4WD 4dr Platinum  2015    Ford                     Expedition 4WD 4dr Platinum         None            Expedition           4WD 4dr Platinum            87901  31995  Ruby Red Metallic Tinted Clearcoat    Brunell W/black    Automatic  3.5L V6 Cylinder Engine  Four Wheel Drive  1FMJU1MT2FEF15902  J&M Automotive  756/820 New Haven Road              06770       Naugatuck               CT  https://www.jmautomotive.com/cars-for-sale-in-... 2022-03-27 22:19:45.868625

# %%
c.isnull().sum()
# Out:
# title                  0
# year                   0
# make                   0
# model_trim             0
# vehicle_type          50
# model                  0
# trim                   0
# vehicle_mileage        0
# price                  0
# exterior_color         0
# interior_color         1
# transmission           0
# engine                 0
# drivetrain             0
# vin                    0
# dealership_name        0
# dealership_address     0
# dealership_zipcode     0
# dealership_city        0
# dealership_state       0
# inventory_url          0
# scraped_date           0
# dtype: int64

# %%
## Check Null
c.loc[c.interior_color.isnull(), :]
# Out:
#                                          title  year  make model_trim  \
# 49  2015 Audi Q7 quattro 4dr 3.0T Premium Plus  2015  Audi         Q7
#
#                      vehicle_type  vehicle_mileage  price  \
# 49  quattro 4dr 3.0T Premium Plus            84066  26995
#
#             exterior_color interior_color transmission  \
# 49  Atlantis Blue Metallic            NaN    Automatic
#
#                      engine       drivetrain                vin  \
# 49  3.0L V6 Cylinder Engine  All Wheel Drive  WA1LGAFE8FD004486
#
#    dealership_name      dealership_address dealership_zipcode dealership_city  \
# 49  J&M Automotive  756/820 New Haven Road              06770       Naugatuck
#
#    dealership_state                                      inventory_url  \
# 49               CT  https://www.jmautomotive.com/cars-for-sale-in-...
#
#                  scraped_date
# 49 2022-03-24 22:36:11.509159

# %% [markdown]
# ## Check DB

# %%
# Check other null data points
conn = sqlite3.connect('cars.db')
sql_query = "SELECT * FROM test WHERE dealership_name = 'J&M Automotive'"
#sql_query = "SELECT * FROM inventory_staging"
result = pd.read_sql_query(sql_query, conn)

# %%
result
# Out:
#                                                  title  year     make  \
# 0                2016 Ford F-150 4WD SuperCrew 145 XLT  2016     Ford
# 1    2016 Ford Super Duty F-350 Srw 4WD Crew Cab 15...  2016     Ford
# 2                     2017 Mini Countryman Cooper ALL4  2017     Mini
# 3                  2012 Toyota Fj Cruiser 4WD 4dr Auto  2012   Toyota
# 4                2015 Ford Expedition 4WD 4dr Platinum  2015     Ford
# ..                                                 ...   ...      ...
# 471            2014 Toyota Tacoma 4WD Double Cab V6 AT  2014   Toyota
# 472  2016 Toyota Tacoma 4WD Access Cab V6 AT TRD Of...  2016   Toyota
# 473                       2012 Lincoln Mkz 4dr Sdn AWD  2012  Lincoln
# 474                           2017 Honda Accord LX CVT  2017    Honda
# 475                           2017 Nissan Sentra S CVT  2017   Nissan
#
#                model_trim                       vehicle_type  vehicle_mileage  \
# 0                   F-150              4WD SuperCrew 145 XLT            89305
# 1    Super Duty F-350 Srw          4WD Crew Cab 156 Platinum            24752
# 2              Countryman                        Cooper ALL4            77144
# 3              Fj Cruiser                       4WD 4dr Auto            92465
# 4              Expedition                   4WD 4dr Platinum            87901
# ..                    ...                                ...              ...
# 471                Tacoma               4WD Double Cab V6 AT            53421
# 472                Tacoma  4WD Access Cab V6 AT TRD Off Road            36397
# 473                   Mkz                        4dr Sdn AWD            88925
# 474                Accord                             LX CVT            83396
# 475                Sentra                              S CVT            82109
#
#      price                      exterior_color     interior_color  \
# 0    28995               Ingot Silver Metallic  Medium Earth Gray
# 1    53995                        Shadow Black              Pecan
# 2    18995              Moonwalk Gray Metallic     Satellite Grey
# 3    30995                             Iceberg      Dark Charcoal
# 4    31995  Ruby Red Metallic Tinted Clearcoat    Brunell W/black
# ..     ...                                 ...                ...
# 471  28995                 Silver Sky Metallic           Graphite
# 472  36995                         Super White               None
# 473  12995                 Steel Blue Metallic        Light Camel
# 474  19995                  White Orchid Pearl              Ivory
# 475  13995                               Black               None
#
#     transmission                   engine         drivetrain  \
# 0      Automatic  3.5L V6 Cylinder Engine   Four Wheel Drive
# 1      Automatic   6.2L 8 Cylinder Engine   Four Wheel Drive
# 2         Manual   1.5L 3 Cylinder Engine    All Wheel Drive
# 3      Automatic  4.0L V6 Cylinder Engine   Four Wheel Drive
# 4      Automatic  3.5L V6 Cylinder Engine   Four Wheel Drive
# ..           ...                      ...                ...
# 471    Automatic  4.0L V6 Cylinder Engine   Four Wheel Drive
# 472         None  3.5L V6 Cylinder Engine   Four Wheel Drive
# 473    Automatic  3.5L V6 Cylinder Engine    All Wheel Drive
# 474    Automatic   2.4L 4 Cylinder Engine  Front Wheel Drive
# 475    Automatic   1.8L 4 Cylinder Engine  Front Wheel Drive
#
#                    vin dealership_name      dealership_address  \
# 0    1FTEW1EG5GKD26164  J&M Automotive  756/820 New Haven Road
# 1    1FT8W3B60GEC37377  J&M Automotive  756/820 New Haven Road
# 2    WMZYV5C35H3B75526  J&M Automotive  756/820 New Haven Road
# 3    JTEBU4BF6CK123246  J&M Automotive  756/820 New Haven Road
# 4    1FMJU1MT2FEF15902  J&M Automotive  756/820 New Haven Road
# ..                 ...             ...                     ...
# 471  3TMLU4EN3EM143512  J&M Automotive  756/820 New Haven Road
# 472  5TFSZ5AN8GX008189  J&M Automotive  756/820 New Haven Road
# 473  3LNHL2JC9CR810841  J&M Automotive  756/820 New Haven Road
# 474  1HGCR2F30HA020482  J&M Automotive  756/820 New Haven Road
# 475  3N1AB7AP1HY374009  J&M Automotive  756/820 New Haven Road
#
#     dealership_zipcode dealership_city dealership_state  \
# 0                06770       Naugatuck               CT
# 1                06770       Naugatuck               CT
# 2                06770       Naugatuck               CT
# 3                06770       Naugatuck               CT
# 4                06770       Naugatuck               CT
# ..                 ...             ...              ...
# 471              06770       Naugatuck               CT
# 472              06770       Naugatuck               CT
# 473              06770       Naugatuck               CT
# 474              06770       Naugatuck               CT
# 475              06770       Naugatuck               CT
#
#                                          inventory_url  \
# 0    https://www.jmautomotive.com/cars-for-sale-in-...
# 1    https://www.jmautomotive.com/cars-for-sale-in-...
# 2    https://www.jmautomotive.com/cars-for-sale-in-...
# 3    https://www.jmautomotive.com/cars-for-sale-in-...
# 4    https://www.jmautomotive.com/cars-for-sale-in-...
# ..                                                 ...
# 471  https://www.jmautomotive.com/cars-for-sale-in-...
# 472  https://www.jmautomotive.com/cars-for-sale-in-...
# 473  https://www.jmautomotive.com/cars-for-sale-in-...
# 474  https://www.jmautomotive.com/cars-for-sale-in-...
# 475  https://www.jmautomotive.com/cars-for-sale-in-...
#
#                    scraped_date
# 0    2022-03-25 22:29:02.549807
# 1    2022-03-25 22:29:02.549807
# 2    2022-03-25 22:29:02.549807
# 3    2022-03-25 22:29:02.549807
# 4    2022-03-25 22:29:02.549807
# ..                          ...
# 471  2022-03-25 22:29:24.924182
# 472  2022-03-25 22:29:24.924182
# 473  2022-03-25 22:29:24.924182
# 474  2022-03-25 22:29:24.924182
# 475  2022-03-25 22:29:24.924182
#
# [476 rows x 20 columns]

# %% [markdown]
# ### Before

# %%
conn = sqlite3.connect('cars.db')
sql_query = "SELECT dealership_name, count(*) AS num_of_vehicles FROM inventory_staging GROUP BY 1"
result = pd.read_sql_query(sql_query, conn)
result
# Out:
#            dealership_name  num_of_vehicles
# 0        Avon Auto Brokers              303
# 1           Blasius Boston              289
# 2     Bostonyan Auto Group               18
# 3        Direct Auto Mecca              147
# 4        Fafama Auto Sales              132
# 5         Johns Auto Sales              147
# 6  Newton Automotive Sales               35

# %% [markdown]
# ### After

# %%
conn = sqlite3.connect('cars.db')
sql_query = "SELECT dealership_name, count(*) AS num_of_vehicles FROM inventory_staging GROUP BY 1"
result = pd.read_sql_query(sql_query, conn)
result
# Out:
#            dealership_name  num_of_vehicles
# 0        Avon Auto Brokers              303
# 1           Blasius Boston              289
# 2     Bostonyan Auto Group               18
# 3        Direct Auto Mecca              147
# 4        Fafama Auto Sales              132
# 5           J&M Automotive              476
# 6        John's Auto Sales              294
# 7  Newton Automotive Sales               35

# %% [markdown]
# ### Check Random Null Values to QA

# %%
# Check other null data points
conn = sqlite3.connect('cars.db')
sql_query = "SELECT * FROM inventory_staging WHERE dealership_name = 'J&M Automotive'"
#sql_query = "SELECT * FROM inventory_staging"
result = pd.read_sql_query(sql_query, conn)

# %%
result.tail()
# Out:
#                                                  title  year     make                                model_trim vehicle_type   model                               trim  vehicle_mileage  price       exterior_color interior_color transmission                   engine         drivetrain                vin dealership_name      dealership_address dealership_zipcode dealership_city dealership_state                                      inventory_url                scraped_date
# 471            2014 Toyota Tacoma 4WD Double Cab V6 AT  2014   Toyota               Tacoma 4WD Double Cab V6 AT         None  Tacoma               4WD Double Cab V6 AT            53421  28995  Silver Sky Metallic       Graphite    Automatic  4.0L V6 Cylinder Engine   Four Wheel Drive  3TMLU4EN3EM143512  J&M Automotive  756/820 New Haven Road              06770       Naugatuck               CT  https://www.jmautomotive.com/cars-for-sale-in-...  2022-03-25 22:50:53.953560
# 472  2016 Toyota Tacoma 4WD Access Cab V6 AT TRD Of...  2016   Toyota  Tacoma 4WD Access Cab V6 AT TRD Off Road         None  Tacoma  4WD Access Cab V6 AT TRD Off Road            36397  36995          Super White           None         None  3.5L V6 Cylinder Engine   Four Wheel Drive  5TFSZ5AN8GX008189  J&M Automotive  756/820 New Haven Road              06770       Naugatuck               CT  https://www.jmautomotive.com/cars-for-sale-in-...  2022-03-25 22:50:53.953560
# 473                       2012 Lincoln Mkz 4dr Sdn AWD  2012  Lincoln                           Mkz 4dr Sdn AWD         None     Mkz                        4dr Sdn AWD            88925  12995  Steel Blue Metallic    Light Camel    Automatic  3.5L V6 Cylinder Engine    All Wheel Drive  3LNHL2JC9CR810841  J&M Automotive  756/820 New Haven Road              06770       Naugatuck               CT  https://www.jmautomotive.com/cars-for-sale-in-...  2022-03-25 22:50:53.953560
# 474                           2017 Honda Accord LX CVT  2017    Honda                             Accord LX CVT         None  Accord                             LX CVT            83396  19995   White Orchid Pearl          Ivory    Automatic   2.4L 4 Cylinder Engine  Front Wheel Drive  1HGCR2F30HA020482  J&M Automotive  756/820 New Haven Road              06770       Naugatuck               CT  https://www.jmautomotive.com/cars-for-sale-in-...  2022-03-25 22:50:53.953560
# 475                           2017 Nissan Sentra S CVT  2017   Nissan                              Sentra S CVT         None  Sentra                              S CVT            82109  13995                Black           None    Automatic   1.8L 4 Cylinder Engine  Front Wheel Drive  3N1AB7AP1HY374009  J&M Automotive  756/820 New Haven Road              06770       Naugatuck               CT  https://www.jmautomotive.com/cars-for-sale-in-...  2022-03-25 22:50:53.953560

# %%
result.isnull().sum()
# Out:
# title                   0
# year                    0
# make                    0
# model_trim              0
# vehicle_type          476
# model                   0
# trim                    0
# vehicle_mileage         0
# price                   0
# exterior_color          0
# interior_color         12
# transmission            4
# engine                  0
# drivetrain              0
# vin                     0
# dealership_name         0
# dealership_address      0
# dealership_zipcode      0
# dealership_city         0
# dealership_state        0
# inventory_url           0
# scraped_date            0
# dtype: int64

# %%
result.loc[result.transmission.isnull(), :]
# Out:
#     title  year    make                                 model_trim vehicle_type                 model                  trim  vehicle_mileage  price       exterior_color interior_color transmission                   engine         drivetrain                vin dealership_name      dealership_address dealership_zipcode dealership_city dealership_state                                      inventory_url                scraped_date
# 263  None  2010    Ford  Super Duty F-250 Srw Super Duty F-250 Srw         None  Super Duty F-250 Srw  Super Duty F-250 Srw           170882  17995         Oxford White   Medium Stone         None   5.4L 8 Cylinder Engine   Four Wheel Drive  1FTSX2B52AEA54798  J&M Automotive  756/820 New Haven Road              06770       Naugatuck               CT  https://www.jmautomotive.com/cars-for-sale-in-...  2022-03-25 22:44:08.856191
# 302  None  2008    Ford  Super Duty F-350 Drw Super Duty F-350 Drw         None  Super Duty F-350 Drw  Super Duty F-350 Drw            13454  37995         Oxford White          Camel         None   6.4L 8 Cylinder Engine   Four Wheel Drive  1FDWF37R58ED29916  J&M Automotive  756/820 New Haven Road              06770       Naugatuck               CT  https://www.jmautomotive.com/cars-for-sale-in-...  2022-03-25 22:44:12.383617
# 382  None  2008  Nissan                              Altima Altima         None                Altima                Altima            79330   9995  Dark Slate Metallic          Frost         None   2.5L 4 Cylinder Engine  Front Wheel Drive  1N4AL21E18N417391  J&M Automotive  756/820 New Haven Road              06770       Naugatuck               CT  https://www.jmautomotive.com/cars-for-sale-in-...  2022-03-25 22:44:14.763709
# 472  None  2016  Toyota                              Tacoma Tacoma         None                Tacoma                Tacoma            36397  36995          Super White           None         None  3.5L V6 Cylinder Engine   Four Wheel Drive  5TFSZ5AN8GX008189  J&M Automotive  756/820 New Haven Road              06770       Naugatuck               CT  https://www.jmautomotive.com/cars-for-sale-in-...  2022-03-25 22:44:28.720324

# %%
TABLE_NAME = 'inventory_staging'
DB_NAME = 'cars.db'

#Connecting to sqlite
conn = sqlite3.connect(DB_NAME)

#Creating a cursor object using the cursor() method
cursor = conn.cursor()

#Doping EMPLOYEE table if already exists
cursor.execute(f"DELETE FROM {TABLE_NAME} WHERE dealership_name = 'J&M Automotive'")

#Commit your changes in the database
conn.commit()

#Closing the connection
conn.close()

# %%
TABLE_NAME = 'test'
DB_NAME = 'cars.db'

#Connecting to sqlite
conn = sqlite3.connect(DB_NAME)

#Creating a cursor object using the cursor() method
cursor = conn.cursor()

#Doping EMPLOYEE table if already exists
cursor.execute(f"DROP TABLE {TABLE_NAME}")
print("Table dropped... ")

#Commit your changes in the database
conn.commit()

#Closing the connection
conn.close()
# Out:
# Table dropped...

# %%
TABLE_NAME = 'parsing_errors_test'
DB_NAME = 'cars.db'

#Connecting to sqlite
conn = sqlite3.connect(DB_NAME)

#Creating a cursor object using the cursor() method
cursor = conn.cursor()

#Doping EMPLOYEE table if already exists
cursor.execute(f"DROP TABLE {TABLE_NAME}")
print("Table dropped... ")

#Commit your changes in the database
conn.commit()

#Closing the connection
conn.close()

# %%
conn = sqlite3.connect('cars.db')
sql_query = "SELECT * FROM test"
result = pd.read_sql_query(sql_query, conn)
result
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~/opt/anaconda3/envs/dash/lib/python3.9/site-packages/pandas/io/sql.py in execute(self, *args, **kwargs)
#    2019         try:
# -> 2020             cur.execute(*args, **kwargs)
#    2021             return cur
#
# OperationalError: no such table: test
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# /var/folders/xb/kngqrs1n3n5474zrpfc02thc0000gn/T/ipykernel_93798/1773065003.py in <module>
#       1 conn = sqlite3.connect('cars.db')
#       2 sql_query = "SELECT * FROM test"
# ----> 3 result = pd.read_sql_query(sql_query, conn)
#       4 result
#
# ~/opt/anaconda3/envs/dash/lib/python3.9/site-packages/pandas/io/sql.py in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize, dtype)
#     397     """
#     398     pandas_sql = pandasSQL_builder(con)
# --> 399     return pandas_sql.read_query(
#     400         sql,
#     401         index_col=index_col,
#
# ~/opt/anaconda3/envs/dash/lib/python3.9/site-packages/pandas/io/sql.py in read_query(self, sql, index_col, coerce_float, params, parse_dates, chunksize, dtype)
#    2078
#    2079         args = _convert_params(sql, params)
# -> 2080         cursor = self.execute(*args)
#    2081         columns = [col_desc[0] for col_desc in cursor.description]
#    2082
#
# ~/opt/anaconda3/envs/dash/lib/python3.9/site-packages/pandas/io/sql.py in execute(self, *args, **kwargs)
#    2030
#    2031             ex = DatabaseError(f"Execution failed on sql '{args[0]}': {exc}")
# -> 2032             raise ex from exc
#    2033
#    2034     @staticmethod
#
# DatabaseError: Execution failed on sql 'SELECT * FROM test': no such table: test

# %%
conn = sqlite3.connect('cars.db')
sql_query = "SELECT * FROM parsing_errors_test"
result = pd.read_sql_query(sql_query, conn)
result
# Out:
#               error      dealership                        date                                                url
# 0   Data Validation  J&M Automotive  2022-03-27 22:40:08.113547  https://www.jmautomotive.com/cars-for-sale-in-...
# 1   Data Validation  J&M Automotive  2022-03-27 22:40:10.914048  https://www.jmautomotive.com/inventory.aspx?pg...
# 2   Data Validation  J&M Automotive  2022-03-27 22:40:16.223653  https://www.jmautomotive.com/inventory.aspx?pg...
# 3   Data Validation  J&M Automotive  2022-03-27 22:40:18.094522  https://www.jmautomotive.com/inventory.aspx?pg...
# 4   Data Validation  J&M Automotive  2022-03-28 21:01:05.218135  https://www.jmautomotive.com/cars-for-sale-in-...
# 5   Data Validation  J&M Automotive  2022-03-28 21:01:08.227569  https://www.jmautomotive.com/inventory.aspx?pg...
# 6   Data Validation  J&M Automotive  2022-03-28 21:01:11.191049  https://www.jmautomotive.com/inventory.aspx?pg...
# 7   Data Validation  J&M Automotive  2022-03-28 21:01:14.558022  https://www.jmautomotive.com/inventory.aspx?pg...
# 8   Data Validation  J&M Automotive  2022-03-28 21:01:17.641471  https://www.jmautomotive.com/inventory.aspx?pg...
# 9   Data Validation  J&M Automotive  2022-03-28 21:01:20.537513  https://www.jmautomotive.com/inventory.aspx?pg...
# 10  Data Validation  J&M Automotive  2022-03-28 21:01:23.483930  https://www.jmautomotive.com/inventory.aspx?pg...
# 11  Data Validation  J&M Automotive  2022-03-28 21:01:25.386833  https://www.jmautomotive.com/inventory.aspx?pg...
# 12  Data Validation  J&M Automotive  2022-03-28 21:01:27.481258  https://www.jmautomotive.com/inventory.aspx?pg...

# %%
error_df = pd.DataFrame()
error_df.at[0, 'error'] = 'Data Validation'
error_df.at[0, 'dealership'] = 'JM Automotive'
error_df.at[0, 'date'] = datetime.now(tz = None)  
error_df.at[0, 'url'] = 'https://www.jmautomotive.com/inventory.aspx?pg=2&sort=12&limit=50&vstatus=1&status=6'

# %%
error_df
# Out:
#              error     dealership                       date                                                url
# 0  Data Validation  JM Automotive 2022-03-27 22:36:23.886094  https://www.jmautomotive.com/inventory.aspx?pg...

# %%
def add_data_to_sqlite3(db_name, tbl_name, df):
    # Add data to a SQLite database
    conn = sqlite3.connect(db_name) # 'cars.db'
    df.to_sql(tbl_name, conn, if_exists='append', index=False)

# %%
TABLE_NAME = 'test'
ERROR_TBL_NAME = 'parsing_errors_test'
DB_NAME = 'cars.db'

# %%
add_data_to_sqlite3(DB_NAME, ERROR_TBL_NAME, error_df)
