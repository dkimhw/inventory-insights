# %%
import parse_inventory as pi
import parse_dealership
import requests
import re
from bs4 import BeautifulSoup
import pandas as pd
from datetime import datetime
import sqlite3
import numpy as np

# %% [markdown]
# ## Test Connection
#
# Check that the html for the page is being pulled in correctly

# %%
headers = {
    'user-agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/56.0.2924.87 Safari/537.36',
}

URL = 'https://www.jmautomotive.com/cars-for-sale-in-Naugatuck-CT-Hartford-New-Haven/used_cars'
response = requests.get(URL, headers = headers)
soup = BeautifulSoup(response.text, "html.parser")

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en-us">
#  <head>
#   <title>
#    Used cars for sale in Naugatuck, Waterbury, Hartford, New Haven, CT | J&amp;M Automotive Sls&amp;Svc LLC
#   </title>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="black" name="apple-mobile-web-app-status-bar-style"/>
#   <meta content="width=device-width, user-scalable=yes, initial-scale=1.0, minimum-scale=1.0, maximum-scale=9.0" name="viewport"/>
#   <meta content="index, follow" name="robots"/>
#   <meta content="J&amp;M Automotive Sls&amp;Svc LLC, used cars for sale, used car dealer, Connecticut, CT, Naugatuck, Waterbury, Hartford, New Haven, New Haven County, Waterbury CT, Hartford CT, Prospect CT, Oxford CT, Seymour CT, Cheshire CT, Southbury CT, Wolcott CT, Watertown CT, Woodbury CT, Woodbridge CT, Ansonia CT, Hamden CT, Derby CT, North Haven CT and Shelton CT,  used cars, used suv, used trucks, used pickups, used minivans, car financing, service and repair center in Naugatuck, CT" name="keywords"/>
#   <meta content="Used cars for sale in Naugatuck, Waterbury, Hartford, New Haven, Connecticut | J&amp;M Automotive Sls&amp;Svc LLC | Cars in New Haven County, Waterbury CT, Hartford CT, Prospect CT, Oxford CT, Seymour CT, Cheshire CT, Southbury CT, Wolcott CT, Watertown CT, Woodbury CT, Woodbridge CT, Ansonia CT, Hamden CT, Derby CT, North Haven CT and Shelton CT" name="description"/>
#   <meta content="Copyright J&amp;M Automotive Sls&amp;Svc LLC - Naugatuck, CT. All rights reserved." name="copyright"/>
#   <meta content="J&amp;M Automotive Sls&amp;Svc LLC - Naugatuck, CT" name="author"/>
#   <meta content="General" name="rating"/>
#   <meta content="DB59462BDEB106B04DA73EABB07F4A23" name="msvalidate.01"/>
#   <meta content="46C0DFC6DF57F09BF0F60B1C94E05B75" name="msvalidate.01"/>
#   <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
#   <meta content="telephone=no" name="format-detection"/>
#   <meta content="https://www.jmautomotive.com/cars-for-sale-in-Naugatuck-CT-Hartford-New-Haven/used_cars" property="og:url">
#    <meta content="J&amp;M Automotive Sls&amp;Svc LLC" property="og:site_name">
#     <meta content="Used cars for sale in Naugatuck, Waterbury, Hartford, New Haven, CT | J&amp;M Automotive Sls&amp;Svc LLC" property="og:title"/>
#     <meta content="Used cars for sale in Naugatuck, Waterbury, Hartford, New Haven, Connecticut | J&amp;M Automotive Sls&amp;Svc LLC | Cars in New Haven County, Waterbury CT, Hartford CT, Prospect CT, Oxford CT, Seymour CT, Cheshire CT, Southbury CT, Wolcott CT, Watertown CT, Woodbury CT, Woodbridge CT, Ansonia CT, Hamden CT, Derby CT, North Haven CT and Shelton CT" property="og:description"/>
#     <meta content="website" property="og:type"/>
#     <meta content="https://www.jmautomotive.com/Dealer-Websites/J+Mautomotive/images/sharingLogoImg_10.png" property="og:image"/>
#     <meta content="summary" name="twitter:card"/>
#     <meta content="Used cars for sale in Naugatuck, Waterbury, Hartford, New Haven, CT | J&amp;M Automotive Sls&amp;Svc LLC" name="twitter:title"/>
#     <meta content="Used cars for sale in Naugatuck, Waterbury, Hartford, New Haven, Connecticut | J&amp;M Automotive Sls&amp;Svc LLC | Cars in New Haven County, Waterbury CT, Hartford CT, Prospect CT, Oxford CT, Seymour CT, Cheshire CT, Southbury CT, Wolcott CT, Watertown CT, Woodbury CT, Woodbridge CT, Ansonia CT, Hamden CT, Derby CT, North Haven CT and Shelton CT" name="twitter:description"/>
#     <meta content="J&amp;M Automotive Sls&amp;Svc LLC" name="twitter:site"/>
#     <meta content="https://www.jmautomotive.com/Dealer-Websites/J+Mautomotive/images/sharingLogoImg_10.png" name="twitter:image"/>
#     <link href="https://www.jmautomotive.com/cars-for-sale-in-Naugatuck-CT-Waterbury-Hartford/used_cars" rel="canonical"/>
#     <link href="https://www.jmautomotive.com/inventory.aspx?pg=2&amp;sort=12&amp;limit=50&amp;vstatus=1&amp;status=6" rel="next"/>
#     <link href="/HttpCombiner.ashx?s=DW_Common-CSS-min&amp;t=text/css&amp;v=2022.03.21.A&amp;d=467" rel="stylesheet" type="text/css">
#      <link href="/Dealer-Websites/J+Mautomotive/stylesheet/theme.css?v=2022.03.21.A" rel="stylesheet" type="text/css"/>
#      <link href="https://www.jmautomotive.com/Dealer-Websites/J+Mautomotive/images/favicon.ico?v=2022.03.21.A" rel="shortcut icon" type="image/x-icon">
#      </link>
#     </link>
#    </meta>
#   </meta>
#  </head>
#  <body class="SearchBarEnabled ChatDisabled DesktopCss FBChatChatDisabled body_CaptchaCodeEnabled" id="body_inventory">
#   <noscript>
#    <iframe class="DwNoDisplay" height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-K6T6T3V" title="Google Tag Manager" width="0">
#    </iframe>
#   </noscript>
#   <noscript>
#    <img alt="" class="DwNoDisplay" height="1" src="https://www.facebook.com/tr?id=171808093741209&amp;ev=PageView&amp;noscript=1" width="1"/>
#    <img alt="" class="DwNoDisplay" height="1" src="https://www.facebook.com/tr?id=599518190591013&amp;ev=PageView&amp;noscript=1" width="1"/>
#    <img alt="" class="DwNoDisplay" height="1" src="https://www.facebook.com/tr?id=149383822442668&amp;ev=PageView&amp;noscript=1" width="1"/>
#   </noscript>
#   <div class="dw-container-1" id="dw-container">
#    <div id="skip-content">
#     <a href="#DWnavigation">
#      Skip to main content
#     </a>
#    </div>
#    <div class="dw-block" id="dw-topbar-container" itemref="dw-dealership dw-logo DW_StoreHours" itemscope="" itemtype="http://schema.org/AutoDealer">
#     <div id="dw-append-address">
#      <span class="dw-top-addr" itemprop="address" itemscope="" itemtype="http://schema.org/PostalAddress">
#       <span class="dw-block" itemprop="streetAddress">
#        756/820 New Haven Road
#       </span>
#       <span>
#        <span itemprop="addressLocality">
#         Naugatuck
#        </span>
#        ,
#       </span>
#       <span itemprop="addressRegion" title="Connecticut">
#        CT
#       </span>
#       <span class="nbspL" itemprop="postalCode">
#        06770
#       </span>
#      </span>
#      <span>
#       <span class="nbspR dw-hide-dd">
#        |
#       </span>
#       <a aria-label="Driving Directions(opens in a new tab)" class="dw-hide-dd" href="https://maps.google.com/maps?f=q&amp;hl=en&amp;q=J%26M+Automotive+Sls%26Svc+LLC,756/820+New+Haven+Road,Naugatuck,CT+06770&amp;ie=UTF8&amp;om=1&amp;maptype=terrain" id="aGoogleLink1" itemprop="hasMap" target="_blank">
#        Driving Directions
#       </a>
#      </span>
#     </div>
#     <div id="dw-append-fb">
#      <a aria-label="fb recommend (opens ina new tab)" href="https://www.facebook.com/pages/JM-Automotive-SlsSvc-LLC/159851630780993" target="_blank">
#       <img alt="fb" height="19" src="/2/images/fb_rec.png" title="fb recommend" width="99"/>
#      </a>
#     </div>
#     <div id="dw-topbar-info">
#      <div class="dw-fr" id="DWSocialContainer">
#       <div class="dw-social" id="divInstagram">
#        <a aria-label="Instagram" class="dw-top-social" href="https://www.instagram.com/jmautomotivenaugatuck/" id="IconInstagram" itemprop="sameAs" target="_blank">
#         <i class="fa fa-instagram">
#         </i>
#        </a>
#       </div>
#       <div class="dw-social" id="divFacebook">
#        <a aria-label="Facebook" class="dw-top-social" href="https://www.facebook.com/pages/JM-Automotive-SlsSvc-LLC/159851630780993" id="IconFacebook" itemprop="sameAs" target="_blank">
#         <i class="fa fa-facebook">
#         </i>
#        </a>
#       </div>
#       <div class="dw-social" id="divRSS">
#        <a aria-label="Rss" class="dw-top-social" href="https://www.jmautomotive.com/rss.aspx" id="IconRss" target="_blank">
#         <i class="fa fa-rss">
#         </i>
#        </a>
#       </div>
#      </div>
#      <div class="dw-fr" id="dw-append-dealerinfo">
#       <span class="dw-block dw-top-dname" itemprop="name">
#        J&amp;M Automotive Sls&amp;Svc LLC
#       </span>
#       <span class="dw-top-website">
#        <a href="https://www.jmautomotive.com" rel="home">
#         www.jmautomotive.com
#        </a>
#       </span>
#       <span class="dw-pipe">
#        |
#       </span>
#       <span>
#        <a href="tel:2037235666">
#         <span itemprop="telephone">
#          (203) 723-5666
#         </span>
#        </a>
#       </span>
#      </div>
#     </div>
#    </div>
#    <div id="dw-searchbar-append">
#     <div class="dw-block" id="dw-searchbar-c">
#      <div class="dw-searchbar">
#       <div class="dw-searchbox-c">
#        <input aria-label="Search our inventory" autocomplete="off" class="dw-searchbox" id="dw-searchbox" placeholder="Search our inventory" title="Search our inventory" type="text" value=""/>
#       </div>
#       <div id="dw-searchbox-btn" role="button" tabindex="0">
#        <i class="material-icons">
#         search
#        </i>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="dw-block" id="dw-affix-container">
#     <div class="dw-top-header">
#      <div class="dw-table" id="dw-top-DRB">
#       <div class="dw-row">
#        <div class="dw-cell-c dw-cell-3 dw-m-hide">
#         <div class="dwc-cell-1">
#          <img alt="over 550 pre-owned automobiles in stock" class="pre_ownedBanner" id="pre_ownedBanner" src="/Dealer-Websites/J+Mautomotive/images/550.gif" title="over 550 pre-owned automobiles in stock">
#           <br/>
#           <a href="https://www.jmautomotive.com/Dealer-Websites/J+Mautomotive/Get-Financing.aspx?IsGeneric=0&amp;">
#            <img alt="Nosotras Financianos La Identificacion Fiscal" class="tax_Banner" id="tax_Banner" src="/Dealer-Websites/J+Mautomotive/images/getFinancing.png" title="Nosotras Financianos La Identificacion Fiscal"/>
#           </a>
#          </img>
#         </div>
#        </div>
#        <div class="dw-cell dw-cell-2" id="dw-logo">
#         <a href="https://www.jmautomotive.com">
#          <img alt="J&amp;M Automotive Sls&amp;Svc LLC, Naugatuck, CT" class="logoImg" itemprop="logo" src="/Dealer-Websites/J+Mautomotive/images/logo.png" title="J&amp;M Automotive Sls&amp;Svc LLC, Naugatuck, CT"/>
#         </a>
#         <div class="dwc-cell-2">
#          <img alt="OPEN 7 DAYS A WEEK" id="dealerRaterimg" src="/Dealer-Websites/J+Mautomotive/images/OPEN-7-DAYS-A-WEEK.png" title="OPEN 7 DAYS A WEEK"/>
#         </div>
#        </div>
#        <div class="dw-cell-c dw-cell-1 dw-m-hide">
#         <div>
#          <span class="dw-cell-4">
#           <a href="/Dealer-Websites/J+Mautomotive/Sell-You-Car.aspx">
#            <img alt="click here to sell your car and get paid on the spot" class="pre_ownedBanner" src="/Dealer-Websites/J+Mautomotive/images/sellYourCar.jpg" title="click here to sell your car and get paid on the spot"/>
#           </a>
#          </span>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="dw-block" id="dw-scroll-header">
#     </div>
#     <div class="dw-top-menu menu">
#      <nav class="navbar navbar-inverse samp">
#       <div class="container-fluid">
#        <div class="navbar-header">
#         <span id="divIconShare">
#          <a aria-label="share(opens in a new tab)" href="javascript:void(0)" id="aIconShare" role="button">
#           <i class="material-icons">
#            share
#           </i>
#          </a>
#         </span>
#         <span id="divIconDirection">
#          <a aria-label="place(opens in a new tab)" href="https://maps.google.com/maps?f=q&amp;hl=en&amp;q=J%26M+Automotive+Sls%26Svc+LLC,756/820+New+Haven+Road,Naugatuck,CT+06770&amp;ie=UTF8&amp;om=1&amp;maptype=terrain" id="aIconDirection" target="_blank">
#           <i class="material-icons">
#            place
#           </i>
#          </a>
#         </span>
#         <span id="divIconCall">
#          <a aria-label="call(opens in a new tab)" href="tel:2037235666" id="aIconCall">
#           <i class="material-icons">
#            call
#           </i>
#          </a>
#         </span>
#         <div class="navbar-toggle" id="divMenuButton">
#          <i class="material-icons">
#           menu
#          </i>
#         </div>
#        </div>
#        <div class="collapse navbar-collapse" id="DWnavigation">
#         <ul class="main_menu nav navbar-nav" id="main_menu">
#          <li class="dropdown" id="main_menu_1">
#           <a aria-label="HOME" class="dropdown-toggle" data-hover="dropdown" href="https://www.jmautomotive.com" rel="home">
#            HOME
#           </a>
#          </li>
#          <li class="dropdown" id="main_menu_2">
#           <a aria-expanded="false" aria-haspopup="true" aria-label="INVENTORY" class="dropdown-toggle haschildren" data-hover="dropdown" href="https://www.jmautomotive.com/cars-for-sale-in-Naugatuck-CT-Hartford-New-Haven/used_cars">
#            INVENTORY
#           </a>
#           <span class="droparrow">
#            <span class="caretfont">
#             <i aria-hidden="true" class="fa fa-caret-down">
#             </i>
#            </span>
#           </span>
#           <ul class="sub_menu dropdown-menu">
#            <li>
#             <a aria-label="View used cars" class="dropdown-toggle" data-hover="dropdown" href="https://www.jmautomotive.com/cars-for-sale-in-Naugatuck-CT-Hartford-New-Haven/used_cars">
#              View used cars
#             </a>
#            </li>
#            <li>
#             <a aria-label="Featured used cars" class="dropdown-toggle" data-hover="dropdown" href="https://www.jmautomotive.com/search-cars/featured-used-cars-JandM-Automotive-SlsandSvc-LLC">
#              Featured used cars
#             </a>
#            </li>
#            <li>
#             <a aria-label="Used car finder" class="dropdown-toggle" data-hover="dropdown" href="https://www.jmautomotive.com/find-car-for-me">
#              Used car finder
#             </a>
#            </li>
#            <li>
#             <a aria-label="Used cars under $10,000" class="dropdown-toggle" data-hover="dropdown" href="https://www.jmautomotive.com/search-cars/cheap-cars-under-10000-dollars-Naugatuck-Hartford-New-Haven-CT">
#              Used cars under $10,000
#             </a>
#            </li>
#            <li>
#             <a aria-label="$10,000 to $15,000" class="dropdown-toggle" data-hover="dropdown" href="https://www.jmautomotive.com/search-cars/deals-on-cars-under-15000-dollars">
#              $10,000 to $15,000
#             </a>
#            </li>
#            <li>
#             <a aria-label="$15,000 to $20,000" class="dropdown-toggle" data-hover="dropdown" href="https://www.jmautomotive.com/search-cars/deals-on-cars-under-20000-dollars">
#              $15,000 to $20,000
#             </a>
#            </li>
#            <li>
#             <a aria-label="Used cars over $20,000" class="dropdown-toggle" data-hover="dropdown" href="https://www.jmautomotive.com/search-cars/deals-on-cars-over-20000-dollars">
#              Used cars over $20,000
#             </a>
#            </li>
#           </ul>
#          </li>
#          <li class="dropdown" id="main_menu_3">
#           <a aria-expanded="false" aria-haspopup="true" aria-label="SERVICE DEPARTMENT" class="dropdown-toggle haschildren" data-hover="dropdown" href="#">
#            SERVICE DEPARTMENT
#           </a>
#           <span class="droparrow">
#            <span class="caretfont">
#             <i aria-hidden="true" class="fa fa-caret-down">
#             </i>
#            </span>
#           </span>
#           <ul class="sub_menu dropdown-menu">
#            <li>
#             <a aria-label="J&amp;M Service Department" class="dropdown-toggle" data-hover="dropdown" href="https://www.jmautomotive.com/Dealer-Websites/J+Mautomotive/servicedepartment.aspx">
#              J&amp;M Service Department
#             </a>
#            </li>
#           </ul>
#          </li>
#          <li class="dropdown" id="main_menu_4">
#           <a aria-label="VIDEO TOUR" class="dropdown-toggle" data-hover="dropdown" href="javascript:dwmaHdVideoShow()">
#            VIDEO TOUR
#           </a>
#          </li>
#          <li class="dropdown" id="main_menu_5">
#           <a aria-label="FINANCE" class="dropdown-toggle" data-hover="dropdown" href="https://www.jmautomotive.com/Dealer-Websites/J+Mautomotive/Get-Financing.aspx">
#            FINANCE
#           </a>
#          </li>
#          <li class="dropdown" id="main_menu_6">
#           <a aria-expanded="false" aria-haspopup="true" aria-label="ABOUT US" class="dropdown-toggle haschildren" data-hover="dropdown" href="https://www.jmautomotive.com/Dealer-Websites/J+Mautomotive/aboutus.aspx">
#            ABOUT US
#           </a>
#           <span class="droparrow">
#            <span class="caretfont">
#             <i aria-hidden="true" class="fa fa-caret-down">
#             </i>
#            </span>
#           </span>
#           <ul class="sub_menu dropdown-menu">
#            <li>
#             <a aria-label="Our staff" class="dropdown-toggle" data-hover="dropdown" href="https://www.jmautomotive.com/our-staff">
#              Our staff
#             </a>
#            </li>
#            <li>
#             <a aria-label="Contact us" class="dropdown-toggle" data-hover="dropdown" href="https://www.jmautomotive.com/contact-JandM-Automotive-SlsandSvc-LLC">
#              Contact us
#             </a>
#            </li>
#            <li>
#             <a aria-label="Driving directions" class="dropdown-toggle" data-hover="dropdown" href="https://www.jmautomotive.com/driving-directions-to-JandM-Automotive-SlsandSvc-LLC">
#              Driving directions
#             </a>
#            </li>
#            <li>
#             <a aria-label="Our warranties" class="dropdown-toggle" data-hover="dropdown" href="https://www.jmautomotive.com/used-car-warranty-service-contracts-Naugatuck-CT">
#              Our warranties
#             </a>
#            </li>
#            <li>
#             <a aria-label="Remote Purchase Process" class="dropdown-toggle" data-hover="dropdown" href="https://www.jmautomotive.com/Dealer-Websites/J+Mautomotive/remotePurchase.aspx">
#              Remote Purchase Process
#             </a>
#            </li>
#           </ul>
#          </li>
#          <li class="dropdown" id="main_menu_7">
#           <a aria-expanded="false" aria-haspopup="true" aria-label="REVIEWS" class="dropdown-toggle haschildren" data-hover="dropdown" href="https://www.jmautomotive.com/JandM-Automotive-SlsandSvc-LLC-reviews-testimonials">
#            REVIEWS
#           </a>
#           <span class="droparrow">
#            <span class="caretfont">
#             <i aria-hidden="true" class="fa fa-caret-down">
#             </i>
#            </span>
#           </span>
#           <ul class="sub_menu dropdown-menu">
#            <li>
#             <a aria-label="View reviews" class="dropdown-toggle" data-hover="dropdown" href="https://www.jmautomotive.com/JandM-Automotive-SlsandSvc-LLC-reviews-testimonials">
#              View reviews
#             </a>
#            </li>
#            <li>
#             <a aria-label="Submit one" class="dropdown-toggle" data-hover="dropdown" href='javascript:GE_DW_Set_myPopup_invoked_function("myPopup_Testimonial_Show");' role="button">
#              Submit one
#             </a>
#            </li>
#           </ul>
#          </li>
#          <li class="dropdown" id="main_menu_8">
#           <a aria-expanded="false" aria-haspopup="true" class="dropdown-toggle haschildren" data-hover="dropdown" href="javascript:void(0)">
#            <img alt="Google Transilator" id="Transilator" src="/Dealer-Websites/J+Mautomotive/images/language.gif"/>
#           </a>
#           <span class="droparrow">
#            <span class="caretfont">
#             <i aria-hidden="true" class="fa fa-caret-down">
#             </i>
#            </span>
#           </span>
#           <ul class="sub_menu dropdown-menu">
#            <li>
#             <a class="dropdown-toggle" data-hover="dropdown" href="javascript:void(0)">
#              <span id="Transilator_top">
#               Transilator
#              </span>
#             </a>
#            </li>
#           </ul>
#          </li>
#          <li class="dropdown" id="main_menu_end">
#           <a class="dropdown-toggle" data-hover="dropdown" href="javascript:void(0)">
#            <img alt="car fax" src="/Dealer-Websites/J+Mautomotive/images/topcarfaxmenu.png" title="car fax"/>
#           </a>
#          </li>
#         </ul>
#         <div class="dw-desk-hide">
#          <div class="dw-mob-contact-m">
#           <div class="dw-block">
#            756/820 New Haven Road
#           </div>
#           <div class="dw-block">
#            Naugatuck,
#            <span class="nbsp">
#            </span>
#            CT
#            <span class="nbsp" role="presentation">
#            </span>
#            06770
#           </div>
#           <div class="dw-block">
#            <a href="tel:2037235666" id="contactAdd_Phone">
#             (203) 723-5666
#            </a>
#           </div>
#           <div class="dw-block dw-hide-dd">
#            <a aria-label="Driving Directions(opens in a new tab)" href="https://maps.google.com/maps?f=q&amp;hl=en&amp;q=J%26M+Automotive+Sls%26Svc+LLC,756/820+New+Haven+Road,Naugatuck,CT+06770&amp;ie=UTF8&amp;om=1&amp;maptype=terrain" id="contactAdd_Direction" target="_blank">
#             Driving Directions
#            </a>
#           </div>
#          </div>
#          <div id="Mob_ExtraDiv">
#          </div>
#          <div class="googletransMob" id="google_translate_element_mob">
#          </div>
#         </div>
#        </div>
#       </div>
#      </nav>
#     </div>
#    </div>
#    <form action="Dealer-Websites/J+Mautomotive/inventory.aspx?key=vstatus%3d1&amp;status=6" aria-label="inventory" id="searchform" method="post" name="searchform">
#     <div>
#      <input id="__VIEWSTATE" name="__VIEWSTATE" type="hidden" value="kYksNeqYf+mwJeNXHnchvBsMAsQEHpzKldvLfK2ryW+S7O/ZGRi0pVqzcQEZDybtlJ6CL4JQkpIg1MfP7ZBLxeubu+yfn3Rfnfh0qqNM7dU="/>
#     </div>
#     <div>
#      <input id="__VIEWSTATEGENERATOR" name="__VIEWSTATEGENERATOR" type="hidden" value="4D9B6F97"/>
#     </div>
#     <div aria-hidden="true" class="modal fade" id="div_myPopup_AFDWVideo" role="dialog" tabindex="-1">
#      <div class="modal-dialog" id="div-modal-dialog">
#       <div class="modal-content">
#        <div class="modal-header">
#         <button aria-hidden="true" class="close" data-dismiss="modal" id="dw-video-close" tabindex="-1" type="button">
#          ×
#         </button>
#         <h4>
#          Watch Video
#         </h4>
#        </div>
#        <div class="modal-body video-container" id="div_myPopup_AFDWVideoCnt">
#        </div>
#       </div>
#      </div>
#     </div>
#     <div aria-hidden="true" class="modal fade" id="div_myPopup_AFDWPhoto" role="dialog" tabindex="-1">
#      <div class="modal-dialog dw-modal-dialog-photo">
#       <div class="modal-content">
#        <div class="modal-header">
#         <button aria-hidden="true" class="close" data-dismiss="modal" tabindex="-1" type="button">
#          ×
#         </button>
#         <h4>
#          Inventory Images
#         </h4>
#        </div>
#        <div class="modal-body" id="div_myPopup_AFDWPhotoCnt">
#        </div>
#       </div>
#      </div>
#     </div>
#     <div aria-hidden="true" class="modal fade" id="myPopup_AdvanceSearch_Show" role="dialog" tabindex="-1">
#      <div class="modal-dialog modal-dialog-adv">
#       <div class="modal-content">
#        <div class="modal-header">
#         <button aria-hidden="true" class="close" data-dismiss="modal" tabindex="-1" type="button">
#          ×
#         </button>
#         <h4 id="div_Popup_AdvanceSearch_Title">
#          ADVANCED SEARCH
#         </h4>
#        </div>
#        <div class="modal-body" id="myPopup_AdvanceSearch_Body">
#         <div class="row">
#          <div class="col-lg-12">
#           <div class="ExpandColapaseAll" id="ExpandColapaseAll">
#            <a href="javascript:void(0)" id="expandAll" onclick="inventoryShowMore('-1')">
#             <span>
#              Expand All
#             </span>
#            </a>
#            <span class="nbsp">
#            </span>
#            |
#            <span class="nbspR">
#            </span>
#            <a href="javascript:void(0)" id="collapseAll" onclick="inventoryShowMore('-2')">
#             <span>
#              Collapse All
#             </span>
#            </a>
#           </div>
#           <div class="adv_RangeSlider">
#            <div class="col-sm-12 advSearchSlider">
#             <div class="wpas-range_1 wpas-generic-field wpas-field" id="wpas-range_1">
#              <div class="label-container">
#               <label for="range_1">
#                By Price
#                <i class="icon-help-circled-1 tooltip hide-on-change">
#                </i>
#               </label>
#              </div>
#              <input id="range_1" name="range_1" type="text" value="0;80000"/>
#             </div>
#            </div>
#            <div class="col-sm-12 advSearchSlider">
#             <div class="wpas-range_1 wpas-generic-field wpas-field" id="wpas-range_2">
#              <div class="label-container">
#               <label for="range_2">
#                By Year
#                <i class="icon-help-circled-1 tooltip hide-on-change">
#                </i>
#               </label>
#              </div>
#              <input id="range_2" name="range_2" type="text" value="2000;2016"/>
#             </div>
#            </div>
#            <div class="col-sm-12 advSearchSlider">
#             <div class="wpas-range_1 wpas-generic-field wpas-field" id="wpas-range_3">
#              <div class="label-container">
#               <label for="range_3">
#                By Mileage
#                <i class="icon-help-circled-1 tooltip hide-on-change">
#                </i>
#               </label>
#              </div>
#              <input id="range_3" name="range_3" type="text" value="0;80000"/>
#             </div>
#            </div>
#           </div>
#           <div class="adv_searchType">
#            <div class="col-sm-12 advSearchColorType">
#             <div class="SR_boder">
#              <div class="addSearch">
#               <div>
#                <h5>
#                 By Color
#                </h5>
#               </div>
#               <div class="chkbox">
#                <label>
#                 <input checked="checked" class="CB_AdvSearchPopup" id="chkcolor" name="chkcolor" onclick="setColorBodyAll('chkcolor')" type="checkbox" value="C_All"/>
#                 <strong class="p">
#                  Select all
#                 </strong>
#                </label>
#               </div>
#              </div>
#              <div class="addSearchR" id="adSearchColor">
#              </div>
#             </div>
#            </div>
#            <div class="col-sm-12 advSearchBodyType">
#             <div class="SR_boder">
#              <div class="addSearch">
#               <div>
#                <h5>
#                 By Body Types
#                </h5>
#               </div>
#               <div class="chkbox">
#                <label>
#                 <input checked="checked" class="CB_AdvSearchPopup" id="chkbodyt" name="chkbodyt" onclick="setColorBodyAll('chkbodyt')" type="checkbox" value="B_All"/>
#                 <strong class="p">
#                  Select all
#                 </strong>
#                </label>
#               </div>
#              </div>
#              <div class="addSearchR" id="addSearchRBodyType">
#              </div>
#             </div>
#            </div>
#           </div>
#           <div class="dw-cseachbtn" id="div_addsearchSend">
#            <div class="dw-addDW_send01">
#             <a class="btn btn-primary pull-right" href="javascript:void(0)" id="addbtnSend" onclick="showVechicle()">
#              <i class="fa fa-send fa-btn">
#              </i>
#              Submit
#             </a>
#            </div>
#           </div>
#           <div class="col-sm-12 wpas-field" id="dw-adsfilterlist">
#            <div class="addSearch dw-addSearch">
#            </div>
#            <div class="addSearchR">
#             <div id="divsearch">
#              <table role="presentation">
#               <tbody>
#                <tr>
#                 <td class="valignTop240">
#                  <div class="valignTop240" id="MakeSearch1">
#                  </div>
#                 </td>
#                 <td class="valignTop240">
#                  <div class="valignTop240" id="MakeSearch2">
#                  </div>
#                 </td>
#                 <td class="valignTop240">
#                  <div class="valignTop240" id="MakeSearch3">
#                  </div>
#                 </td>
#                </tr>
#               </tbody>
#              </table>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div aria-hidden="true" class="modal fade" id="myPopup_Vehicle_History" role="dialog" tabindex="-1">
#      <div class="modal-dialog" id="vehicle-history-modal-dialog">
#       <div class="modal-content">
#        <div class="modal-header">
#         <button aria-hidden="true" class="close" data-dismiss="modal" tabindex="-1" type="button">
#          ×
#         </button>
#         <h4>
#          Vehicle History
#         </h4>
#        </div>
#        <div class="modal-body" id="myPopup_Vehicle_History_Body">
#        </div>
#       </div>
#      </div>
#     </div>
#     <div aria-hidden="true" class="modal fade" id="div_myPopup_AFDWUrlImage360" role="dialog" tabindex="-1">
#      <div class="modal-dialog" id="div-modal-dialog-UrlImage360">
#       <div class="modal-content">
#        <div class="modal-header">
#         <button aria-hidden="true" class="close" data-dismiss="modal" id="dw-UrlImage360-close" tabindex="-1" type="button">
#          ×
#         </button>
#         <h4>
#          360° view of the exterior
#         </h4>
#        </div>
#        <div class="modal-body UrlImage360-container" id="div_myPopup_AFDWUrlImage360Cnt">
#        </div>
#       </div>
#      </div>
#     </div>
#     <div aria-hidden="true" class="modal fade" id="myPopup_Request_ConfirmAvail" role="dialog" tabindex="-1">
#      <div class="modal-dialog">
#       <div class="modal-content">
#        <div class="modal-header" id="myPopup_Request_ConfirmAvail_header">
#         <button aria-hidden="true" class="close" data-dismiss="modal" tabindex="-1" type="button">
#          ×
#         </button>
#         <h4>
#          CONFIRM AVAILABILITY
#         </h4>
#        </div>
#        <div class="modal-body" id="myPopup_Request_ConfirmAvail_body">
#         <div id="loader">
#          <img alt="loader" src="/1/images/ajax-loader.gif"/>
#         </div>
#         <div class="myPopup_bodyHead" id="myPopup_bodyHead">
#          <b>
#           INTERESTED VEHICLE
#          </b>
#         </div>
#         <div id="myPopup_Request_ConfirmAvail_bodyText">
#         </div>
#         <div id="myPopup_ConfirmAvail_body">
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="contentbg make_False model_False" id="divcontentinv">
#      <div class="contentbg0">
#       <div class="container cover002">
#        <div class="panel panel-primary ClsMobile_False" id="divInvMakeContainer">
#         <div class="panel-heading" id="divInvHeading">
#          <div class="panel-title bdr-btm1" id="MidH1Text">
#           INVENTORY
#          </div>
#         </div>
#         <div class="panel-body" id="divMakeListing">
#          <div class="MakesDiv">
#           <a href="https://www.jmautomotive.com/used/make/Acura/Naugatuck/CT/Waterbury/Hartford/New-Haven/NEW-HAVEN" title="8 Acura for sale in Naugatuck, CT 06770 | J&amp;M Automotive Sls&amp;Svc LLC. Naugatuck, Connecticut">
#            <div class="Lst-car">
#             <strong class="badge">
#              8
#             </strong>
#             <span class="dw-makes">
#              Acura
#             </span>
#            </div>
#           </a>
#          </div>
#          <div class="MakesDiv">
#           <a href="https://www.jmautomotive.com/used/make/Audi/Naugatuck/CT/Waterbury/Hartford/New-Haven/NEW-HAVEN" title="23 Audi for sale in Naugatuck, CT 06770 | J&amp;M Automotive Sls&amp;Svc LLC. Naugatuck, Connecticut">
#            <div class="Lst-car">
#             <strong class="badge">
#              23
#             </strong>
#             <span class="dw-makes">
#              Audi
#             </span>
#            </div>
#           </a>
#          </div>
#          <div class="MakesDiv">
#           <a href="https://www.jmautomotive.com/used/make/BMW/Naugatuck/CT/Waterbury/Hartford/New-Haven/NEW-HAVEN" title="14 BMW for sale in Naugatuck, CT 06770 | J&amp;M Automotive Sls&amp;Svc LLC. Naugatuck, Connecticut">
#            <div class="Lst-car">
#             <strong class="badge">
#              14
#             </strong>
#             <span class="dw-makes">
#              BMW
#             </span>
#            </div>
#           </a>
#          </div>
#          <div class="MakesDiv">
#           <a href="https://www.jmautomotive.com/used/make/Buick/Naugatuck/CT/Waterbury/Hartford/New-Haven/NEW-HAVEN" title="7 Buick for sale in Naugatuck, CT 06770 | J&amp;M Automotive Sls&amp;Svc LLC. Naugatuck, Connecticut">
#            <div class="Lst-car">
#             <strong class="badge">
#              7
#             </strong>
#             <span class="dw-makes">
#              Buick
#             </span>
#            </div>
#           </a>
#          </div>
#          <div class="MakesDiv">
#           <a href="https://www.jmautomotive.com/used/make/Cadillac/Naugatuck/CT/Waterbury/Hartford/New-Haven/NEW-HAVEN" title="8 Cadillac for sale in Naugatuck, CT 06770 | J&amp;M Automotive Sls&amp;Svc LLC. Naugatuck, Connecticut">
#            <div class="Lst-car">
#             <strong class="badge">
#              8
#             </strong>
#             <span class="dw-makes">
#              Cadillac
#             </span>
#            </div>
#           </a>
#          </div>
#          <div class="MakesDiv">
#           <a href="https://www.jmautomotive.com/used/make/Chevrolet/Naugatuck/CT/Waterbury/Hartford/New-Haven/NEW-HAVEN" title="25 Chevrolet for sale in Naugatuck, CT 06770 | J&amp;M Automotive Sls&amp;Svc LLC. Naugatuck, Connecticut">
#            <div class="Lst-car">
#             <strong class="badge">
#              25
#             </strong>
#             <span class="dw-makes">
#              Chevrolet
#             </span>
#            </div>
#           </a>
#          </div>
#          <div class="MakesDiv">
#           <a href="https://www.jmautomotive.com/used/make/Chrysler/Naugatuck/CT/Waterbury/Hartford/New-Haven/NEW-HAVEN" title="7 Chrysler for sale in Naugatuck, CT 06770 | J&amp;M Automotive Sls&amp;Svc LLC. Naugatuck, Connecticut">
#            <div class="Lst-car">
#             <strong class="badge">
#              7
#             </strong>
#             <span class="dw-makes">
#              Chrysler
#             </span>
#            </div>
#           </a>
#          </div>
#          <div class="MakesDiv">
#           <a href="https://www.jmautomotive.com/used/make/Dodge/Naugatuck/CT/Waterbury/Hartford/New-Haven/NEW-HAVEN" title="13 Dodge for sale in Naugatuck, CT 06770 | J&amp;M Automotive Sls&amp;Svc LLC. Naugatuck, Connecticut">
#            <div class="Lst-car">
#             <strong class="badge">
#              13
#             </strong>
#             <span class="dw-makes">
#              Dodge
#             </span>
#            </div>
#           </a>
#          </div>
#          <div class="MakesDiv">
#           <a href="https://www.jmautomotive.com/used/make/Fiat/Naugatuck/CT/Waterbury/Hartford/New-Haven/NEW-HAVEN" title="4 Fiat for sale in Naugatuck, CT 06770 | J&amp;M Automotive Sls&amp;Svc LLC. Naugatuck, Connecticut">
#            <div class="Lst-car">
#             <strong class="badge">
#              4
#             </strong>
#             <span class="dw-makes">
#              Fiat
#             </span>
#            </div>
#           </a>
#          </div>
#          <div class="MakesDiv">
#           <a href="https://www.jmautomotive.com/used/make/Ford/Naugatuck/CT/Waterbury/Hartford/New-Haven/NEW-HAVEN" title="43 Ford for sale in Naugatuck, CT 06770 | J&amp;M Automotive Sls&amp;Svc LLC. Naugatuck, Connecticut">
#            <div class="Lst-car">
#             <strong class="badge">
#              43
#             </strong>
#             <span class="dw-makes">
#              Ford
#             </span>
#            </div>
#           </a>
#          </div>
#          <div class="MakesDiv">
#           <a href="https://www.jmautomotive.com/used/make/GMC/Naugatuck/CT/Waterbury/Hartford/New-Haven/NEW-HAVEN" title="11 GMC for sale in Naugatuck, CT 06770 | J&amp;M Automotive Sls&amp;Svc LLC. Naugatuck, Connecticut">
#            <div class="Lst-car">
#             <strong class="badge">
#              11
#             </strong>
#             <span class="dw-makes">
#              GMC
#             </span>
#            </div>
#           </a>
#          </div>
#          <div class="MakesDiv">
#           <a href="https://www.jmautomotive.com/used/make/Honda/Naugatuck/CT/Waterbury/Hartford/New-Haven/NEW-HAVEN" title="38 Honda for sale in Naugatuck, CT 06770 | J&amp;M Automotive Sls&amp;Svc LLC. Naugatuck, Connecticut">
#            <div class="Lst-car">
#             <strong class="badge">
#              38
#             </strong>
#             <span class="dw-makes">
#              Honda
#             </span>
#            </div>
#           </a>
#          </div>
#          <div class="MakesDiv">
#           <a href="https://www.jmautomotive.com/used/make/Hyundai/Naugatuck/CT/Waterbury/Hartford/New-Haven/NEW-HAVEN" title="17 Hyundai for sale in Naugatuck, CT 06770 | J&amp;M Automotive Sls&amp;Svc LLC. Naugatuck, Connecticut">
#            <div class="Lst-car">
#             <strong class="badge">
#              17
#             </strong>
#             <span class="dw-makes">
#              Hyundai
#             </span>
#            </div>
#           </a>
#          </div>
#          <div class="MakesDiv">
#           <a href="https://www.jmautomotive.com/used/make/Infiniti/Naugatuck/CT/Waterbury/Hartford/New-Haven/NEW-HAVEN" title="13 Infiniti for sale in Naugatuck, CT 06770 | J&amp;M Automotive Sls&amp;Svc LLC. Naugatuck, Connecticut">
#            <div class="Lst-car">
#             <strong class="badge">
#              13
#             </strong>
#             <span class="dw-makes">
#              Infiniti
#             </span>
#            </div>
#           </a>
#          </div>
#          <div class="MakesDiv">
#           <a href="https://www.jmautomotive.com/used/make/Jeep/Naugatuck/CT/Waterbury/Hartford/New-Haven/NEW-HAVEN" title="28 Jeep for sale in Naugatuck, CT 06770 | J&amp;M Automotive Sls&amp;Svc LLC. Naugatuck, Connecticut">
#            <div class="Lst-car">
#             <strong class="badge">
#              28
#             </strong>
#             <span class="dw-makes">
#              Jeep
#             </span>
#            </div>
#           </a>
#          </div>
#          <div class="MakesDiv">
#           <a href="https://www.jmautomotive.com/used/make/Kia/Naugatuck/CT/Waterbury/Hartford/New-Haven/NEW-HAVEN" title="11 Kia for sale in Naugatuck, CT 06770 | J&amp;M Automotive Sls&amp;Svc LLC. Naugatuck, Connecticut">
#            <div class="Lst-car">
#             <strong class="badge">
#              11
#             </strong>
#             <span class="dw-makes">
#              Kia
#             </span>
#            </div>
#           </a>
#          </div>
#          <div class="MakesDiv">
#           <a href="https://www.jmautomotive.com/used/make/Land+Rover/Naugatuck/CT/Waterbury/Hartford/New-Haven/NEW-HAVEN" title="1 Land Rover for sale in Naugatuck, CT 06770 | J&amp;M Automotive Sls&amp;Svc LLC. Naugatuck, Connecticut">
#            <div class="Lst-car">
#             <strong class="badge">
#              1
#             </strong>
#             <span class="dw-makes">
#              Land Rover
#             </span>
#            </div>
#           </a>
#          </div>
#          <div class="MakesDiv">
#           <a href="https://www.jmautomotive.com/used/make/Lexus/Naugatuck/CT/Waterbury/Hartford/New-Haven/NEW-HAVEN" title="13 Lexus for sale in Naugatuck, CT 06770 | J&amp;M Automotive Sls&amp;Svc LLC. Naugatuck, Connecticut">
#            <div class="Lst-car">
#             <strong class="badge">
#              13
#             </strong>
#             <span class="dw-makes">
#              Lexus
#             </span>
#            </div>
#           </a>
#          </div>
#          <div class="MakesDiv">
#           <a href="https://www.jmautomotive.com/used/make/Lincoln/Naugatuck/CT/Waterbury/Hartford/New-Haven/NEW-HAVEN" title="6 Lincoln for sale in Naugatuck, CT 06770 | J&amp;M Automotive Sls&amp;Svc LLC. Naugatuck, Connecticut">
#            <div class="Lst-car">
#             <strong class="badge">
#              6
#             </strong>
#             <span class="dw-makes">
#              Lincoln
#             </span>
#            </div>
#           </a>
#          </div>
#          <div class="MakesDiv">
#           <a href="https://www.jmautomotive.com/used/make/Mazda/Naugatuck/CT/Waterbury/Hartford/New-Haven/NEW-HAVEN" title="14 Mazda for sale in Naugatuck, CT 06770 | J&amp;M Automotive Sls&amp;Svc LLC. Naugatuck, Connecticut">
#            <div class="Lst-car">
#             <strong class="badge">
#              14
#             </strong>
#             <span class="dw-makes">
#              Mazda
#             </span>
#            </div>
#           </a>
#          </div>
#          <div class="MakesDiv">
#           <a href="https://www.jmautomotive.com/used/make/Mercedes-benz/Naugatuck/CT/Waterbury/Hartford/New-Haven/NEW-HAVEN" title="12 Mercedes-benz for sale in Naugatuck, CT 06770 | J&amp;M Automotive Sls&amp;Svc LLC. Naugatuck, Connecticut">
#            <div class="Lst-car">
#             <strong class="badge">
#              12
#             </strong>
#             <span class="dw-makes">
#              Mercedes-benz
#             </span>
#            </div>
#           </a>
#          </div>
#          <div class="MakesDiv">
#           <a href="https://www.jmautomotive.com/used/make/Mini/Naugatuck/CT/Waterbury/Hartford/New-Haven/NEW-HAVEN" title="8 Mini for sale in Naugatuck, CT 06770 | J&amp;M Automotive Sls&amp;Svc LLC. Naugatuck, Connecticut">
#            <div class="Lst-car">
#             <strong class="badge">
#              8
#             </strong>
#             <span class="dw-makes">
#              Mini
#             </span>
#            </div>
#           </a>
#          </div>
#          <div class="MakesDiv">
#           <a href="https://www.jmautomotive.com/used/make/Mitsubishi/Naugatuck/CT/Waterbury/Hartford/New-Haven/NEW-HAVEN" title="2 Mitsubishi for sale in Naugatuck, CT 06770 | J&amp;M Automotive Sls&amp;Svc LLC. Naugatuck, Connecticut">
#            <div class="Lst-car">
#             <strong class="badge">
#              2
#             </strong>
#             <span class="dw-makes">
#              Mitsubishi
#             </span>
#            </div>
#           </a>
#          </div>
#          <div class="MakesDiv">
#           <a href="https://www.jmautomotive.com/used/make/Nissan/Naugatuck/CT/Waterbury/Hartford/New-Haven/NEW-HAVEN" title="22 Nissan for sale in Naugatuck, CT 06770 | J&amp;M Automotive Sls&amp;Svc LLC. Naugatuck, Connecticut">
#            <div class="Lst-car">
#             <strong class="badge">
#              22
#             </strong>
#             <span class="dw-makes">
#              Nissan
#             </span>
#            </div>
#           </a>
#          </div>
#          <div class="MakesDiv">
#           <a href="https://www.jmautomotive.com/used/make/Ram/Naugatuck/CT/Waterbury/Hartford/New-Haven/NEW-HAVEN" title="12 Ram for sale in Naugatuck, CT 06770 | J&amp;M Automotive Sls&amp;Svc LLC. Naugatuck, Connecticut">
#            <div class="Lst-car">
#             <strong class="badge">
#              12
#             </strong>
#             <span class="dw-makes">
#              Ram
#             </span>
#            </div>
#           </a>
#          </div>
#          <div class="MakesDiv">
#           <a href="https://www.jmautomotive.com/used/make/Scion/Naugatuck/CT/Waterbury/Hartford/New-Haven/NEW-HAVEN" title="1 Scion for sale in Naugatuck, CT 06770 | J&amp;M Automotive Sls&amp;Svc LLC. Naugatuck, Connecticut">
#            <div class="Lst-car">
#             <strong class="badge">
#              1
#             </strong>
#             <span class="dw-makes">
#              Scion
#             </span>
#            </div>
#           </a>
#          </div>
#          <div class="MakesDiv">
#           <a href="https://www.jmautomotive.com/used/make/Subaru/Naugatuck/CT/Waterbury/Hartford/New-Haven/NEW-HAVEN" title="24 Subaru for sale in Naugatuck, CT 06770 | J&amp;M Automotive Sls&amp;Svc LLC. Naugatuck, Connecticut">
#            <div class="Lst-car">
#             <strong class="badge">
#              24
#             </strong>
#             <span class="dw-makes">
#              Subaru
#             </span>
#            </div>
#           </a>
#          </div>
#          <div class="MakesDiv">
#           <a href="https://www.jmautomotive.com/used/make/Toyota/Naugatuck/CT/Waterbury/Hartford/New-Haven/NEW-HAVEN" title="33 Toyota for sale in Naugatuck, CT 06770 | J&amp;M Automotive Sls&amp;Svc LLC. Naugatuck, Connecticut">
#            <div class="Lst-car">
#             <strong class="badge">
#              33
#             </strong>
#             <span class="dw-makes">
#              Toyota
#             </span>
#            </div>
#           </a>
#          </div>
#          <div class="MakesDiv">
#           <a href="https://www.jmautomotive.com/used/make/Volkswagen/Naugatuck/CT/Waterbury/Hartford/New-Haven/NEW-HAVEN" title="32 Volkswagen for sale in Naugatuck, CT 06770 | J&amp;M Automotive Sls&amp;Svc LLC. Naugatuck, Connecticut">
#            <div class="Lst-car">
#             <strong class="badge">
#              32
#             </strong>
#             <span class="dw-makes">
#              Volkswagen
#             </span>
#            </div>
#           </a>
#          </div>
#          <div class="MakesDiv">
#           <a href="https://www.jmautomotive.com/used/make/Volvo/Naugatuck/CT/Waterbury/Hartford/New-Haven/NEW-HAVEN" title="5 Volvo for sale in Naugatuck, CT 06770 | J&amp;M Automotive Sls&amp;Svc LLC. Naugatuck, Connecticut">
#            <div class="Lst-car">
#             <strong class="badge">
#              5
#             </strong>
#             <span class="dw-makes">
#              Volvo
#             </span>
#            </div>
#           </a>
#          </div>
#         </div>
#        </div>
#        <div class="navbar-inverse" id="divFilterButton">
#         FILTER
#         <i class="fa fa-filter">
#         </i>
#        </div>
#        <div class="invpaging ClsMobile_False" id="invpaging">
#         <div id="ipages">
#          <div class="dwfloatL">
#           <strong>
#            Now viewing: Vehicle Status » Used
#           </strong>
#           <span>
#            |
#           </span>
#           <strong>
#            1 - 50
#           </strong>
#           <span>
#            of
#           </span>
#           <strong id="inv_maxCount">
#            455
#           </strong>
#           <span>
#            |
#           </span>
#           <a href="https://www.jmautomotive.com/inventory.aspx?pg=2&amp;sort=12&amp;limit=50&amp;vstatus=1&amp;status=6">
#            Next
#           </a>
#           <span>
#            |
#           </span>
#           <span>
#            Page(s)
#           </span>
#           <a class="pageLinkActive" href="https://www.jmautomotive.com/inventory.aspx?pg=1&amp;sort=12&amp;limit=50&amp;vstatus=1&amp;status=6" id="ipg1">
#            1
#           </a>
#           <a class="pageLink" href="https://www.jmautomotive.com/inventory.aspx?pg=2&amp;sort=12&amp;limit=50&amp;vstatus=1&amp;status=6" id="ipg2">
#            2
#           </a>
#           <a class="pageLink" href="https://www.jmautomotive.com/inventory.aspx?pg=3&amp;sort=12&amp;limit=50&amp;vstatus=1&amp;status=6" id="ipg3">
#            3
#           </a>
#           <a class="pageLink" href="https://www.jmautomotive.com/inventory.aspx?pg=4&amp;sort=12&amp;limit=50&amp;vstatus=1&amp;status=6" id="ipg4">
#            4
#           </a>
#           <a class="pageLink" href="https://www.jmautomotive.com/inventory.aspx?pg=5&amp;sort=12&amp;limit=50&amp;vstatus=1&amp;status=6" id="ipg5">
#            5
#           </a>
#           <a class="pageLink" href="https://www.jmautomotive.com/inventory.aspx?pg=6&amp;sort=12&amp;limit=50&amp;vstatus=1&amp;status=6" id="ipg6">
#            6
#           </a>
#           <a class="pageLink" href="https://www.jmautomotive.com/inventory.aspx?pg=7&amp;sort=12&amp;limit=50&amp;vstatus=1&amp;status=6" id="ipg7">
#            7
#           </a>
#           <a class="pageLink" href="https://www.jmautomotive.com/inventory.aspx?pg=8&amp;sort=12&amp;limit=50&amp;vstatus=1&amp;status=6" id="ipg8">
#            8
#           </a>
#           <a class="pageLink" href="https://www.jmautomotive.com/inventory.aspx?pg=9&amp;sort=12&amp;limit=50&amp;vstatus=1&amp;status=6" id="ipg9">
#            9
#           </a>
#           <a class="pageLink" href="https://www.jmautomotive.com/inventory.aspx?pg=10&amp;sort=12&amp;limit=50&amp;vstatus=1&amp;status=6" id="ipg10">
#            10
#           </a>
#           <span>
#            of
#           </span>
#           <strong>
#            10
# ...
#     <div class="col-lg-3 col-md-3 dw-col-1 dw-p0 dw-m-hide">
#      <h2>
#       About J&amp;M Automotive Sls&amp;Svc LLC
#      </h2>
#      <ul>
#       <li>
#        <a aria-label="Our staff" class="dropdown-toggle" data-hover="dropdown" href="https://www.jmautomotive.com/our-staff">
#         Our staff
#        </a>
#       </li>
#       <li>
#        <a aria-label="Contact us" class="dropdown-toggle" data-hover="dropdown" href="https://www.jmautomotive.com/contact-JandM-Automotive-SlsandSvc-LLC">
#         Contact us
#        </a>
#       </li>
#       <li>
#        <a aria-label="Driving directions" class="dropdown-toggle" data-hover="dropdown" href="https://www.jmautomotive.com/driving-directions-to-JandM-Automotive-SlsandSvc-LLC">
#         Driving directions
#        </a>
#       </li>
#       <li>
#        <a aria-label="Our warranties" class="dropdown-toggle" data-hover="dropdown" href="https://www.jmautomotive.com/used-car-warranty-service-contracts-Naugatuck-CT">
#         Our warranties
#        </a>
#       </li>
#       <li>
#        <a aria-label="Remote Purchase Process" class="dropdown-toggle" data-hover="dropdown" href="https://www.jmautomotive.com/Dealer-Websites/J+Mautomotive/remotePurchase.aspx">
#         Remote Purchase Process
#        </a>
#       </li>
#      </ul>
#     </div>
#     <div class="col-lg-3 col-md-3 dw-col-2 dw-p0 dw-m-hide">
#      <h2>
#       J&amp;M Automotive Sls&amp;Svc LLC Inventory tools
#      </h2>
#      <ul>
#       <li>
#        <a aria-label="View used cars" class="dropdown-toggle" data-hover="dropdown" href="https://www.jmautomotive.com/cars-for-sale-in-Naugatuck-CT-Hartford-New-Haven/used_cars">
#         View used cars
#        </a>
#       </li>
#       <li>
#        <a aria-label="Featured used cars" class="dropdown-toggle" data-hover="dropdown" href="https://www.jmautomotive.com/search-cars/featured-used-cars-JandM-Automotive-SlsandSvc-LLC">
#         Featured used cars
#        </a>
#       </li>
#       <li>
#        <a aria-label="Used car finder" class="dropdown-toggle" data-hover="dropdown" href="https://www.jmautomotive.com/find-car-for-me">
#         Used car finder
#        </a>
#       </li>
#       <li>
#        <a aria-label="Used cars under $10,000" class="dropdown-toggle" data-hover="dropdown" href="https://www.jmautomotive.com/search-cars/cheap-cars-under-10000-dollars-Naugatuck-Hartford-New-Haven-CT">
#         Used cars under $10,000
#        </a>
#       </li>
#       <li>
#        <a aria-label="$10,000 to $15,000" class="dropdown-toggle" data-hover="dropdown" href="https://www.jmautomotive.com/search-cars/deals-on-cars-under-15000-dollars">
#         $10,000 to $15,000
#        </a>
#       </li>
#       <li>
#        <a aria-label="$15,000 to $20,000" class="dropdown-toggle" data-hover="dropdown" href="https://www.jmautomotive.com/search-cars/deals-on-cars-under-20000-dollars">
#         $15,000 to $20,000
#        </a>
#       </li>
#       <li>
#        <a aria-label="Used cars over $20,000" class="dropdown-toggle" data-hover="dropdown" href="https://www.jmautomotive.com/search-cars/deals-on-cars-over-20000-dollars">
#         Used cars over $20,000
#        </a>
#       </li>
#      </ul>
#     </div>
#     <div class="col-lg-3 col-md-3 dw-col-3 dw-p0 dw-m-hide">
#      <h2>
#       <a href="https://www.jmautomotive.com">
#        www.jmautomotive.com
#       </a>
#      </h2>
#      <ul>
#       <li>
#        <a href="https://www.jmautomotive.com/cars-for-sale-in-Naugatuck-CT-Waterbury-Hartford/used_cars">
#         Vehicle inventory
#        </a>
#       </li>
#       <li>
#        <a href="https://www.jmautomotive.com/sitemap.aspx">
#         Sitemap
#        </a>
#       </li>
#       <li>
#        <a href="https://www.jmautomotive.com/privacy-policy" rel="nofollow">
#         Privacy policy
#        </a>
#       </li>
#      </ul>
#     </div>
#     <div class="col-lg-3 col-md-3 dw-col-4 dw-p0 dw-m-hide">
#      <h2>
#       J&amp;M Automotive Sls&amp;Svc LLC
#      </h2>
#      <ul id="dw-address">
#       <li class="l1">
#        <p>
#         756/820 New Haven Road
#        </p>
#       </li>
#       <li class="l2">
#        Naugatuck,
#        <span class="nbsp" role="presentation">
#        </span>
#        CT
#        <span class="nbsp" role="presentation">
#        </span>
#        06770
#        <span class="nbsp" role="presentation">
#        </span>
#        <span class="dw-hide-dd">
#         |
#        </span>
#        <span class="nbsp" role="presentation">
#        </span>
#        <a aria-label="Driving Directions(opens in a new tab)" class="dw-hide-dd" href="https://maps.google.com/maps?f=q&amp;hl=en&amp;q=J%26M+Automotive+Sls%26Svc+LLC,756/820+New+Haven+Road,Naugatuck,CT+06770&amp;ie=UTF8&amp;om=1&amp;maptype=terrain" id="dw-contGoogLinkFoot01" target="_blank">
#         Driving Directions
#        </a>
#       </li>
#       <li class="l3">
#        <p>
#         <i class="fa-lg fa fa-phone-square" role="presentation">
#         </i>
#         <span>
#          <span class="nbsp" role="presentation">
#          </span>
#          <span class="nbsp" role="presentation">
#          </span>
#          Tel:
#         </span>
#         <a href="tel:2037235666">
#          (203) 723-5666
#         </a>
#        </p>
#       </li>
#       <li class="l4">
#        <p>
#         <i class="fa-lg fa fa-fax" role="presentation">
#         </i>
#         <span>
#          <span class="nbsp" role="presentation">
#          </span>
#          <span class="nbsp" role="presentation">
#          </span>
#          Fax:
#         </span>
#         <a href="tel:2037231937">
#          (203) 723-1937
#         </a>
#        </p>
#       </li>
#      </ul>
#      <div class="dw-block">
#       <a aria-label="Rss" href="https://www.jmautomotive.com/rss.aspx" id="IconRssF" target="_blank">
#        <i class="fa-lg fa dw-icon fa-rss">
#        </i>
#       </a>
#       <a aria-label="Facebook" href="https://www.facebook.com/pages/JM-Automotive-SlsSvc-LLC/159851630780993" id="IconFacebookF" target="_blank">
#        <i class="fa-lg fa dw-icon fa-facebook">
#        </i>
#       </a>
#       <a aria-label="Instagram" href="https://www.instagram.com/jmautomotivenaugatuck/" id="IconInstagramF" target="_blank">
#        <i class="fa-lg fa dw-icon fa-instagram">
#        </i>
#       </a>
#      </div>
#     </div>
#     <div class="dw-block dw-sub-footer">
#      <h4 class="dw-copyright">
#       <span>
#        All rights reserved. © 2003-2022
#       </span>
#       <span>
#        <a href="https://www.jmautomotive.com" title="Used car dealer in Naugatuck | J&amp;M Automotive Sls&amp;Svc LLC. Naugatuck Connecticut">
#         J&amp;M Automotive Sls&amp;Svc LLC
#        </a>
#       </span>
#       <span>
#        <a aria-label="Autofunds - Dealership Management Software(opens in new tab)" href="//www.autofunds.com" target="_blank">
#         Autofunds - Dealership Management Software
#        </a>
#       </span>
#      </h4>
#     </div>
#    </div>
#    <div class="dw-block dw-bottom-bar dw-m-hide">
#     <div class="dw-recent">
#      <span class="dw-recent-c" id="dw-recently-bar" role="button" tabindex="0">
#       Recently viewed
#       <span>
#        (0)
#       </span>
#      </span>
#      <span class="dw-bot-translate" id="google_translate_element" role="presentation">
#      </span>
#     </div>
#     <div id="dw-recently-bar-outer-cont">
#      <div id="dw-recently-bar-cont">
#      </div>
#     </div>
#    </div>
#    <div class="dw-none dw-dealership-info" id="dw-dealership">
#     <input id="hdnDealerID" type="hidden" value="467"/>
#     <input id="hdnDealerName" type="hidden" value="J&amp;M Automotive Sls&amp;Svc LLC"/>
#     <input id="hdnDealersiteFolder" type="hidden" value="Dealer-Websites/J+Mautomotive"/>
#     <input id="hdnDealerSiteUrl" type="hidden" value="https://www.jmautomotive.com"/>
#     <input id="hdnInventoryUrl" type="hidden" value="https://www.jmautomotive.com/cars-for-sale-in-Naugatuck-CT-Waterbury-Hartford/used_cars"/>
#     <input id="hdnFinanceUrl" type="hidden" value="https://www.jmautomotive.com/Dealer-Websites/J+Mautomotive/Get-Financing.aspx?IsGeneric=0&amp;"/>
#     <input id="hdnDealerCity" type="hidden" value="Naugatuck"/>
#     <input id="hdnDealerState" type="hidden" value="CT"/>
#     <input id="hdnDealerPhone" type="hidden" value="(203) 723-5666"/>
#     <input id="hdnIsMobile" type="hidden" value="false"/>
#     <input id="hdnRegion1" type="hidden" value="Waterbury"/>
#     <input id="hdnRegion2" type="hidden" value="Hartford"/>
#     <input id="hdnRegion3" type="hidden" value="New Haven"/>
#     <input id="hdnCounty" type="hidden" value="NEW HAVEN"/>
#     <input id="hdnCountry" type="hidden" value="USA"/>
#     <input id="hdnIsSecureURL" type="hidden" value="true"/>
#     <input id="hdnHidePrices" type="hidden" value="false"/>
#     <input id="hdnInventoryUrlType" type="hidden" value="1"/>
#     <input id="hdnContactReferralSetting" type="hidden" value="0"/>
#     <input id="hdnCurrentPN" type="hidden" value="inventory"/>
#     <input id="hdnDirectionsEmbedurl" type="hidden" value="https://www.google.com/maps/embed/v1/place?key=AIzaSyDLzPWMvwGmTYXNk0aZuHUAVq9luEpGAiI&amp;q=J%26M+Automotive+Sls%26Svc+LLC,756/820+New+Haven+Road,Naugatuck,CT+06770&amp;zoom=15"/>
#     <input id="hdnPixelID" type="hidden" value="599518190591013,149383822442668"/>
#     <input id="hdnGoogleTagManagerID" type="hidden" value="GTM-K6T6T3V"/>
#     <input id="hdnGoogleTrackingID" type="hidden" value=""/>
#     <input id="hdnIsDebug" type="hidden" value="false"/>
#     <input id="hdnUserWayWidgetCode" type="hidden" value="mhqa48d5HX"/>
#     <input id="hdnIsChatActive" type="hidden" value="false"/>
#     <input id="hdnChatEncryptedID" type="hidden" value="j8l9fpWVa8k="/>
#     <input id="hdnIsFBChatActive" type="hidden" value="false"/>
#     <input id="hdnFacebookPageID" type="hidden" value="159851630780993"/>
#     <input id="hdnFBChatSkinColor" type="hidden" value=""/>
#     <input id="hdnShowCaptchaCode" type="hidden" value="true"/>
#     <input id="hdnContactFieldSetting" type="hidden" value="0"/>
#     <input id="hdnAFTagProductionURL" type="hidden" value="https://cctags.com"/>
#     <input id="hdnAFTagVersion" type="hidden" value="1.1.2"/>
#     <input id="hdnAFTagDecryptedId" type="hidden" value="Y0RyYmRDRFZqTTA9"/>
#     <input id="hdnOverlayURL" type="hidden" value=""/>
#     <input id="hdnOverlayOnFirstImageOnly" type="hidden" value="false"/>
#     <input id="hdnSoldLotId" type="hidden" value="-1"/>
#     <input id="hdnDealerEmail" type="hidden" value="sales@jmautomotive.com"/>
#     <input id="hdnFinanceURLTarget" type="hidden" value=""/>
#     <input id="hdnShowReducedPrice" type="hidden" value="true"/>
#     <input id="hdnDealerAddress1" type="hidden" value="756/820 New Haven Road"/>
#     <input id="hdnDealerStateFull" type="hidden" value="Connecticut"/>
#     <input id="hdnDealerZip" type="hidden" value="06770"/>
#     <input id="hdnDirectionsurl" type="hidden" value="https://maps.google.com/maps?f=q&amp;hl=en&amp;q=J%26M+Automotive+Sls%26Svc+LLC,756/820+New+Haven+Road,Naugatuck,CT+06770&amp;ie=UTF8&amp;om=1&amp;maptype=terrain"/>
#     <input id="hdnDealerAPR" type="hidden" value=""/>
#     <input id="hdnContactusUrl" type="hidden" value="https://www.jmautomotive.com/contact-JandM-Automotive-SlsandSvc-LLC"/>
#     <input id="hdnCCProductionDomain" type="hidden" value="chatchasers.com"/>
#     <input id="hdnGCLID" type="hidden" value=""/>
#     <input id="hdnDealerFax" type="hidden" value="(203) 723-1937"/>
#     <input id="hdnInventoryNoImageURL" type="hidden" value="https://invimg2.autofunds.com/InventoryNoImages"/>
#     <input id="hdnInventoryOverlayImageURL" type="hidden" value="https://invimg2.autofunds.com/OverlayImages"/>
#     <input id="hdnDealerAddress2" type="hidden" value=""/>
#     <div itemprop="geo" itemscope="" itemtype="http://schema.org/GeoCoordinates">
#      <meta content="41.4737946" itemprop="latitude">
#       <meta content="-73.0430881" itemprop="longitude">
#       </meta>
#      </meta>
#     </div>
#     <meta content="https://www.jmautomotive.com/cars-for-sale-in-Naugatuck-CT-Hartford-New-Haven/used_cars" itemprop="url">
#      <meta content="(203) 723-1937" itemprop="faxNumber">
#       <meta content="sales@jmautomotive.com" itemprop="email">
#        <meta content="https://www.jmautomotive.com/Dealer-Websites/J+Mautomotive/images/sharingLogoImg_10.png" itemprop="image"/>
#       </meta>
#      </meta>
#     </meta>
#    </div>
#    <div id="disablingDiv">
#    </div>
#    <div aria-hidden="true" class="modal fade" id="myPopup_Testimonial_Show" role="dialog" tabindex="-1">
#     <div class="modal-dialog">
#      <div class="modal-content">
#       <div class="modal-header">
#        <button aria-hidden="true" class="close" data-dismiss="modal" tabindex="-1" type="button">
#         ×
#        </button>
#        <h4 id="div_Popup_NewTestimonial_Title">
#         Write a review
#        </h4>
#       </div>
#       <p class="review_headtxt">
#        Tell us about your experience at J&amp;M Automotive Sls&amp;Svc LLC.
#       </p>
#       <div class="modal-body" id="myPopup_Testimonial_Body">
#       </div>
#      </div>
#     </div>
#    </div>
#    <div aria-hidden="true" class="modal fade" id="myPopup_Book_TestDrive" role="dialog" tabindex="-1">
#     <div class="modal-dialog">
#      <div class="modal-content">
#       <div class="modal-header">
#        <button aria-hidden="true" class="close" data-dismiss="modal" tabindex="-1" type="button">
#         ×
#        </button>
#        <h4>
#         Book a test drive
#        </h4>
#       </div>
#       <div class="modal-body" id="myPopup_Book_TestDrive_Body">
#       </div>
#      </div>
#     </div>
#    </div>
#    <div aria-hidden="true" class="modal fade" id="myPopup_Shedule_Appointment" role="dialog" tabindex="-1">
#     <div class="modal-dialog">
#      <div class="modal-content">
#       <div class="modal-header">
#        <button aria-hidden="true" class="close" data-dismiss="modal" tabindex="-1" type="button">
#         ×
#        </button>
#        <h4>
#         Schedule appointment
#        </h4>
#       </div>
#       <div class="modal-body" id="myPopup_Shedule_Appointment_Body">
#       </div>
#      </div>
#     </div>
#    </div>
#    <div aria-hidden="true" class="modal fade" id="myPopup_Shedule_Service_Appointment" role="dialog" tabindex="-1">
#     <div class="modal-dialog">
#      <div class="modal-content">
#       <div class="modal-header">
#        <button aria-hidden="true" class="close" data-dismiss="modal" tabindex="-1" type="button">
#         ×
#        </button>
#        <h4>
#         Schedule appointment
#        </h4>
#       </div>
#       <div class="modal-body" id="myPopup_Shedule_Service_Appointment_Body">
#       </div>
#      </div>
#     </div>
#    </div>
#    <div aria-hidden="true" class="modal fade" id="myPopup_Shedule_Lease_Appointment" role="dialog" tabindex="-1">
#     <div class="modal-dialog">
#      <div class="modal-content">
#       <div class="modal-header">
#        <button aria-hidden="true" class="close" data-dismiss="modal" tabindex="-1" type="button">
#         ×
#        </button>
#        <h4>
#         Schedule appointment
#        </h4>
#       </div>
#       <div class="modal-body" id="myPopup_Shedule_Lease_Appointment_Body">
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="modal-box" id="DivAlertPopup">
#     <div aria-label="Missing information" id="DivHeader" role="main">
#      <a class="js-modal-close errclose" href="javascript:void(0)" role="button">
#       ×
#      </a>
#      <div class="error-head" role="heading">
#       Missing information
#      </div>
#     </div>
#     <div class="modal-body" id="DivAlertPopup_body">
#      <div id="modal-item">
#      </div>
#     </div>
#     <div id="DivFooter">
#      <a class="js-modal-close btn btn-primary pull-right" href="javascript:void(0)" role="button">
#       OK
#      </a>
#     </div>
#    </div>
#    <a aria-label="Back to top" class="overlayST" href="javascript:void(0)" id="dw-back-to-top" role="button" title="Back to top">
#     <i class="fa fa-arrow-circle-up" role="presentation">
#     </i>
#    </a>
#   </div>
#   <script async="" defer="" src="/HttpCombiner.ashx?s=DW_Common-Scripts-min&amp;t=text/javascript&amp;v=2022.03.21.A&amp;d=467">
#   </script>
#   <script async="" defer="" src="https://cctags.com/get/tag-1.1.2.min.js?Y0RyYmRDRFZqTTA9">
#   </script>
#   <input id="hdnASP_NET_SessionID" type="hidden" value="k0aeswsd3arqjsq0cpaazbrh"/>
#  </body>
# </html>

# %% [markdown]
# ## Test Extracting Columns

# %% [markdown]
# ### Title

# %%
pi.parse_subsection_attr(soup, 'title','div', 'a', 'thumbnail', 'listitemlink')
# Out:
# ['Used 2016 Ford F-150 4WD SuperCrew 145 XLT for sale in Naugatuck, CT',
#  "Used 2017 Ford F-150 XLT 4WD SuperCrew 5.5' Box for sale in Naugatuck, CT",
#  'Used 2016 Ford Super Duty F-350 Srw 4WD Crew Cab 156 Platinum for sale in Naugatuck, CT',
#  'Used 2017 Mini Countryman Cooper ALL4 for sale in Naugatuck, CT',
#  'Used 2012 Toyota Fj Cruiser 4WD 4dr Auto for sale in Naugatuck, CT',
#  'Used 2013 Mercedes-benz C-class 4dr Sdn C 300 Luxury 4MATIC for sale in Naugatuck, CT',
#  'Used 2015 Ford Expedition 4WD 4dr Platinum for sale in Naugatuck, CT',
#  'Used 2018 Volkswagen Jetta 1.4T SE Auto for sale in Naugatuck, CT',
#  'Used 2015 Ford Super Duty F-250 Srw 4WD Crew Cab 156 XL for sale in Naugatuck, CT',
#  'Used 2017 Infiniti Q50 3.0t Premium AWD for sale in Naugatuck, CT',
#  'Used 2017 Kia Optima LX Auto for sale in Naugatuck, CT',
#  'Used 2015 Toyota Tundra Double Cab 5.7L V8 6-Spd AT SR for sale in Naugatuck, CT',
#  'Used 2013 Audi Tts 2dr Cpe S tronic quattro 2.0T Prest for sale in Naugatuck, CT',
#  'Used 2015 GMC Yukon 4WD 4dr Denali for sale in Naugatuck, CT',
#  'Used 2013 Jeep Wrangler Unlimited 4WD 4dr Sport for sale in Naugatuck, CT',
#  'Used 2015 Lexus Is 250 4dr Sport Sdn AWD for sale in Naugatuck, CT',
#  'Used 2014 Audi S4 4dr Sdn S Tronic Prestige for sale in Naugatuck, CT',
#  'Used 1993 Chevrolet Corvette 2dr Convertible for sale in Naugatuck, CT',
#  'Used 2014 Mercedes-benz E-class 2dr Cpe E 350 4MATIC for sale in Naugatuck, CT',
#  'Used 2004 Chevrolet Ssr Reg Cab 116.0 WB LS for sale in Naugatuck, CT',
#  'Used 2016 Lexus Rx 350 AWD 4dr for sale in Naugatuck, CT',
#  'Used 2014 Toyota Fj Cruiser 4WD 4dr Auto for sale in Naugatuck, CT',
#  'Used 2017 Nissan Titan 4x4 Crew Cab SV for sale in Naugatuck, CT',
#  'Used 2015 Chevrolet Silverado 3500hd 4WD Crew Cab 153.7 High Country for sale in Naugatuck, CT',
#  'Used 2012 GMC Sierra 1500 4WD Ext Cab 143.5 Work Truck for sale in Naugatuck, CT',
#  'Used 2009 Honda Ridgeline 4WD Crew Cab RTL for sale in Naugatuck, CT',
#  'Used 2016 Hyundai Genesis 4dr Sdn V6 3.8L AWD for sale in Naugatuck, CT',
#  'Used 2018 Volvo S60 T5 AWD Dynamic for sale in Naugatuck, CT',
#  'Used 2016 BMW 6 Series 4dr Sdn 640i RWD Gran Coupe for sale in Naugatuck, CT',
#  'Used 2020 Acura Tlx 3.5L SH-AWD w/Technology Pkg for sale in Naugatuck, CT',
#  'Used 2018 Dodge Challenger GT AWD for sale in Naugatuck, CT',
#  'Used 2019 Dodge Challenger SXT AWD for sale in Naugatuck, CT',
#  'Used 2012 Honda Accord 4dr I4 Auto LX for sale in Naugatuck, CT',
#  'Used 2018 Nissan Rogue AWD SL for sale in Naugatuck, CT',
#  'Used 2014 Subaru Xv Crosstrek 5dr Auto 2.0i Premium for sale in Naugatuck, CT',
#  'Used 2015 Toyota 4runner 4WD 4dr V6 Limited for sale in Naugatuck, CT',
#  'Used 2014 Lexus Es 350 4dr Sdn for sale in Naugatuck, CT',
#  'Used 2012 Nissan Maxima 4dr Sdn V6 CVT 3.5 SV for sale in Naugatuck, CT',
#  'Used 2016 Nissan Maxima 4dr Sdn 3.5 Platinum for sale in Naugatuck, CT',
#  'Used 2016 Honda Pilot AWD 4dr EX for sale in Naugatuck, CT',
#  'Used 2018 Infiniti Q50 3.0t LUXE AWD for sale in Naugatuck, CT',
#  'Used 2015 Kia Optima 4dr Sdn LX for sale in Naugatuck, CT',
#  'Used 2016 Chrysler Town & Country 4dr Wgn Touring for sale in Naugatuck, CT',
#  'Used 2014 Ford Fusion 4dr Sdn SE FWD for sale in Naugatuck, CT',
#  'Used 2014 Audi S4 4dr Sdn Man Premium Plus for sale in Naugatuck, CT',
#  'Used 2013 Cadillac Xts 4dr Sdn Platinum AWD for sale in Naugatuck, CT',
#  'Used 2015 GMC Sierra 1500 4WD Crew Cab 143.5 SLE for sale in Naugatuck, CT',
#  'Used 2020 Mazda Cx-5 Grand Touring AWD for sale in Naugatuck, CT',
#  'Used 2018 Toyota Sienna LE FWD 8-Passenger for sale in Naugatuck, CT',
#  'Used 2019 Chevrolet Colorado 4WD Crew Cab 128.3 LT for sale in Naugatuck, CT']

# %% [markdown]
# ### Year

# %%
pi.parse_main_section_attr_text_all(soup, 'div', 'thumbnail', 'itemprop', 'vehicleModelDate')
# Out:
# ['2016',
#  '2017',
#  '2016',
#  '2017',
#  '2012',
#  '2013',
#  '2015',
#  '2018',
#  '2015',
#  '2017',
#  '2017',
#  '2015',
#  '2013',
#  '2015',
#  '2013',
#  '2015',
#  '2014',
#  '1993',
#  '2014',
#  '2004',
#  '2016',
#  '2014',
#  '2017',
#  '2015',
#  '2012',
#  '2009',
#  '2016',
#  '2018',
#  '2016',
#  '2020',
#  '2018',
#  '2019',
#  '2012',
#  '2018',
#  '2014',
#  '2015',
#  '2014',
#  '2012',
#  '2016',
#  '2016',
#  '2018',
#  '2015',
#  '2016',
#  '2014',
#  '2014',
#  '2013',
#  '2015',
#  '2020',
#  '2018',
#  '2019']

# %% [markdown]
# ### Make

# %%
pi.parse_main_section_attr_text_all(soup, 'div', 'thumbnail', 'itemprop', 'manufacturer')
# Out:
# ['Ford',
#  'Ford',
#  'Ford',
#  'Mini',
#  'Toyota',
#  'Mercedes-benz',
#  'Ford',
#  'Volkswagen',
#  'Ford',
#  'Infiniti',
#  'Kia',
#  'Toyota',
#  'Audi',
#  'GMC',
#  'Jeep',
#  'Lexus',
#  'Audi',
#  'Chevrolet',
#  'Mercedes-benz',
#  'Chevrolet',
#  'Lexus',
#  'Toyota',
#  'Nissan',
#  'Chevrolet',
#  'GMC',
#  'Honda',
#  'Hyundai',
#  'Volvo',
#  'BMW',
#  'Acura',
#  'Dodge',
#  'Dodge',
#  'Honda',
#  'Nissan',
#  'Subaru',
#  'Toyota',
#  'Lexus',
#  'Nissan',
#  'Nissan',
#  'Honda',
#  'Infiniti',
#  'Kia',
#  'Chrysler',
#  'Ford',
#  'Audi',
#  'Cadillac',
#  'GMC',
#  'Mazda',
#  'Toyota',
#  'Chevrolet']

# %% [markdown]
# ### Model

# %%
pi.parse_main_section_attr_text_all(soup, 'div', 'thumbnail', 'itemprop', 'model')
# Out:
# ['F-150',
#  'F-150',
#  'Super Duty F-350 Srw',
#  'Countryman',
#  'Fj Cruiser',
#  'C-class',
#  'Expedition',
#  'Jetta',
#  'Super Duty F-250 Srw',
#  'Q50',
#  'Optima',
#  'Tundra',
#  'Tts',
#  'Yukon',
#  'Wrangler Unlimited',
#  'Is 250',
#  'S4',
#  'Corvette',
#  'E-class',
#  'Ssr',
#  'Rx 350',
#  'Fj Cruiser',
#  'Titan',
#  'Silverado 3500hd',
#  'Sierra 1500',
#  'Ridgeline',
#  'Genesis',
#  'S60',
#  '6 Series',
#  'Tlx',
#  'Challenger',
#  'Challenger',
#  'Accord',
#  'Rogue',
#  'Xv Crosstrek',
#  '4runner',
#  'Es 350',
#  'Maxima',
#  'Maxima',
#  'Pilot',
#  'Q50',
#  'Optima',
#  'Town & Country',
#  'Fusion',
#  'S4',
#  'Xts',
#  'Sierra 1500',
#  'Cx-5',
#  'Sienna',
#  'Colorado']

# %% [markdown]
# ### Trim

# %%
pi.parse_main_section_attr_text_all(soup, 'div', 'thumbnail', 'itemprop', 'vehicleConfiguration')
# Out:
# ['4WD SuperCrew 145 XLT',
#  "XLT 4WD SuperCrew 5.5' Box",
#  '4WD Crew Cab 156 Platinum',
#  'Cooper ALL4',
#  '4WD 4dr Auto',
#  '4dr Sdn C 300 Luxury 4MATIC',
#  '4WD 4dr Platinum',
#  '1.4T SE Auto',
#  '4WD Crew Cab 156 XL',
#  '3.0t Premium AWD',
#  'LX Auto',
#  'Double Cab 5.7L V8 6-Spd AT SR',
#  '2dr Cpe S tronic quattro 2.0T Prest',
#  '4WD 4dr Denali',
#  '4WD 4dr Sport',
#  '4dr Sport Sdn AWD',
#  '4dr Sdn S Tronic Prestige',
#  '2dr Convertible',
#  '2dr Cpe E 350 4MATIC',
#  'Reg Cab 116.0 WB LS',
#  'AWD 4dr',
#  '4WD 4dr Auto',
#  '4x4 Crew Cab SV',
#  '4WD Crew Cab 153.7 High Country',
#  '4WD Ext Cab 143.5 Work Truck',
#  '4WD Crew Cab RTL',
#  '4dr Sdn V6 3.8L AWD',
#  'T5 AWD Dynamic',
#  '4dr Sdn 640i RWD Gran Coupe',
#  '3.5L SH-AWD w/Technology Pkg',
#  'GT AWD',
#  'SXT AWD',
#  '4dr I4 Auto LX',
#  'AWD SL',
#  '5dr Auto 2.0i Premium',
#  '4WD 4dr V6 Limited',
#  '4dr Sdn',
#  '4dr Sdn V6 CVT 3.5 SV',
#  '4dr Sdn 3.5 Platinum',
#  'AWD 4dr EX',
#  '3.0t LUXE AWD',
#  '4dr Sdn LX',
#  '4dr Wgn Touring',
#  '4dr Sdn SE FWD',
#  '4dr Sdn Man Premium Plus',
#  '4dr Sdn Platinum AWD',
#  '4WD Crew Cab 143.5 SLE',
#  'Grand Touring AWD',
#  'LE FWD 8-Passenger',
#  '4WD Crew Cab 128.3 LT']
