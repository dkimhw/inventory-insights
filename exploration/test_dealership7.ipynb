# %%
import parse_inventory as pi
import parse_dealership
import requests
import re
from bs4 import BeautifulSoup
import pandas as pd
from datetime import datetime
import sqlite3
import numpy as np

# %%
headers = {
    'user-agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/56.0.2924.87 Safari/537.36',
}

URL = 'https://johnsautosales.com/newandusedcars?clearall=1'
response = requests.get(URL, headers = headers)
soup = BeautifulSoup(response.text, "html.parser")

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <title>
#    Used Cars for Sale Somerville MA 02143 John's Auto Sales
#   </title>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <meta content="used cars Somerville MA, used car dealer Somerville MA, used cars 02143, used car lot Somerville, used trucks Somerville MA, used truck dealer Somerville MA, used trucks 02143, John's Auto Sales Somerville MA" name="keywords"/>
#   <meta content="Used Cars for Sale Somerville MA 02143 John's Auto Sales" name="description"/>
#   <meta content="f6011zaohtded4th9b6nt0ot0cqtag" name="facebook-domain-verification">
#    <meta content="https://imagescdn.dealercarsearch.com/dealerimages/13526/26263/logo.png" name="og:image" property="og:image"/>
#    <meta content="https://johnsautosales.com/newandusedcars" name="og:url" property="og:url"/>
#    <meta content="Used Cars for Sale Somerville MA 02143 John's Auto Sales" name="og:title" property="og:title"/>
#    <meta content="Used Cars for Sale Somerville MA 02143 John's Auto Sales" name="og:description" property="og:description"/>
#    <!-- Meta Pixel Code -->
#    <script>
#     !function(f,b,e,v,n,t,s)
#
# {if(f.fbq)return;n=f.fbq=function(){n.callMethod?
#
# n.callMethod.apply(n,arguments):n.queue.push(arguments)};
#
# if(!f._fbq)f._fbq=n;n.push=n;n.loaded=!0;n.version='2.0';
#
# n.queue=[];t=b.createElement(e);t.async=!0;
#
# t.src=v;s=b.getElementsByTagName(e)[0];
#
# s.parentNode.insertBefore(t,s)}(window, document,'script',
#
# 'https://connect.facebook.net/en_US/fbevents.js');
#
# fbq('init', '322504756443439');
#
# fbq('track', 'PageView');
#    </script>
#    <!-- End Meta Pixel Code -->
#    <link crossorigin="" href="https://userway.org" rel="preconnect"/>
#    <link href="https://www.google-analytics.com" rel="preconnect"/>
#    <script type="text/javascript">
#     var _userway_config = {
#     position: "5",
#     size: "small",
#     account: "RKc9SJg9ce"
#   };
#    </script>
#    <script async="" src="https://cdn.userway.org/widget.js" type="text/javascript">
#    </script>
#    <link href="/Dealers/13001_14000/13526_mvc/26263.min.css?v=nODdFZBWM8L-WM6AhgPZWLoxNOFNWYep3xsKtXlGADE" rel="stylesheet"/>
#    <link href="https://johnsautosales.com/newandusedcars" rel="canonical"/>
#    <link href="https://imagescdn.dealercarsearch.com/dealerimages/13526/26263/touch-favicon.png" rel="apple-touch-icon" type="image/png"/>
#    <link href="https://imagescdn.dealercarsearch.com/dealerimages/13526/26263/favicon.png" rel="icon" type="image/png"/>
#    <!-- Global site tag (gtag.js) - Google Analytics -->
#    <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-3RNWQYM023">
#    </script>
#    <script>
#     window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#   gtag('config', 'G-3RNWQYM023');
#    </script>
#    <script>
#     (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#   ga('create', 'UA-142154570-1', 'auto', 'Dealer');  ga('Dealer.send', 'pageview');
#    </script>
#    <script snippettoken="6f0c395560247129540dc3a3704f39fc071ffdc3" src=" https://d3ik3c8i0ryee8.cloudfront.net/curbcallSnippet.js ">
#    </script>
#   </meta>
#  </head>
#  <body class="listPage newandusedcars-dcs">
#   <header class="s57r_headerWrapper">
#    <div id="topBar">
#     <div class="topHeader container">
#      <div class="s57r_addressPane" id="AddressPane">
#       <div class="ContentPane_154678 AddressAndPhone AddressAndPhone_154678">
#        <div class="AddressPhone_Main">
#         <span class="LabelAddress1">
#          <i class="fas fa-map-marker-alt">
#          </i>
#          181 Somerville Ave
#         </span>
#         <span class="LabelCityStateZip1">
#          Somerville, MA 02143
#         </span>
#         <span class="LabelPhone1">
#          <i class="fas fa-phone">
#          </i>
#          <a href="tel:617-628-5511">
#           617-628-5511
#          </a>
#         </span>
#        </div>
#       </div>
#      </div>
#      <div class="s57r_SocialMediaPane" id="SocialMediaPane">
#       <div class="ContentPane_154677 SocialMedia SocialMedia_154677">
#        <div class="socialMedia">
#         <a aria-label="Follow Us on Facebook" href="https://www.facebook.com/JohnsAutoSales181/" rel="noopener" target="_blank" title="Follow Us on Facebook">
#          <i class="fab fa-facebook-f">
#          </i>
#         </a>
#         <a aria-label="Follow Us on Twitter" href="https://twitter.com/johnsautosalesm" rel="noopener" target="_blank" title="Follow Us on Twitter">
#          <i class="fab fa-twitter">
#          </i>
#         </a>
#         <a aria-label="Follow Us on Google" href="https://www.google.com/maps/place/John's+Auto+Sales/@42.3776496,-71.0895347,15z/data=!4m2!3m1!1s0x0:0x2824d504146cc54d?sa=X&amp;ved=2ahUKEwii5vH0hafyAhVEa80KHbU3DLUQ_BIwE3oECF0QBQ" rel="noopener" target="_blank" title="Follow Us on Google">
#          <i class="fab fa-google">
#          </i>
#         </a>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="s57r_header bottomHeader container">
#     <div class="logoWrapper">
#      <a aria-label="Dealer Logo" href="//johnsautosales.com" id="hlLogo">
#       <img alt="John's Auto Sales Logo" class="dealerLogo logo logo_13526 img-fluid" src="https://imagescdn.dealercarsearch.com/dealerimages/13526/26263/logo.png" title="John's Auto Sales Logo"/>
#      </a>
#     </div>
#     <div class="menuWrapper">
#      <nav class="navbar navbar-expand-lg" id="s57r_menu">
#       <button aria-controls="siteNav" aria-expanded="false" aria-label="Toggle navigation" class="siteMenu navbar-toggler" data-target="#siteNav" data-toggle="collapse" type="button">
#        Site Menu
#       </button>
#       <div class="collapse navbar-collapse" id="siteNav">
#        <ul class="navbar-nav">
#         <li class="nav-item">
#          <a class="nav-link" href="/newandusedcars?clearall=1">
#           <span>
#            Inventory
#           </span>
#          </a>
#         </li>
#         <li class="nav-item dropdown">
#          <a aria-expanded="false" aria-haspopup="true" class="nav-link dropdown-toggle" data-toggle="dropdown" href="/creditapp?">
#           <span>
#            Financing
#           </span>
#          </a>
#          <div class="dropdown-menu">
#           <a class="dropdown-item" href="/creditapp">
#            <span>
#             Apply Online
#            </span>
#           </a>
#           <a class="dropdown-item" href="/loancalculator">
#            <span>
#             Loan Calculator
#            </span>
#           </a>
#          </div>
#         </li>
#         <li class="nav-item">
#          <a class="nav-link" href="/directions">
#           <span>
#            Visit Us
#           </span>
#          </a>
#         </li>
#         <li class="nav-item dropdown">
#          <a aria-expanded="false" aria-haspopup="true" class="nav-link dropdown-toggle" data-toggle="dropdown" href="/sendcomments?">
#           <span>
#            Services
#           </span>
#          </a>
#          <div class="dropdown-menu">
#           <a class="dropdown-item" href="/trade">
#            <span>
#             We Buy Cars
#            </span>
#           </a>
#           <a class="dropdown-item" href="/locatorservice">
#            <span>
#             Vehicle Finder
#            </span>
#           </a>
#          </div>
#         </li>
#         <li class="nav-item dropdown">
#          <a aria-expanded="false" aria-haspopup="true" class="nav-link dropdown-toggle" data-toggle="dropdown" href="/directions?">
#           <span>
#            Our Store
#           </span>
#          </a>
#          <div class="dropdown-menu">
#           <a class="dropdown-item" href="/aboutus">
#            <span>
#             About Us
#            </span>
#           </a>
#           <a class="dropdown-item" href="/blog">
#            <span>
#             Blog
#            </span>
#           </a>
#           <a class="dropdown-item" href="/sendcomments">
#            <span>
#             Contact Us
#            </span>
#           </a>
#           <a class="dropdown-item" href="/meetourstaff">
#            <span>
#             Meet Our Staff
#            </span>
#           </a>
#           <a class="dropdown-item" href="/testimonials">
#            <span>
#             Reviews
#            </span>
#           </a>
#           <a class="dropdown-item" href="/privacy">
#            <span>
#             Privacy Policy
#            </span>
#           </a>
#          </div>
#         </li>
#        </ul>
#       </div>
#      </nav>
#     </div>
#    </div>
#   </header>
#   <main id="contentWrapper">
#    <section class="contentWrapper container">
#     <div class="s57r_list clearfix" id="ContentPane">
#      <div class="ContentPane_1313316 ResponsiveInventoryModule2 ResponsiveInventoryModule2_1313316">
#       <h1 class="dcsTitle">
#        Used Cars &amp; Trucks For Sale In Somerville, MA
#       </h1>
#       <div class="i02r" id="vehicles">
#        <div class="inv-loading-overlay d-none">
#        </div>
#        <form action="/InventoryModule/RefreshInventoryModule?pagename=newandusedcars" data-ajax="true" data-ajax-failure="inventoryModuleFormFailure();" data-ajax-method="get" data-ajax-mode="replace-with" data-ajax-success="inventoryModuleFormSuccess()" data-ajax-update="#vehicles" id="filterForm" method="post">
#         <div class="inv-filter-wrap">
#          <button aria-controls="panelRefine" aria-expanded="false" class="btn filterBtn filter-btn-wide" data-target="#panelRefine" data-toggle="collapse" type="button">
#           <i class="fas fa-sliders-h">
#           </i>
#           Filter Vehicles
#          </button>
#          <div class="inv-filterRow collapse show" data-id-to-update="filters" id="panelRefine">
#           <div class="refineSearchWrap">
#            <div class="refineSearch panel-group" id="refineAccordion">
#             <div id="filterFields">
#              <div class="cd-filter-block">
#               <label aria-label="Year">
#                Year
#               </label>
#               <div class="cd-filter-content">
#                <select aria-label="FilterYear" class="selectpicker form-control" data-dropdown-align-right="true" data-selected-text-format="count &gt; 2" id="FilterYear" multiple="" name="year">
#                 <option selected="" value="">
#                  Any
#                 </option>
#                 <option name="year" value="1929">
#                  1929 (1)
#                 </option>
#                 <option name="year" value="1964">
#                  1964 (1)
#                 </option>
#                 <option name="year" value="1968">
#                  1968 (1)
#                 </option>
#                 <option name="year" value="1987">
#                  1987 (1)
#                 </option>
#                 <option name="year" value="1996">
#                  1996 (1)
#                 </option>
#                 <option name="year" value="2000">
#                  2000 (1)
#                 </option>
#                 <option name="year" value="2001">
#                  2001 (1)
#                 </option>
#                 <option name="year" value="2003">
#                  2003 (2)
#                 </option>
#                 <option name="year" value="2004">
#                  2004 (1)
#                 </option>
#                 <option name="year" value="2005">
#                  2005 (2)
#                 </option>
#                 <option name="year" value="2006">
#                  2006 (4)
#                 </option>
#                 <option name="year" value="2007">
#                  2007 (5)
#                 </option>
#                 <option name="year" value="2008">
#                  2008 (5)
#                 </option>
#                 <option name="year" value="2009">
#                  2009 (3)
#                 </option>
#                 <option name="year" value="2010">
#                  2010 (7)
#                 </option>
#                 <option name="year" value="2011">
#                  2011 (10)
#                 </option>
#                 <option name="year" value="2012">
#                  2012 (11)
#                 </option>
#                 <option name="year" value="2013">
#                  2013 (17)
#                 </option>
#                 <option name="year" value="2014">
#                  2014 (16)
#                 </option>
#                 <option name="year" value="2015">
#                  2015 (10)
#                 </option>
#                 <option name="year" value="2016">
#                  2016 (6)
#                 </option>
#                 <option name="year" value="2017">
#                  2017 (7)
#                 </option>
#                 <option name="year" value="2018">
#                  2018 (3)
#                 </option>
#                 <option name="year" value="2019">
#                  2019 (3)
#                 </option>
#                 <option name="year" value="2020">
#                  2020 (1)
#                 </option>
#                </select>
#               </div>
#              </div>
#              <div class="cd-filter-block">
#               <label aria-label="Make">
#                Make
#               </label>
#               <div class="cd-filter-content">
#                <select aria-label="FilterMakeName" class="selectpicker form-control" data-dropdown-align-right="true" data-selected-text-format="count &gt; 2" id="FilterMakeName" multiple="" name="makename">
#                 <option selected="" value="">
#                  Any
#                 </option>
#                 <option name="makename" value="Acura">
#                  Acura (1)
#                 </option>
#                 <option name="makename" value="Audi">
#                  Audi (3)
#                 </option>
#                 <option name="makename" value="BMW">
#                  BMW (2)
#                 </option>
#                 <option name="makename" value="Buick">
#                  Buick (1)
#                 </option>
#                 <option name="makename" value="Cadillac">
#                  Cadillac (3)
#                 </option>
#                 <option name="makename" value="Chevrolet">
#                  Chevrolet (12)
#                 </option>
#                 <option name="makename" value="Chrysler">
#                  Chrysler (3)
#                 </option>
#                 <option name="makename" value="Dodge">
#                  Dodge (4)
#                 </option>
#                 <option name="makename" value="Fiat">
#                  Fiat (3)
#                 </option>
#                 <option name="makename" value="Ford">
#                  Ford (12)
#                 </option>
#                 <option name="makename" value="GMC">
#                  GMC (3)
#                 </option>
#                 <option name="makename" value="HUMMER">
#                  HUMMER (2)
#                 </option>
#                 <option name="makename" value="Honda">
#                  Honda (8)
#                 </option>
#                 <option name="makename" value="Hyundai">
#                  Hyundai (7)
#                 </option>
#                 <option name="makename" value="Jeep">
#                  Jeep (7)
#                 </option>
#                 <option name="makename" value="Kia">
#                  Kia (2)
#                 </option>
#                 <option name="makename" value="Lexus">
#                  Lexus (5)
#                 </option>
#                 <option name="makename" value="Mazda">
#                  Mazda (2)
#                 </option>
#                 <option name="makename" value="Mercedes-Benz">
#                  Mercedes-Benz (5)
#                 </option>
#                 <option name="makename" value="Mercury">
#                  Mercury (1)
#                 </option>
#                 <option name="makename" value="Mitsubishi">
#                  Mitsubishi (1)
#                 </option>
#                 <option name="makename" value="Nissan">
#                  Nissan (8)
#                 </option>
#                 <option name="makename" value="RAM">
#                  RAM (2)
#                 </option>
#                 <option name="makename" value="Subaru">
#                  Subaru (4)
#                 </option>
#                 <option name="makename" value="Toyota">
#                  Toyota (15)
#                 </option>
#                 <option name="makename" value="Volkswagen">
#                  Volkswagen (2)
#                 </option>
#                 <option name="makename" value="Volvo">
#                  Volvo (2)
#                 </option>
#                </select>
#               </div>
#              </div>
#              <div class="cd-filter-block">
#               <label aria-label="Model">
#                Model
#               </label>
#               <div class="cd-filter-content">
#                <select aria-label="FilterModelName" class="selectpicker form-control" data-dropdown-align-right="true" data-selected-text-format="count &gt; 2" disabled="" id="FilterModelName" multiple="" name="modelname">
#                 <option selected="" value="">
#                  Any
#                 </option>
#                 <option name="modelname" value="1500">
#                  1500 (1)
#                 </option>
#                 <option name="modelname" value="1500 Classic">
#                  1500 Classic (1)
#                 </option>
#                 <option name="modelname" value="300">
#                  300 (2)
#                 </option>
#                 <option name="modelname" value="500">
#                  500 (3)
#                 </option>
#                 <option name="modelname" value="6 Series">
#                  6 Series (1)
#                 </option>
#                 <option name="modelname" value="A4">
#                  A4 (2)
#                 </option>
#                 <option name="modelname" value="Acadia">
#                  Acadia (2)
#                 </option>
#                 <option name="modelname" value="Accent">
#                  Accent (1)
#                 </option>
#                 <option name="modelname" value="Accord Sdn">
#                  Accord Sdn (1)
#                 </option>
#                 <option name="modelname" value="Accord Sedan">
#                  Accord Sedan (2)
#                 </option>
#                 <option '="" name="modelname" value="Allante">
#                  Allante' (1)
#                 </option>
#                 <option name="modelname" value="Altima">
#                  Altima (2)
#                 </option>
#                 <option name="modelname" value="C-Class">
#                  C-Class (2)
#                 </option>
#                 <option name="modelname" value="CR-V">
#                  CR-V (2)
#                 </option>
#                 <option name="modelname" value="CTS">
#                  CTS (1)
#                 </option>
#                 <option name="modelname" value="CX-5">
#                  CX-5 (1)
#                 </option>
#                 <option name="modelname" value="Camaro">
#                  Camaro (1)
#                 </option>
#                 <option name="modelname" value="Camry">
#                  Camry (6)
#                 </option>
#                 <option name="modelname" value="Charger">
#                  Charger (2)
#                 </option>
#                 <option name="modelname" value="Cherokee">
#                  Cherokee (1)
#                 </option>
#                 <option name="modelname" value="Civic Sedan">
#                  Civic Sedan (1)
#                 </option>
#                 <option name="modelname" value="Compass">
#                  Compass (1)
#                 </option>
#                 <option name="modelname" value="Corolla">
#                  Corolla (2)
#                 </option>
#                 <option name="modelname" value="Cruze">
#                  Cruze (1)
#                 </option>
#                 <option name="modelname" value="ES 350">
#                  ES 350 (1)
#                 </option>
#                 <option name="modelname" value="Econoline Cargo Van">
#                  Econoline Cargo Van (1)
#                 </option>
#                 <option name="modelname" value="Elantra">
#                  Elantra (1)
#                 </option>
#                 <option name="modelname" value="Elantra Coupe">
#                  Elantra Coupe (1)
#                 </option>
#                 <option name="modelname" value="Elantra GT">
#                  Elantra GT (2)
#                 </option>
#                 <option name="modelname" value="Elantra Touring">
#                  Elantra Touring (1)
#                 </option>
#                 <option name="modelname" value="Encore">
#                  Encore (1)
#                 </option>
#                 <option name="modelname" value="Equinox">
#                  Equinox (2)
#                 </option>
#                 <option name="modelname" value="Escape">
#                  Escape (2)
#                 </option>
#                 <option name="modelname" value="Excursion">
#                  Excursion (1)
#                 </option>
#                 <option name="modelname" value="Explorer">
#                  Explorer (1)
#                 </option>
#                 <option name="modelname" value="Express Cargo Van">
#                  Express Cargo Van (1)
#                 </option>
#                 <option name="modelname" value="Fleetwood">
#                  Fleetwood (1)
#                 </option>
#                 <option name="modelname" value="Forte">
#                  Forte (2)
#                 </option>
#                 <option name="modelname" value="Fusion">
#                  Fusion (3)
#                 </option>
#                 <option name="modelname" value="GL-Class">
#                  GL-Class (1)
#                 </option>
#                 <option name="modelname" value="GLK-Class">
#                  GLK-Class (1)
#                 </option>
#                 <option name="modelname" value="Gazelle">
#                  Gazelle (1)
#                 </option>
#                 <option name="modelname" value="Grand Cherokee">
#                  Grand Cherokee (3)
#                 </option>
#                 <option name="modelname" value="H2">
#                  H2 (2)
#                 </option>
#                 <option name="modelname" value="HR-V">
#                  HR-V (1)
#                 </option>
#                 <option name="modelname" value="Impreza Wagon">
#                  Impreza Wagon (2)
#                 </option>
#                 <option name="modelname" value="Jetta">
#                  Jetta (1)
#                 </option>
#                 <option name="modelname" value="Legacy Wagon">
#                  Legacy Wagon (1)
#                 </option>
#                 <option name="modelname" value="MAZDA6">
#                  MAZDA6 (1)
#                 </option>
#                 <option name="modelname" value="Maxima">
#                  Maxima (2)
#                 </option>
#                 <option name="modelname" value="Mirage">
#                  Mirage (1)
#                 </option>
#                 <option name="modelname" value="Monterey">
#                  Monterey (1)
#                 </option>
#                 <option name="modelname" value="Mustang">
#                  Mustang (1)
#                 </option>
#                 <option name="modelname" value="New Beetle Coupe">
#                  New Beetle Coupe (1)
#                 </option>
#                 <option name="modelname" value="Q5">
#                  Q5 (1)
#                 </option>
#                 <option name="modelname" value="RAV4">
#                  RAV4 (4)
#                 </option>
#                 <option name="modelname" value="RDX">
#                  RDX (1)
#                 </option>
#                 <option name="modelname" value="RX 350">
#                  RX 350 (4)
#                 </option>
#                 <option name="modelname" value="Ram 2500">
#                  Ram 2500 (1)
#                 </option>
#                 <option name="modelname" value="Ram 3500">
#                  Ram 3500 (1)
#                 </option>
#                 <option name="modelname" value="Ridgeline">
#                  Ridgeline (1)
#                 </option>
#                 <option name="modelname" value="Rogue">
#                  Rogue (2)
#                 </option>
#                 <option name="modelname" value="S60">
#                  S60 (1)
#                 </option>
#                 <option name="modelname" value="Sienna">
#                  Sienna (1)
#                 </option>
#                 <option name="modelname" value="Silverado 1500">
#                  Silverado 1500 (2)
#                 </option>
#                 <option name="modelname" value="Sonata">
#                  Sonata (1)
#                 </option>
#                 <option name="modelname" value="Spark">
#                  Spark (1)
#                 </option>
#                 <option name="modelname" value="Suburban">
#                  Suburban (1)
#                 </option>
#                 <option name="modelname" value="Super Duty F-350 SRW">
#                  Super Duty F-350 SRW (1)
#                 </option>
#                 <option name="modelname" value="Super Duty F-550 DRW">
#                  Super Duty F-550 DRW (1)
#                 </option>
#                 <option name="modelname" value="Tacoma">
#                  Tacoma (1)
#                 </option>
#                 <option name="modelname" value="Tahoe">
#                  Tahoe (2)
#                 </option>
#                 <option name="modelname" value="Terrain">
#                  Terrain (1)
#                 </option>
#                 <option name="modelname" value="Titan">
#                  Titan (1)
#                 </option>
#                 <option name="modelname" value="Town &amp; Country">
#                  Town &amp; Country (1)
#                 </option>
#                 <option name="modelname" value="Trailblazer">
#                  Trailblazer (1)
#                 </option>
#                 <option name="modelname" value="Transit Connect">
#                  Transit Connect (1)
#                 </option>
#                 <option name="modelname" value="Tundra 4WD Truck">
#                  Tundra 4WD Truck (1)
#                 </option>
#                 <option name="modelname" value="Versa">
#                  Versa (1)
#                 </option>
#                 <option name="modelname" value="Wrangler">
#                  Wrangler (2)
#                 </option>
#                 <option name="modelname" value="X5">
#                  X5 (1)
#                 </option>
#                 <option name="modelname" value="XC90">
#                  XC90 (1)
#                 </option>
#                 <option name="modelname" value="XV Crosstrek">
#                  XV Crosstrek (1)
#                 </option>
#                </select>
#               </div>
#              </div>
#              <div class="cd-filter-block">
#               <label aria-label="Trim">
#                Trim
#               </label>
#               <div class="cd-filter-content">
#                <select aria-label="FilterTrimName" class="selectpicker form-control" data-dropdown-align-right="true" data-selected-text-format="count &gt; 2" disabled="" id="FilterTrimName" multiple="" name="trimname">
#                 <option selected="" value="">
#                  Any
#                 </option>
#                 <option name="trimname" value="1.4T Se Auto">
#                  1.4T Se Auto (1)
#                 </option>
#                 <option name="trimname" value='114.6" Xlt W/Side &amp; Rear Door Privacy Glass'>
#                  114.6" Xlt W/Side &amp; Rear Door Privacy Glass (1)
#                 </option>
#                 <option name="trimname" value='137" Wb 6.8L Xlt Premium 4Wd'>
#                  137" Wb 6.8L Xlt Premium 4Wd (1)
#                 </option>
#                 <option name="trimname" value="2.5 Sv Sedan">
#                  2.5 Sv Sedan (1)
#                 </option>
#                 <option name="trimname" value="2014.5 4Dr Sdn I4 Auto Se Sport (Natl)">
#                  2014.5 4Dr Sdn I4 Auto Se Sport (Natl) (1)
#                 </option>
#                 <option name="trimname" value="2Dr Convertible">
#                  2Dr Convertible (1)
#                 </option>
#                 <option name="trimname" value="2Dr Coupe Convertible">
#                  2Dr Coupe Convertible (1)
#                 </option>
#                 <option name="trimname" value="2Dr Cpe 2Ls">
#                  2Dr Cpe 2Ls (1)
#                 </option>
#                 <option name="trimname" value="2Dr Cpe Gls Auto">
#                  2Dr Cpe Gls Auto (1)
#                 </option>
#                 <option name="trimname" value="2Dr Hb Pop">
#                  2Dr Hb Pop (2)
#                 </option>
#                 <option name="trimname" value="2Dr Hb Turbo">
#                  2Dr Hb Turbo (1)
#                 </option>
#                 <option name="trimname" value="2Dr Pzev">
#                  2Dr Pzev (1)
#                 </option>
#                 <option name="trimname" value="4Dr 1500 4Wd Ls">
#                  4Dr 1500 4Wd Ls (1)
#                 </option>
#                 <option name="trimname" value="4Dr 4Wd Ls">
#                  4Dr 4Wd Ls (1)
#                 </option>
#                 <option name="trimname" value="4Dr Awd Ls">
#                  4Dr Awd Ls (1)
#                 </option>
#                 <option name="trimname" value="4Dr Cvt Lx">
#                  4Dr Cvt Lx (1)
#                 </option>
#                 <option name="trimname" value="4Dr H4 At Outback Ltd">
#                  4Dr H4 At Outback Ltd (1)
#                 </option>
#                 <option name="trimname" value="4Dr I4 Cvt Ex-L">
#                  4Dr I4 Cvt Ex-L (1)
#                 </option>
#                 <option name="trimname" value="4Dr I4 Man Sport">
#                  4Dr I4 Man Sport (1)
#                 </option>
#                 <option name="trimname" value='4Dr Quad Cab 155" Wb Drw 4Wd'>
#                  4Dr Quad Cab 155" Wb Drw 4Wd (1)
#                 </option>
#                 <option name="trimname" value="4Dr Sdn">
#                  4Dr Sdn (1)
#                 </option>
#                 <option name="trimname" value="4Dr Sdn 2.4L Se Pzev">
#                  4Dr Sdn 2.4L Se Pzev (1)
#                 </option>
#                 <option name="trimname" value="4Dr Sdn 2.5T Fwd">
#                  4Dr Sdn 2.5T Fwd (1)
#                 </option>
#                 <option name="trimname" value="4Dr Sdn Auto 2.0T Quattro Prem">
#                  4Dr Sdn Auto 2.0T Quattro Prem (1)
#                 </option>
#                 <option name="trimname" value="4Dr Sdn Auto Ex">
#                  4Dr Sdn Auto Ex (1)
#                 </option>
#                 <option name="trimname" value="4Dr Sdn Auto I Touring">
#                  4Dr Sdn Auto I Touring (1)
#                 </option>
#                 <option name="trimname" value="4Dr Sdn Auto Le Special Edition (Natl)">
#                  4Dr Sdn Auto Le Special Edition (Natl) (2)
#                 </option>
#                 <option name="trimname" value="4Dr Sdn Auto Quattro 2.0T Premium">
#                  4Dr Sdn Auto Quattro 2.0T Premium (1)
#                 </option>
#                 <option name="trimname" value="4Dr Sdn Awd W/1Sa">
#                  4Dr Sdn Awd W/1Sa (1)
#                 </option>
#                 <option name="trimname" value="4Dr Sdn C 300 Sport 4Matic">
#                  4Dr Sdn C 300 Sport 4Matic (2)
#                 </option>
#                 <option name="trimname" value="4Dr Sdn Cvt 1.6 S Plus">
#                  4Dr Sdn Cvt 1.6 S Plus (1)
#                 </option>
#                 <option name="trimname" value="4Dr Sdn I4 2.5">
#                  4Dr Sdn I4 2.5 (1)
#                 </option>
#                 <option name="trimname" value="4Dr Sdn I4 Auto Xle (Natl)">
#                  4Dr Sdn I4 Auto Xle (Natl) (2)
#                 </option>
#                 <option name="trimname" value="4Dr Sdn I4 Man Le (Natl)">
#                  4Dr Sdn I4 Man Le (Natl) (2)
#                 </option>
#                 <option name="trimname" value="4Dr Sdn I4 Se Fwd">
#                  4Dr Sdn I4 Se Fwd (1)
#                 </option>
#                 <option name="trimname" value="4Dr Sdn Le V6 Auto (Natl)">
#                  4Dr Sdn Le V6 Auto (Natl) (1)
#                 </option>
#                 <option name="trimname" value="4Dr Sdn Ls">
#                  4Dr Sdn Ls (1)
#                 </option>
#                 <option name="trimname" value="4Dr Sdn Se Rwd">
#                  4Dr Sdn Se Rwd (2)
#                 </option>
#                 <option name="trimname" value="4Dr Sdn Touring Signature Awd">
#                  4Dr Sdn Touring Signature Awd (1)
#                 </option>
#                 <option name="trimname" value="4Dr Sdn V6 Sel Awd">
#                  4Dr Sdn V6 Sel Awd (1)
#                 </option>
#                 <option name="trimname" value="4Dr Sdn V8 300C Awd">
#                  4Dr Sdn V8 300C Awd (1)
#                 </option>
#                 <option name="trimname" value="4Dr Sedan">
#                  4Dr Sedan (1)
#                 </option>
#                 <option name="trimname" value="4Dr Sport 4Wd">
#                  4Dr Sport 4Wd (1)
#                 </option>
#                 <option name="trimname" value="4Dr Wgn 4Wd Suv">
#                  4Dr Wgn 4Wd Suv (1)
#                 </option>
#                 <option name="trimname" value="4Dr Wgn Auto Gls">
#                  4Dr Wgn Auto Gls (1)
#                 </option>
#                 <option name="trimname" value="4Dr Wgn Suv">
#                  4Dr Wgn Suv (1)
#                 </option>
#                 <option name="trimname" value="4Dr Wgn Touring">
#                  4Dr Wgn Touring (1)
#                 </option>
#                 <option name="trimname" value="4Matic 4Dr 4.7L">
#                  4Matic 4Dr 4.7L (1)
#                 </option>
#                 <option name="trimname" value="4Matic 4Dr Glk 350">
#                  4Matic 4Dr Glk 350 (1)
#                 </option>
#                 <option name="trimname" value="4Wd 4Dr 1500 Ltz">
#                  4Wd 4Dr 1500 Ltz (1)
#                 </option>
#                 <option name="trimname" value="4Wd 4Dr 4-Cyl 4-Spd At (Natl)">
#                  4Wd 4Dr 4-Cyl 4-Spd At (Natl) (2)
#                 </option>
#                 <option name="trimname" value="4Wd 4Dr Laredo">
#                  4Wd 4Dr Laredo (1)
#                 </option>
#                 <option name="trimname" value="4Wd 4Dr Latitude">
#                  4Wd 4Dr Latitude (1)
#                 </option>
#                 <option name="trimname" value="4Wd 4Dr Lt">
#                  4Wd 4Dr Lt (1)
#                 </option>
#                 <option name="trimname" value="4Wd 4Dr Overland">
#                  4Wd 4Dr Overland (1)
#                 </option>
#                 <option name="trimname" value="4Wd 4Dr Se">
#                  4Wd 4Dr Se (1)
#                 </option>
#                 <option name="trimname" value="4Wd 4Dr Unlimited Sahara">
#                  4Wd 4Dr Unlimited Sahara (1)
#                 </option>
#                 <option name="trimname" value="4Wd 4Dr Unlimited X">
#                  4Wd 4Dr Unlimited X (1)
#                 </option>
#                 <option name="trimname" value="4Wd 4Dr Xlt">
#                  4Wd 4Dr Xlt (1)
#                 </option>
#                 <option name="trimname" value="4Wd Crew Cab Rts">
#                  4Wd Crew Cab Rts (1)
#                 </option>
#                 <option name="trimname" value="4Wd Double Cab V6 Mt (Natl)">
#                  4Wd Double Cab V6 Mt (Natl) (1)
#                 </option>
#                 <option name="trimname" value='4Wd Ext Cab 143.5" Lt'>
#                  4Wd Ext Cab 143.5" Lt (2)
#                 </option>
#                 <option name="trimname" value="4Wd King Cab Swb Pro-4X">
#                  4Wd King Cab Swb Pro-4X (1)
#                 </option>
#                 <option name="trimname" value='4Wd Quad Cab 140.5" Big Horn'>
#                  4Wd Quad Cab 140.5" Big Horn (1)
#                 </option>
#                 <option name="trimname" value='4Wd Reg Cab 140.5" St'>
#                  4Wd Reg Cab 140.5" St (1)
#                 </option>
#                 <option name="trimname" value='4Wd Reg Cab 141" Wb 60" Ca Xlt'>
#                  4Wd Reg Cab 141" Wb 60" Ca Xlt (1)
#                 </option>
#                 <option name="trimname" value="5Dr 7-Pass Van V6 Le Awd (Natl)">
#                  5Dr 7-Pass Van V6 Le Awd (Natl) (1)
#                 </option>
#                 <option name="trimname" value="5Dr Auto 2.0I Premium">
#                  5Dr Auto 2.0I Premium (1)
#                 </option>
#                 <option name="trimname" value="5Dr Auto 2.5I Premium Special Edition">
#                  5Dr Auto 2.5I Premium Special Edition (1)
#                 </option>
#                 <option name="trimname" value="5Dr Cvt 2.0I Sport Premium">
#                  5Dr Cvt 2.0I Sport Premium (1)
#                 </option>
#                 <option name="trimname" value="5Dr Hb Auto">
#                  5Dr Hb Auto (1)
#                 </option>
#                 <option name="trimname" value="5Dr Hb Auto Pzev">
#                  5Dr Hb Auto Pzev (1)
#                 </option>
#                 <option name="trimname" value="5Dr Hb Auto Se">
#                  5Dr Hb Auto Se (1)
#                 </option>
#                 <option name="trimname" value="5Dr Hb Cvt Ls">
#                  5Dr Hb Cvt Ls (1)
#                 </option>
#                 <option name="trimname" value="650Ci 2Dr Cpe">
#                  650Ci 2Dr Cpe (1)
#                 </option>
#                 <option name="trimname" value="Awd 4Dr">
#                  Awd 4Dr (3)
#                 </option>
#                 <option name="trimname" value="Awd 4Dr Cvt Lx">
#                  Awd 4Dr Cvt Lx (1)
#                 </option>
#                 <option name="trimname" value="Awd 4Dr Denali">
#                  Awd 4Dr Denali (1)
#                 </option>
#                 <option name="trimname" value="Awd 4Dr F Sport">
#                  Awd 4Dr F Sport (1)
#                 </option>
#                 <option name="trimname" value="Awd 4Dr Lt W/1Lt">
#                  Awd 4Dr Lt W/1Lt (1)
#                 </option>
#                 <option name="trimname" value="Awd 4Dr S">
#                  Awd 4Dr S (1)
#                 </option>
#                 <option name="trimname" value="Awd 4Dr Sl">
#                  Awd 4Dr Sl (1)
#                 </option>
#                 <option name="trimname" value="Awd 4Dr Sle W/Sle-2">
#                  Awd 4Dr Sle W/Sle-2 (1)
#                 </option>
#                 <option name="trimname" value="Awd 4Dr Slt">
#                  Awd 4Dr Slt (1)
#                 </option>
#                 <option name="trimname" value="Awd 4Dr Tech Pkg">
#                  Awd 4Dr Tech Pkg (1)
#                 </option>
#                 <option name="trimname" value="Awd 4Dr Xdrive35i">
#                  Awd 4Dr Xdrive35i (1)
#                 </option>
#                 <option name="trimname" value="Awd 4Dr Xle (Natl)">
#                  Awd 4Dr Xle (Natl) (1)
#                 </option>
#                 <option name="trimname" value="Awd 5Dr Ex-L">
#                  Awd 5Dr Ex-L (1)
#                 </option>
#                 <option name="trimname" value="Awd 5Dr Lx">
#                  Awd 5Dr Lx (1)
#                 </option>
#                 <option name="trimname" value="Convenience">
#                  Convenience (1)
#                 </option>
#                 <option name="trimname" value="Double Cab 4.6L V8 6-Spd At (Natl)">
#                  Double Cab 4.6L V8 6-Spd At (Natl) (1)
#                 </option>
#                 <option name="trimname" value="E-350 Super Duty Ext Recreational">
#                  E-350 Super Duty Ext Recreational (1)
#                 </option>
#                 <option name="trimname" value="Es Cvt">
#                  Es Cvt (1)
#                 </option>
#                 <option 4"="" box'="" name="trimname" value="Express 4X4 Quad Cab 6">
#                  Express 4X4 Quad Cab 6'4" Box (1)
#                 </option>
#                 <option name="trimname" value="Fwd 4Dr Convenience">
#                  Fwd 4Dr Convenience (1)
#                 </option>
#                 <option name="trimname" value="Fwd 4Dr Premier Plus">
#                  Fwd 4Dr Premier Plus (1)
#                 </option>
#                 <option name="trimname" value="Grand Select Awd">
#                  Grand Select Awd (1)
#                 </option>
#                 <option name="trimname" value="Le Awd (Natl)">
#                  Le Awd (Natl) (1)
#                 </option>
#                 <option name="trimname" value="Limited 4X4">
#                  Limited 4X4 (1)
#                 </option>
#                 <option name="trimname" value="Lx Cvt">
#                  Lx Cvt (1)
#                 </option>
#                 <option name="trimname" value="Lxs Ivt">
#                  Lxs Ivt (1)
#                 </option>
#                 <option name="trimname" value="Platinum 3.5L">
#                  Platinum 3.5L (1)
#                 </option>
#                 <option name="trimname" value="Quattro 4Dr 2.0T Premium">
#                  Quattro 4Dr 2.0T Premium (1)
#                 </option>
#                 <option name="trimname" value="Replica">
#                  Replica (1)
#                 </option>
#                 <option name="trimname" value='Rwd 1500 135"'>
#                  Rwd 1500 135" (1)
#                 </option>
#                 <option name="trimname" value="Se 2.0L Auto (Ulsan)">
#                  Se 2.0L Auto (Ulsan) (1)
#                 </option>
#                 <option name="trimname" value="Se Awd">
#                  Se Awd (1)
#                 </option>
#                 <option name="trimname" value='Supercab 142" Harley-Davidson 4Wd'>
#                  Supercab 142" Harley-Davidson 4Wd (1)
#                 </option>
#                 <option name="trimname" value="Sv 3.5L">
#                  Sv 3.5L (1)
#                 </option>
#                 <option name="trimname" value="Titanium 4Wd">
#                  Titanium 4Wd (1)
#                 </option>
#                </select>
#               </div>
#              </div>
#              <div class="cd-filter-block">
#               <label aria-label="Color">
#                Color
#               </label>
#               <div class="cd-filter-content">
#                <select aria-label="FilterExteriorColor" class="selectpicker form-control" data-dropdown-align-right="true" data-selected-text-format="count &gt; 2" id="FilterExteriorColor" multiple="" name="color">
#                 <option selected="" value="">
#                  Any
#                 </option>
#                 <option name="color" value="Black">
#                  Black (26)
#                 </option>
#                 <option name="color" value="Blue">
#                  Blue (15)
#                 </option>
#                 <option name="color" value="Brown">
#                  Brown (1)
#                 </option>
#                 <option name="color" value="Burgundy">
#                  Burgundy (1)
#                 </option>
#                 <option name="color" value="Charcoal">
#                  Charcoal (3)
#                 </option>
#                 <option name="color" value="Cream">
#                  Cream (2)
#                 </option>
#                 <option name="color" value="Dark Blue">
#                  Dark Blue (5)
#                 </option>
#                 <option name="color" value="Dark Green">
#                  Dark Green (2)
#                 </option>
#                 <option name="color" value="Gray">
#                  Gray (6)
#                 </option>
#                 <option name="color" value="Light Blue">
#                  Light Blue (3)
#                 </option>
#                 <option name="color" value="Light Green">
#                  Light Green (1)
#                 </option>
#                 <option name="color" value="Red">
#                  Red (13)
#                 </option>
#                 <option name="color" value="Silver">
#                  Silver (15)
#                 </option>
#                 <option name="color" value="Tan">
#                  Tan (1)
#                 </option>
#                 <option name="color" value="White">
#                  White (24)
#                 </option>
#                 <option name="color" value="Yellow">
#                  Yellow (2)
#                 </option>
#                </select>
#               </div>
#              </div>
#              <div class="cd-filter-block">
#               <label aria-label="Interior Color">
#                Interior Color
#               </label>
#               <div class="cd-filter-content">
#                <select aria-label="FilterInteriorColor" class="selectpicker form-control" data-dropdown-align-right="true" data-selected-text-format="count &gt; 2" id="FilterInteriorColor" multiple="" name="intcolor">
#                 <option selected="" value="">
#                  Any
#                 </option>
#                 <option name="intcolor" value="Beige">
#                  Beige (3)
#                 </option>
#                 <option name="intcolor" value="Black">
#                  Black (50)
#                 </option>
#                 <option name="intcolor" value="Brown">
#                  Brown (2)
#                 </option>
#                 <option name="intcolor" value="Gray">
#                  Gray (50)
#                 </option>
#                 <option name="intcolor" value="Red">
#                  Red (1)
#                 </option>
#                 <option name="intcolor" value="Select">
#                  Select (1)
#                 </option>
#                 <option name="intcolor" value="Tan">
#                  Tan (13)
#                 </option>
#                </select>
#               </div>
#              </div>
#              <div class="cd-filter-block">
#               <label aria-label="Interior">
#                Interior
#               </label>
#               <div class="cd-filter-content">
#                <select aria-label="FilterInteriorType" class="selectpicker form-control" data-dropdown-align-right="true" data-selected-text-format="count &gt; 2" id="FilterInteriorType" multiple="" name="inttype">
#                 <option selected="" value="">
#                  Any
#                 </option>
#                 <option name="inttype" value="Cloth     ">
#                  Cloth      (64)
#                 </option>
#                 <option name="inttype" value="Leather   ">
#                  Leather    (49)
#                 </option>
#                 <option name="inttype" value="Leather Trim">
#                  Leather Trim (4)
#                 </option>
#                 <option name="inttype" value="Select">
#                  Select (1)
#                 </option>
#                 <option name="inttype" value="Vinyl     ">
#                  Vinyl      (2)
#                 </option>
#                </select>
#               </div>
#              </div>
#              <div class="cd-filter-block">
#               <label aria-label="Body Type">
#                Body Type
#               </label>
#               <div class="cd-filter-content">
#                <select aria-label="FilterAllBodyTypes" class="selectpicker form-control" data-dropdown-align-right="true" data-selected-text-format="count &gt; 2" id="FilterAllBodyTypes" multiple="" name="alltype">
#                 <option selected="" value="">
#                  Any
#                 </option>
#                 <option name="alltype" value="Cargo Van">
#                  Cargo Van (1)
#                 </option>
#                 <option name="alltype" value="Convertible">
#                  Convertible (3)
#                 </option>
#                 <option name="alltype" value="Coupe">
#                  Coupe (4)
#                 </option>
#                 <option name="alltype" value="Hatchback">
#                  Hatchback (9)
#                 </option>
#                 <option name="alltype" value="Pickup Truck">
#                  Pickup Truck (1)
#                 </option>
#                 <option name="alltype" value="Sedan">
#                  Sedan (39)
#                 </option>
#                 <option name="alltype" value="Suv">
#                  Suv (38)
#                 </option>
#                 <option name="alltype" value="Truck">
#                  Truck (11)
#                 </option>
# ...
#                <input aria-label="Contact Consent" class="form-check-input" data-val="true" data-val-range="Please check the box to verify acknowledgement and consent." data-val-range-max="True" data-val-range-min="True" data-val-required="The ContactDisclaimerConsent field is required." id="chkContactDisclaimerConsent" name="ContactDisclaimerConsent" type="checkbox" value="true">
#                 <label aria-labelledby="chkContactDisclaimerConsent" for="chkContactDisclaimerConsent">
#                  <strong>
#                   ACKNOWLEDGMENT AND CONSENT:
#                  </strong>
#                 </label>
#                 <span class="text-danger field-validation-valid" data-valmsg-for="ContactDisclaimerConsent" data-valmsg-replace="true">
#                 </span>
#                </input>
#               </div>
#               I hereby consent to receive text messages or phone calls from or on behalf of the dealer or their employees to the mobile phone number I provided above.  By opting in,  I understand that message and data rates may apply.  This acknowledgement constitutes my written consent to receive text messages to my cell phone and phone calls, including communications sent using an auto-dialer or pre-recorded message. You may withdraw your consent at any time by texting "STOP".
#              </div>
#             </div>
#             <div>
#             </div>
#             <button class="btn price-drop-form-button">
#              Submit
#              <i class="fas fa-spinner fa-spin fa-fw price-drop-form-spinner" style="display: none">
#              </i>
#             </button>
#             <input name="CssClassPrefix" type="hidden" value="i01r">
#              <input data-val="true" data-val-required="The InventoryId field is required." id="priceDropInventoryId" name="InventoryId" type="hidden" value="0">
#               <input data-val="true" data-val-required="The DealerId field is required." id="priceDropDealerId" name="DealerId" type="hidden" value="0">
#                <input data-val="true" data-val-required="The PriceType field is required." id="priceDropPriceType" name="PriceType" type="hidden" value="Undefined">
#                 <input id="priceDropStockNumber" name="StockNumber" type="hidden" value="">
#                  <div class="RowIce">
#                   <input aria-label="Name" autocomplete="off" class="form-control" name="Name" type="text"/>
#                  </div>
#                  <input name="__RequestVerificationToken" type="hidden" value="CfDJ8M23iDBLc7xIvR1mlIAam6tTC-8_-m5_mC-4KrLXnFfl0II5nbPGmyTdgAsOEk0612jaRuSbDiuQTrUugkG4VF9ET5VGl6DwTSJpkw4JSg97f0vGfadrXEEXOAGtjqWyjLCjt6W197PLNKy7CuVV9bo"/>
#                  <input name="ContactDisclaimerConsent" type="hidden" value="false"/>
#                 </input>
#                </input>
#               </input>
#              </input>
#             </input>
#            </form>
#           </div>
#          </div>
#          <div class="modal-footer">
#          </div>
#         </div>
#        </div>
#       </div>
#       <script src="https://widget.carstory.com/v1.0/button.js" type="text/javascript">
#       </script>
#       <script>
#        document.addEventListener('DOMContentLoaded',
#         function() {
#
#             var referrer = 'dcs-two';
#             var cswButt0n = setInterval(function() {
#                         window.CarStory &&
#                             (clearInterval(cswButt0n), CarStory.buildButtons({ referrer: referrer || null, useNoConflict: !0, noClickButtons: true }));
#                     },
#                     100),
#                 cb = function() {
#                     var e = document.createElement('link');
#                     e.rel = 'stylesheet', e.href = '//widget.carstory.com/v1.0/no-click-button.css';
#                     var t = document.getElementsByTagName('head')[0];
#                     t.parentNode.insertBefore(e, t);
#                 },
#                 raf = requestAnimationFrame || mozRequestAnimationFrame || webkitRequestAnimationFrame || msRequestAnimationFrame;
#             raf ? raf(cb) : window.addEventListener('load', cb);
#         });
#       </script>
#       <script src="https://snapshot.carfax.com/latest/snapshot.js" type="text/javascript">
#       </script>
#      </div>
#      <div class="ContentPane_1586163 HTMLModule HTMLModule_1586163">
#       <hr/>
#       <h3>
#        Browse our inventory of used cars, trucks, SUVs for sale near me in Somerville,MA
#       </h3>
#       <p>
#        John's Auto Sales, we’re your go-to dealership for premier quality pre-owned
#        <a href="/newandusedcarscars?clearall=1&amp;typelist=Convertible,Coupe,Hatchback,Sedan">
#         cars
#        </a>
#        ,
#        <a href="/newandusedcarscars?clearall=1&amp;type=Truck">
#         trucks
#        </a>
#        ,
#        <a href="/newandusedcarscars?clearall=1&amp;type=SUV">
#         SUVs
#        </a>
#        , and much more. We have a wide variety of everyday vehicles for you to choose from. With our years of experience and our extensive collection of pre-owned vehicles, our sales team will gladly assist you in finding the vehicle that suits you. We also have a variety of vehicle brands, including
#        <strong>
#         Audi, Chevrolet, Ford, Honda, Kia,Toyota
#        </strong>
#        and more. Feel free to
#        <a href="/directions">
#         visit us
#        </a>
#        to see our great selection of pre-owned vehicles here at John's Auto Sales!
#       </p>
#      </div>
#     </div>
#    </section>
#   </main>
#   <footer id="Footer_wrap">
#    <div class="s57r_Footer container" id="FooterPane">
#     <div class="ContentPane_154673 SocialMedia SocialMedia_154673">
#      <div class="socialMedia">
#       <a aria-label="Follow Us on Facebook" href="https://www.facebook.com/JohnsAutoSales181/" rel="noopener" target="_blank" title="Follow Us on Facebook">
#        <i class="fab fa-facebook-f">
#        </i>
#       </a>
#       <a aria-label="Follow Us on Twitter" href="https://twitter.com/johnsautosalesm" rel="noopener" target="_blank" title="Follow Us on Twitter">
#        <i class="fab fa-twitter">
#        </i>
#       </a>
#       <a aria-label="Follow Us on Google" href="https://www.google.com/maps/place/John's+Auto+Sales/@42.3776496,-71.0895347,15z/data=!4m2!3m1!1s0x0:0x2824d504146cc54d?sa=X&amp;ved=2ahUKEwii5vH0hafyAhVEa80KHbU3DLUQ_BIwE3oECF0QBQ" rel="noopener" target="_blank" title="Follow Us on Google">
#        <i class="fab fa-google">
#        </i>
#       </a>
#      </div>
#     </div>
#     <div class="FooterNav FooterNav_154674" id="ContentPane_154674">
#      <h2 class="dcsTitle">
#       Used Car Dealership In Boston, MA
#      </h2>
#      <div class="footerNav">
#       <a aria-label="Home" href="/default" target="_top" title="Home">
#        Home
#       </a>
#       <span class="footer-sep">
#        |
#       </span>
#       <a aria-label="About Us" href="/aboutus" target="_top" title="About Us">
#        About Us
#       </a>
#       <span class="footer-sep">
#        |
#       </span>
#       <a aria-label="Contact Us" href="/sendcomments" target="_top" title="Contact Us">
#        Contact Us
#       </a>
#       <span class="footer-sep">
#        |
#       </span>
#       <a aria-label="Privacy" href="/privacy" target="_top" title="Privacy">
#        Privacy Policy
#       </a>
#      </div>
#     </div>
#     <div class="ContentPane_154672 Copyright Copyright_154672">
#      <div class="copyright_main">
#       <div class="dcsLogin">
#        <a href="https://www.dealercarsearch.com" rel="noopener" target="_blank">
#         Dealer Car Search Login
#        </a>
#       </div>
#       <div class="copyright">
#        Copyright 2022        |
#        <a href="/sitemap" rel="noopener" target="_blank">
#         Sitemap
#        </a>
#       </div>
#      </div>
#     </div>
#     <div class="ContentPane_154675 SEO SEO_154675">
#      <div class="SeoText" itemscope="" itemtype="http://schema.org/AutoDealer">
#       <span itemprop="name">
#        John's Auto Sales
#       </span>
#       <i itemprop="address" itemscope="" itemtype="http://schema.org/PostalAddress">
#        <span itemprop="streetAddress">
#         181 Somerville Ave,
#        </span>
#        <span itemprop="addressLocality">
#         Somerville,
#        </span>
#        <span itemprop="addressRegion">
#         MA
#        </span>
#        <span itemprop="postalCode">
#         02143
#        </span>
#       </i>
#       <a href="tel://617-628-5511" itemprop="telephone">
#        617-628-5511
#       </a>
#       <a href="https://johnsautosales.com" itemprop="url">
#        https://johnsautosales.com
#       </a>
#       <img alt="Logo" itemprop="logo" src="/Dealers/13001_14000/13526_mvc/images/logo.png"/>
#      </div>
#     </div>
#    </div>
#   </footer>
#   <div class="" id="ChatPane">
#    <div class="ContentPane_154676 ResponsiveSMSTexting ResponsiveSMSTexting_154676">
#     <div id="textingFormReplaceDiv">
#      <a class="smsBtn smsBtnFS" data-target="#SMSModal" data-toggle="modal" href="javascript:void(0);">
#       <div class="sms-fixed__bottom">
#        <span class="sms-icon">
#         <i class="fas fa-comments">
#         </i>
#        </span>
#        <span class="sms-text">
#         Text Us
#        </span>
#       </div>
#      </a>
#      <div aria-hidden="true" aria-labelledby="myModalLabel" class="smsModalFS modal fade" id="SMSModal" role="dialog" tabindex="-1">
#       <div class="modal-dialog">
#        <div class="modal-content">
#         <div class="modal-header">
#          <h4 class="modal-title" id="H1">
#           Text us
#          </h4>
#          <button class="close" data-dismiss="modal" type="button">
#           <span aria-hidden="true">
#            ×
#           </span>
#           <span class="sr-only">
#            Close
#           </span>
#          </button>
#         </div>
#         <div class="modal-body">
#          <form action="/LeadModule/ResponsiveSmsSubmitForm?pagename=newandusedcars&amp;modulename=ResponsiveSMSTextingForm&amp;websitepagemoduleid=0" data-ajax="true" data-ajax-begin="$('.btn-SMSModal').prop('disabled',true);" data-ajax-failure="ajaxFailure" data-ajax-loading=".spinner-SMSModal" data-ajax-method="post" data-ajax-mode="replace-with" data-ajax-success="formLeadTracking('0', '', 'SMS Texting Form')" data-ajax-update="#textingFormReplaceDiv" data-recaptcha-id="ResponsiveSmsTextingRecaptchaToken" data-recaptcha-site-key="" data-recaptcha-type="Undefined" id="ResponsiveSmsTextingForm-SMSModal" method="post">
#           <div class="form-group">
#            <label for="FirstName" id="lblSMSFirstNameFS">
#             First Name
#            </label>
#            <input aria-labelledby="lblSMSFirstNameFS" class="form-control" data-val="true" data-val-required="The First Name field is required." id="txtSMSFirstNameFS" name="FirstName" type="text" value=""/>
#            <span class="text-danger field-validation-valid" data-valmsg-for="FirstName" data-valmsg-replace="true">
#            </span>
#           </div>
#           <div class="form-group">
#            <label for="LastName" id="lblSMSLastNameFS">
#             Last Name
#            </label>
#            <input aria-labelledby="lblSMSLastNameFS" class="form-control" data-val="true" data-val-required="The Last Name field is required." id="txtSMSLastNameFS" name="LastName" type="text" value=""/>
#            <span class="text-danger field-validation-valid" data-valmsg-for="LastName" data-valmsg-replace="true">
#            </span>
#           </div>
#           <div class="form-group">
#            <label for="MobilePhone" id="lblSMSPhoneNumberFS">
#             Mobile Phone
#            </label>
#            <input aria-labelledby="lblSMSPhoneNumberFS" class="form-control" data-val="true" data-val-regex="ex. ###-###-####" data-val-regex-pattern="^\([0-9]{3}\)\s?[0-9]{3}(-|\s)?[0-9]{4}$|^[0-9]{3}-?[0-9]{3}-?[0-9]{4}$" data-val-required="The Mobile Phone field is required." id="txtSMSPhoneNumberFS" name="MobilePhone" type="tel" value=""/>
#            <span class="text-danger field-validation-valid" data-valmsg-for="MobilePhone" data-valmsg-replace="true">
#            </span>
#           </div>
#           <div class="form-group">
#            <label for="Comments" id="lblMessage">
#             Comments
#            </label>
#            <textarea aria-labelledby="lblMessage" class="form-control form-textarea" data-val="true" data-val-required="The Comments field is required." id="Message" name="Comments">
# </textarea>
#            <span class="text-danger field-validation-valid" data-valmsg-for="Comments" data-valmsg-replace="true">
#            </span>
#           </div>
#           <div class="contact-disclaimer">
#            <div class="form-group">
#             <div class="form-check">
#              <input aria-label="Contact Consent" class="form-check-input" data-val="true" data-val-range="Please check the box to verify acknowledgement and consent." data-val-range-max="True" data-val-range-min="True" data-val-required="The ContactDisclaimerConsent field is required." id="chkContactDisclaimerConsent" name="ContactDisclaimerConsent" type="checkbox" value="true"/>
#              <label aria-labelledby="chkContactDisclaimerConsent" for="chkContactDisclaimerConsent">
#               <strong>
#                ACKNOWLEDGMENT AND CONSENT:
#               </strong>
#              </label>
#              <span class="text-danger field-validation-valid" data-valmsg-for="ContactDisclaimerConsent" data-valmsg-replace="true">
#              </span>
#             </div>
#             I hereby consent to receive text messages or phone calls from or on behalf of the dealer or their employees to the mobile phone number I provided above.  By opting in,  I understand that message and data rates may apply.  This acknowledgement constitutes my written consent to receive text messages to my cell phone and phone calls, including communications sent using an auto-dialer or pre-recorded message. You may withdraw your consent at any time by texting "STOP".
#            </div>
#           </div>
#           <div>
#           </div>
#           <div class="modal-footer">
#            <button class="sms_submitButtonFS btn btn-SMSModal">
#             I agree, Send Text
#             <i class="fas fa-spinner fa-spin fa-fw spinner-SMSModal" style="display: none">
#             </i>
#            </button>
#            <a href="/privacy" rel="noopener" target="_blank">
#             Privacy Policy
#            </a>
#           </div>
#           <input data-val="true" data-val-required="The VehicleId field is required." id="responsiveSmsTextingFormVehicleId" name="VehicleId" type="hidden" value="0"/>
#           <input data-val="true" data-val-required="The HasAccountSid field is required." id="HasAccountSid" name="HasAccountSid" type="hidden" value="True"/>
#           <div class="RowIce">
#            <input aria-label="Name" autocomplete="off" class="form-control" name="Name" type="text"/>
#           </div>
#           <input name="__RequestVerificationToken" type="hidden" value="CfDJ8M23iDBLc7xIvR1mlIAam6tTC-8_-m5_mC-4KrLXnFfl0II5nbPGmyTdgAsOEk0612jaRuSbDiuQTrUugkG4VF9ET5VGl6DwTSJpkw4JSg97f0vGfadrXEEXOAGtjqWyjLCjt6W197PLNKy7CuVV9bo"/>
#           <input name="ContactDisclaimerConsent" type="hidden" value="false"/>
#          </form>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <a aria-label="Go to top of page" class="top" href="#" title="Go to top of page">
#    <i class="fas fa-chevron-up">
#    </i>
#   </a>
#   <script src="/Dealers/13001_14000/13526_mvc/26263.min.js?v=I4Ta7qWzJfj7pvi8pF-DXiG7yuX8HbH1xE6GjkKBF4k" type="text/javascript">
#   </script>
#   <noscript>
#    <img height="1" src="https://www.facebook.com/tr?id=322504756443439&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/>
#   </noscript>
#   <!--
# DEBUG INFORMATION
# =================
#
# Running on DCSPCMS13
# Release Name: Release-82
# Release Definition: new-cms-production-release
# Environment: Prod (Odd)
# Build Definition Id: 83
# Build Definition Name: cms-production-build
# Build Number: cms-production-build_2022.1.26.1
# Build Id: 19064
# Build URI: vstfs:///Build/Build/19064
# Source Branch: refs/heads/master
# Source Branch Name: master
# Source Version: 81676b4f2db95956c9da48fe4b988aab1bc8a3a8
# Requested For: Matthew Ingram
# Build Type: Build
#
# -->
#  </body>
# </html>

# %%
pi.clean_text_data(pi.parse_subsection(soup, 'div', 'h4', 'row no-gutters invMainCell', 'd-md-none titleWrapPhoneView', 'get_text'))
# Out:
# ['2013 Acura RDX AWD 4dr Tech Pkg',
#  '2009 Audi A4 4dr Sdn Auto 2.0T quattro Prem',
#  '2012 Audi A4 4dr Sdn Auto quattro 2.0T Premium',
#  '2013 Audi Q5 quattro 4dr 2.0T Premium',
#  '2006 BMW 6 Series 650Ci 2dr Cpe',
#  '2013 BMW X5 AWD 4dr xDrive35i',
#  '2014 Buick Encore FWD 4dr Convenience',
#  "1987 Cadillac Allante' 2dr Coupe Convertible",
#  '2008 Cadillac CTS 4dr Sdn AWD w/1SA',
#  '1964 Cadillac Fleetwood 4dr Sedan',
#  '2012 Chevrolet Camaro 2dr Cpe 2LS',
#  '2011 Chevrolet Cruze 4dr Sdn LS',
#  '2006 Chevrolet Equinox 4dr AWD LS',
#  '2015 Chevrolet Equinox AWD 4dr LT w/1LT',
#  '2014 Chevrolet Express Cargo Van RWD 1500 135"',
#  '2009 Chevrolet Silverado 1500 4WD Ext Cab 143.5" LT',
#  '2011 Chevrolet Silverado 1500 4WD Ext Cab 143.5" LT',
#  '2014 Chevrolet Spark 5dr HB CVT LS',
#  '2005 Chevrolet Suburban 4dr 1500 4WD LS',
#  '2010 Chevrolet Tahoe 4WD 4dr 1500 LTZ',
#  '2015 Chevrolet Tahoe 4WD 4dr LT',
#  '2006 Chevrolet TrailBlazer 4dr 4WD LS',
#  '2010 Chrysler 300 4dr Sdn Touring Signature AWD',
#  '2012 Chrysler 300 4dr Sdn V8 300C AWD',
#  '2014 Chrysler Town & Country 4dr Wgn Touring']

# %%
pi.parse_subsection(soup, 'div', 'span', 'row no-gutters invMainCell', 'vehicleTrim', 'get_text')
# Out:
# ['AWD 4dr Tech Pkg',
#  '4dr Sdn Auto 2.0T quattro Prem',
#  '4dr Sdn Auto quattro 2.0T Premium',
#  'quattro 4dr 2.0T Premium',
#  '650Ci 2dr Cpe',
#  'AWD 4dr xDrive35i',
#  'FWD 4dr Convenience',
#  '2dr Coupe Convertible',
#  '4dr Sdn AWD w/1SA',
#  '4dr Sedan',
#  '2dr Cpe 2LS',
#  '4dr Sdn LS',
#  '4dr AWD LS',
#  'AWD 4dr LT w/1LT',
#  'RWD 1500 135"',
#  '4WD Ext Cab 143.5" LT',
#  '4WD Ext Cab 143.5" LT',
#  '5dr HB CVT LS',
#  '4dr 1500 4WD LS',
#  '4WD 4dr 1500 LTZ',
#  '4WD 4dr LT',
#  '4dr 4WD LS',
#  '4dr Sdn Touring Signature AWD',
#  '4dr Sdn V8 300C AWD',
#  '4dr Wgn Touring']

# %%
# optMileage
pi.convert_to_numeric_type(pi.parse_subsection(soup, 'div', 'span', 'row no-gutters invMainCell', 'lblPrice'))
# Out:
# [19995,
#  11995,
#  nan,
#  19995,
#  9995,
#  19995,
#  16995,
#  9995,
#  7995,
#  17995,
#  16995,
#  9995,
#  6995,
#  15995,
#  15995,
#  12995,
#  18995,
#  10995,
#  9995,
#  16995,
#  30995,
#  nan,
#  10995,
#  16995,
#  nan]

# %%
pi.clean_text_data(pi.parse_subsection(soup, 'div', 'p', 'row no-gutters invMainCell', 'optTrans', 'get_text'), 'Trans')
# Out:
# ['Automatic',
#  'Automatic',
#  'Automatic',
#  'Automatic',
#  'Automatic',
#  'Automatic',
#  'Automatic',
#  'Automatic',
#  'Automatic',
#  'Automatic',
#  'Automatic',
#  'Automatic',
#  'Automatic',
#  'Automatic',
#  'Automatic',
#  'Automatic',
#  'Automatic',
#  'Automatic',
#  'Automatic',
#  'Automatic',
#  'Automatic',
#  'Automatic',
#  'Automatic',
#  'Automatic',
#  'Automatic']

# %%
pi.clean_text_data(pi.parse_subsection(soup, 'div', 'p', 'row no-gutters invMainCell', 'optVin', 'get_text'), 'VIN')
# Out:
# ['5J8TB4H51DL005972',
#  'WAULF78K69N067192',
#  'WAUBFAFL8CN004834',
#  'WA1CFAFP1DA085124',
#  'WBAEH13486CR51196',
#  '5UXZV4C5XD0B17566',
#  'KL4CJBSB2EB544171',
#  '1G6VR3176HU102161',
#  '1G6DG577280131877',
#  '64M082190X',
#  '2G1FA1E32C9176793',
#  '1G1PC5SH5B7221750',
#  '2CNDL23F266135982',
#  '2GNFLFEK8F6252360',
#  '1GCSGAFX6E1185297',
#  '2GCEK290991116376',
#  '1GCRKSE37BZ399181',
#  'KL8CB6S97EC522550',
#  '1GNFK16Z75J158134',
#  '1GNUKCE07AR136247',
#  '1GNSKBKC3FR242301',
#  '1GNDT13S762251193',
#  '2C3CK5CV9AH305056',
#  '2C3CCAKT6CH188934',
#  '2C4RC1BG9ER295790']

# %%
dealerships = {
    'Bostonyan Auto Group': {
        'url': 'https://www.bostonyanautogroup.com/view-inventory',
        'pagination_url': '',
        'dealership_name': 'Bostonyan Auto Group',
        'address': '119 Worcester St',
        'zipcode': '01760',
        'city': 'Natick',
        'state': 'MA'
    },
    'Direct Auto Mecca': {
        'url': 'https://www.directautomecca.com/view-inventory.aspx',
        'pagination_url': 'https://www.directautomecca.com/inventory.aspx?_new=true&_used=true&_page=2',
        'dealership_name': 'Direct Auto Mecca',
        'address': '154 Waverly Street',
        'zipcode': '01760',
        'city': 'Natick',
        'state': 'MA'
    },
    'Fafama Auto Sales': {
        'url': 'https://www.fafama.com/used-cars.aspx',
        'pagination_url': 'https://www.fafama.com/inventory.aspx?_used=true&_page=2',
        'dealership_name': 'Fafama Auto Sales',
        'address': '5 Cape Road',
        'zipcode': '01757',
        'city': 'Milford',
        'state': 'MA'
    },
    'Newton Automotive Sales': {
        'url': 'https://www.newtonautoandsales.com/cars-for-sale',
        'pagination_url': 'https://www.newtonautoandsales.com/cars-for-sale?PageNumber=2&Sort=MakeAsc&StockNumber=&Condition=&BodyStyle=&Make=&MaxPrice=&Mileage=&SoldStatus=AllVehicles&StockNumber=',
        'dealership_name': 'Newton Automotive Sales',
        'address': '249 Centre Street',
        'zipcode': '02458',
        'city': 'Newton',
        'state': 'MA'
    },
    'Blasius Boston': {
        'url': 'https://www.blasiusboston.com/used-cars-holliston-ma',
        'pagination_url': 'https://www.blasiusboston.com/used-cars-holliston-ma?page=2',
        'dealership_name': 'Blasius Boston',
        'address': '1286 Washington Street',
        'zipcode': '01746',
        'city': 'Holliston',
        'state': 'MA'
    },
    'Avon Auto Brokers': {
        'url': 'https://avonautobrokers.com/newandusedcars?clearall=1',
        'pagination_url': 'https://avonautobrokers.com/newandusedcars?page=2',
        'dealership_name': 'Avon Auto Brokers',
        'address': '159 Memorial Drive',
        'zipcode': '02322',
        'city': 'Avon',
        'state': 'MA'
    }, 
    'Johns Auto Sales': {
        'url': 'https://johnsautosales.com/newandusedcars?clearall=1',
        'pagination_url': 'https://johnsautosales.com/newandusedcars?page=2',
        'dealership_name': "John's Auto Sales",
        'address': '181 Somerville Avenue',
        'zipcode': '02143',
        'city': 'Somerville',
        'state': 'MA'
    }
}

# %%
c = parse_dealership.get_johns_auto_inventory_data(soup, dealerships['Johns Auto Sales'])

# %%
c
# Out:
#                                                 title  year       make  \
# 0                     2013 Acura RDX AWD 4dr Tech Pkg  2013      Acura
# 1         2009 Audi A4 4dr Sdn Auto 2.0T quattro Prem  2009       Audi
# 2      2012 Audi A4 4dr Sdn Auto quattro 2.0T Premium  2012       Audi
# 3               2013 Audi Q5 quattro 4dr 2.0T Premium  2013       Audi
# 4                     2006 BMW 6 Series 650Ci 2dr Cpe  2006        BMW
# 5                       2013 BMW X5 AWD 4dr xDrive35i  2013        BMW
# 6               2014 Buick Encore FWD 4dr Convenience  2014      Buick
# 7        1987 Cadillac Allante' 2dr Coupe Convertible  1987   Cadillac
# 8                 2008 Cadillac CTS 4dr Sdn AWD w/1SA  2008   Cadillac
# 9                   1964 Cadillac Fleetwood 4dr Sedan  1964   Cadillac
# 10                  2012 Chevrolet Camaro 2dr Cpe 2LS  2012  Chevrolet
# 11                    2011 Chevrolet Cruze 4dr Sdn LS  2011  Chevrolet
# 12                  2006 Chevrolet Equinox 4dr AWD LS  2006  Chevrolet
# 13            2015 Chevrolet Equinox AWD 4dr LT w/1LT  2015  Chevrolet
# 14     2014 Chevrolet Express Cargo Van RWD 1500 135"  2014  Chevrolet
# 15  2009 Chevrolet Silverado 1500 4WD Ext Cab 143....  2009  Chevrolet
# 16  2011 Chevrolet Silverado 1500 4WD Ext Cab 143....  2011  Chevrolet
# 17                 2014 Chevrolet Spark 5dr HB CVT LS  2014  Chevrolet
# 18            2005 Chevrolet Suburban 4dr 1500 4WD LS  2005  Chevrolet
# 19              2010 Chevrolet Tahoe 4WD 4dr 1500 LTZ  2010  Chevrolet
# 20                    2015 Chevrolet Tahoe 4WD 4dr LT  2015  Chevrolet
# 21              2006 Chevrolet TrailBlazer 4dr 4WD LS  2006  Chevrolet
# 22    2010 Chrysler 300 4dr Sdn Touring Signature AWD  2010   Chrysler
# 23              2012 Chrysler 300 4dr Sdn V8 300C AWD  2012   Chrysler
# 24       2014 Chrysler Town & Country 4dr Wgn Touring  2014   Chrysler
#
#                               model_trim vehicle_type model  \
# 0                   RDX AWD 4dr Tech Pkg         None  None
# 1      A4 4dr Sdn Auto 2.0T quattro Prem         None  None
# 2   A4 4dr Sdn Auto quattro 2.0T Premium         None  None
# 3            Q5 quattro 4dr 2.0T Premium         None  None
# 4                 6 Series 650Ci 2dr Cpe         None  None
# 5                   X5 AWD 4dr xDrive35i         None  None
# 6             Encore FWD 4dr Convenience         None  None
# 7              Allante' 2dr  Convertible        Coupe  None
# 8                  CTS 4dr Sdn AWD w/1SA         None  None
# 9                          Fleetwood 4dr        Sedan  None
# 10                    Camaro 2dr Cpe 2LS         None  None
# 11                      Cruze 4dr Sdn LS         None  None
# 12                    Equinox 4dr AWD LS         None  None
# 13              Equinox AWD 4dr LT w/1LT         None  None
# 14                Express  RWD 1500 135"    Cargo Van  None
# 15  Silverado 1500 4WD Ext Cab 143.5" LT         None  None
# 16  Silverado 1500 4WD Ext Cab 143.5" LT         None  None
# 17                   Spark 5dr HB CVT LS         None  None
# 18              Suburban 4dr 1500 4WD LS         None  None
# 19                Tahoe 4WD 4dr 1500 LTZ         None  None
# 20                      Tahoe 4WD 4dr LT         None  None
# 21                TrailBlazer 4dr 4WD LS         None  None
# 22     300 4dr Sdn Touring Signature AWD         None  None
# 23               300 4dr Sdn V8 300C AWD         None  None
# 24        Town & Country 4dr Wgn Touring         None  None
#
#                                  trim  vehicle_mileage    price  \
# 0                    AWD 4dr Tech Pkg            78120  19995.0
# 1      4dr Sdn Auto 2.0T quattro Prem           118649  11995.0
# 2   4dr Sdn Auto quattro 2.0T Premium           118451      NaN
# 3            quattro 4dr 2.0T Premium            70165  19995.0
# 4                       650Ci 2dr Cpe           142077   9995.0
# 5                   AWD 4dr xDrive35i           106583  19995.0
# 6                 FWD 4dr Convenience            72421  16995.0
# 7               2dr Coupe Convertible           115290   9995.0
# 8                   4dr Sdn AWD w/1SA           125476   7995.0
# 9                           4dr Sedan                1  17995.0
# 10                        2dr Cpe 2LS            98033  16995.0
# 11                         4dr Sdn LS           104986   9995.0
# 12                         4dr AWD LS           112546   6995.0
# 13                   AWD 4dr LT w/1LT           137514  15995.0
# 14                      RWD 1500 135"           141772  15995.0
# 15              4WD Ext Cab 143.5" LT           112210  12995.0
# 16              4WD Ext Cab 143.5" LT            75867  18995.0
# 17                      5dr HB CVT LS            75996  10995.0
# 18                    4dr 1500 4WD LS            84716   9995.0
# 19                   4WD 4dr 1500 LTZ           145791  16995.0
# 20                         4WD 4dr LT           106577  30995.0
# 21                         4dr 4WD LS           175486      NaN
# 22      4dr Sdn Touring Signature AWD            99639  10995.0
# 23                4dr Sdn V8 300C AWD           119052  16995.0
# 24                    4dr Wgn Touring           113940      NaN
#
#    exterior_color  ...                                             engine  \
# 0      Light Blue  ...                3.5L SOHC 24-valve i-VTEC V6 engine
# 1           Black  ...                   2.0L FSI I4 turbo-charged engine
# 2          Silver  ...                   2.0L FSI I4 turbo-charged engine
# 3       Dark Blue  ...                   2.0L TFSI turbocharged I4 engine
# 4           Black  ...  4.8L DOHC 32-valve V8 engine w/steplessly vari...
# 5           Black  ...  3.0-liter, 300-horsepower, 24-valve inline 6-c...
# 6           Black  ...  Engine, ECOTEC Turbo 1.4L Variable Valve Timin...
# 7           Brown  ...                                  8 Cylinder Engine
# 8             Red  ...  Engine, 3.6L Variable Valve Timing V6 PFI (263...
# 9           White  ...                                             Select
# 10         Yellow  ...  Engine, 3.6L SIDI DOHC V6 VVT (323 hp [240.8 k...
# 11         Silver  ...  Engine, ECOTEC 1.8L Variable Valve Timing DOHC...
# 12            RED  ...  Engine, 3.4L 3400 V6 (185 HP [138.0 kW] @ 5200...
# 13          Black  ...  Engine, 2.4L DOHC 4-cylinder SIDI (Spark Ignit...
# 14          Black  ...  Engine, Vortec 4.3L V6 MFI (195 hp [145.4 kW] ...
# 15       Burgundy  ...  VORTEC 5.3L V8 SFI FLEXFUEL WITH ACTIVE FUEL M...
# 16           Blue  ...  VORTEC 5.3L VARIABLE VALVE TIMING V8 SFI FLEXF...
# 17          White  ...  Engine, ECOTEC 1.2L DOHC 4-cylinder MFI (84 hp...
# 18          White  ...  Engine, Vortec 5300 V8 SFI Flex-Fuel, capable ...
# 19            Tan  ...  Engine, Vortec 5.3L V8 SFI FlexFuel with Activ...
# 20          Black  ...  Engine, 5.3L EcoTec3 V8 with Active Fuel Manag...
# 21           Blue  ...  Engine, Vortec 4200 SFI I6, includes transmiss...
# 22          White  ...                     3.5L MPI 24-valve HO V6 engine
# 23          Black  ...                        5.7L V8 hemi MDS VVT engine
# 24           Blue  ...                                    3.6L V6 24V VVT
#
#    drivetrain                vin    dealership_name     dealership_address  \
# 0         AWD  5J8TB4H51DL005972  John's Auto Sales  181 Somerville Avenue
# 1         AWD  WAULF78K69N067192  John's Auto Sales  181 Somerville Avenue
# 2         FWD  WAUBFAFL8CN004834  John's Auto Sales  181 Somerville Avenue
# 3         AWD  WA1CFAFP1DA085124  John's Auto Sales  181 Somerville Avenue
# 4         RWD  WBAEH13486CR51196  John's Auto Sales  181 Somerville Avenue
# 5         AWD  5UXZV4C5XD0B17566  John's Auto Sales  181 Somerville Avenue
# 6         FWD  KL4CJBSB2EB544171  John's Auto Sales  181 Somerville Avenue
# 7         FWD  1G6VR3176HU102161  John's Auto Sales  181 Somerville Avenue
# 8         AWD  1G6DG577280131877  John's Auto Sales  181 Somerville Avenue
# 9         FWD         64M082190X  John's Auto Sales  181 Somerville Avenue
# 10        RWD  2G1FA1E32C9176793  John's Auto Sales  181 Somerville Avenue
# 11        FWD  1G1PC5SH5B7221750  John's Auto Sales  181 Somerville Avenue
# 12        AWD  2CNDL23F266135982  John's Auto Sales  181 Somerville Avenue
# 13        AWD  2GNFLFEK8F6252360  John's Auto Sales  181 Somerville Avenue
# 14        RWD  1GCSGAFX6E1185297  John's Auto Sales  181 Somerville Avenue
# 15        4WD  2GCEK290991116376  John's Auto Sales  181 Somerville Avenue
# 16        4WD  1GCRKSE37BZ399181  John's Auto Sales  181 Somerville Avenue
# 17        FWD  KL8CB6S97EC522550  John's Auto Sales  181 Somerville Avenue
# 18        4WD  1GNFK16Z75J158134  John's Auto Sales  181 Somerville Avenue
# 19        4WD  1GNUKCE07AR136247  John's Auto Sales  181 Somerville Avenue
# 20        4WD  1GNSKBKC3FR242301  John's Auto Sales  181 Somerville Avenue
# 21        4WD  1GNDT13S762251193  John's Auto Sales  181 Somerville Avenue
# 22        AWD  2C3CK5CV9AH305056  John's Auto Sales  181 Somerville Avenue
# 23        AWD  2C3CCAKT6CH188934  John's Auto Sales  181 Somerville Avenue
# 24        FWD  2C4RC1BG9ER295790  John's Auto Sales  181 Somerville Avenue
#
#    dealership_zipcode dealership_city dealership_state  \
# 0               02143      Somerville               MA
# 1               02143      Somerville               MA
# 2               02143      Somerville               MA
# 3               02143      Somerville               MA
# 4               02143      Somerville               MA
# 5               02143      Somerville               MA
# 6               02143      Somerville               MA
# 7               02143      Somerville               MA
# 8               02143      Somerville               MA
# 9               02143      Somerville               MA
# 10              02143      Somerville               MA
# 11              02143      Somerville               MA
# 12              02143      Somerville               MA
# 13              02143      Somerville               MA
# 14              02143      Somerville               MA
# 15              02143      Somerville               MA
# 16              02143      Somerville               MA
# 17              02143      Somerville               MA
# 18              02143      Somerville               MA
# 19              02143      Somerville               MA
# 20              02143      Somerville               MA
# 21              02143      Somerville               MA
# 22              02143      Somerville               MA
# 23              02143      Somerville               MA
# 24              02143      Somerville               MA
#
#                                         inventory_url  \
# 0   https://johnsautosales.com/newandusedcars?clea...
# 1   https://johnsautosales.com/newandusedcars?clea...
# 2   https://johnsautosales.com/newandusedcars?clea...
# 3   https://johnsautosales.com/newandusedcars?clea...
# 4   https://johnsautosales.com/newandusedcars?clea...
# 5   https://johnsautosales.com/newandusedcars?clea...
# 6   https://johnsautosales.com/newandusedcars?clea...
# 7   https://johnsautosales.com/newandusedcars?clea...
# 8   https://johnsautosales.com/newandusedcars?clea...
# 9   https://johnsautosales.com/newandusedcars?clea...
# 10  https://johnsautosales.com/newandusedcars?clea...
# 11  https://johnsautosales.com/newandusedcars?clea...
# 12  https://johnsautosales.com/newandusedcars?clea...
# 13  https://johnsautosales.com/newandusedcars?clea...
# 14  https://johnsautosales.com/newandusedcars?clea...
# 15  https://johnsautosales.com/newandusedcars?clea...
# 16  https://johnsautosales.com/newandusedcars?clea...
# 17  https://johnsautosales.com/newandusedcars?clea...
# 18  https://johnsautosales.com/newandusedcars?clea...
# 19  https://johnsautosales.com/newandusedcars?clea...
# 20  https://johnsautosales.com/newandusedcars?clea...
# 21  https://johnsautosales.com/newandusedcars?clea...
# 22  https://johnsautosales.com/newandusedcars?clea...
# 23  https://johnsautosales.com/newandusedcars?clea...
# 24  https://johnsautosales.com/newandusedcars?clea...
#
#                  scraped_date
# 0  2022-03-15 18:27:54.469048
# 1  2022-03-15 18:27:54.469048
# 2  2022-03-15 18:27:54.469048
# 3  2022-03-15 18:27:54.469048
# 4  2022-03-15 18:27:54.469048
# 5  2022-03-15 18:27:54.469048
# 6  2022-03-15 18:27:54.469048
# 7  2022-03-15 18:27:54.469048
# 8  2022-03-15 18:27:54.469048
# 9  2022-03-15 18:27:54.469048
# 10 2022-03-15 18:27:54.469048
# 11 2022-03-15 18:27:54.469048
# 12 2022-03-15 18:27:54.469048
# 13 2022-03-15 18:27:54.469048
# 14 2022-03-15 18:27:54.469048
# 15 2022-03-15 18:27:54.469048
# 16 2022-03-15 18:27:54.469048
# 17 2022-03-15 18:27:54.469048
# 18 2022-03-15 18:27:54.469048
# 19 2022-03-15 18:27:54.469048
# 20 2022-03-15 18:27:54.469048
# 21 2022-03-15 18:27:54.469048
# 22 2022-03-15 18:27:54.469048
# 23 2022-03-15 18:27:54.469048
# 24 2022-03-15 18:27:54.469048
#
# [25 rows x 22 columns]
