# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
from datetime import datetime
import sqlite3
import re

# %%
#URL = 'https://www.bernardihondanatick.com/used-inventory/index.htm'
#URL = 'https://www.unitedautonatick.com/'

headers = {
    'user-agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/56.0.2924.87 Safari/537.36',
}

URL = 'https://www.directautomecca.com/view-inventory.aspx'
response = requests.get(URL, headers = headers)

soup = BeautifulSoup(response.text, "html.parser")

print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en-US">
#  <head>
#   <title>
#    Boston Used cars|Used Cars Serving the Boston Area |Used Audi|Used Toyota|Used Bmw|Nissan|Honda
#   </title>
#   <meta content="Boston Used Cars, for best selection of used cars in Boston. Worcester Used Prices  Audis,Toyotas,Bmws,Nissans,Hondas." name="description"/>
#   <meta content="Boston Used Cars, Used Audis in Boston, Used Toyotas in Boston, Used Bmw dealer in Boston, Used Nissan cars in boston, Honda certified cars in Boston." name="keywords"/>
#   <meta content="text/html; charset=utf-8" http-equiv="content-type">
#    <meta content="DirectAutomecca.com" name="author">
#     <meta content="width=device-width, initial-scale=1" name="viewport"/>
#     <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#     <meta content="Boston Used cars|Used Cars Serving the Boston Area |Used Audi|Used Toyota|Used Bmw|Nissan|Honda" name="og:title"/>
#     <meta content="website" name="og:type"/>
#     <meta content="DirectAutomecca.com" property="og:site_name"/>
#     <meta content="http://www.directautomecca.com/view-inventory.aspx" name="og:url"/>
#     <meta content="Boston Used Cars, for best selection of used cars in Boston. Worcester Used Prices  Audis,Toyotas,Bmws,Nissans,Hondas." name="og:description"/>
#     <meta content="https://images.ebizautos.media/Foundation/Sites/7725/AccountTemplate/images/dealer-image.jpg" property="og:image"/>
#     <link href="https://www.directautomecca.com/view-inventory.aspx" rel="canonical"/>
#     <link href="//images.ebizautos.media/Foundation/Templates/-2147483646/images/favicon.ico" rel="icon" type="image/x-icon"/>
#     <link crossorigin="" href="https://images.ebizautos.media" rel="preconnect"/>
#     <link crossorigin="" href="https://cdn.ebizautos.media" rel="preconnect"/>
#     <link crossorigin="" href="https://stockphotos.ebizautos.media" rel="preconnect"/>
#     <link as="font" crossorigin="" href="https://images.ebizautos.media/fonts/foundation-icons/font-icons.woff" rel="preload" type="font/woff"/>
#     <link as="font" crossorigin="" href="https://images.ebizautos.media/fonts/foundation-icons/font-icons.woff2" rel="preload" type="font/woff2"/>
#     <link as="font" crossorigin="" href="https://images.ebizautos.media/fonts/foundation-icons/font-icons-2.woff" rel="preload" type="font/woff"/>
#     <link as="font" crossorigin="" href="https://images.ebizautos.media/fonts/foundation-icons/font-icons-2.woff2" rel="preload" type="font/woff2"/>
#     <link as="font" crossorigin="" href="https://images.ebizautos.media/fonts/foundation-icons/font-icons-3.woff" rel="preload" type="font/woff"/>
#     <link as="font" crossorigin="" href="https://images.ebizautos.media/fonts/foundation-icons/font-icons-3.woff2" rel="preload" type="font/woff2"/>
#     <link as="font" crossorigin="" href="https://images.ebizautos.media/fonts/foundation-icons/font-icons-4.woff" rel="preload" type="font/woff"/>
#     <link as="font" crossorigin="" href="https://images.ebizautos.media/fonts/foundation-icons/font-icons-4.woff2" rel="preload" type="font/woff2"/>
#     <link as="font" crossorigin="" href="https://images.ebizautos.media/fonts/foundation-icons/lined-icons.woff" rel="preload" type="font/woff"/>
#     <link as="font" crossorigin="" href="https://images.ebizautos.media/fonts/foundation-icons/lined-icons.woff2" rel="preload" type="font/woff2"/>
#     <link as="font" crossorigin="" href="https://images.ebizautos.media/fonts/foundation-icons/Simple-Line-Icons.woff" rel="preload" type="font/woff"/>
#     <link as="font" crossorigin="" href="https://images.ebizautos.media/fonts/foundation-icons/Simple-Line-Icons.woff2" rel="preload" type="font/woff2"/>
#     <link as="font" crossorigin="" href="https://images.ebizautos.media/fonts/foundation-icons/font-vehicles.woff" rel="preload" type="font/woff"/>
#     <link as="font" crossorigin="" href="https://images.ebizautos.media/fonts/foundation-icons/font-vehicles.woff2" rel="preload" type="font/woff2"/>
#     <link as="font" crossorigin="" href="https://images.ebizautos.media/fonts/foundation-icons/font-features.woff" rel="preload" type="font/woff"/>
#     <link as="font" crossorigin="" href="https://images.ebizautos.media/fonts/foundation-icons/font-features.woff2" rel="preload" type="font/woff2"/>
#     <link href="https://images.ebizautos.media/Foundation/Controls/-2147483583/css/foundation.css" rel="stylesheet" type="text/css">
#      <link href="https://images.ebizautos.media/Foundation/Controls/-2147483583/css/font-icons.css" rel="stylesheet" type="text/css">
#       <link href="https://images.ebizautos.media/Foundation/Templates/-2147483602/css/fonts.css" rel="stylesheet" type="text/css">
#        <link href="https://images.ebizautos.media/Foundation/Templates/-2147483602/css/foundation-theme.css" rel="stylesheet" type="text/css">
#         <link href="https://images.ebizautos.media/Foundation/Templates/-2147483602/css/responsive.css" rel="stylesheet" type="text/css">
#          <link href="https://images.ebizautos.media/Foundation/Sites/7725/AccountTemplate/css/custom.css" rel="stylesheet" type="text/css">
#           <style type="text/css">
#           </style>
#           <!--[if lt IE 9]>
#   <script src="//css3-mediaqueries-js.googlecode.com/svn/trunk/css3-mediaqueries.js"></script>
# <![endif]-->
#           <!-- HeaderContents_Foundation_jQuery_v1.12.0 -->
#           <script src="https://images.ebizautos.media/Foundation/Templates/-2147483646/js/jquery.min.js">
#           </script>
#           <script src="https://images.ebizautos.media/Foundation/Templates/-2147483646/js/jquery.cookie.min.js">
#           </script>
#           <!-- HeaderContents_PriceAlert_JS -->
#           <script defer="" src="https://images.ebizautos.media/Foundation/Templates/-2147483646/js/pas-common.min.js">
#           </script>
#           <script defer="" src="https://images.ebizautos.media/Foundation/Templates/-2147483646/js/pas-client.min.js">
#           </script>
#           <script language="javascript" type="text/javascript">
#            var _leadJSParams = {
# 		14 : 'https://secure-leads.motorcar.com/leads/?siteguid=47db61e2-a054-4304-b8b6-94ec4beb4087&leadsource=ebizautos&leadtype=scheduleappointmentrequest&contactid=18623&pageid=23852&pagetypeid=2&campaignid=9&campaignsitetypeid=1&segmentdefaultcampaignid=9&initialrefer=&initialurl=&initialtarget=http%3A%2F%2Fwww.directautomecca.com%2Fview-inventory.aspx&sourcepage=http%3A%2F%2Fwww.directautomecca.com%2Fview-inventory.aspx&hastoincludetransferfee=false&campaigntypeid=10&sitebox=sitebox_general2',
# 29 : 'https://secure-leads.motorcar.com/leads/?siteguid=47db61e2-a054-4304-b8b6-94ec4beb4087&leadsource=ebizautos&leadtype=partsrequest&contactid=36594&pageid=23852&pagetypeid=2&campaignid=9&campaignsitetypeid=1&segmentdefaultcampaignid=9&initialrefer=&initialurl=&initialtarget=http%3A%2F%2Fwww.directautomecca.com%2Fview-inventory.aspx&sourcepage=http%3A%2F%2Fwww.directautomecca.com%2Fview-inventory.aspx&hastoincludetransferfee=false&campaigntypeid=10&sitebox=sitebox_general2',
# 13 : 'https://secure-leads.motorcar.com/leads/?siteguid=47db61e2-a054-4304-b8b6-94ec4beb4087&leadsource=ebizautos&leadtype=vehiclefinder&contactid=10284&pageid=23852&pagetypeid=2&campaignid=9&campaignsitetypeid=1&segmentdefaultcampaignid=9&initialrefer=&initialurl=&initialtarget=http%3A%2F%2Fwww.directautomecca.com%2Fview-inventory.aspx&sourcepage=http%3A%2F%2Fwww.directautomecca.com%2Fview-inventory.aspx&hastoincludetransferfee=false&campaigntypeid=10&sitebox=sitebox_general2',
# 40 : 'https://secure-leads.motorcar.com/leads/?siteguid=47db61e2-a054-4304-b8b6-94ec4beb4087&leadsource=ebizautos&leadtype=contactus&contactid=10284&pageid=23852&pagetypeid=2&campaignid=9&campaignsitetypeid=1&segmentdefaultcampaignid=9&initialrefer=&initialurl=&initialtarget=http%3A%2F%2Fwww.directautomecca.com%2Fview-inventory.aspx&sourcepage=http%3A%2F%2Fwww.directautomecca.com%2Fview-inventory.aspx&hastoincludetransferfee=false&campaigntypeid=10&sitebox=sitebox_general2',
# 1 : 'https://secure-leads.motorcar.com/leads/?siteguid=47db61e2-a054-4304-b8b6-94ec4beb4087&leadsource=ebizautos&leadtype=email&pageid=23852&pagetypeid=2&campaignid=9&campaignsitetypeid=1&segmentdefaultcampaignid=9&initialrefer=&initialurl=&initialtarget=http%3A%2F%2Fwww.directautomecca.com%2Fview-inventory.aspx&sourcepage=http%3A%2F%2Fwww.directautomecca.com%2Fview-inventory.aspx&hastoincludetransferfee=false&campaigntypeid=10&sitebox=sitebox_general2',
# 45 : 'https://secure-leads.motorcar.com/leads/?siteguid=47db61e2-a054-4304-b8b6-94ec4beb4087&leadsource=ebizautos&leadtype=textrequest&pageid=23852&pagetypeid=2&campaignid=9&campaignsitetypeid=1&segmentdefaultcampaignid=9&initialrefer=&initialurl=&initialtarget=http%3A%2F%2Fwww.directautomecca.com%2Fview-inventory.aspx&sourcepage=http%3A%2F%2Fwww.directautomecca.com%2Fview-inventory.aspx&hastoincludetransferfee=false&campaigntypeid=10&sitebox=sitebox_general2',
# 9 : 'https://secure-leads.motorcar.com/leads/?siteguid=47db61e2-a054-4304-b8b6-94ec4beb4087&leadsource=ebizautos&leadtype=tradeappraisal&contactid=10284&pageid=23852&pagetypeid=2&campaignid=9&campaignsitetypeid=1&segmentdefaultcampaignid=9&initialrefer=&initialurl=&initialtarget=http%3A%2F%2Fwww.directautomecca.com%2Fview-inventory.aspx&sourcepage=http%3A%2F%2Fwww.directautomecca.com%2Fview-inventory.aspx&hastoincludetransferfee=false&campaigntypeid=10&sitebox=sitebox_general2',
# 27 : 'https://secure-leads.motorcar.com/leads/?siteguid=47db61e2-a054-4304-b8b6-94ec4beb4087&leadsource=ebizautos&leadtype=requestatestdrive&contactid=10284&pageid=23852&pagetypeid=2&campaignid=9&campaignsitetypeid=1&segmentdefaultcampaignid=9&initialrefer=&initialurl=&initialtarget=http%3A%2F%2Fwww.directautomecca.com%2Fview-inventory.aspx&sourcepage=http%3A%2F%2Fwww.directautomecca.com%2Fview-inventory.aspx&hastoincludetransferfee=false&campaigntypeid=10&sitebox=sitebox_general2',
#
# 	};
# 	var _commonJSParams = {
# 		DealerName: 'DirectAutomecca.com',
# 		DealerState: 'Massachusetts',
# 		DealerStateCode: 'MA',
# 		DealerZip: '01702',
# 		LexusDealerId: '',
# 		DealerDomain: '//www.directautomecca.com/',
# 		DefaultProxyUrl: '//www.directautomecca.com/',
# 		HostWithoutTLD: 'directautomecca',
# 		SiteId: '7725',
# 		SiteGuid: '47db61e2-a054-4304-b8b6-94ec4beb4087',
# 		PageName: 'view-inventory',
# 		PageType: 2,
# 		Title: 'Boston Used cars|Used Cars Serving the Boston Area |Used Audi|Used Toyota|Used Bmw|Nissan|Honda',
# 		TrafficType: 'Typed/Bookmarked',
# 		Language: 'en',
# 		SecureSharedLocation: 'https://secure-leads.motorcar.com/',
# 		PASLocation: '//pas.motorcar.com/api/gallery/',
# 		ReferrerPage: '',
# 		SiteboxName: 'sitebox_general2'
# 	};
# 	var _trackingParams = {
# 		IsBmwTrackingOn: false,
# 		IsMiniTrackingOn: false,
# 		IsGoogleEventTrackingOn: true,
# 		IsConversionTrackingOn: true,
# 		IsToyotaTrackingOn: false,
# 		IsPorscheTrackingOn: false,
# 		IsVolkswagenTrackingOn: false,
# 		IsNTPageTrackingOn: false,
# 		GaTrackerNames: 'eBizReports',
# 		IsBmwFranchise: false,
# 		IsMiniFranchise: false,
# 		IsVolkswagenFranchise: false,
# 		VehicleId: '',
# 		VinNumberParam: '',
# 		InventoryYearParam: 'no value',
# 		InventoryTrimParam: 'no value',
# 		InventoryMakeParam: 'no value',
# 		InventoryModelParam: 'no value',
# 		InventoryTypeParam: 'all',
# 		InventoryTransmissionParam: '',
# 		InventoryIntColorTypeParam: '',
# 		InventoryIntColorParam: '',
# 		InventoryExtColorParam: '',
# 		InventoryEngineParam: '',
# 		InventoryPriceFromParam: '0',
# 		InventoryPriceToParam: '0',
# 		InventoryMultipleMakesParam: '',
# 		InventoryMultipleModelsParam: '',
# 		InventoryMultipleTrimsParam: '',
# 		InventoryMultipleExtColorsParam: '',
# 		InventoryMultipleBodyStylesParam: '',
# 		InventoryMultipleYearsParam: '',
# 		InventorySearchPhraseParam: '',
# 		InventorySearchStatusParam: '',
# 		LowestPriceValueParam: '0',
# 		MsrpParam: '0',
# 		LowestPrice: '',
# 		SpecialType: '',
# 		SpecialInventoryType: '',
# 		SearchInventoryResult: '151',
# 		SearchPhrases: '',
# 		SearchInventoryTypeResult: '',
# 		LeadTypeId: 0,
# 		IsFormSubmited: false,
# 		IsLeadForm: false,
# 		IsFormError: false,
# 		prop1: '',
# 		eVar8: '',
# 		channel: '',
# 		customToyotaPageName: '',
# 	};
# 	var _socialMediaBarParams = {
# 		YouTubeUserName: 'UC6mGIPgsYrrRQfeO-IO8qcg'
# 	};
#           </script>
#           <script language="javascript" type="text/javascript">
#           </script>
#           <script>
#            (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#     (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#     m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#     })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
# 	ga('create', 'UA-7364301-1', 'auto', {'allowLinker': true});
# 	ga('require', 'linker');
# 	ga('linker:autoLink', ['.ebizautos.com']);
#     ga('send', 'pageview');
#           </script>
#           <script language="javascript" type="text/javascript">
#           </script>
#           <script language="javascript" src="https://images.ebizautos.media/foundation/gallery/js/global.js?18" type="text/javascript">
#           </script>
#           <script language="javascript" src="https://images.ebizautos.media/foundation/gallery/js/gallery.js?20" type="text/javascript">
#           </script>
#           <!-- Facebook Pixel GTM -->
#           <script>
#            (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src='https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);})(window,document,'script','dataLayer','GTM-NFTX3XB');
#           </script>
#           <!-- End Facebook Pixel GTM -->
#           <script>
#            (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
# 	ga('DealerCode3.send', 'pageview');
#           </script>
#           <script type="text/javascript">
#            window.__lo_site_id = 110869;
#
# 	(function() {
# 		var wa = document.createElement('script'); wa.type = 'text/javascript'; wa.async = true;
# 		wa.src = 'https://d10lpsik1i8c69.cloudfront.net/w.js';
# 		var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(wa, s);
# 	  })();
#           </script>
#           <!-- Facebook Pixel Code -->
#           <script>
#            !function(f,b,e,v,n,t,s)
# {if(f.fbq)return;n=f.fbq=function(){n.callMethod?
# n.callMethod.apply(n,arguments):n.queue.push(arguments)};
# if(!f._fbq)f._fbq=n;n.push=n;n.loaded=!0;n.version='2.0';
# n.queue=[];t=b.createElement(e);t.async=!0;
# t.src=v;s=b.getElementsByTagName(e)[0];
# s.parentNode.insertBefore(t,s)}(window,document,'script',
# 'https://connect.facebook.net/en_US/fbevents.js');
# fbq('init', '386714442977799');
# fbq('track', 'PageView');
#           </script>
#           <noscript>
#            <img height="1" src="https://www.facebook.com/tr?id=386714442977799&amp;ev=PageView
# &amp;noscript=1" width="1"/>
#           </noscript>
#           <!-- End Facebook Pixel Code -->
#           <meta content="pPQDzhWyOSqj6DZWmk0XVsG9Setegcd2TZxLLoS10r0=" name="verify-v1"/>
#           <meta content="5fc4b12c460584f40b019ae4191c4b46" name="p:domain_verify">
#            <!-- Google Tag Manager -->
#            <script>
#             (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-NTTDKDF');
#            </script>
#            <!-- End Google Tag Manager -->
#           </meta>
#          </link>
#         </link>
#        </link>
#       </link>
#      </link>
#     </link>
#    </meta>
#   </meta>
#  </head>
#  <body class="stretched no-transition side-panel-left pageType-Inventory pageName-view-inventory">
#   <!-- Body_Inventory_Filters -->
#   <input id="siteDefaultUrl" type="hidden" value="//www.directautomecca.com/"/>
#   <input id="filtersActionUrl" type="hidden" value="//www.directautomecca.com/inventory.aspx?_new=true&amp;_used=true"/>
#   <input id="paginationActionUrl" type="hidden" value="http://www.directautomecca.com/view-inventory.aspx"/>
#   <!-- Body_CustomCodeBodyTop -->
#   <!-- Facebook Pixel GTM (noscript) -->
#   <noscript>
#    <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-NFTX3XB" style="display:none;visibility:hidden" width="0">
#    </iframe>
#   </noscript>
#   <!-- End Facebook Pixel GTM (noscript) -->
#   <!-- Clarivoy Tracking Code -->
#   <script src="//tags-cdn.clarivoy.com/northendmotors/td/tva/loader.js" type="text/javascript">
#   </script>
#   <!-- End Clarivoy Tracking Code -->
#   <!-- Google Tag Manager -->
#   <noscript>
#    <iframe height="0" src="//www.googletagmanager.com/ns.html?id=GTM-P77RWX" style="display:none;visibility:hidden" width="0">
#    </iframe>
#   </noscript>
#   <script>
#    (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# '//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-P77RWX');
#   </script>
#   <!-- End Google Tag Manager -->
#   <!-- Google Tag Manager (noscript) -->
#   <noscript>
#    <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-NTTDKDF" style="display:none;visibility:hidden" width="0">
#    </iframe>
#   </noscript>
#   <!-- End Google Tag Manager (noscript) -->
#   <div class="clearfix" id="wrapper">
#    <div role="banner">
#     <!-- Skip to main content for ADA compliance -->
#     <a class="skip-main button button-small" href="#content">
#      Skip to main content
#     </a>
#     <!-- Skip to main content for ADA compliance -->
#     <!-- Body_SidePanelNav -->
#     <div class="body-overlay d-none">
#     </div>
#     <div class="d-none" id="side-panel">
#      <div class="side-panel-trigger" id="side-panel-trigger-close">
#       <a aria-label="Close" href="#">
#        <i class="icon-line-cross">
#        </i>
#       </a>
#      </div>
#      <div class="side-panel-wrap">
#       <div id="mobile-custom-area-1">
#       </div>
#       <nav aria-label="Mobile Menu" id="mobile-menu" role="navigation">
#        <ul aria-label="Mobile Menu" role="menubar">
#         <li id="mobile-navID-23858" role="menuitem">
#          <a href="//www.directautomecca.com/">
#           Home
#          </a>
#         </li>
#         <li aria-haspopup="true" class="current" id="mobile-navID-23860" role="menuitem">
#          <a href="//www.directautomecca.com/view-inventory.aspx">
#           Pre Owned Car Inventory
#          </a>
#          <ul aria-label="Pre Owned Car Inventory" role="menu">
#           <li class="current" id="mobile-navID-23860-sub" role="menuitem">
#            <a href="//www.directautomecca.com/view-inventory.aspx">
#             Pre Owned Car Inventory
#            </a>
#           </li>
#           <li id="mobile-navID-23861" role="menuitem">
#            <a href="http://www.directautomecca.com/view-inventory.aspx">
#             Inventory
#            </a>
#           </li>
#           <li id="mobile-navID-23862" role="menuitem">
#            <a href="//www.directautomecca.com/found-a-car-you-love.aspx">
#             Found A Car You Love ?
#            </a>
#           </li>
#           <li id="mobile-navID-23865" role="menuitem">
#            <a href="//www.directautomecca.com/pickup-truck-inventory.aspx">
#             Pickup Truck Inventory
#            </a>
#           </li>
#           <li id="mobile-navID-23866" role="menuitem">
#            <a href="//www.directautomecca.com/suv-inventory.aspx">
#             SUV Inventory
#            </a>
#           </li>
#           <li id="mobile-navID-23867" role="menuitem">
#            <a href="//www.directautomecca.com/sedan-inventory.aspx">
#             Sedan Inventory
#            </a>
#           </li>
#           <li id="mobile-navID-23868" role="menuitem">
#            <a href="//www.directautomecca.com/value-your-trade.aspx">
#             Value Your Trade
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li id="mobile-navID-23869" role="menuitem">
#          <a href="//www.directautomecca.com/special-offers.aspx">
#           Specials
#          </a>
#         </li>
#         <li id="mobile-navID-23887" role="menuitem">
#          <a href="//www.directautomecca.com/sell-your-vehicle.aspx">
#           Sell Your Vehicle
#          </a>
#         </li>
#         <li id="mobile-navID-23888" role="menuitem">
#          <a href="//www.directautomecca.com/car-finder.aspx">
#           Direct Locate
#          </a>
#         </li>
#         <li aria-haspopup="true" id="mobile-navID-23891" role="menuitem">
#          <a href="//www.directautomecca.com/financing.aspx">
#           Get Approved Now
#          </a>
#          <ul aria-label="Get Approved Now" role="menu">
#           <li id="mobile-navID-23891-sub" role="menuitem">
#            <a href="//www.directautomecca.com/financing.aspx">
#             Get Approved Now
#            </a>
#           </li>
#           <li id="mobile-navID-23893" role="menuitem">
#            <a href="https://www.directautomecca.com/value-your-trade.aspx">
#             Value Your Trade
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li id="mobile-navID-23896" role="menuitem">
#          <a href="//www.directautomecca.com/service.aspx">
#           Service Department
#          </a>
#         </li>
#         <li aria-haspopup="true" id="mobile-navID-23907" role="menuitem">
#          <a href="//www.directautomecca.com/dealership-info.aspx">
#           Dealership Info
#          </a>
#          <ul aria-label="Dealership Info" role="menu">
#           <li id="mobile-navID-23907-sub" role="menuitem">
#            <a href="//www.directautomecca.com/dealership-info.aspx">
#             Dealership Info
#            </a>
#           </li>
#           <li id="mobile-navID-23908" role="menuitem">
#            <a href="//www.directautomecca.com/reviews.aspx">
#             Reviews
#            </a>
#           </li>
#           <li id="mobile-navID-23909" role="menuitem">
#            <a href="//www.directautomecca.com/terms-of-sale.aspx">
#             Terms of Sale
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li aria-haspopup="true" id="mobile-navID-23914" role="menuitem">
#          <a href="//www.directautomecca.com/contact-us.aspx">
#           Contact Us
#          </a>
#          <ul aria-label="Contact Us" role="menu">
#           <li id="mobile-navID-23914-sub" role="menuitem">
#            <a href="//www.directautomecca.com/contact-us.aspx">
#             Contact Us
#            </a>
#           </li>
#           <li id="mobile-navID-23916" role="menuitem">
#            <a href="//www.directautomecca.com/new-career-1.aspx">
#             New Career
#            </a>
#           </li>
#          </ul>
#         </li>
#        </ul>
#       </nav>
#       <div id="mobil-custom-area-2">
#       </div>
#       <!-- Body_SidePanelSocial -->
#       <div class="clearfix" id="mobile-social-media">
#        <a aria-label="View our Facebook Page" class="social-icon si-colored si-facebook" href="https://www.facebook.com/DirectAutomecca" onclick="return confirm('Are you sure you want to leave this page?')" rel="noopener" target="_blank">
#         <i class="icon-facebook">
#         </i>
#        </a>
#        <a aria-label="View Our Twitter Page" class="social-icon si-colored si-twitter" href="https://www.twitter.com/directautomecca" onclick="return confirm('Are you sure you want to leave this page?')" rel="noopener" target="_blank">
#         <i class="icon-twitter">
#         </i>
#        </a>
#        <a aria-label="View Our Instagram Page" class="social-icon si-colored si-instagram" href="https://www.instagram.com/directautomecca" onclick="return confirm('Are you sure you want to leave this page?')" rel="noopener" target="_blank">
#         <i class="icon-instagram2">
#         </i>
#        </a>
#        <a aria-label="View Our YouTube Page" class="social-icon si-colored si-youtube" href="https://www.youtube.com/channel/UC6mGIPgsYrrRQfeO-IO8qcg" onclick="return confirm('Are you sure you want to leave this page?')" rel="noopener" target="_blank">
#         <i class="icon-youtube">
#         </i>
#        </a>
#       </div>
#       <!-- Body_SidePanelSocialClose -->
#       <div id="mobile-custom-area-3">
#       </div>
#      </div>
#     </div>
#     <!-- Body_SearchFlyout -->
#     <div aria-labelledby="search-flyout-label" id="search-flyout" role="dialog" tabindex="-1">
#      <div class="wrapper">
#       <a aria-label="Close Search Flyout" class="search-flyout-close" href="#" id="search-flyout-close">
#        <i class="icon-line-cross">
#        </i>
#       </a>
#       <div class="container clearfix">
#        <div class="text-center">
#         <h2 id="search-flyout-label">
#          Search Inventory
#         </h2>
#        </div>
#        <div class="search-wrapper">
#         <form action="/inventory.aspx" autocomplete="on" class="ebiz-search-inventory-form" method="get">
#          <div class="row">
#           <div class="col-md-10">
#            <div class="input">
#             <input aria-label="Search Our Inventory" class="search-flyout-input" name="_search" placeholder="Search Inventory" type="text" value=""/>
#            </div>
#           </div>
#           <div class="col-md-2">
#            <button class="button btn-block m-0 ebiz-search-submit" id="submit-button" name="submit">
#             GO
#            </button>
#           </div>
#          </div>
#         </form>
#        </div>
#       </div>
#      </div>
#     </div>
#     <!-- Body_TopBar_V2_Start -->
#     <div class="bgcolor-2 pt-2 pb-2 d-none d-md-block" id="top-bar-v2">
#      <div class="container-fullwidth clearfix">
#       <div class="row d-flex">
#        <div class="col-md-12 d-block d-md-flex align-items-center justify-content-end w-100">
#         <!-- Body_TopBar_V2_Content -->
#         <div class="ml-4" id="tb-item-4">
#          <div aria-label="Search Inventory Form" class="tb-search d-none d-md-block" role="group">
#           <form action="/inventory.aspx" autocomplete="on" class="ebiz-search-inventory-form form-inline m-0 h-100" method="get">
#            <div class="form-group input">
#             <input aria-label="Search Inventory" id="_topbarv2search" name="_search" placeholder="Search Inventory" type="text" value=""/>
#            </div>
#            <button aria-label="Search" class="button button-small m-0 h-100" type="submit">
#             <i class="icon-search3 m-0">
#             </i>
#            </button>
#           </form>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="clear">
#     </div>
#     <!-- Body_TopBar_V2_End -->
#     <!-- Body_HeaderStyle2_NoSearch -->
#     <header class="sticky-style-2 mobile-center" id="header">
#      <div class="container-fullwidth clearfix">
#       <div class="side-panel-trigger d-block d-md-none" id="side-panel-trigger">
#        <a aria-label="Menu" href="javascript:void(0);">
#         <i class="icon-line-menu">
#         </i>
#        </a>
#       </div>
#       <div id="logo">
#        <a aria-label="Home" class="standard-logo" href="//www.directautomecca.com/">
#         <img alt="Dealership Logo" src="https://images.ebizautos.media/Foundation/Sites/7725/AccountTemplate/images/logo.png?v2"/>
#        </a>
#        <a class="retina-logo" href="//www.directautomecca.com/">
#         <img alt="Dealership Logo" src="https://images.ebizautos.media/Foundation/Sites/7725/AccountTemplate/images/logo@2x.png?v2"/>
#        </a>
#        <a class="retina-mobile-logo" href="//www.directautomecca.com/">
#         <img alt="Dealership Logo" src="https://images.ebizautos.media/Foundation/Sites/7725/AccountTemplate/images/logo@2x-mobile.png?v2"/>
#        </a>
#       </div>
#       <ul class="header-extras">
#        <li>
#         <div class="he-text tright">
#         </div>
#        </li>
#        <li>
#         <div class="he-text tright">
#         </div>
#        </li>
#        <li>
#         <div class="he-text tright">
#          154 Waverly Street
#          <br/>
#          Framingham, MA 01702
#          <a class="map-link" href="https://www.google.com/maps?q=154 Waverly Street+,Framingham,MA+01702&amp;spn=0.023888,0.039669&amp;t=h&amp;hl=en" target="_blank">
#           <i class="icon-map-marker2">
#           </i>
#           Map
#          </a>
#          <br/>
#          Sales:
#          <span>
#           508-812-7804
#          </span>
#          <br/>
#         </div>
#        </li>
#       </ul>
#      </div>
#      <div id="header-wrap">
#       <nav aria-label="Primary Menu" class="flexbox style-2 link-style-2" id="primary-menu">
#        <div class="container-fullwidth clearfix">
#         <ul aria-label="Primary Menu" role="menubar">
#          <li id="navID-23858" role="none">
#           <a href="//www.directautomecca.com/" role="menuitem">
#            <div>
#             Home
#            </div>
#           </a>
#          </li>
#          <li aria-haspopup="true" class="current" id="navID-23860" role="none">
#           <a href="//www.directautomecca.com/view-inventory.aspx" role="menuitem">
#            <div>
#             Pre Owned Car Inventory
#            </div>
#           </a>
#           <ul aria-label="Pre Owned Car Inventory" role="menu">
#            <li id="navID-23861" role="none">
#             <a href="http://www.directautomecca.com/view-inventory.aspx" role="menuitem">
#              <div>
#               Inventory
#              </div>
#             </a>
#            </li>
#            <li id="navID-23862" role="none">
#             <a href="//www.directautomecca.com/found-a-car-you-love.aspx" role="menuitem">
#              <div>
#               Found A Car You Love ?
#              </div>
#             </a>
#            </li>
#            <li id="navID-23865" role="none">
#             <a href="//www.directautomecca.com/pickup-truck-inventory.aspx" role="menuitem">
#              <div>
#               Pickup Truck Inventory
#              </div>
#             </a>
#            </li>
#            <li id="navID-23866" role="none">
#             <a href="//www.directautomecca.com/suv-inventory.aspx" role="menuitem">
#              <div>
#               SUV Inventory
#              </div>
#             </a>
#            </li>
#            <li id="navID-23867" role="none">
#             <a href="//www.directautomecca.com/sedan-inventory.aspx" role="menuitem">
#              <div>
#               Sedan Inventory
#              </div>
#             </a>
#            </li>
#            <li id="navID-23868" role="none">
#             <a href="//www.directautomecca.com/value-your-trade.aspx" role="menuitem">
#              <div>
#               Value Your Trade
#              </div>
#             </a>
#            </li>
#           </ul>
#          </li>
#          <li id="navID-23869" role="none">
#           <a href="//www.directautomecca.com/special-offers.aspx" role="menuitem">
#            <div>
#             Specials
#            </div>
#           </a>
#          </li>
#          <li id="navID-23887" role="none">
#           <a href="//www.directautomecca.com/sell-your-vehicle.aspx" role="menuitem">
#            <div>
#             Sell Your Vehicle
#            </div>
#           </a>
#          </li>
#          <li id="navID-23888" role="none">
#           <a href="//www.directautomecca.com/car-finder.aspx" role="menuitem">
#            <div>
#             Direct Locate
#            </div>
#           </a>
#          </li>
#          <li aria-haspopup="true" id="navID-23891" role="none">
#           <a href="//www.directautomecca.com/financing.aspx" role="menuitem">
#            <div>
#             Get Approved Now
#            </div>
#           </a>
#           <ul aria-label="Get Approved Now" role="menu">
#            <li id="navID-23893" role="none">
#             <a href="https://www.directautomecca.com/value-your-trade.aspx" role="menuitem">
#              <div>
#               Value Your Trade
#              </div>
#             </a>
#            </li>
#           </ul>
#          </li>
#          <li id="navID-23896" role="none">
#           <a href="//www.directautomecca.com/service.aspx" role="menuitem">
#            <div>
#             Service Department
#            </div>
#           </a>
#          </li>
#          <li aria-haspopup="true" id="navID-23907" role="none">
#           <a href="//www.directautomecca.com/dealership-info.aspx" role="menuitem">
#            <div>
#             Dealership Info
#            </div>
#           </a>
#           <ul aria-label="Dealership Info" role="menu">
#            <li id="navID-23908" role="none">
#             <a href="//www.directautomecca.com/reviews.aspx" role="menuitem">
#              <div>
#               Reviews
#              </div>
#             </a>
#            </li>
#            <li id="navID-23909" role="none">
#             <a href="//www.directautomecca.com/terms-of-sale.aspx" role="menuitem">
#              <div>
#               Terms of Sale
#              </div>
#             </a>
#            </li>
#           </ul>
#          </li>
#          <li aria-haspopup="true" id="navID-23914" role="none">
#           <a href="//www.directautomecca.com/contact-us.aspx" role="menuitem">
#            <div>
#             Contact Us
#            </div>
#           </a>
#           <ul aria-label="Contact Us" role="menu">
#            <li id="navID-23916" role="none">
#             <a href="//www.directautomecca.com/new-career-1.aspx" role="menuitem">
#              <div>
#               New Career
#              </div>
#             </a>
#            </li>
#           </ul>
#          </li>
#         </ul>
#        </div>
#       </nav>
#      </div>
#     </header>
#     <div class="clear">
#     </div>
#     <!-- Body_MobileHeaderStart -->
#     <div class="clearfix d-block d-md-none" id="bottom-mobile-header">
#      <!-- Body_MobileHeaderLinks_ClickUsed -->
#      <ul>
#       <li>
#        <a class="ebiz-calltoday-button ebiz-clicktocall-button" href="tel:508-812-7804 ">
#         <i class="icon-phone3">
#         </i>
#         Call Us
#        </a>
#       </li>
#       <li>
#        <a class="top-mobile-map-trigger ebiz-view-google-map" href="https://www.google.com/maps?q=154 Waverly Street+,Framingham,MA+01702&amp;spn=0.023888,0.039669&amp;t=h&amp;hl=en" rel="noopener" target="_blank">
#         <i class="icon-map-marker2">
#         </i>
#         Map
#        </a>
#       </li>
#       <li class="mobile-header-trigger">
#        <div data-mobile-section="#mobile-header-section--search">
#         <a href="javascript:void(0);">
#          <i class="icon-search3">
#          </i>
#          Search
#         </a>
#        </div>
#       </li>
#       <!-- Body_MobileHeaderLinks_MobilePriceAlertLogin -->
#       <li id="btn-mobile-login">
#        <a href="javascript:void(0);">
#         <i class="icon-user">
#         </i>
#         Login
#        </a>
#       </li>
#      </ul>
#      <!-- Body_MobileHeaderLinksEnd -->
#     </div>
#     <!-- Body_MobileHeaderEnd -->
#     <!-- Body_MobileHeaderSearch -->
#     <div class="mobile-header-section" id="mobile-header-section--call-us">
#      <div class="mobile-bar-row clearfix d-flex align-items-center">
#       <div class="col-xs-5">
#        <div class="tleft">
#         Sales Dept.
#        </div>
#       </div>
#       <div class="col-xs-7">
#        <div class="tright">
#         <a class="ebiz-calltoday-button ebiz-clicktocall-button button button-small" href="tel:508-812-7804">
#          <i class="icon-phone3">
#          </i>
#          508-812-7804
#         </a>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="mobile-header-section" id="mobile-header-section--search">
#      <form action="/inventory.aspx" autocomplete="on" class="ebiz-search-inventory-form m-0" method="get">
#       <div class="wrapper clearfix">
#        <div class="col-xs-10 col-sm-10">
#         <div class="input m-0">
#          <input aria-label="Search Inventory" class="form-control" name="_search" placeholder="Search Inventory" type="text"/>
#         </div>
#        </div>
#        <div class="col-xs-2 col-sm-2 pl-0">
#         <button class="button btn-block m-0 p-0" type="submit">
#          Go
#         </button>
#        </div>
#       </div>
#      </form>
#     </div>
#    </div>
#    <!-- role="banner" end -->
#    <!-- Inventory_GEOPageTitle -->
#    <section class="page-title-center" id="page-title">
#     <div class="container clearfix">
#      <h1>
#       151 Used Vehicles For Sale
#       <span>
#        Serving Framingham, MA
#       </span>
#      </h1>
#      <ol aria-label="Breadcrumb Links" class="breadcrumb">
#       <li id="breadcrumb-0">
#        <a href="//www.directautomecca.com/" title="Home">
#         Home
#        </a>
#       </li>
#       <li aria-hidden="true" class="active" id="breadcrumb-1">
#        All  Cars
#       </li>
#      </ol>
#     </div>
#    </section>
#    <!-- Inventory_TopSort -->
#    <section id="content" role="main">
#     <div class="container bg1 clearfix">
#      <div class="py-4 border-bottom d-none d-sm-block">
#       <div class="py-4 border-bottom d-none d-sm-block">
#        <link href="https://fonts.googleapis.com/css?family=Open+Sans:400,700" rel="stylesheet"/>
#        <center>
#         <div data-key="6be38aaa-8b96-4438-9375-432258527f10" data-modal-z-index="2000" data-url="https://tradeinadvisor.kbb.com" id="kbb-leaddriver-search" style="width:100%;max-width: 1140px;margin: auto; color:#424242;">
#         </div>
#        </center>
#        <script defer="" src="https://tradeinadvisor.kbb.com/scripts/predictive-search.min.js">
#        </script>
#       </div>
#       <div class="row py-2">
#        <div class="col-xs-12 col-sm-4 col-md-6">
#         <div class="pagination-wrapper">
#          <div class="pagination-control">
#           <ul aria-label="List of Pages" class="list-unstyled list-inline m-0 p-0 text-center text-sm-left">
#            <li aria-hidden="true" class="px-0">
#             Page:
#            </li>
#            <li class="active px-2 font-weight-bold">
#             1
#            </li>
#            <li class="px-2 underline">
#             <a href="//www.directautomecca.com/inventory.aspx?_new=true&amp;_used=true&amp;_page=2" rel="nofollow">
#              2
#             </a>
#            </li>
#           </ul>
#          </div>
#         </div>
#        </div>
#        <div class="col-xs-12 col-sm-8 col-md-6 d-none d-sm-block">
#         <div class="row">
#          <div class="col-sm-6 col-md-5 col-lg-6 text-right">
#           <label for="pageSize">
#            Vehicles Per Page:
#           </label>
#          </div>
#          <div class="col-sm-6 col-md-7 col-lg-6">
#           <div class="input-wrapper">
#            <div class="select small">
#             <select aria-label="Vehicles Per Page" id="pageSize" name="pageSize" role="listbox">
#              <option value="10">
#               Show 10 Vehicles
#              </option>
#              <option value="25">
#               Show 25 Vehicles
#              </option>
#              <option value="50">
#               Show 50 Vehicles
#              </option>
#              <option selected="selected" value="100">
#               Show 100 Vehicles
#              </option>
#             </select>
#             <i class="icon-angle-down">
#             </i>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div id="srp-top-sort">
#       <div class="row">
#        <div class="col-xs-6 col-md-6 d-block d-md-none">
#         <a class="button" data-target="#srp-modal-refine-search" data-toggle="modal" href="#" id="srp-refine-search-mobile">
#          <i class="icon-filter">
#          </i>
#          Refine Search
#         </a>
#        </div>
#        <div class="col-xs-6 col-md-6 d-block d-md-none">
#         <button class="button fright" data-target="#srp-modal-sortby" data-toggle="modal">
#          <i class="icon-sort">
#          </i>
#          Sort By
#         </button>
#        </div>
#        <div class="col-md-6 d-none d-md-block">
#         <div class="clearfix" id="srp-sortby">
#          <ul class="sortby">
#           <li class="title">
#            Sort By:
#           </li>
#           <li>
#            <a class="ebiz-sort-link" href="//www.directautomecca.com/inventory.aspx?_new=true&amp;_used=true&amp;_sort=yearasc" rel="nofollow">
#             Year
#            </a>
#            |
#           </li>
#           <li>
#            <a class="ebiz-sort-link" href="//www.directautomecca.com/inventory.aspx?_new=true&amp;_used=true&amp;_sort=makeasc" rel="nofollow">
#             Make
#            </a>
#            |
#           </li>
#           <li>
#            <a class="ebiz-sort-link" href="//www.directautomecca.com/inventory.aspx?_new=true&amp;_used=true&amp;_sort=modelasc" rel="nofollow">
#             Model
#            </a>
#            |
#           </li>
#           <li>
#            <a class="ebiz-sort-link" href="//www.directautomecca.com/inventory.aspx?_new=true&amp;_used=true&amp;_sort=mileageasc" rel="nofollow">
#             Mileage
#            </a>
#            |
#           </li>
#           <li>
#            <a class="ebiz-sort-link" href="//www.directautomecca.com/inventory.aspx?_new=true&amp;_used=true&amp;_sort=priceasc" rel="nofollow">
#             Price
#            </a>
#            |
#           </li>
#           <li>
#            <a class="ebiz-sort-link" href="//www.directautomecca.com/inventory.aspx?_new=true&amp;_used=true&amp;_sort=photoasc" rel="nofollow">
#             Photos
#            </a>
#           </li>
#          </ul>
#         </div>
#        </div>
#        <div class="col-md-6 d-none d-md-block">
#         <div class="clearfix" id="srp-vehicle-comparison">
#          <div class="srp-vehicle-comparison-wrapper">
#           <div class="row">
#            <div class="col-md-5 col-md-offset-2 p-0 srp-vehicle-comparison-images d-flex align-items-stretch h-100">
#             <div class="col-md-4 p-0">
#              <div class="VehicleComparingImage h-100 SelectedVehicle1">
#               <img alt="" class="VehiclePhoto responsive" src="">
#                <i aria-label="Remove Vehicle" class="icon icon-line2-close remove-car" onclick="javascript:removeItemFromCompareBar(0);" role="button" style="display: none;" tabindex="0">
#                </i>
#               </img>
#              </div>
#             </div>
#             <div class="col-md-4 p-0">
#              <div class="VehicleComparingImage h-100 SelectedVehicle2">
#               <img alt="" class="VehiclePhoto responsive" src="">
#                <i aria-label="Remove Vehicle" class="icon icon-line2-close remove-car" onclick="javascript:removeItemFromCompareBar(0);" role="button" style="display: none;" tabindex="0">
#                </i>
#               </img>
#              </div>
#             </div>
#             <div class="col-md-4 p-0">
#              <div class="VehicleComparingImage h-100 SelectedVehicle3">
#               <img alt="" class="VehiclePhoto responsive" src="">
#                <i aria-label="Remove Vehicle" class="icon icon-line2-close remove-car" onclick="javascript:removeItemFromCompareBar(0);" role="button" style="display: none;" tabindex="0">
#                </i>
#               </img>
#              </div>
#             </div>
#            </div>
#            <div class="col-md-5 center">
#             <div class="srp-vehicle-comparison-button">
#              <a class="button button-alt btn-block m-0 py-0 px-2 fright" href="#" id="srp-button-compare" onclick="showVehicleCompare()" rel="nofollow">
#               Compare Vehicles
#               <i class="icon-caret-right ml-1 mr-0">
#               </i>
#              </a>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div class="py-4 border-bottom d-block d-sm-none">
#       <div class="row py-2">
#        <div class="col-xs-4 d-sm-none">
#        </div>
#        <div class="col-xs-4 d-sm-none text-center">
#         <div class="d-inline-block p-0">
#          Page:
#          <br/>
#          1 of 2
#         </div>
#        </div>
#        <div class="col-xs-4 d-sm-none text-right">
#         <a class="button button-small" href="//www.directautomecca.com/inventory.aspx?_new=true&amp;_used=true&amp;_page=2" rel="nofollow" title="Next Page">
#          Next
#          <i class="icon-chevron-right ml-2 mr-0">
#          </i>
#         </a>
#        </div>
#       </div>
#      </div>
#      <!-- Inventory_LeftSearchFilter_Sliders -->
#      <div class="clearfix" id="srp">
#       <div class="col-md-3 col-lg-3 d-none d-md-block p-0">
#        <div class="pt-4 pb-3 srp-search-title">
#         <h2 class="h4 body-font text-center">
#          Your Current Search
#         </h2>
#        </div>
#        <div class="srp-current-search-wrapper" id="srp-current-search">
#         <div class="current-search-item clearfix">
#          <div class="current-search-group clearfix">
#           <div class="item-title">
#            Condition
#           </div>
#           <div class="remove-group clearfix">
#            <div class="item-detail fleft">
#             New
#            </div>
#            <div class="item-clear fright">
#             <a aria-label="Remove New" class="ebiz-filter-link" href="//www.directautomecca.com/used-cars/" rel="nofollow">
#              <i class="icon-line-cross">
#              </i>
#             </a>
#            </div>
#           </div>
#           <div class="remove-group clearfix">
#            <div class="item-detail fleft">
#             Used
#            </div>
#            <div class="item-clear fright">
#             <a aria-label="Remove Used" class="ebiz-filter-link" href="//www.directautomecca.com/new-cars/" rel="nofollow">
#              <i class="icon-line-cross">
#              </i>
#             </a>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#        <div id="srp-search-filter">
#         <div class="srp-search-filter-wrapper">
#          <div class="pt-4 pb-3 srp-search-title">
#           <h2 class="h4 body-font text-center">
#            Refine Your Search
#           </h2>
#          </div>
#          <div class="toggle" data-state="open" id="srp-make-toggle">
#           <!-- All Other Sections-->
#           <div class="togglet">
#            Make
#            <i class="toggle-closed icon-angle-down">
#            </i>
#            <i class="toggle-open icon-angle-up">
#            </i>
#           </div>
#           <div class="togglec">
#            <div class="filter-element clearfix">
#             <a class="ebiz-filter-link" href="//www.directautomecca.com/inventory.aspx?_new=true&amp;_used=true&amp;_makef=audi" rel="nofollow">
#              Audi
#             </a>
#             <span class="label label-default">
#              1
#             </span>
#            </div>
#            <div class="filter-element clearfix">
#             <a class="ebiz-filter-link" href="//www.directautomecca.com/inventory.aspx?_new=true&amp;_used=true&amp;_makef=bmw" rel="nofollow">
#              BMW
#             </a>
#             <span class="label label-default">
#              2
#             </span>
#            </div>
#            <div class="filter-element clearfix">
#             <a class="ebiz-filter-link" href="//www.directautomecca.com/inventory.aspx?_new=true&amp;_used=true&amp;_makef=cadillac" rel="nofollow">
#              Cadillac
#             </a>
#             <span class="label label-default">
#              2
#             </span>
#            </div>
#            <div class="filter-element clearfix">
#             <a class="ebiz-filter-link" href="//www.directautomecca.com/inventory.aspx?_new=true&amp;_used=true&amp;_makef=chevrolet" rel="nofollow">
#              Chevrolet
#             </a>
#             <span class="label label-default">
#              37
#             </span>
#            </div>
#            <div class="filter-element clearfix">
#             <a class="ebiz-filter-link" href="//www.directautomecca.com/inventory.aspx?_new=true&amp;_used=true&amp;_makef=chrysler" rel="nofollow">
#              Chrysler
#             </a>
#             <span class="label label-default">
#              2
#             </span>
#            </div>
#            <div class="filter-element clearfix">
#             <a class="ebiz-filter-link" href="//www.directautomecca.com/inventory.aspx?_new=true&amp;_used=true&amp;_makef=dodge" rel="nofollow">
#              Dodge
#             </a>
#             <span class="label label-default">
#              2
#             </span>
#            </div>
#            <div class="filter-element clearfix">
# ...
#             },
#
#             {
#                 "@type": "ListItem",
#                 "position": 65,
#                 "name": "2015 Jeep Wrangler Unlimited Sport",
#                 "image": "//cdn.ebizautos.media/used-2015-jeep-wrangler-unlimitedsport-7725-21197485-1-640.jpg",
#                 "url": "//www.directautomecca.com/details-2015-jeep-wrangler-unlimited_sport-used-1c4bjwdg8fl687882.html"
#             },
#
#             {
#                 "@type": "ListItem",
#                 "position": 66,
#                 "name": "2020 Nissan Pathfinder SL",
#                 "image": "//cdn.ebizautos.media/used-2020-nissan-pathfinder-sl-7725-21255896-1-640.jpg",
#                 "url": "//www.directautomecca.com/details-2020-nissan-pathfinder-sl-used-5n1dr2cm9lc605909.html"
#             },
#
#             {
#                 "@type": "ListItem",
#                 "position": 67,
#                 "name": "2018 Land Rover Discovery Sport SE",
#                 "image": "//cdn.ebizautos.media/used-2018-land_rover-discovery_sport-se-7725-21255904-1-640.jpg",
#                 "url": "//www.directautomecca.com/details-2018-land_rover-discovery_sport-se-used-salcp2rx9jh750688.html"
#             },
#
#             {
#                 "@type": "ListItem",
#                 "position": 68,
#                 "name": "2017 Toyota Highlander XLE",
#                 "image": "//cdn.ebizautos.media/used-2017-toyota-highlander-xle-7725-21265604-1-640.jpg",
#                 "url": "//www.directautomecca.com/details-2017-toyota-highlander-xle-used-5tdjzrfh9hs465008.html"
#             },
#
#             {
#                 "@type": "ListItem",
#                 "position": 69,
#                 "name": "2018 Jeep Wrangler JK Unlimited Sport",
#                 "image": "//cdn.ebizautos.media/used-2018-jeep-wrangler_jk-unlimitedsport-7725-21104342-1-640.jpg",
#                 "url": "//www.directautomecca.com/details-2018-jeep-wrangler_jk-unlimited_sport-used-1c4bjwdg3jl803787.html"
#             },
#
#             {
#                 "@type": "ListItem",
#                 "position": 70,
#                 "name": "2018 Chevrolet Silverado 1500 LT",
#                 "image": "//cdn.ebizautos.media/used-2018-chevrolet-silverado_1500-lt-7725-21158795-1-640.jpg",
#                 "url": "//www.directautomecca.com/details-2018-chevrolet-silverado_1500-lt-used-1gcvkrec5jz189085.html"
#             },
#
#             {
#                 "@type": "ListItem",
#                 "position": 71,
#                 "name": "2018 GMC Sierra 1500 Base",
#                 "image": "//cdn.ebizautos.media/used-2018-gmc-sierra_1500-base-7725-21254503-1-640.jpg",
#                 "url": "//www.directautomecca.com/details-2018-gmc-sierra_1500-base-used-1gtv2lec8jz261863.html"
#             },
#
#             {
#                 "@type": "ListItem",
#                 "position": 72,
#                 "name": "2018 Ford F-150 XLT",
#                 "image": "//cdn.ebizautos.media/used-2018-ford-f~150-xlt-7725-21275395-1-640.jpg",
#                 "url": "//www.directautomecca.com/details-2018-ford-f~150-xlt-used-1ftfw1eg5jfc72837.html"
#             },
#
#             {
#                 "@type": "ListItem",
#                 "position": 73,
#                 "name": "2020 GMC Acadia SLT",
#                 "image": "//cdn.ebizautos.media/used-2020-gmc-acadia-slt-7725-21275687-1-640.jpg",
#                 "url": "//www.directautomecca.com/details-2020-gmc-acadia-slt-used-1gkknml45lz178412.html"
#             },
#
#             {
#                 "@type": "ListItem",
#                 "position": 74,
#                 "name": "2017 Chevrolet Silverado 1500 LT",
#                 "image": "//cdn.ebizautos.media/used-2017-chevrolet-silverado_1500-lt-7725-20989681-1-640.jpg",
#                 "url": "//www.directautomecca.com/details-2017-chevrolet-silverado_1500-lt-used-1gcvkreh1hz244542.html"
#             },
#
#             {
#                 "@type": "ListItem",
#                 "position": 75,
#                 "name": "2020 BMW X1 xDrive28i",
#                 "image": "//cdn.ebizautos.media/used-2020-bmw-x1-xdrive28i-7725-21273652-1-640.jpg",
#                 "url": "//www.directautomecca.com/details-2020-bmw-x1-xdrive28i-used-wbxjg9c09l3l85922.html"
#             },
#
#             {
#                 "@type": "ListItem",
#                 "position": 76,
#                 "name": "2020 Toyota Highlander LE",
#                 "image": "//cdn.ebizautos.media/used-2020-toyota-highlander-le-7725-21277395-1-640.jpg",
#                 "url": "//www.directautomecca.com/details-2020-toyota-highlander-le-used-5tdbzrbh7ls008555.html"
#             },
#
#             {
#                 "@type": "ListItem",
#                 "position": 77,
#                 "name": "2018 Cadillac XTS Premium",
#                 "image": "//cdn.ebizautos.media/used-2018-cadillac-xts-premium-7725-21142639-1-640.jpg",
#                 "url": "//www.directautomecca.com/details-2018-cadillac-xts-premium-used-2g61r5s31j9148067.html"
#             },
#
#             {
#                 "@type": "ListItem",
#                 "position": 78,
#                 "name": "2019 Ram 1500 Big Horn/Lone Star",
#                 "image": "//cdn.ebizautos.media/used-2019-ram-1500-bighornlonestar-7725-21136403-1-640.jpg",
#                 "url": "//www.directautomecca.com/details-2019-ram-1500-big_horn_lone_star-used-1c6srfft3kn654278.html"
#             },
#
#             {
#                 "@type": "ListItem",
#                 "position": 79,
#                 "name": "2018 Ram 1500 Big Horn",
#                 "image": "//cdn.ebizautos.media/used-2018-ram-1500-bighorn-7725-21087144-1-640.jpg",
#                 "url": "//www.directautomecca.com/details-2018-ram-1500-big_horn-used-1c6rr7lt4js332693.html"
#             },
#
#             {
#                 "@type": "ListItem",
#                 "position": 80,
#                 "name": "2016 Ram 1500 Sport",
#                 "image": "//cdn.ebizautos.media/used-2016-ram-1500-sport-7725-21097828-1-640.jpg",
#                 "url": "//www.directautomecca.com/details-2016-ram-1500-sport-used-1c6rr7ut0gs324016.html"
#             },
#
#             {
#                 "@type": "ListItem",
#                 "position": 81,
#                 "name": "2015 Ford Transit-350 XL",
#                 "image": "//cdn.ebizautos.media/used-2015-ford-transit~350-xl-7725-21217036-1-640.jpg",
#                 "url": "//www.directautomecca.com/details-2015-ford-transit~350-xl-used-1fbzx2xmxfka51644.html"
#             },
#
#             {
#                 "@type": "ListItem",
#                 "position": 82,
#                 "name": "2020 Dodge Durango GT",
#                 "image": "//cdn.ebizautos.media/used-2020-dodge-durango-gt-7725-21279023-1-640.jpg",
#                 "url": "//www.directautomecca.com/details-2020-dodge-durango-gt-used-1c4rdjdg8lc260738.html"
#             },
#
#             {
#                 "@type": "ListItem",
#                 "position": 83,
#                 "name": "2019 Chevrolet Silverado 1500 Custom Trail Boss",
#                 "image": "//cdn.ebizautos.media/used-2019-chevrolet-silverado_1500-customtrailboss-7725-21121701-1-640.jpg",
#                 "url": "//www.directautomecca.com/details-2019-chevrolet-silverado_1500-custom_trail_boss-used-1gcrycef1kz302426.html"
#             },
#
#             {
#                 "@type": "ListItem",
#                 "position": 84,
#                 "name": "2014 Toyota FJ Cruiser Base",
#                 "image": "//cdn.ebizautos.media/used-2014-toyota-fj_cruiser-base-7725-21213724-1-640.jpg",
#                 "url": "//www.directautomecca.com/details-2014-toyota-fj_cruiser-base-used-jtebu4bf8ek182382.html"
#             },
#
#             {
#                 "@type": "ListItem",
#                 "position": 85,
#                 "name": "2018 Ford F-150 XLT",
#                 "image": "//cdn.ebizautos.media/used-2018-ford-f~150-xlt-7725-21265954-1-640.jpg",
#                 "url": "//www.directautomecca.com/details-2018-ford-f~150-xlt-used-1ftew1ep8jke20160.html"
#             },
#
#             {
#                 "@type": "ListItem",
#                 "position": 86,
#                 "name": "2016 Chevrolet Silverado 2500HD Work Truck",
#                 "image": "//cdn.ebizautos.media/used-2016-chevrolet-silverado_2500hd-worktruck-7725-21269779-1-640.jpg",
#                 "url": "//www.directautomecca.com/details-2016-chevrolet-silverado_2500hd-work_truck-used-1gc2kueg4gz188964.html"
#             },
#
#             {
#                 "@type": "ListItem",
#                 "position": 87,
#                 "name": "2019 Toyota 4Runner SR5",
#                 "image": "//cdn.ebizautos.media/used-2019-toyota-4runner-sr5-7725-21104383-1-640.jpg",
#                 "url": "//www.directautomecca.com/details-2019-toyota-4runner-sr5-used-jtebu5jr6k5683086.html"
#             },
#
#             {
#                 "@type": "ListItem",
#                 "position": 88,
#                 "name": "2019 Chevrolet Silverado 1500 LT",
#                 "image": "//cdn.ebizautos.media/used-2019-chevrolet-silverado_1500-lt-7725-21210303-1-640.jpg",
#                 "url": "//www.directautomecca.com/details-2019-chevrolet-silverado_1500-lt-used-1gcryded6kz314172.html"
#             },
#
#             {
#                 "@type": "ListItem",
#                 "position": 89,
#                 "name": "2017 Ford Transit-250 Base",
#                 "image": "//cdn.ebizautos.media/used-2017-ford-transit~250-base-7725-21263538-1-640.jpg",
#                 "url": "//www.directautomecca.com/details-2017-ford-transit~250-base-used-1ftyr1cm6hka96066.html"
#             },
#
#             {
#                 "@type": "ListItem",
#                 "position": 90,
#                 "name": "2019 Ford F-150 XLT",
#                 "image": "//cdn.ebizautos.media/used-2019-ford-f~150-xlt-7725-20835249-1-640.jpg",
#                 "url": "//www.directautomecca.com/details-2019-ford-f~150-xlt-used-1ftfw1e54kfb96981.html"
#             },
#
#             {
#                 "@type": "ListItem",
#                 "position": 91,
#                 "name": "2019 Ram 1500 Big Horn/Lone Star",
#                 "image": "//cdn.ebizautos.media/used-2019-ram-1500-bighornlonestar-7725-21092954-1-640.jpg",
#                 "url": "//www.directautomecca.com/details-2019-ram-1500-big_horn_lone_star-used-1c6rrffg1kn811369.html"
#             },
#
#             {
#                 "@type": "ListItem",
#                 "position": 92,
#                 "name": "2020 Chevrolet Express 2500 Work Van",
#                 "image": "//cdn.ebizautos.media/used-2020-chevrolet-express_2500-workvan-7725-21251719-1-640.jpg",
#                 "url": "//www.directautomecca.com/details-2020-chevrolet-express_2500-work_van-used-1gcwgbfgxl1155160.html"
#             },
#
#             {
#                 "@type": "ListItem",
#                 "position": 93,
#                 "name": "2020 Chevrolet Silverado 1500 LT",
#                 "image": "//cdn.ebizautos.media/used-2020-chevrolet-silverado_1500-lt-7725-21092955-1-640.jpg",
#                 "url": "//www.directautomecca.com/details-2020-chevrolet-silverado_1500-lt-used-1gcryded4lz198603.html"
#             },
#
#             {
#                 "@type": "ListItem",
#                 "position": 94,
#                 "name": "2018 Ford Transit-250 Base",
#                 "image": "//cdn.ebizautos.media/used-2018-ford-transit~250-base-7725-21251722-1-640.jpg",
#                 "url": "//www.directautomecca.com/details-2018-ford-transit~250-base-used-1ftyr1zm2jkb48001.html"
#             },
#
#             {
#                 "@type": "ListItem",
#                 "position": 95,
#                 "name": "2019 Ram ProMaster 2500 High Roof",
#                 "image": "//cdn.ebizautos.media/used-2019-ram-promaster_2500-highroof-7725-21265601-1-640.jpg",
#                 "url": "//www.directautomecca.com/details-2019-ram-promaster_2500-high_roof-used-3c6trvcg7ke539175.html"
#             },
#
#             {
#                 "@type": "ListItem",
#                 "position": 96,
#                 "name": "2018 Ram ProMaster 2500 High Roof",
#                 "image": "//cdn.ebizautos.media/used-2018-ram-promaster_2500-highroof-7725-21217038-1-640.jpg",
#                 "url": "//www.directautomecca.com/details-2018-ram-promaster_2500-high_roof-used-3c6trvcg6je112911.html"
#             },
#
#             {
#                 "@type": "ListItem",
#                 "position": 97,
#                 "name": "2018 Ram ProMaster 2500 High Roof",
#                 "image": "//cdn.ebizautos.media/used-2018-ram-promaster_2500-highroof-7725-21220543-1-640.jpg",
#                 "url": "//www.directautomecca.com/details-2018-ram-promaster_2500-high_roof-used-3c6trvcgxje138699.html"
#             },
#
#             {
#                 "@type": "ListItem",
#                 "position": 98,
#                 "name": "2018 Ford Transit-250 Base",
#                 "image": "//cdn.ebizautos.media/used-2018-ford-transit~250-base-7725-21220544-1-640.jpg",
#                 "url": "//www.directautomecca.com/details-2018-ford-transit~250-base-used-1ftyr2ym8jkb09923.html"
#             },
#
#             {
#                 "@type": "ListItem",
#                 "position": 99,
#                 "name": "2019 Chevrolet Express 2500 Work Van",
#                 "image": "//cdn.ebizautos.media/used-2019-chevrolet-express_2500-workvan-7725-21244857-1-640.jpg",
#                 "url": "//www.directautomecca.com/details-2019-chevrolet-express_2500-work_van-used-1gcwgbfp6k1163996.html"
#             }
#
#         ]
#     }
#   </script>
#   <!-- Footer_Breadcrumb_Schema_org -->
#   <script type="application/ld+json">
#    {
#   "@context": "http://schema.org",
#   "@type": "BreadcrumbList",
#   "itemListElement": [
#     {
#     "@type": "ListItem",
#     "position": 1,
#     "item": {
#       "@id": "//www.directautomecca.com/",
#       "name": "Home"
#     }
#   },
#
#     {
#     "@type": "ListItem",
#     "position": 2,
#     "item": {
#       "@id": "https://www.directautomecca.com/view-inventory.aspx",
#       "name": "All  Cars"
#     }
#   }
#   ]
# }
#   </script>
#   <!-- HTML_End -->
#   <script type="application/ld+json">
#    {
# 	  "@context": "http://www.schema.org",
# 	  "@type": "AutoDealer",
# 	  "name": "DirectAutomecca.com",
# 	  "url": "http://www.directautomecca.com/",
# 	  "logo": "https://images.ebizautos.media/Foundation/Sites/7725/AccountTemplate/images/logo.png?v2",
# 	  "image": "https://images.ebizautos.media/Foundation/Sites/7725/AccountTemplate/images/dealer-image.jpg",
# 	  "telephone": "+1 508-812-7804",
# 	  "address": {
# 		"@type": "PostalAddress",
# 		"streetAddress": "154 Waverly Street ",
# 		"addressLocality": "Framingham",
# 		"addressRegion": "MA",
# 		"postalCode": "01702",
# 		"addressCountry": "USA"
# 	  },
# 	  "priceRange": "$$",
# 	  "geo": {
# 		"@type": "GeoCoordinates",
# 		"latitude": "42.2785425",
# 		"longitude": "-71.4062965"
# 	  },
# 	  "contactPoint": {
# 		"@type": "ContactPoint",
# 		"telephone": "+1 508-812-7804",
# 		"contactType": "sales"
# 	  },
# 	  "sameAs": [
#         "https://www.facebook.com/DirectAutomecca",
#         "https://www.twitter.com/directautomecca",
#         "https://www.youtube.com/channel/UC6mGIPgsYrrRQfeO-IO8qcg",
#         "https://www.instagram.com/directautomecca",
#         "",
#         ""
#       ]
# 	}
#   </script>
#   <script>
#    $(document).ready(function() {
#     setTimeout(function() {
#         if (window.SpinCarLeadReportUrl) {
#             $('.ebiz-leadform-button').each(function() {
#                 $(this).attr("data-source", $(this).attr("data-source") + "&spurl=" + window.SpinCarLeadReportUrl);
#             });
#             $('.spin-frame').attr("title","Vehicle Spins and Images")
#         } else {
#             console.log("SpinCar not installed.")
#         }
#     }, 1900);
# });
#   </script>
#  </body>
# </html>

# %%
# Parse a specific tag + class
def parseColumn(soup, html_tag, html_class):
    dataColumn = soup.find_all(html_tag, class_=html_class)
    new_col_list = []
    
    for i in range(0, len(dataColumn)):
        new_col_list.append(dataColumn[i].get_text())
        
    return new_col_list

# Add new column to data frame
def addColumnDF(df, arr, col_name):
    df_tmp = pd.DataFrame(arr, columns = [col_name])
    df[col_name] = df_tmp[col_name]

# Grab vehicle manufacture year
def get_valid_year(soup, html_tag, html_class):
    models = parseColumn(soup, html_tag, html_class)
    new_col_list = []
    
    for model in models:
        new_col_list.append(model[0:4])
        
    return new_col_list

# Make & Model & Vehicle Type
def get_car_make_model_type(soup, html_tag, html_class):
    full_titles = parseColumn(soup, html_tag, html_class)
    makes = []
    models = []
    vehicle_types = []
    valid_makes = ['BMW', 'Audi', 'Toyota', 'Lexus', 'Ford', 'Honda'
                   , 'Hyundai', 'Kia', 'Chevrolet', 'Jeep', 'Nissan', 'Volkswagen'
                   , 'Mitsubishi', 'Mazda', 'GMC', 'Cadillac', 'Land Rover', 'Dodge'           
                   , 'Subaru', 'Ram', 'Chrysler', 'Acura', 'Mercedes-Benz', 'Infiniti']
    
    valid_vehicle_type = ['Sedan', 'SUV', 'Coupe', 'Wagon']
    
    # Remove years
    for idx in range(len(full_titles)):
        full_titles[idx] = full_titles[idx][5:]
        
    for model in full_titles:
        clean_model = ''
        stripped_make = ''
        stripped_type = ''
        for make in valid_makes:
            if make.lower() in model.lower():
                stripped_make = make
                clean_model = model.replace(make, '')
        
        for vt in valid_vehicle_type:
            if vt.lower() in clean_model.lower():
                stripped_type = vt
                clean_model = clean_model.replace(vt, '')
                
        if (stripped_make != ''):
            makes.append(stripped_make.strip())
        else:
            makes.append(None) # if none matches add a none
        
        if (stripped_type != ''):
            vehicle_types.append(stripped_type.strip())
        else:
            vehicle_types.append(None) # if none matches add a none
        
        models.append(clean_model.strip()) 

    return makes, models, vehicle_types

# def get_numeric_vehicle_data(html_tag, html_class):
#     scraped_mileages = parseColumn(html_tag, html_class)
#     mileages = []
    
#     for mileage in scraped_mileages:
#         mileages.append(int(re.sub("[^0-9]", "", mileage)))
    
#     return mileages

def get_numeric_vehicle_data(soup, html_tag, html_class):
    scraped_data = parseColumn(soup, html_tag, html_class)
    parsed_data = []
    numeric_data = []
    
    for el in scraped_data:
        parsed_data.append(re.sub("[^0-9]", "", el))
        
    for data in parsed_data:
        if data == '':
            numeric_data.append(np.nan)
        else:
            numeric_data.append(int(data))
    
    return numeric_data

# %%
title = parseColumn('h2', 'ebiz-vdp-title color m-0')
title
# Out:
# ['2014 Volkswagen Jetta',
#  '2014 Volkswagen Passat',
#  '2015 Nissan Rogue',
#  '2019 Chevrolet Spark',
#  '2016 Nissan Rogue',
#  '2017 Mitsubishi Outlander',
#  '2018 Kia Sportage',
#  '2014 Chevrolet Camaro',
#  '2020 Kia Soul',
#  '2017 Honda Accord',
#  '2018 Nissan Kicks',
#  '2018 Toyota Corolla',
#  '2016 Chevrolet Silverado 1500',
#  '2019 Nissan Kicks',
#  '2014 Chrysler 300C',
#  '2019 Honda Civic',
#  '2019 Ford Fusion Hybrid',
#  '2018 Nissan Rogue',
#  '2018 Chevrolet Trax',
#  '2020 Mitsubishi Outlander Sport',
#  '2018 Nissan Rogue Sport',
#  '2016 Mercedes-Benz CLA',
#  '2021 Toyota Corolla',
#  '2015 Mercedes-Benz GLK',
#  '2020 Mitsubishi Outlander',
#  '2014 Ram 1500',
#  '2019 Chevrolet Equinox',
#  '2019 Jeep Compass',
#  '2018 Ford Escape',
#  '2019 Ford Escape',
#  '2021 Nissan Sentra',
#  '2014 Chevrolet Silverado 1500',
#  '2021 Kia K5',
#  '2020 Honda HR-V',
#  '2018 Jeep Compass',
#  '2018 Nissan Rogue',
#  '2020 Mazda CX-5',
#  '2020 Hyundai Santa Fe',
#  '2014 Chevrolet Silverado 1500',
#  '2014 GMC Sierra 1500',
#  '2019 Chevrolet Colorado',
#  '2016 GMC Sierra 1500',
#  '2018 Ram ProMaster City',
#  '2020 Chrysler Voyager',
#  '2017 Chevrolet Camaro',
#  '2015 Ram 1500',
#  '2020 Ford Escape',
#  '2014 Jeep Wrangler',
#  '2018 Subaru WRX',
#  '2018 Cadillac XT5',
#  '2014 Chevrolet Express 1500',
#  '2020 Toyota RAV4',
#  '2018 Chevrolet Camaro',
#  '2017 Chevrolet Colorado',
#  '2017 Ford F-150',
#  '2019 Jeep Cherokee',
#  '2017 Jeep Grand Cherokee',
#  '2016 Chevrolet Silverado 1500',
#  '2019 Honda CR-V',
#  '2017 Ford Explorer',
#  '2016 Audi SQ5',
#  '2016 Ford F-150',
#  '2019 Toyota RAV4',
#  '2016 GMC Canyon',
#  '2019 GMC Acadia',
#  '2015 Jeep Wrangler',
#  '2020 Nissan Pathfinder',
#  '2018 Land Rover Discovery Sport',
#  '2017 Toyota Highlander',
#  '2018 Jeep Wrangler JK',
#  '2018 Chevrolet Silverado 1500',
#  '2018 GMC Sierra 1500',
#  '2018 Ford F-150',
#  '2020 GMC Acadia',
#  '2017 Chevrolet Silverado 1500',
#  '2020 BMW X1',
#  '2020 Toyota Highlander',
#  '2018 Cadillac XTS',
#  '2019 Ram 1500',
#  '2018 Ram 1500',
#  '2016 Ram 1500',
#  '2015 Ford Transit-350',
#  '2020 Dodge Durango',
#  '2019 Chevrolet Silverado 1500',
#  '2014 Toyota FJ Cruiser',
#  '2018 Ford F-150',
#  '2016 Chevrolet Silverado 2500HD',
#  '2019 Toyota 4Runner',
#  '2019 Chevrolet Silverado 1500',
#  '2017 Ford Transit-250',
#  '2019 Ford F-150',
#  '2019 Ram 1500',
#  '2020 Chevrolet Express 2500',
#  '2020 Chevrolet Silverado 1500',
#  '2018 Ford Transit-250',
#  '2019 Ram ProMaster 2500',
#  '2018 Ram ProMaster 2500',
#  '2018 Ram ProMaster 2500',
#  '2018 Ford Transit-250',
#  '2019 Chevrolet Express 2500']

# %%
import numpy as np
def get_numeric_vehicle_data(html_tag, html_class):
    scraped_data = parseColumn(html_tag, html_class)
    parsed_data = []
    numeric_data = []
    
    for el in scraped_data:
        parsed_data.append(re.sub("[^0-9]", "", el))
        
    for data in parsed_data:
        if data == '':
            numeric_data.append(np.nan)
        else:
            numeric_data.append(int(data))
    
    return numeric_data

x = get_numeric_vehicle_data('div', 'price-item')
x
# Out:
# [10000,
#  13497,
#  17597,
#  17997,
#  18497,
#  18997,
#  20000,
#  20000,
#  20000,
#  20597,
#  20997,
#  20997,
#  21697,
#  21997,
#  21997,
#  22997,
#  23997,
#  23997,
#  23997,
#  23997,
#  24597,
#  25000,
#  25000,
#  25000,
#  25597,
#  25697,
#  25997,
#  25997,
#  25997,
#  25997,
#  26997,
#  27497,
#  27597,
#  27697,
#  27697,
#  27797,
#  27997,
#  27997,
#  28497,
#  28997,
#  28997,
#  28997,
#  28997,
#  28997,
#  nan,
#  29197,
#  nan,
#  29697,
#  nan,
#  30000,
#  30000,
#  30000,
#  30000,
#  30197,
#  30597,
#  30697,
#  30797,
#  30897,
#  30897,
#  30997,
#  30997,
#  nan,
#  31997,
#  32997,
#  33597,
#  33597,
#  33597,
#  33997,
#  33997,
#  35000,
#  35000,
#  35000,
#  35000,
#  35000,
#  35697,
#  35997,
#  35997,
#  36597,
#  36997,
#  37497,
#  37497,
#  37997,
#  37997,
#  38597,
#  38597,
#  38997,
#  38997,
#  40000,
#  40000,
#  40000,
#  40497,
#  40497,
#  40597,
#  40897,
#  40997,
#  40997,
#  41597,
#  41697,
#  nan,
#  nan]

# %%
def get_numeric_vehicle_data(html_tag, html_class):
    parsed_data = parseColumn(html_tag, html_class)
    numeric_data = []
    
    for el in parsed_data:
        parsed_string = re.sub("[^0-9]", "", el)
        for data in parsed_string:
            if data === '':
                numeric_data.append(np.nan)
            else:
                numeric_data.append(int(parsed_string))
    
    return numeric_data



x = parseColumn('div', 'price-item')
for el in x:
    print(re.sub("[^0-9]", "", el))
# Out:
# 10000
# 13497
# 17597
# 17997
# 18497
# 18997
# 20000
# 20000
# 20000
# 20597
# 20997
# 20997
# 21697
# 21997
# 21997
# 22997
# 23997
# 23997
# 23997
# 23997
# 24597
# 25000
# 25000
# 25000
# 25597
# 25697
# 25997
# 25997
# 25997
# 25997
# 26997
# 27497
# 27597
# 27697
# 27697
# 27797
# 27997
# 27997
# 28497
# 28997
# 28997
# 28997
# 28997
# 28997
#
# 29197
#
# 29697
#
# 30000
# 30000
# 30000
# 30000
# 30197
# 30597
# 30697
# 30797
# 30897
# 30897
# 30997
# 30997
#
# 31997
# 32997
# 33597
# 33597
# 33597
# 33997
# 33997
# 35000
# 35000
# 35000
# 35000
# 35000
# 35697
# 35997
# 35997
# 36597
# 36997
# 37497
# 37497
# 37997
# 37997
# 38597
# 38597
# 38997
# 38997
# 40000
# 40000
# 40000
# 40497
# 40497
# 40597
# 40897
# 40997
# 40997
# 41597
# 41697

# %%
prices2 = parseColumn('div', 'price-item')
prices2 = pd.Series(prices2).str.replace('\n', '')
prices2 = pd.Series(prices2).str.replace('Internet Price', '')
# Out:
# ['\nInternet Price\n$10,000\n',
#  '\nInternet Price\n$13,497\n',
#  '\nInternet Price\n$17,597\n',
#  '\nInternet Price\n$17,997\n',
#  '\nInternet Price\n$18,497\n',
#  '\nInternet Price\n$18,997\n',
#  '\nInternet Price\n$20,000\n',
#  '\nInternet Price\n$20,000\n',
#  '\nInternet Price\n$20,000\n',
#  '\nInternet Price\n$20,597\n',
#  '\nInternet Price\n$20,997\n',
#  '\nInternet Price\n$20,997\n',
#  '\nInternet Price\n$21,697\n',
#  '\nInternet Price\n$21,997\n',
#  '\nInternet Price\n$21,997\n',
#  '\nInternet Price\n$22,997\n',
#  '\nInternet Price\n$23,997\n',
#  '\nInternet Price\n$23,997\n',
#  '\nInternet Price\n$23,997\n',
#  '\nInternet Price\n$23,997\n',
#  '\nInternet Price\n$24,597\n',
#  '\nInternet Price\n$25,000\n',
#  '\nInternet Price\n$25,000\n',
#  '\nInternet Price\n$25,000\n',
#  '\nInternet Price\n$25,597\n',
#  '\nInternet Price\n$25,697\n',
#  '\nInternet Price\n$25,997\n',
#  '\nInternet Price\n$25,997\n',
#  '\nInternet Price\n$25,997\n',
#  '\nInternet Price\n$25,997\n',
#  '\nInternet Price\n$26,997\n',
#  '\nInternet Price\n$27,497\n',
#  '\nInternet Price\n$27,597\n',
#  '\nInternet Price\n$27,697\n',
#  '\nInternet Price\n$27,697\n',
#  '\nInternet Price\n$27,797\n',
#  '\nInternet Price\n$27,997\n',
#  '\nInternet Price\n$27,997\n',
#  '\nInternet Price\n$28,497\n',
#  '\nInternet Price\n$28,997\n',
#  '\nInternet Price\n$28,997\n',
#  '\nInternet Price\n$28,997\n',
#  '\nInternet Price\n$28,997\n',
#  '\nInternet Price\n$28,997\n',
#  '\nSale Pending\n',
#  '\nInternet Price\n$29,197\n',
#  '\nSale Pending\n',
#  '\nInternet Price\n$29,697\n',
#  '\nSale Pending\n',
#  '\nInternet Price\n$30,000\n',
#  '\nInternet Price\n$30,000\n',
#  '\nInternet Price\n$30,000\n',
#  '\nInternet Price\n$30,000\n',
#  '\nInternet Price\n$30,197\n',
#  '\nInternet Price\n$30,597\n',
#  '\nInternet Price\n$30,697\n',
#  '\nInternet Price\n$30,797\n',
#  '\nInternet Price\n$30,897\n',
#  '\nInternet Price\n$30,897\n',
#  '\nInternet Price\n$30,997\n',
#  '\nInternet Price\n$30,997\n',
#  '\nSale Pending\n',
#  '\nInternet Price\n$31,997\n',
#  '\nInternet Price\n$32,997\n',
#  '\nInternet Price\n$33,597\n',
#  '\nInternet Price\n$33,597\n',
#  '\nInternet Price\n$33,597\n',
#  '\nInternet Price\n$33,997\n',
#  '\nInternet Price\n$33,997\n',
#  '\nInternet Price\n$35,000\n',
#  '\nInternet Price\n$35,000\n',
#  '\nInternet Price\n$35,000\n',
#  '\nInternet Price\n$35,000\n',
#  '\nInternet Price\n$35,000\n',
#  '\nInternet Price\n$35,697\n',
#  '\nInternet Price\n$35,997\n',
#  '\nInternet Price\n$35,997\n',
#  '\nInternet Price\n$36,597\n',
#  '\nInternet Price\n$36,997\n',
#  '\nInternet Price\n$37,497\n',
#  '\nInternet Price\n$37,497\n',
#  '\nInternet Price\n$37,997\n',
#  '\nInternet Price\n$37,997\n',
#  '\nInternet Price\n$38,597\n',
#  '\nInternet Price\n$38,597\n',
#  '\nInternet Price\n$38,997\n',
#  '\nInternet Price\n$38,997\n',
#  '\nInternet Price\n$40,000\n',
#  '\nInternet Price\n$40,000\n',
#  '\nInternet Price\n$40,000\n',
#  '\nInternet Price\n$40,497\n',
#  '\nInternet Price\n$40,497\n',
#  '\nInternet Price\n$40,597\n',
#  '\nInternet Price\n$40,897\n',
#  '\nInternet Price\n$40,997\n',
#  '\nInternet Price\n$40,997\n',
#  '\nInternet Price\n$41,597\n',
#  '\nInternet Price\n$41,697\n',
#  '\nSale Pending\n',
#  '\nSale Pending\n']

# %%
# Prices
prices = parseColumn('h4', 'money-sign-disp body-font d-inline m-0')
prices
# Out:
# ['$10,000',
#  '$13,497',
#  '$17,597',
#  '$17,997',
#  '$18,497',
#  '$18,997',
#  '$20,000',
#  '$20,000',
#  '$20,000',
#  '$20,597',
#  '$20,997',
#  '$20,997',
#  '$21,697',
#  '$21,997',
#  '$21,997',
#  '$22,997',
#  '$23,997',
#  '$23,997',
#  '$23,997',
#  '$23,997',
#  '$24,597',
#  '$25,000',
#  '$25,000',
#  '$25,000',
#  '$25,597',
#  '$25,697',
#  '$25,997',
#  '$25,997',
#  '$25,997',
#  '$25,997',
#  '$26,997',
#  '$27,497',
#  '$27,597',
#  '$27,697',
#  '$27,697',
#  '$27,797',
#  '$27,997',
#  '$27,997',
#  '$28,497',
#  '$28,997',
#  '$28,997',
#  '$28,997',
#  '$28,997',
#  '$28,997',
#  '$29,197',
#  '$29,697',
#  '$30,000',
#  '$30,000',
#  '$30,000',
#  '$30,000',
#  '$30,197',
#  '$30,597',
#  '$30,697',
#  '$30,797',
#  '$30,897',
#  '$30,897',
#  '$30,997',
#  '$30,997',
#  '$31,997',
#  '$32,997',
#  '$33,597',
#  '$33,597',
#  '$33,597',
#  '$33,997',
#  '$33,997',
#  '$35,000',
#  '$35,000',
#  '$35,000',
#  '$35,000',
#  '$35,000',
#  '$35,697',
#  '$35,997',
#  '$35,997',
#  '$36,597',
#  '$36,997',
#  '$37,497',
#  '$37,497',
#  '$37,997',
#  '$37,997',
#  '$38,597',
#  '$38,597',
#  '$38,997',
#  '$38,997',
#  '$40,000',
#  '$40,000',
#  '$40,000',
#  '$40,497',
#  '$40,497',
#  '$40,597',
#  '$40,897',
#  '$40,997',
#  '$40,997',
#  '$41,597',
#  '$41,697']

# %%
# Miles
miles = parseColumn('li', 'mileage-units')
miles
# Out:
# ['Miles: 96,889',
#  'Miles: 68,956',
#  'Miles: 82,552',
#  'Miles: 22,395',
#  'Miles: 84,059',
#  'Miles: 84,265',
#  'Miles: 75,969',
#  'Miles: 92,997',
#  'Miles: 50,265',
#  'Miles: 85,621',
#  'Miles: 28,153',
#  'Miles: 31,876',
#  'Miles: 76,139',
#  'Miles: 27,783',
#  'Miles: 57,658',
#  'Miles: 32,179',
#  'Miles: 34,450',
#  'Miles: 51,021',
#  'Miles: 26,323',
#  'Miles: 45,072',
#  'Miles: 36,657',
#  'Miles: 70,615',
#  'Miles: 20,660',
#  'Miles: 60,319',
#  'Miles: 48,332',
#  'Miles: 85,103',
#  'Miles: 29,799',
#  'Miles: 38,252',
#  'Miles: 26,732',
#  'Miles: 29,368',
#  'Miles: 5,182',
#  'Miles: 90,329',
#  'Miles: 19,388',
#  'Miles: 20,655',
#  'Miles: 39,375',
#  'Miles: 37,749',
#  'Miles: 34,044',
#  'Miles: 53,179',
#  'Miles: 65,619',
#  'Miles: 78,939',
#  'Miles: 55,699',
#  'Miles: 71,040',
#  'Miles: 6,889',
#  'Miles: 58,477',
#  'Miles: 39,131',
#  'Miles: 77,335',
#  'Miles: 55,180',
#  'Miles: 73,459',
#  'Miles: 41,460',
#  'Miles: 67,916',
#  'Miles: 81,799',
#  'Miles: 46,777',
#  'Miles: 22,960',
#  'Miles: 62,566',
#  'Miles: 73,012',
#  'Miles: 40,493',
#  'Miles: 52,810',
#  'Miles: 75,733',
#  'Miles: 46,189',
#  'Miles: 74,421',
#  'Miles: 77,330',
#  'Miles: 88,185',
#  'Miles: 40,954',
#  'Miles: 49,809',
#  'Miles: 41,790',
#  'Miles: 62,779',
#  'Miles: 48,725',
#  'Miles: 34,631',
#  'Miles: 55,465',
#  'Miles: 35,439',
#  'Miles: 59,465',
#  'Miles: 41,313',
#  'Miles: 66,052',
#  'Miles: 53,369',
#  'Miles: 27,436',
#  'Miles: 46,947',
#  'Miles: 53,924',
#  'Miles: 62,050',
#  'Miles: 72,680',
#  'Miles: 21,140',
#  'Miles: 58,427',
#  'Miles: 78,341',
#  'Miles: 52,308',
#  'Miles: 98,995',
#  'Miles: 70,239',
#  'Miles: 52,190',
#  'Miles: 64,369',
#  'Miles: 25,229',
#  'Miles: 50,792',
#  'Miles: 83,069',
#  'Miles: 13,804',
#  'Miles: 22,823',
#  'Miles: 78,342',
#  'Miles: 24,633',
#  'Miles: 39,113',
#  'Miles: 59,259',
#  'Miles: 53,371',
#  'Miles: 53,055',
#  'Miles: 36,325',
#  'Miles: 53,070']

# %%
# VIN
vin = parseColumn('li', 'vin')
vin
# Out:
# ['VIN #: 3VW1K7AJ1EM371670',
#  'VIN #: 1VWAT7A35EC091203',
#  'VIN #: KNMAT2MV0FP507719',
#  'VIN #: KL8CF6SA2KC750949',
#  'VIN #: JN8AT2MV3GW141234',
#  'VIN #: JA4AZ2A38HZ070328',
#  'VIN #: KNDPMCAC4J7345148',
#  'VIN #: 2G1FC1E33E9311597',
#  'VIN #: KNDJ23AU7L7006276',
#  'VIN #: 1HGCR2F12HA154683',
#  'VIN #: 3N1CP5CU0JL509193',
#  'VIN #: 2T1BURHE8JC083752',
#  'VIN #: 1GCNCNEH9GZ311344',
#  'VIN #: 3N1CP5CU8KL509315',
#  'VIN #: 2C3CCAKT3EH203134',
#  'VIN #: 2HGFC2F61KH520426',
#  'VIN #: 3FA6P0LU5KR125847',
#  'VIN #: 5N1AT2MV3JC764725',
#  'VIN #: 3GNCJPSB4JL155115',
#  'VIN #: JA4AR3AU1LU019354',
#  'VIN #: JN1BJ1CR9JW289354',
#  'VIN #: WDDSJ4GB7GN374614',
#  'VIN #: JTDEPMAE4MJ129197',
#  'VIN #: WDCGG8JBXFG350075',
#  'VIN #: JA4AZ3A36LZ025421',
#  'VIN #: 3C6JR7CT6EG330728',
#  'VIN #: 3GNAXSEVXKL292124',
#  'VIN #: 3C4NJDBB1KT647232',
#  'VIN #: 1FMCU9HD5JUA38116',
#  'VIN #: 1FMCU9GD3KUB66924',
#  'VIN #: 3N1AB8DV0MY250548',
#  'VIN #: 1GCVKREC7EZ306879',
#  'VIN #: 5XXG14J21MG054513',
#  'VIN #: 3CZRU6H16LM703125',
#  'VIN #: 3C4NJDCB9JT323202',
#  'VIN #: 5N1AT2MV4JC768167',
#  'VIN #: JM3KFACM7L0768954',
#  'VIN #: 5NMS2CAD7LH239913',
#  'VIN #: 1GCVKREH2EZ415651',
#  'VIN #: 1GTV2UEC7EZ270310',
#  'VIN #: 1GCGSBEN4K1309024',
#  'VIN #: 1GTV2LEH8GZ381652',
#  'VIN #: ZFBERFBB4J6J29311',
#  'VIN #: 2C4RC1DG9LR258488',
#  'VIN #: 1G1FB3DS9H0197305',
#  'VIN #: 3C6RR7LTXFG598637',
#  'VIN #: 1FMCU9J98LUB19944',
#  'VIN #: 1C4AJWBG7EL130149',
#  'VIN #: JF1VA1C63J9806104',
#  'VIN #: 1GYKNBRS2JZ122893',
#  'VIN #: 1GNSHCF49E1190483',
#  'VIN #: 2T3H1RFV1LC051290',
#  'VIN #: 1G1FB1RX4J0189398',
#  'VIN #: 1GCGTBEN5H1323617',
#  'VIN #: 1FTEX1EP6HFB84687',
#  'VIN #: 1C4PJMDX7KD321006',
#  'VIN #: 1C4RJFBG1HC806991',
#  'VIN #: 1GCVKREC5GZ422276',
#  'VIN #: 2HKRW2H52KH652710',
#  'VIN #: 1FM5K8HT3HGD73366',
#  'VIN #: WA1CCAFP3GA029974',
#  'VIN #: 1FTFW1EF7GFD27806',
#  'VIN #: JTMP1RFV1KD014987',
#  'VIN #: 1GTG6CE35G1370320',
#  'VIN #: 1GKKNULS6KZ128003',
#  'VIN #: 1C4BJWDG8FL687882',
#  'VIN #: 5N1DR2CM9LC605909',
#  'VIN #: SALCP2RX9JH750688',
#  'VIN #: 5TDJZRFH9HS465008',
#  'VIN #: 1C4BJWDG3JL803787',
#  'VIN #: 1GCVKREC5JZ189085',
#  'VIN #: 1GTV2LEC8JZ261863',
#  'VIN #: 1FTFW1EG5JFC72837',
#  'VIN #: 1GKKNML45LZ178412',
#  'VIN #: 1GCVKREH1HZ244542',
#  'VIN #: WBXJG9C09L3L85922',
#  'VIN #: 5TDBZRBH7LS008555',
#  'VIN #: 2G61R5S31J9148067',
#  'VIN #: 1C6SRFFT3KN654278',
#  'VIN #: 1C6RR7LT4JS332693',
#  'VIN #: 1C6RR7UT0GS324016',
#  'VIN #: 1FBZX2XMXFKA51644',
#  'VIN #: 1C4RDJDG8LC260738',
#  'VIN #: 1GCRYCEF1KZ302426',
#  'VIN #: JTEBU4BF8EK182382',
#  'VIN #: 1FTEW1EP8JKE20160',
#  'VIN #: 1GC2KUEG4GZ188964',
#  'VIN #: JTEBU5JR6K5683086',
#  'VIN #: 1GCRYDED6KZ314172',
#  'VIN #: 1FTYR1CM6HKA96066',
#  'VIN #: 1FTFW1E54KFB96981',
#  'VIN #: 1C6RRFFG1KN811369',
#  'VIN #: 1GCWGBFGXL1155160',
#  'VIN #: 1GCRYDED4LZ198603',
#  'VIN #: 1FTYR1ZM2JKB48001',
#  'VIN #: 3C6TRVCG7KE539175',
#  'VIN #: 3C6TRVCG6JE112911',
#  'VIN #: 3C6TRVCGXJE138699',
#  'VIN #: 1FTYR2YM8JKB09923',
#  'VIN #: 1GCWGBFP6K1163996']

# %%
# Transmission
transmission = parseColumn('ul', 'small list-unstyled mb-0')
transmission[0].split('\n')

for el in transmission[0].split('\n'):
    if 'Engine' in el:
        print(el.split(':')[1].strip())
# Out:
# 2.0L 4 Cylinder

# %%
# Use for when vehicle data doesn't have specific class names
def get_vehicle_data_direct_mecca(soup, html_tag, html_class, vehicle_data_type):
    misc_vehicle_data = parseColumn(soup, html_tag, html_class)
    vehicle_data_list = []
    for row in misc_vehicle_data:
        for el in row.split('\n'):
            if vehicle_data_type.lower() in el.lower():
                vehicle_data_list.append(el.split(':')[1].strip())
    return vehicle_data_list
                
                
engine = get_vehicle_data_direct_mecca(soup, 'ul', 'small list-unstyled mb-0', 'engine')
engine
# Out:
# ['2.0L 4 Cylinder',
#  '1.8L 4 Cylinder',
#  '2.5L 4 Cylinder',
#  '1.4L 4 Cylinder',
#  '2.5L 4 Cylinder',
#  '2.4L 4 Cylinder',
#  '2.4L 4 Cylinder',
#  '3.6L V6 Cylinder',
#  '2.0L 4 Cylinder',
#  '2.4L 4 Cylinder',
#  '1.6L 4 Cylinder',
#  '1.8L 4 Cylinder',
#  '4.3L V6 CYLINDER',
#  '1.6L 4 Cylinder',
#  '5.7L 8 Cylinder',
#  '2.0L 4 Cylinder',
#  '2.0L 4 Cylinder',
#  '2.5L 4 Cylinder',
#  '1.4L 4 CYLINDER',
#  '2.0L 4 Cylinder',
#  '2.0L 4 Cylinder',
#  '2.0L 4 Cylinder',
#  '1.8L 4 Cylinder',
#  '3.5L V6 Cylinder',
#  '2.4L 4 Cylinder',
#  '5.7L 8 Cylinder',
#  '1.5L 4 Cylinder',
#  '2.4L 4 Cylinder',
#  '1.5L 4 Cylinder',
#  '1.5L 4 Cylinder',
#  '2.0L 4 Cylinder',
#  '2.4L 4 Cylinder',
#  '5.3L 8 Cylinder',
#  '1.6L 4 Cylinder',
#  '1.8L 4 Cylinder',
#  '2.4L 4 Cylinder',
#  '2.5L 4 Cylinder',
#  '2.5L 4 CYLINDER',
#  '2.4L 4 Cylinder',
#  '4.3L V6 Cylinder',
#  '5.3L 8 Cylinder',
#  '3.6L V6 Cylinder',
#  '4.3L V6 Cylinder',
#  '2.4L 4 CYLINDER',
#  '3.6L V6 Cylinder',
#  '3.6L V6 Cylinder',
#  '5.7L 8 Cylinder',
#  '2.0L 4 Cylinder',
#  '3.6L V6 Cylinder',
#  '2.0L 4 Cylinder',
#  '3.6L V6 Cylinder',
#  '5.3L 8 Cylinder',
#  '2.5L 4 Cylinder',
#  '2.0L 4 Cylinder',
#  '3.6L V6 Cylinder',
#  '2.7L V6 Cylinder',
#  '3.2L V6 Cylinder',
#  '3.6L V6 Cylinder',
#  '5.3L 8 Cylinder',
#  '1.5L 4 Cylinder',
#  '3.5L V6 Cylinder',
#  '3.0L V6 Cylinder',
#  '5.0L 8 Cylinder',
#  '2.5L 4 Cylinder',
#  '3.6L V6 Cylinder',
#  '3.6L V6 Cylinder',
#  '3.6L V6 Cylinder',
#  '3.5L V6 Cylinder',
#  '2.0L 4 Cylinder',
#  '3.5L V6 Cylinder',
#  '3.6L V6 CYLINDER',
#  '5.3L 8 Cylinder',
#  '5.3L 8 Cylinder',
#  '3.5L V6 Cylinder',
#  '2.0L 4 Cylinder',
#  '4.3L V6 Cylinder',
#  '2.0L 4 Cylinder',
#  '3.5L V6 Cylinder',
#  '3.6L V6 Cylinder',
#  '5.7L 8 Cylinder',
#  '5.7L 8 CYLINDER',
#  '5.7L 8 CYLINDER',
#  '3.7L V6 SFI DOHC 24V',
#  '3.6L V6 Cylinder',
#  '5.3L 8 Cylinder',
#  '4.0L V6 Cylinder',
#  '2.7L V6 ECOBOOST',
#  '6.0L 8 Cylinder',
#  '4.0L V6 Cylinder',
#  '5.3L 8 Cylinder',
#  '3.7L V6 Cylinder',
#  '5.0L 8 Cylinder',
#  '3.6L V6 CYLINDER',
#  '6.0L 8 Cylinder',
#  '5.3L 8 CYLINDER',
#  '3.7L V6 Cylinder',
#  '3.6L V6 Cylinder',
#  '3.6L V6 Cylinder',
#  '3.6L V6 Cylinder',
#  '3.7L V6 Cylinder']

# %%
dealerships = {
    'Bostonyan Auto Group': {
        'url': 'https://www.bostonyanautogroup.com/view-inventory',
        'dealership_name': 'Bostonyan Auto Group',
        'address': '119 Worcester St',
        'zipcode': '01760',
        'city': 'Natick',
        'state': 'MA'
    },
    'Direct Auto Mecca': {
        'url': 'https://www.directautomecca.com/view-inventory.aspx',
        'dealership_name': 'Direct Auto Mecca',
        'address': '154 Waverly Street',
        'zipcode': '01760',
        'city': 'Natick',
        'state': 'MA'
    }
}

# %%
# Scrape inventory HTML
def get_direct_auto_inventory_data(soup, dealership_info):    
    # Initialize empty data frame
    cars = pd.DataFrame()
    
    # Add title
    title = parseColumn(soup, 'h2', 'ebiz-vdp-title color m-0')    
    addColumnDF(cars, title, 'title')

    # Add vehicle manufacture date
    years = get_valid_year(soup, 'h2', 'ebiz-vdp-title color m-0')
    addColumnDF(cars, years, 'year')

    # Add make, models, and vehicle type
    makes, models, vtypes = get_car_make_model_type(soup, 'h2', 'ebiz-vdp-title color m-0')
    addColumnDF(cars, makes, 'make')
    addColumnDF(cars, models, 'models')
    addColumnDF(cars, vtypes, 'vehicle_type')

    # Add mileage col
    miles = get_numeric_vehicle_data(soup, 'li', 'mileage-units')
    addColumnDF(cars, miles, 'vehicle_mileage')

    # Add price
    car_prices = get_numeric_vehicle_data(soup, 'div', 'price-item')
    print(car_prices)
    addColumnDF(cars, car_prices, 'price')

    # Add Colors & transmission & other cols
    addColumnDF(cars, get_vehicle_data_direct_mecca(soup, 'ul', 'small list-unstyled mb-0', 'exterior'), 'exterior_color')
    addColumnDF(cars, get_vehicle_data_direct_mecca(soup, 'ul', 'small list-unstyled mb-0', 'interior'), 'interior_color')
    addColumnDF(cars, get_vehicle_data_direct_mecca(soup, 'ul', 'small list-unstyled mb-0', 'transmission'), 'transmission')
    addColumnDF(cars, get_vehicle_data_direct_mecca(soup, 'ul', 'small list-unstyled mb-0', 'engine'), 'engine')
    addColumnDF(cars, parseColumn(soup, 'li', 'vin'), 'vin')
    cars['vin'] = cars['vin'].str.replace('VIN #: ', '')
    
    # Add dealership info + scrape date
    cars['dealership_name'] = dealership_info['dealership_name']
    cars['dealership_address'] = dealership_info['address']
    cars['dealership_zipcode'] = dealership_info['zipcode']
    cars['dealership_city'] = dealership_info['city']
    cars['dealership_state'] = dealership_info['state']
    cars['inventory_url'] = dealership_info['url']
    cars['scraped_date'] = datetime.now(tz = None)
    
    return cars
    # Add data to a SQLite database
#     conn = sqlite3.connect('cars.db')
#     cars.to_sql('inventory', conn, if_exists='append', index=False)

# %%
response = requests.get(dealerships['Direct Auto Mecca']['url'], headers = headers)
soup = BeautifulSoup(response.text, "html.parser")  
c = get_direct_auto_inventory_data(soup, dealerships['Direct Auto Mecca'])
# Out:
# [10000, 13497, 17597, 17997, 18497, 18997, 20000, 20000, 20000, 20597, 20997, 20997, 21697, 21997, 21997, 22997, 23997, 23997, 23997, 23997, 24597, 25000, 25000, 25000, 25597, 25697, 25997, 25997, 25997, 25997, 26997, 26997, 27497, 27597, 27697, 27697, 27797, 27997, 27997, 28497, 28997, 28997, 28997, 28997, 28997, nan, 29197, nan, 29697, nan, 30000, 30000, 30000, 30000, 30197, 30597, 30697, 30797, 30897, 30897, 30997, 30997, nan, 31997, 32997, 33597, 33597, 33597, 33997, 33997, 35000, 35000, 35000, 35000, 35000, 35697, 35997, 35997, 36597, 36997, 37497, 37497, 37997, 37997, 38597, 38597, 38997, 38997, 40000, 40000, 40000, 40497, 40497, 40597, 40897, 40997, 40997, 41597, 41697, nan]

# %%
c.isnull().sum()
# Out:
# title                   0
# year                    0
# make                    0
# models                  0
# vehicle_type          100
# vehicle_mileage         0
# price                   5
# exterior_color          0
# interior_color          0
# transmission            0
# engine                  0
# vin                     0
# dealership_name         0
# dealership_address      0
# dealership_zipcode      0
# dealership_city         0
# dealership_state        0
# inventory_url           0
# scraped_date            0
# dtype: int64

# %%
c.loc[c['price'].isnull(), ['title', 'price', 'vin']]
# Out:
#                     title  price                vin
# 45  2017 Chevrolet Camaro    NaN  1G1FB3DS9H0197305
# 47       2020 Ford Escape    NaN  1FMCU9J98LUB19944
# 49        2018 Subaru WRX    NaN  JF1VA1C63J9806104
# 62        2016 Ford F-150    NaN  1FTFW1EF7GFD27806
# 99  2018 Ford Transit-250    NaN  1FTYR2YM8JKB09923

# %%
c
# Out:
#                       title  year        make          models vehicle_type  \
# 0     2014 Volkswagen Jetta  2014  Volkswagen           Jetta         None
# 1    2014 Volkswagen Passat  2014  Volkswagen          Passat         None
# 2         2015 Nissan Rogue  2015      Nissan           Rogue         None
# 3      2019 Chevrolet Spark  2019   Chevrolet           Spark         None
# 4         2016 Nissan Rogue  2016      Nissan           Rogue         None
# ..                      ...   ...         ...             ...          ...
# 95    2018 Ford Transit-250  2018        Ford     Transit-250         None
# 96  2019 Ram ProMaster 2500  2019         Ram  ProMaster 2500         None
# 97  2018 Ram ProMaster 2500  2018         Ram  ProMaster 2500         None
# 98  2018 Ram ProMaster 2500  2018         Ram  ProMaster 2500         None
# 99    2018 Ford Transit-250  2018        Ford     Transit-250         None
#
#     vehicle_mileage    price          exterior_color  \
# 0             96889  10000.0                  Silver
# 1             68956  13497.0                  Silver
# 2             82552  17597.0             Super Black
# 3             22395  17997.0     Silver Ice Metallic
# 4             84059  18497.0            Gun Metallic
# ..              ...      ...                     ...
# 95            39113  40997.0                   White
# 96            59259  40997.0  Bright White Clearcoat
# 97            53371  41597.0  Bright White Clearcoat
# 98            53055  41697.0  Bright White Clearcoat
# 99            36325      NaN                   White
#
#                              interior_color     transmission  \
# 0                          Mar Grigalauskas     5 Spd Manual
# 1                                      Gray  6 Spd Automatic
# 2                                     Black              CVT
# 3   Jet Black/Dark Anderson Silver Metallic              CVT
# 4                                  Charcoal              CVT
# ..                                      ...              ...
# 95                                    Black  6 Spd Automatic
# 96                                    Black  6 Spd Automatic
# 97                                    Black  6 Spd Automatic
# 98                                    Black  6 Spd Automatic
# 99                                     Gray  6 Spd Automatic
#
#               engine                vin    dealership_name  \
# 0    2.0L 4 Cylinder  3VW1K7AJ1EM371670  Direct Auto Mecca
# 1    1.8L 4 Cylinder  1VWAT7A35EC091203  Direct Auto Mecca
# 2    2.5L 4 Cylinder  KNMAT2MV0FP507719  Direct Auto Mecca
# 3    1.4L 4 Cylinder  KL8CF6SA2KC750949  Direct Auto Mecca
# 4    2.5L 4 Cylinder  JN8AT2MV3GW141234  Direct Auto Mecca
# ..               ...                ...                ...
# 95  3.7L V6 Cylinder  1FTYR1ZM2JKB48001  Direct Auto Mecca
# 96  3.6L V6 Cylinder  3C6TRVCG7KE539175  Direct Auto Mecca
# 97  3.6L V6 Cylinder  3C6TRVCG6JE112911  Direct Auto Mecca
# 98  3.6L V6 Cylinder  3C6TRVCGXJE138699  Direct Auto Mecca
# 99  3.7L V6 Cylinder  1FTYR2YM8JKB09923  Direct Auto Mecca
#
#     dealership_address dealership_zipcode dealership_city dealership_state  \
# 0   154 Waverly Street              01760          Natick               MA
# 1   154 Waverly Street              01760          Natick               MA
# 2   154 Waverly Street              01760          Natick               MA
# 3   154 Waverly Street              01760          Natick               MA
# 4   154 Waverly Street              01760          Natick               MA
# ..                 ...                ...             ...              ...
# 95  154 Waverly Street              01760          Natick               MA
# 96  154 Waverly Street              01760          Natick               MA
# 97  154 Waverly Street              01760          Natick               MA
# 98  154 Waverly Street              01760          Natick               MA
# 99  154 Waverly Street              01760          Natick               MA
#
#                                         inventory_url  \
# 0   https://www.directautomecca.com/view-inventory...
# 1   https://www.directautomecca.com/view-inventory...
# 2   https://www.directautomecca.com/view-inventory...
# 3   https://www.directautomecca.com/view-inventory...
# 4   https://www.directautomecca.com/view-inventory...
# ..                                                ...
# 95  https://www.directautomecca.com/view-inventory...
# 96  https://www.directautomecca.com/view-inventory...
# 97  https://www.directautomecca.com/view-inventory...
# 98  https://www.directautomecca.com/view-inventory...
# 99  https://www.directautomecca.com/view-inventory...
#
#                  scraped_date
# 0  2022-03-04 23:33:33.293842
# 1  2022-03-04 23:33:33.293842
# 2  2022-03-04 23:33:33.293842
# 3  2022-03-04 23:33:33.293842
# 4  2022-03-04 23:33:33.293842
# ..                        ...
# 95 2022-03-04 23:33:33.293842
# 96 2022-03-04 23:33:33.293842
# 97 2022-03-04 23:33:33.293842
# 98 2022-03-04 23:33:33.293842
# 99 2022-03-04 23:33:33.293842
#
# [100 rows x 19 columns]

# %%
# Scrape inventory HTML
response = requests.get('https://www.directautomecca.com/inventory.aspx?_new=true&_used=true&_page=3', headers = headers)
soup_test = BeautifulSoup(response.text, "html.parser")

# %%
soup_test
# Out:
# <!DOCTYPE html>
#
# <html dir="ltr" lang="en-US">
# <head>
# <title>New, Used Cars at DirectAutomecca.com Serving Framingham, MA, Inventory</title>
# <meta content="Serving Framingham, Massachusetts (MA), DirectAutomecca.com is the place to purchase your next car. View photos and details of our entire inventory." name="description"/>
# <meta content="DirectAutomecca.com Serving Framingham, MA, Inventory, New, Used" name="keywords"/>
# <meta content="text/html; charset=utf-8" http-equiv="content-type">
# <meta content="DirectAutomecca.com" name="author">
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="New, Used Cars at DirectAutomecca.com Serving Framingham, MA, Inventory" name="og:title"/>
# <meta content="website" name="og:type"/>
# <meta content="DirectAutomecca.com" property="og:site_name"/>
# <meta content="http://www.directautomecca.com/inventory.aspx?_new=true&amp;_used=true&amp;_page=3" name="og:url"/>
# <meta content="Serving Framingham, Massachusetts (MA), DirectAutomecca.com is the place to purchase your next car. View photos and details of our entire inventory." name="og:description"/>
# <meta content="https://images.ebizautos.media/Foundation/Sites/7725/AccountTemplate/images/dealer-image.jpg" property="og:image"/>
# <meta content="noindex,nofollow,noodp" name="robots"/>
# <link href="https://www.directautomecca.com/inventory.aspx" rel="canonical"/>
# <link href="//images.ebizautos.media/Foundation/Templates/-2147483646/images/favicon.ico" rel="icon" type="image/x-icon"/>
# <link crossorigin="" href="https://images.ebizautos.media" rel="preconnect"/>
# <link crossorigin="" href="https://cdn.ebizautos.media" rel="preconnect"/>
# <link crossorigin="" href="https://stockphotos.ebizautos.media" rel="preconnect"/>
# <link as="font" crossorigin="" href="https://images.ebizautos.media/fonts/foundation-icons/font-icons.woff" rel="preload" type="font/woff"/>
# <link as="font" crossorigin="" href="https://images.ebizautos.media/fonts/foundation-icons/font-icons.woff2" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="" href="https://images.ebizautos.media/fonts/foundation-icons/font-icons-2.woff" rel="preload" type="font/woff"/>
# <link as="font" crossorigin="" href="https://images.ebizautos.media/fonts/foundation-icons/font-icons-2.woff2" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="" href="https://images.ebizautos.media/fonts/foundation-icons/font-icons-3.woff" rel="preload" type="font/woff"/>
# <link as="font" crossorigin="" href="https://images.ebizautos.media/fonts/foundation-icons/font-icons-3.woff2" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="" href="https://images.ebizautos.media/fonts/foundation-icons/font-icons-4.woff" rel="preload" type="font/woff"/>
# <link as="font" crossorigin="" href="https://images.ebizautos.media/fonts/foundation-icons/font-icons-4.woff2" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="" href="https://images.ebizautos.media/fonts/foundation-icons/lined-icons.woff" rel="preload" type="font/woff"/>
# <link as="font" crossorigin="" href="https://images.ebizautos.media/fonts/foundation-icons/lined-icons.woff2" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="" href="https://images.ebizautos.media/fonts/foundation-icons/Simple-Line-Icons.woff" rel="preload" type="font/woff"/>
# <link as="font" crossorigin="" href="https://images.ebizautos.media/fonts/foundation-icons/Simple-Line-Icons.woff2" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="" href="https://images.ebizautos.media/fonts/foundation-icons/font-vehicles.woff" rel="preload" type="font/woff"/>
# <link as="font" crossorigin="" href="https://images.ebizautos.media/fonts/foundation-icons/font-vehicles.woff2" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="" href="https://images.ebizautos.media/fonts/foundation-icons/font-features.woff" rel="preload" type="font/woff"/>
# <link as="font" crossorigin="" href="https://images.ebizautos.media/fonts/foundation-icons/font-features.woff2" rel="preload" type="font/woff2"/>
# <link href="https://images.ebizautos.media/Foundation/Controls/-2147483583/css/foundation.css" rel="stylesheet" type="text/css">
# <link href="https://images.ebizautos.media/Foundation/Controls/-2147483583/css/font-icons.css" rel="stylesheet" type="text/css">
# <link href="https://images.ebizautos.media/Foundation/Templates/-2147483602/css/fonts.css" rel="stylesheet" type="text/css">
# <link href="https://images.ebizautos.media/Foundation/Templates/-2147483602/css/foundation-theme.css" rel="stylesheet" type="text/css">
# <link href="https://images.ebizautos.media/Foundation/Templates/-2147483602/css/responsive.css" rel="stylesheet" type="text/css">
# <link href="https://images.ebizautos.media/Foundation/Sites/7725/AccountTemplate/css/custom.css" rel="stylesheet" type="text/css">
# <style type="text/css"></style>
# <!--[if lt IE 9]>
#   <script src="//css3-mediaqueries-js.googlecode.com/svn/trunk/css3-mediaqueries.js"></script>
# <![endif]-->
# <!-- HeaderContents_Foundation_jQuery_v1.12.0 -->
# <script src="https://images.ebizautos.media/Foundation/Templates/-2147483646/js/jquery.min.js"></script>
# <script src="https://images.ebizautos.media/Foundation/Templates/-2147483646/js/jquery.cookie.min.js"></script>
# <!-- HeaderContents_PriceAlert_JS -->
# <script defer="" src="https://images.ebizautos.media/Foundation/Templates/-2147483646/js/pas-common.min.js"></script>
# <script defer="" src="https://images.ebizautos.media/Foundation/Templates/-2147483646/js/pas-client.min.js"></script>
# <script language="javascript" type="text/javascript">
# 	var _leadJSParams = {
# 		14 : 'https://secure-leads.motorcar.com/leads/?siteguid=47db61e2-a054-4304-b8b6-94ec4beb4087&leadsource=ebizautos&leadtype=scheduleappointmentrequest&contactid=18623&pageid=23815&pagetypeid=2&campaignid=9&campaignsitetypeid=1&segmentdefaultcampaignid=9&initialrefer=&initialurl=&initialtarget=http%3A%2F%2Fwww.directautomecca.com%2Finventory.aspx%3F_new%3Dtrue%26_used%3Dtrue%26_page%3D3&sourcepage=http%3A%2F%2Fwww.directautomecca.com%2Finventory.aspx%3F_new%3Dtrue%26_used%3Dtrue%26_page%3D3&hastoincludetransferfee=false&campaigntypeid=10&sitebox=sitebox_general2',
# 29 : 'https://secure-leads.motorcar.com/leads/?siteguid=47db61e2-a054-4304-b8b6-94ec4beb4087&leadsource=ebizautos&leadtype=partsrequest&contactid=36594&pageid=23815&pagetypeid=2&campaignid=9&campaignsitetypeid=1&segmentdefaultcampaignid=9&initialrefer=&initialurl=&initialtarget=http%3A%2F%2Fwww.directautomecca.com%2Finventory.aspx%3F_new%3Dtrue%26_used%3Dtrue%26_page%3D3&sourcepage=http%3A%2F%2Fwww.directautomecca.com%2Finventory.aspx%3F_new%3Dtrue%26_used%3Dtrue%26_page%3D3&hastoincludetransferfee=false&campaigntypeid=10&sitebox=sitebox_general2',
# 13 : 'https://secure-leads.motorcar.com/leads/?siteguid=47db61e2-a054-4304-b8b6-94ec4beb4087&leadsource=ebizautos&leadtype=vehiclefinder&contactid=10284&pageid=23815&pagetypeid=2&campaignid=9&campaignsitetypeid=1&segmentdefaultcampaignid=9&initialrefer=&initialurl=&initialtarget=http%3A%2F%2Fwww.directautomecca.com%2Finventory.aspx%3F_new%3Dtrue%26_used%3Dtrue%26_page%3D3&sourcepage=http%3A%2F%2Fwww.directautomecca.com%2Finventory.aspx%3F_new%3Dtrue%26_used%3Dtrue%26_page%3D3&hastoincludetransferfee=false&campaigntypeid=10&sitebox=sitebox_general2',
# 40 : 'https://secure-leads.motorcar.com/leads/?siteguid=47db61e2-a054-4304-b8b6-94ec4beb4087&leadsource=ebizautos&leadtype=contactus&contactid=10284&pageid=23815&pagetypeid=2&campaignid=9&campaignsitetypeid=1&segmentdefaultcampaignid=9&initialrefer=&initialurl=&initialtarget=http%3A%2F%2Fwww.directautomecca.com%2Finventory.aspx%3F_new%3Dtrue%26_used%3Dtrue%26_page%3D3&sourcepage=http%3A%2F%2Fwww.directautomecca.com%2Finventory.aspx%3F_new%3Dtrue%26_used%3Dtrue%26_page%3D3&hastoincludetransferfee=false&campaigntypeid=10&sitebox=sitebox_general2',
# 1 : 'https://secure-leads.motorcar.com/leads/?siteguid=47db61e2-a054-4304-b8b6-94ec4beb4087&leadsource=ebizautos&leadtype=email&pageid=23815&pagetypeid=2&campaignid=9&campaignsitetypeid=1&segmentdefaultcampaignid=9&initialrefer=&initialurl=&initialtarget=http%3A%2F%2Fwww.directautomecca.com%2Finventory.aspx%3F_new%3Dtrue%26_used%3Dtrue%26_page%3D3&sourcepage=http%3A%2F%2Fwww.directautomecca.com%2Finventory.aspx%3F_new%3Dtrue%26_used%3Dtrue%26_page%3D3&hastoincludetransferfee=false&campaigntypeid=10&sitebox=sitebox_general2',
# 45 : 'https://secure-leads.motorcar.com/leads/?siteguid=47db61e2-a054-4304-b8b6-94ec4beb4087&leadsource=ebizautos&leadtype=textrequest&pageid=23815&pagetypeid=2&campaignid=9&campaignsitetypeid=1&segmentdefaultcampaignid=9&initialrefer=&initialurl=&initialtarget=http%3A%2F%2Fwww.directautomecca.com%2Finventory.aspx%3F_new%3Dtrue%26_used%3Dtrue%26_page%3D3&sourcepage=http%3A%2F%2Fwww.directautomecca.com%2Finventory.aspx%3F_new%3Dtrue%26_used%3Dtrue%26_page%3D3&hastoincludetransferfee=false&campaigntypeid=10&sitebox=sitebox_general2',
# 9 : 'https://secure-leads.motorcar.com/leads/?siteguid=47db61e2-a054-4304-b8b6-94ec4beb4087&leadsource=ebizautos&leadtype=tradeappraisal&contactid=10284&pageid=23815&pagetypeid=2&campaignid=9&campaignsitetypeid=1&segmentdefaultcampaignid=9&initialrefer=&initialurl=&initialtarget=http%3A%2F%2Fwww.directautomecca.com%2Finventory.aspx%3F_new%3Dtrue%26_used%3Dtrue%26_page%3D3&sourcepage=http%3A%2F%2Fwww.directautomecca.com%2Finventory.aspx%3F_new%3Dtrue%26_used%3Dtrue%26_page%3D3&hastoincludetransferfee=false&campaigntypeid=10&sitebox=sitebox_general2',
# 27 : 'https://secure-leads.motorcar.com/leads/?siteguid=47db61e2-a054-4304-b8b6-94ec4beb4087&leadsource=ebizautos&leadtype=requestatestdrive&contactid=10284&pageid=23815&pagetypeid=2&campaignid=9&campaignsitetypeid=1&segmentdefaultcampaignid=9&initialrefer=&initialurl=&initialtarget=http%3A%2F%2Fwww.directautomecca.com%2Finventory.aspx%3F_new%3Dtrue%26_used%3Dtrue%26_page%3D3&sourcepage=http%3A%2F%2Fwww.directautomecca.com%2Finventory.aspx%3F_new%3Dtrue%26_used%3Dtrue%26_page%3D3&hastoincludetransferfee=false&campaigntypeid=10&sitebox=sitebox_general2',
#
# 	};
# 	var _commonJSParams = {
# 		DealerName: 'DirectAutomecca.com',
# 		DealerState: 'Massachusetts',
# 		DealerStateCode: 'MA',
# 		DealerZip: '01702',
# 		LexusDealerId: '',
# 		DealerDomain: '//www.directautomecca.com/',
# 		DefaultProxyUrl: '//www.directautomecca.com/',
# 		HostWithoutTLD: 'directautomecca',
# 		SiteId: '7725',
# 		SiteGuid: '47db61e2-a054-4304-b8b6-94ec4beb4087',
# 		PageName: 'inventory',
# 		PageType: 2,
# 		Title: '',
# 		TrafficType: 'Typed/Bookmarked',
# 		Language: 'en',
# 		SecureSharedLocation: 'https://secure-leads.motorcar.com/',
# 		PASLocation: '//pas.motorcar.com/api/gallery/',
# 		ReferrerPage: '',
# 		SiteboxName: 'sitebox_general2'
# 	};
# 	var _trackingParams = {
# 		IsBmwTrackingOn: false,
# 		IsMiniTrackingOn: false,
# 		IsGoogleEventTrackingOn: true,
# 		IsConversionTrackingOn: true,
# 		IsToyotaTrackingOn: false,
# 		IsPorscheTrackingOn: false,
# 		IsVolkswagenTrackingOn: false,
# 		IsNTPageTrackingOn: false,
# 		GaTrackerNames: 'eBizReports',
# 		IsBmwFranchise: false,
# 		IsMiniFranchise: false,
# 		IsVolkswagenFranchise: false,
# 		VehicleId: '',
# 		VinNumberParam: '',
# 		InventoryYearParam: 'no value',
# 		InventoryTrimParam: 'no value',
# 		InventoryMakeParam: 'no value',
# 		InventoryModelParam: 'no value',
# 		InventoryTypeParam: 'all',
# 		InventoryTransmissionParam: '',
# 		InventoryIntColorTypeParam: '',
# 		InventoryIntColorParam: '',
# 		InventoryExtColorParam: '',
# 		InventoryEngineParam: '',
# 		InventoryPriceFromParam: '0',
# 		InventoryPriceToParam: '0',
# 		InventoryMultipleMakesParam: '',
# 		InventoryMultipleModelsParam: '',
# 		InventoryMultipleTrimsParam: '',
# 		InventoryMultipleExtColorsParam: '',
# 		InventoryMultipleBodyStylesParam: '',
# 		InventoryMultipleYearsParam: '',
# 		InventorySearchPhraseParam: '',
# 		InventorySearchStatusParam: '',
# 		LowestPriceValueParam: '0',
# 		MsrpParam: '0',
# 		LowestPrice: '',
# 		SpecialType: '',
# 		SpecialInventoryType: '',
# 		SearchInventoryResult: '151',
# 		SearchPhrases: '',
# 		SearchInventoryTypeResult: '',
# 		LeadTypeId: 0,
# 		IsFormSubmited: false,
# 		IsLeadForm: false,
# 		IsFormError: false,
# 		prop1: '',
# 		eVar8: '',
# 		channel: '',
# 		customToyotaPageName: '',
# 	};
# 	var _socialMediaBarParams = {
# 		YouTubeUserName: 'UC6mGIPgsYrrRQfeO-IO8qcg'
# 	};
# 	</script>
# <script language="javascript" type="text/javascript"></script>
# <script>
#     (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#     (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#     m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#     })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
# 	ga('create', 'UA-7364301-1', 'auto', {'allowLinker': true});
# 	ga('require', 'linker');
# 	ga('linker:autoLink', ['.ebizautos.com']);
#     ga('send', 'pageview');
# </script>
# <script language="javascript" type="text/javascript"></script>
# <script language="javascript" src="https://images.ebizautos.media/foundation/gallery/js/global.js?18" type="text/javascript"></script>
# <script language="javascript" src="https://images.ebizautos.media/foundation/gallery/js/gallery.js?20" type="text/javascript"></script> <!-- Facebook Pixel GTM -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src='https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);})(window,document,'script','dataLayer','GTM-NFTX3XB');</script>
# <!-- End Facebook Pixel GTM -->
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
# 	ga('create', 'UA-17415666-1', 'auto', {'name': 'dealercode2'});
# 	ga('create', 'UA-107121041-1', 'auto', {'name': 'eBizReports','allowLinker': true});
# 	ga('create', 'UA-67569135-1', 'auto', {'name': 'DealerUACode'});
# 	ga('create', 'UA-67569135-3', 'auto', {'name': 'DealerCode3'});
# 	ga('dealercode2.send', 'pageview');
# 	ga('eBizReports.send', 'pageview');
# 	ga('DealerUACode.send', 'pageview');
# 	ga('DealerCode3.send', 'pageview');
#
# </script>
# <script type="text/javascript">
# window.__lo_site_id = 110869;
#
# 	(function() {
# 		var wa = document.createElement('script'); wa.type = 'text/javascript'; wa.async = true;
# 		wa.src = 'https://d10lpsik1i8c69.cloudfront.net/w.js';
# 		var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(wa, s);
# 	  })();
# 	</script> <!-- Facebook Pixel Code -->
# <script>
# !function(f,b,e,v,n,t,s)
# {if(f.fbq)return;n=f.fbq=function(){n.callMethod?
# n.callMethod.apply(n,arguments):n.queue.push(arguments)};
# if(!f._fbq)f._fbq=n;n.push=n;n.loaded=!0;n.version='2.0';
# n.queue=[];t=b.createElement(e);t.async=!0;
# t.src=v;s=b.getElementsByTagName(e)[0];
# s.parentNode.insertBefore(t,s)}(window,document,'script',
# 'https://connect.facebook.net/en_US/fbevents.js');
# fbq('init', '386714442977799');
# fbq('track', 'PageView');
# </script>
# <noscript>
# <img height="1" src="https://www.facebook.com/tr?id=386714442977799&amp;ev=PageView
# &amp;noscript=1" width="1"/>
# </noscript>
# <!-- End Facebook Pixel Code -->
# <meta content="pPQDzhWyOSqj6DZWmk0XVsG9Setegcd2TZxLLoS10r0=" name="verify-v1"/>
# <meta content="5fc4b12c460584f40b019ae4191c4b46" name="p:domain_verify"><!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-NTTDKDF');</script>
# <!-- End Google Tag Manager -->
# </meta></link></link></link></link></link></link></meta></meta></head>
# <body class="stretched no-transition side-panel-left pageType-Inventory pageName-inventory">
# <!-- Body_Inventory_Filters -->
# <input id="siteDefaultUrl" type="hidden" value="//www.directautomecca.com/"/>
# <input id="filtersActionUrl" type="hidden" value="//www.directautomecca.com/inventory.aspx?_new=true&amp;_used=true"/>
# <input id="paginationActionUrl" type="hidden" value="http://www.directautomecca.com/inventory.aspx?_new=true&amp;_used=true"/>
# <!-- Body_CustomCodeBodyTop -->
# <!-- Facebook Pixel GTM (noscript) -->
# <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-NFTX3XB" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <!-- End Facebook Pixel GTM (noscript) --><!-- Clarivoy Tracking Code -->
# <script src="//tags-cdn.clarivoy.com/northendmotors/td/tva/loader.js" type="text/javascript"></script>
# <!-- End Clarivoy Tracking Code --> <!-- Google Tag Manager -->
# <noscript><iframe height="0" src="//www.googletagmanager.com/ns.html?id=GTM-P77RWX" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# '//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-P77RWX');</script>
# <!-- End Google Tag Manager --><!-- Google Tag Manager (noscript) -->
# <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-NTTDKDF" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <!-- End Google Tag Manager (noscript) -->
# <div class="clearfix" id="wrapper">
# <div role="banner">
# <!-- Skip to main content for ADA compliance -->
# <a class="skip-main button button-small" href="#content">Skip to main content</a>
# <!-- Skip to main content for ADA compliance -->
# <!-- Body_SidePanelNav -->
# <div class="body-overlay d-none"></div>
# <div class="d-none" id="side-panel">
# <div class="side-panel-trigger" id="side-panel-trigger-close"><a aria-label="Close" href="#"><i class="icon-line-cross"></i></a></div>
# <div class="side-panel-wrap">
# <div id="mobile-custom-area-1"></div>
# <nav aria-label="Mobile Menu" id="mobile-menu" role="navigation">
# <ul aria-label="Mobile Menu" role="menubar">
# <li id="mobile-navID-23858" role="menuitem">
# <a href="//www.directautomecca.com/">Home</a>
# </li>
# <li aria-haspopup="true" id="mobile-navID-23860" role="menuitem">
# <a href="//www.directautomecca.com/view-inventory.aspx">Pre Owned Car Inventory</a>
# <ul aria-label="Pre Owned Car Inventory" role="menu">
# <li id="mobile-navID-23860-sub" role="menuitem">
# <a href="//www.directautomecca.com/view-inventory.aspx">Pre Owned Car Inventory</a>
# </li>
# <li id="mobile-navID-23861" role="menuitem">
# <a href="http://www.directautomecca.com/view-inventory.aspx">Inventory</a>
# </li>
# <li id="mobile-navID-23862" role="menuitem">
# <a href="//www.directautomecca.com/found-a-car-you-love.aspx">Found A Car You Love ?</a>
# </li>
# <li id="mobile-navID-23865" role="menuitem">
# <a href="//www.directautomecca.com/pickup-truck-inventory.aspx">Pickup Truck Inventory</a>
# </li>
# <li id="mobile-navID-23866" role="menuitem">
# <a href="//www.directautomecca.com/suv-inventory.aspx">SUV Inventory</a>
# </li>
# <li id="mobile-navID-23867" role="menuitem">
# <a href="//www.directautomecca.com/sedan-inventory.aspx">Sedan Inventory</a>
# </li>
# <li id="mobile-navID-23868" role="menuitem">
# <a href="//www.directautomecca.com/value-your-trade.aspx">Value Your Trade</a>
# </li>
# </ul>
# </li>
# <li id="mobile-navID-23869" role="menuitem">
# <a href="//www.directautomecca.com/special-offers.aspx">Specials</a>
# </li>
# <li id="mobile-navID-23887" role="menuitem">
# <a href="//www.directautomecca.com/sell-your-vehicle.aspx">Sell Your Vehicle</a>
# </li>
# <li id="mobile-navID-23888" role="menuitem">
# <a href="//www.directautomecca.com/car-finder.aspx">Direct Locate</a>
# </li>
# <li aria-haspopup="true" id="mobile-navID-23891" role="menuitem">
# <a href="//www.directautomecca.com/financing.aspx">Get Approved Now</a>
# <ul aria-label="Get Approved Now" role="menu">
# <li id="mobile-navID-23891-sub" role="menuitem">
# <a href="//www.directautomecca.com/financing.aspx">Get Approved Now</a>
# </li>
# <li id="mobile-navID-23893" role="menuitem">
# <a href="https://www.directautomecca.com/value-your-trade.aspx">Value Your Trade</a>
# </li>
# </ul>
# </li>
# <li id="mobile-navID-23896" role="menuitem">
# <a href="//www.directautomecca.com/service.aspx">Service Department</a>
# </li>
# <li aria-haspopup="true" id="mobile-navID-23907" role="menuitem">
# <a href="//www.directautomecca.com/dealership-info.aspx">Dealership Info</a>
# <ul aria-label="Dealership Info" role="menu">
# <li id="mobile-navID-23907-sub" role="menuitem">
# <a href="//www.directautomecca.com/dealership-info.aspx">Dealership Info</a>
# </li>
# <li id="mobile-navID-23908" role="menuitem">
# <a href="//www.directautomecca.com/reviews.aspx">Reviews</a>
# </li>
# <li id="mobile-navID-23909" role="menuitem">
# <a href="//www.directautomecca.com/terms-of-sale.aspx">Terms of Sale</a>
# </li>
# </ul>
# </li>
# <li aria-haspopup="true" id="mobile-navID-23914" role="menuitem">
# <a href="//www.directautomecca.com/contact-us.aspx">Contact Us</a>
# <ul aria-label="Contact Us" role="menu">
# <li id="mobile-navID-23914-sub" role="menuitem">
# <a href="//www.directautomecca.com/contact-us.aspx">Contact Us</a>
# </li>
# <li id="mobile-navID-23916" role="menuitem">
# <a href="//www.directautomecca.com/new-career-1.aspx">New Career</a>
# </li>
# </ul>
# </li>
# </ul>
# </nav>
# <div id="mobil-custom-area-2"></div>
# <!-- Body_SidePanelSocial -->
# <div class="clearfix" id="mobile-social-media">
# <a aria-label="View our Facebook Page" class="social-icon si-colored si-facebook" href="https://www.facebook.com/DirectAutomecca" onclick="return confirm('Are you sure you want to leave this page?')" rel="noopener" target="_blank"><i class="icon-facebook"></i></a>
# <a aria-label="View Our Twitter Page" class="social-icon si-colored si-twitter" href="https://www.twitter.com/directautomecca" onclick="return confirm('Are you sure you want to leave this page?')" rel="noopener" target="_blank"><i class="icon-twitter"></i></a>
# <a aria-label="View Our Instagram Page" class="social-icon si-colored si-instagram" href="https://www.instagram.com/directautomecca" onclick="return confirm('Are you sure you want to leave this page?')" rel="noopener" target="_blank"><i class="icon-instagram2"></i></a>
# <a aria-label="View Our YouTube Page" class="social-icon si-colored si-youtube" href="https://www.youtube.com/channel/UC6mGIPgsYrrRQfeO-IO8qcg" onclick="return confirm('Are you sure you want to leave this page?')" rel="noopener" target="_blank"><i class="icon-youtube"></i></a>
# </div>
# <!-- Body_SidePanelSocialClose -->
# <div id="mobile-custom-area-3">
# </div>
# </div>
# </div>
# <!-- Body_SearchFlyout -->
# <div aria-labelledby="search-flyout-label" id="search-flyout" role="dialog" tabindex="-1">
# <div class="wrapper">
# <a aria-label="Close Search Flyout" class="search-flyout-close" href="#" id="search-flyout-close"><i class="icon-line-cross"></i></a>
# <div class="container clearfix">
# <div class="text-center">
# <h2 id="search-flyout-label">Search Inventory</h2>
# </div>
# <div class="search-wrapper">
# <form action="/inventory.aspx" autocomplete="on" class="ebiz-search-inventory-form" method="get">
# <div class="row">
# <div class="col-md-10">
# <div class="input">
# <input aria-label="Search Our Inventory" class="search-flyout-input" name="_search" placeholder="Search Inventory" type="text" value=""/>
# </div>
# </div>
# <div class="col-md-2">
# <button class="button btn-block m-0 ebiz-search-submit" id="submit-button" name="submit">GO</button>
# </div>
# </div>
# </form>
# </div>
# </div>
# </div>
# </div>
# <!-- Body_TopBar_V2_Start -->
# <div class="bgcolor-2 pt-2 pb-2 d-none d-md-block" id="top-bar-v2">
# <div class="container-fullwidth clearfix">
# <div class="row d-flex">
# <div class="col-md-12 d-block d-md-flex align-items-center justify-content-end w-100">
# <!-- Body_TopBar_V2_Content -->
# <div class="ml-4" id="tb-item-4"><div aria-label="Search Inventory Form" class="tb-search d-none d-md-block" role="group">
# <form action="/inventory.aspx" autocomplete="on" class="ebiz-search-inventory-form form-inline m-0 h-100" method="get">
# <div class="form-group input">
# <input aria-label="Search Inventory" id="_topbarv2search" name="_search" placeholder="Search Inventory" type="text" value=""/>
# </div>
# <button aria-label="Search" class="button button-small m-0 h-100" type="submit"><i class="icon-search3 m-0"></i></button>
# </form>
# </div></div>
# </div>
# </div>
# </div>
# </div>
# <div class="clear"></div>
# <!-- Body_TopBar_V2_End -->
# <!-- Body_HeaderStyle2_NoSearch -->
# <header class="sticky-style-2 mobile-center" id="header">
# <div class="container-fullwidth clearfix">
# <div class="side-panel-trigger d-block d-md-none" id="side-panel-trigger">
# <a aria-label="Menu" href="javascript:void(0);"><i class="icon-line-menu"></i></a>
# </div>
# <div id="logo">
# <a aria-label="Home" class="standard-logo" href="//www.directautomecca.com/"><img alt="Dealership Logo" src="https://images.ebizautos.media/Foundation/Sites/7725/AccountTemplate/images/logo.png?v2"/></a>
# <a class="retina-logo" href="//www.directautomecca.com/"><img alt="Dealership Logo" src="https://images.ebizautos.media/Foundation/Sites/7725/AccountTemplate/images/logo@2x.png?v2"/></a>
# <a class="retina-mobile-logo" href="//www.directautomecca.com/"><img alt="Dealership Logo" src="https://images.ebizautos.media/Foundation/Sites/7725/AccountTemplate/images/logo@2x-mobile.png?v2"/></a>
# </div>
# <ul class="header-extras">
# <li>
# <div class="he-text tright">
# </div>
# </li>
# <li>
# <div class="he-text tright">
# </div>
# </li>
# <li>
# <div class="he-text tright">
#
#                             154 Waverly Street<br/>
#                             Framingham, MA 01702 <a class="map-link" href="https://www.google.com/maps?q=154 Waverly Street+,Framingham,MA+01702&amp;spn=0.023888,0.039669&amp;t=h&amp;hl=en" target="_blank"><i class="icon-map-marker2"></i> Map</a><br/>
#
#
#
#
#                                 Sales:
#                                 <span>
#
#
#
#                                             508-812-7804
#
#
#
#                                 </span><br/>
# </div>
# </li>
# </ul>
# </div>
# <div id="header-wrap">
# <nav aria-label="Primary Menu" class="flexbox style-2 link-style-2" id="primary-menu">
# <div class="container-fullwidth clearfix">
# <ul aria-label="Primary Menu" role="menubar">
# <li id="navID-23858" role="none">
# <a href="//www.directautomecca.com/" role="menuitem"><div>Home</div></a>
# </li>
# <li aria-haspopup="true" id="navID-23860" role="none">
# <a href="//www.directautomecca.com/view-inventory.aspx" role="menuitem"><div>Pre Owned Car Inventory</div></a>
# <ul aria-label="Pre Owned Car Inventory" role="menu">
# <li id="navID-23861" role="none">
# <a href="http://www.directautomecca.com/view-inventory.aspx" role="menuitem"><div>Inventory</div></a>
# </li>
# <li id="navID-23862" role="none">
# <a href="//www.directautomecca.com/found-a-car-you-love.aspx" role="menuitem"><div>Found A Car You Love ?</div></a>
# </li>
# <li id="navID-23865" role="none">
# <a href="//www.directautomecca.com/pickup-truck-inventory.aspx" role="menuitem"><div>Pickup Truck Inventory</div></a>
# </li>
# <li id="navID-23866" role="none">
# <a href="//www.directautomecca.com/suv-inventory.aspx" role="menuitem"><div>SUV Inventory</div></a>
# </li>
# <li id="navID-23867" role="none">
# <a href="//www.directautomecca.com/sedan-inventory.aspx" role="menuitem"><div>Sedan Inventory</div></a>
# </li>
# <li id="navID-23868" role="none">
# <a href="//www.directautomecca.com/value-your-trade.aspx" role="menuitem"><div>Value Your Trade</div></a>
# </li>
# </ul>
# </li>
# <li id="navID-23869" role="none">
# <a href="//www.directautomecca.com/special-offers.aspx" role="menuitem"><div>Specials</div></a>
# </li>
# <li id="navID-23887" role="none">
# <a href="//www.directautomecca.com/sell-your-vehicle.aspx" role="menuitem"><div>Sell Your Vehicle</div></a>
# </li>
# <li id="navID-23888" role="none">
# <a href="//www.directautomecca.com/car-finder.aspx" role="menuitem"><div>Direct Locate</div></a>
# </li>
# <li aria-haspopup="true" id="navID-23891" role="none">
# <a href="//www.directautomecca.com/financing.aspx" role="menuitem"><div>Get Approved Now</div></a>
# <ul aria-label="Get Approved Now" role="menu">
# <li id="navID-23893" role="none">
# <a href="https://www.directautomecca.com/value-your-trade.aspx" role="menuitem"><div>Value Your Trade</div></a>
# </li>
# </ul>
# </li>
# <li id="navID-23896" role="none">
# <a href="//www.directautomecca.com/service.aspx" role="menuitem"><div>Service Department</div></a>
# </li>
# <li aria-haspopup="true" id="navID-23907" role="none">
# <a href="//www.directautomecca.com/dealership-info.aspx" role="menuitem"><div>Dealership Info</div></a>
# <ul aria-label="Dealership Info" role="menu">
# <li id="navID-23908" role="none">
# <a href="//www.directautomecca.com/reviews.aspx" role="menuitem"><div>Reviews</div></a>
# </li>
# <li id="navID-23909" role="none">
# <a href="//www.directautomecca.com/terms-of-sale.aspx" role="menuitem"><div>Terms of Sale</div></a>
# </li>
# </ul>
# </li>
# <li aria-haspopup="true" id="navID-23914" role="none">
# <a href="//www.directautomecca.com/contact-us.aspx" role="menuitem"><div>Contact Us</div></a>
# <ul aria-label="Contact Us" role="menu">
# <li id="navID-23916" role="none">
# <a href="//www.directautomecca.com/new-career-1.aspx" role="menuitem"><div>New Career</div></a>
# </li>
# </ul>
# </li>
# </ul>
# </div>
# </nav>
# </div>
# </header>
# <div class="clear"></div>
# <!-- Body_MobileHeaderStart -->
# <div class="clearfix d-block d-md-none" id="bottom-mobile-header">
# <!-- Body_MobileHeaderLinks_ClickUsed -->
# <ul>
# <li>
# <a class="ebiz-calltoday-button ebiz-clicktocall-button" href="tel:508-812-7804 ">
# <i class="icon-phone3"></i> Call Us</a>
# </li>
# <li><a class="top-mobile-map-trigger ebiz-view-google-map" href="https://www.google.com/maps?q=154 Waverly Street+,Framingham,MA+01702&amp;spn=0.023888,0.039669&amp;t=h&amp;hl=en" rel="noopener" target="_blank"><i class="icon-map-marker2"></i> Map</a></li>
# <li class="mobile-header-trigger"><div data-mobile-section="#mobile-header-section--search"><a href="javascript:void(0);"><i class="icon-search3"></i> Search</a></div></li>
# <!-- Body_MobileHeaderLinks_MobilePriceAlertLogin -->
# <li id="btn-mobile-login"><a href="javascript:void(0);"><i class="icon-user"></i> Login</a></li>
# </ul>
# <!-- Body_MobileHeaderLinksEnd -->
# </div>
# <!-- Body_MobileHeaderEnd -->
# <!-- Body_MobileHeaderSearch -->
# <div class="mobile-header-section" id="mobile-header-section--call-us">
# <div class="mobile-bar-row clearfix d-flex align-items-center">
# <div class="col-xs-5">
# <div class="tleft">
# 			Sales Dept.
# 		</div>
# </div>
# <div class="col-xs-7">
# <div class="tright">
# <a class="ebiz-calltoday-button ebiz-clicktocall-button button button-small" href="tel:508-812-7804"><i class="icon-phone3"></i> 508-812-7804</a>
# </div>
# </div>
# </div>
# </div>
# <div class="mobile-header-section" id="mobile-header-section--search">
# <form action="/inventory.aspx" autocomplete="on" class="ebiz-search-inventory-form m-0" method="get">
# <div class="wrapper clearfix">
# <div class="col-xs-10 col-sm-10">
# <div class="input m-0">
# <input aria-label="Search Inventory" class="form-control" name="_search" placeholder="Search Inventory" type="text"/>
# </div>
# </div>
# <div class="col-xs-2 col-sm-2 pl-0">
# <button class="button btn-block m-0 p-0" type="submit">Go</button>
# </div>
# </div>
# </form>
# </div>
# </div> <!-- role="banner" end -->
# <!-- Inventory_GEOPageTitle -->
# <section class="page-title-center" id="page-title">
# <div class="container clearfix">
# <h1>151 Used Vehicles For Sale <span>Serving Framingham, MA</span></h1>
# <ol aria-label="Breadcrumb Links" class="breadcrumb">
# <li id="breadcrumb-0"><a href="//www.directautomecca.com/" title="Home">Home</a></li>
# <li aria-hidden="true" class="active" id="breadcrumb-1">All  Cars</li>
# </ol>
# </div>
# </section>
# <!-- Inventory_TopSort -->
# <section id="content" role="main">
# <div class="container bg1 clearfix">
# <div class="py-4 border-bottom d-none d-sm-block">
# <div class="py-4 border-bottom d-none d-sm-block">
# <link href="https://fonts.googleapis.com/css?family=Open+Sans:400,700" rel="stylesheet"/><center><div data-key="6be38aaa-8b96-4438-9375-432258527f10" data-modal-z-index="2000" data-url="https://tradeinadvisor.kbb.com" id="kbb-leaddriver-search" style="width:100%;max-width: 1140px;margin: auto; color:#424242;"></div></center><script defer="" src="https://tradeinadvisor.kbb.com/scripts/predictive-search.min.js"></script>
# </div>
# <div class="row py-2">
# <div class="col-xs-12 col-sm-4 col-md-6">
# <div class="pagination-wrapper">
# <div class="pagination-control">
# <ul aria-label="List of Pages" class="list-unstyled list-inline m-0 p-0 text-center text-sm-left">
# <li aria-hidden="true" class="px-0">Page: </li>
# <li class="active px-2 font-weight-bold">1</li>
# <li class="px-2 underline"><a href="//www.directautomecca.com/inventory.aspx?_new=true&amp;_used=true&amp;_page=2" rel="nofollow">2</a></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="col-xs-12 col-sm-8 col-md-6 d-none d-sm-block">
# <div class="row">
# <div class="col-sm-6 col-md-5 col-lg-6 text-right">
# <label for="pageSize">Vehicles Per Page:</label>
# </div>
# <div class="col-sm-6 col-md-7 col-lg-6">
# <div class="input-wrapper">
# <div class="select small">
# <select aria-label="Vehicles Per Page" id="pageSize" name="pageSize" role="listbox">
# <option value="10">Show 10 Vehicles</option><option value="25">Show 25 Vehicles</option><option value="50">Show 50 Vehicles</option><option selected="selected" value="100">Show 100 Vehicles</option>
# </select>
# <i class="icon-angle-down"></i>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div id="srp-top-sort">
# <div class="row">
# <div class="col-xs-6 col-md-6 d-block d-md-none">
# <a class="button" data-target="#srp-modal-refine-search" data-toggle="modal" href="#" id="srp-refine-search-mobile"><i class="icon-filter"></i> Refine Search</a>
# </div>
# <div class="col-xs-6 col-md-6 d-block d-md-none">
# <button class="button fright" data-target="#srp-modal-sortby" data-toggle="modal"><i class="icon-sort"></i> Sort By</button>
# </div>
# <div class="col-md-6 d-none d-md-block">
# <div class="clearfix" id="srp-sortby">
# <ul class="sortby">
# <li class="title">Sort By:</li>
# <li>
# <a class="ebiz-sort-link" href="//www.directautomecca.com/inventory.aspx?_new=true&amp;_used=true&amp;_sort=yearasc" rel="nofollow">Year</a> |
#                             </li>
# <li>
# <a class="ebiz-sort-link" href="//www.directautomecca.com/inventory.aspx?_new=true&amp;_used=true&amp;_sort=makeasc" rel="nofollow">Make</a> |
#                             </li>
# <li>
# <a class="ebiz-sort-link" href="//www.directautomecca.com/inventory.aspx?_new=true&amp;_used=true&amp;_sort=modelasc" rel="nofollow">Model</a> |
#                             </li>
# <li>
# <a class="ebiz-sort-link" href="//www.directautomecca.com/inventory.aspx?_new=true&amp;_used=true&amp;_sort=mileageasc" rel="nofollow">Mileage</a> |
#                           </li>
# <li>
# <a class="ebiz-sort-link" href="//www.directautomecca.com/inventory.aspx?_new=true&amp;_used=true&amp;_sort=priceasc" rel="nofollow">Price</a> |
#                           </li>
# <li>
# <a class="ebiz-sort-link" href="//www.directautomecca.com/inventory.aspx?_new=true&amp;_used=true&amp;_sort=photoasc" rel="nofollow">Photos</a>
# </li>
# </ul>
# </div>
# </div>
# <div class="col-md-6 d-none d-md-block">
# <div class="clearfix" id="srp-vehicle-comparison">
# <div class="srp-vehicle-comparison-wrapper">
# <div class="row">
# <div class="col-md-5 col-md-offset-2 p-0 srp-vehicle-comparison-images d-flex align-items-stretch h-100">
# <div class="col-md-4 p-0">
# <div class="VehicleComparingImage h-100 SelectedVehicle1">
# <img alt="" class="VehiclePhoto responsive" src="">
# <i aria-label="Remove Vehicle" class="icon icon-line2-close remove-car" onclick="javascript:removeItemFromCompareBar(0);" role="button" style="display: none;" tabindex="0"></i>
# </img></div>
# </div>
# <div class="col-md-4 p-0">
# <div class="VehicleComparingImage h-100 SelectedVehicle2">
# <img alt="" class="VehiclePhoto responsive" src="">
# <i aria-label="Remove Vehicle" class="icon icon-line2-close remove-car" onclick="javascript:removeItemFromCompareBar(0);" role="button" style="display: none;" tabindex="0"></i>
# </img></div>
# </div>
# <div class="col-md-4 p-0">
# <div class="VehicleComparingImage h-100 SelectedVehicle3">
# <img alt="" class="VehiclePhoto responsive" src="">
# <i aria-label="Remove Vehicle" class="icon icon-line2-close remove-car" onclick="javascript:removeItemFromCompareBar(0);" role="button" style="display: none;" tabindex="0"></i>
# </img></div>
# </div>
# </div>
# <div class="col-md-5 center">
# <div class="srp-vehicle-comparison-button">
# <a class="button button-alt btn-block m-0 py-0 px-2 fright" href="#" id="srp-button-compare" onclick="showVehicleCompare()" rel="nofollow">Compare Vehicles <i class="icon-caret-right ml-1 mr-0"></i></a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="py-4 border-bottom d-block d-sm-none">
# <div class="row py-2">
# <div class="col-xs-4 d-sm-none">
# </div>
# <div class="col-xs-4 d-sm-none text-center">
# <div class="d-inline-block p-0">Page:<br/>1 of 2</div>
# </div>
# <div class="col-xs-4 d-sm-none text-right">
# <a class="button button-small" href="//www.directautomecca.com/inventory.aspx?_new=true&amp;_used=true&amp;_page=2" rel="nofollow" title="Next Page">Next <i class="icon-chevron-right ml-2 mr-0"></i></a>
# </div>
# </div>
# </div>
# <!-- Inventory_LeftSearchFilter_Sliders -->
# <div class="clearfix" id="srp">
# <div class="col-md-3 col-lg-3 d-none d-md-block p-0">
# <div class="pt-4 pb-3 srp-search-title">
# <h2 class="h4 body-font text-center">Your Current Search</h2>
# </div>
# <div class="srp-current-search-wrapper" id="srp-current-search">
# <div class="current-search-item clearfix">
# <div class="current-search-group clearfix">
# <div class="item-title">Condition</div>
# <div class="remove-group clearfix">
# <div class="item-detail fleft">New</div>
# <div class="item-clear fright"><a aria-label="Remove New" class="ebiz-filter-link" href="//www.directautomecca.com/used-cars/" rel="nofollow"><i class="icon-line-cross"></i></a></div>
# </div><div class="remove-group clearfix">
# <div class="item-detail fleft">Used</div>
# <div class="item-clear fright"><a aria-label="Remove Used" class="ebiz-filter-link" href="//www.directautomecca.com/new-cars/" rel="nofollow"><i class="icon-line-cross"></i></a></div>
# </div>
# </div>
# </div>
# </div>
# <div id="srp-search-filter">
# <div class="srp-search-filter-wrapper">
# <div class="pt-4 pb-3 srp-search-title">
# <h2 class="h4 body-font text-center">Refine Your Search</h2>
# </div>
# <div class="toggle" data-state="open" id="srp-make-toggle">
# <!-- All Other Sections-->
# <div class="togglet">Make<i class="toggle-closed icon-angle-down"></i><i class="toggle-open icon-angle-up"></i></div>
# <div class="togglec">
# <div class="filter-element clearfix">
# <a class="ebiz-filter-link" href="//www.directautomecca.com/inventory.aspx?_new=true&amp;_used=true&amp;_makef=audi" rel="nofollow">
#                                 	    Audi
#                                 	</a>
# <span class="label label-default">1</span>
# </div>
# <div class="filter-element clearfix">
# <a class="ebiz-filter-link" href="//www.directautomecca.com/inventory.aspx?_new=true&amp;_used=true&amp;_makef=bmw" rel="nofollow">
#                                 	    BMW
#                                 	</a>
# <span class="label label-default">2</span>
# </div>
# <div class="filter-element clearfix">
# <a class="ebiz-filter-link" href="//www.directautomecca.com/inventory.aspx?_new=true&amp;_used=true&amp;_makef=cadillac" rel="nofollow">
#                                 	    Cadillac
#                                 	</a>
# <span class="label label-default">2</span>
# </div>
# <div class="filter-element clearfix">
# <a class="ebiz-filter-link" href="//www.directautomecca.com/inventory.aspx?_new=true&amp;_used=true&amp;_makef=chevrolet" rel="nofollow">
#                                 	    Chevrolet
#                                 	</a>
# <span class="label label-default">37</span>
# </div>
# <div class="filter-element clearfix">
# <a class="ebiz-filter-link" href="//www.directautomecca.com/inventory.aspx?_new=true&amp;_used=true&amp;_makef=chrysler" rel="nofollow">
#                                 	    Chrysler
#                                 	</a>
# <span class="label label-default">2</span>
# </div>
# <div class="filter-element clearfix">
# <a class="ebiz-filter-link" href="//www.directautomecca.com/inventory.aspx?_new=true&amp;_used=true&amp;_makef=dodge" rel="nofollow">
#                                 	    Dodge
#                                 	</a>
# <span class="label label-default">2</span>
# </div>
# <div class="filter-element clearfix">
# <a class="ebiz-filter-link" href="//www.directautomecca.com/inventory.aspx?_new=true&amp;_used=true&amp;_makef=ford" rel="nofollow">
#                                 	    Ford
#                                 	</a>
# <span class="label label-default">26</span>
# </div>
# <div class="filter-element clearfix">
# <a class="ebiz-filter-link" href="//www.directautomecca.com/inventory.aspx?_new=true&amp;_used=true&amp;_makef=gmc" rel="nofollow">
#                                 	    GMC
#                                 	</a>
# <span class="label label-default">14</span>
# </div>
# <div class="filter-element clearfix">
# <a class="ebiz-filter-link" href="//www.directautomecca.com/inventory.aspx?_new=true&amp;_used=true&amp;_makef=honda" rel="nofollow">
#                                 	    Honda
#                                 	</a>
# <span class="label label-default">4</span>
# </div>
# <div class="filter-element clearfix">
# <a class="ebiz-filter-link" href="//www.directautomecca.com/inventory.aspx?_new=true&amp;_used=true&amp;_makef=hyundai" rel="nofollow">
#                                 	    Hyundai
#                                 	</a>
# <span class="label label-default">1</span>
# </div>
# <div class="filter-element clearfix">
# <a class="ebiz-filter-link" href="//www.directautomecca.com/inventory.aspx?_new=true&amp;_used=true&amp;_makef=jeep" rel="nofollow">
#                                 	    Jeep
#                                 	</a>
# <span class="label label-default">7</span>
# </div>
# <div class="filter-element clearfix">
# <a class="ebiz-filter-link" href="//www.directautomecca.com/inventory.aspx?_new=true&amp;_used=true&amp;_makef=kia" rel="nofollow">
#                                 	    Kia
#                                 	</a>
# <span class="label label-default">3</span>
# </div>
# <div class="filter-element clearfix">
# <a class="ebiz-filter-link" href="//www.directautomecca.com/inventory.aspx?_new=true&amp;_used=true&amp;_makef=land+rover" rel="nofollow">
#                                 	    Land Rover
#                                 	</a>
# <span class="label label-default">1</span>
# </div>
# <div class="filter-element clearfix">
# <a class="ebiz-filter-link" href="//www.directautomecca.com/inventory.aspx?_new=true&amp;_used=true&amp;_makef=mazda" rel="nofollow">
#                                 	    Mazda
#                                 	</a>
# <span class="label label-default">1</span>
# </div>
# <div class="filter-element clearfix">
# <a class="ebiz-filter-link" href="//www.directautomecca.com/inventory.aspx?_new=true&amp;_used=true&amp;_makef=mercedes-benz" rel="nofollow">
#                                 	    Mercedes-Benz
#                                 	</a>
# <span class="label label-default">3</span>
# </div>
# <div class="filter-element clearfix">
# <a class="ebiz-filter-link" href="//www.directautomecca.com/inventory.aspx?_new=true&amp;_used=true&amp;_makef=mitsubishi" rel="nofollow">
#                                 	    Mitsubishi
#                                 	</a>
# <span class="label label-default">3</span>
# </div>
# <div class="filter-element clearfix">
# <a class="ebiz-filter-link" href="//www.directautomecca.com/inventory.aspx?_new=true&amp;_used=true&amp;_makef=nissan" rel="nofollow">
#                                 	    Nissan
#                                 	</a>
# <span class="label label-default">9</span>
# </div>
# <div class="filter-element clearfix">
# <a class="ebiz-filter-link" href="//www.directautomecca.com/inventory.aspx?_new=true&amp;_used=true&amp;_makef=ram" rel="nofollow">
#                                 	    Ram
#                                 	</a>
# <span class="label label-default">16</span>
# </div>
# <div class="filter-element clearfix">
# <a class="ebiz-filter-link" href="//www.directautomecca.com/inventory.aspx?_new=true&amp;_used=true&amp;_makef=subaru" rel="nofollow">
#                                 	    Subaru
#                                 	</a>
# <span class="label label-default">1</span>
# </div>
# <div class="filter-element clearfix">
# <a class="ebiz-filter-link" href="//www.directautomecca.com/inventory.aspx?_new=true&amp;_used=true&amp;_makef=tesla" rel="nofollow">
#                                 	    Tesla
#                                 	</a>
# <span class="label label-default">3</span>
# </div>
# <div class="filter-element clearfix">
# <a class="ebiz-filter-link" href="//www.directautomecca.com/inventory.aspx?_new=true&amp;_used=true&amp;_makef=toyota" rel="nofollow">
#                                 	    Toyota
#                                 	</a>
# <span class="label label-default">11</span>
# </div>
# <div class="filter-element clearfix">
# <a class="ebiz-filter-link" href="//www.directautomecca.com/inventory.aspx?_new=true&amp;_used=true&amp;_makef=volkswagen" rel="nofollow">
#                                 	    Volkswagen
#                                 	</a>
# <span class="label label-default">2</span>
# </div>
# </div>
# </div>
# <div class="toggle" data-state="open" id="srp-bodystyle-toggle">
# <!-- All Other Sections-->
# <div class="togglet">Body Style<i class="toggle-closed icon-angle-down"></i><i class="toggle-open icon-angle-up"></i></div>
# <div class="togglec">
# <div class="filter-element clearfix">
# <a class="ebiz-filter-link" href="//www.directautomecca.com/inventory.aspx?_new=true&amp;_used=true&amp;_bodystyle=1" rel="nofollow">
#                                 	    Convertible
#                                 	</a>
# <span class="label label-default">1</span>
# </div>
# <div class="filter-element clearfix">
# <a class="ebiz-filter-link" href="//www.directautomecca.com/inventory.aspx?_new=true&amp;_used=true&amp;_bodystyle=2" rel="nofollow">
#                                 	    Coupe
#                                 	</a>
# <span class="label label-default">3</span>
# </div>
# <div class="filter-element clearfix">
# <a class="ebiz-filter-link" href="//www.directautomecca.com/inventory.aspx?_new=true&amp;_used=true&amp;_bodystyle=12" rel="nofollow">
#                                 	    SAC
#                                 	</a>
# <span class="label label-default">1</span>
# </div>
# <div class="filter-element clearfix">
# <a class="ebiz-filter-link" href="//www.directautomecca.com/inventory.aspx?_new=true&amp;_used=true&amp;_bodystyle=5" rel="nofollow">
#                                 	    SUV
#                                 	</a>
# <span class="label label-default">50</span>
# </div>
# <div class="filter-element clearfix">
# <a class="ebiz-filter-link" href="//www.directautomecca.com/inventory.aspx?_new=true&amp;_used=true&amp;_bodystyle=4" rel="nofollow">
#                                 	    Sedan
#                                 	</a>
# <span class="label label-default">18</span>
# </div>
# <div class="filter-element clearfix">
# <a class="ebiz-filter-link" href="//www.directautomecca.com/inventory.aspx?_new=true&amp;_used=true&amp;_bodystyle=6" rel="nofollow">
#                                 	    Truck
#                                 	</a>
# <span class="label label-default">57</span>
# </div>
# <div class="filter-element clearfix">
# ...
# </ul>
# </div>
# </div>
# </div>
# <div class="swiper-slide ebiz-viewed-vehicle-template" style="margin-right: 30px;">
# <div class="swiper-slide-content">
# <a class="ebiz-vehicle-details-link" href="#">
# <img alt="Vehicle Image Thumbnail" class="vehicleImage responsive ebiz-vehicle-photo" src=""/>
# </a>
# <div class="notifyMePriceAlert-vehicleInfo center">
# <h3 class="h4 mt-3">
# <a class="color ebiz-vehicle-details-link" href="#">
# <span class="ebiz-vehicle-year">Year</span>
# <span class="ebiz-vehicle-make">Make</span><br>
# <span class="ebiz-vehicle-model">Model</span>
# </br></a>
# </h3>
# </div>
# <div class="notifyMePriceAlert-vehiclePrice clearfix">
# <div class="row">
# <div class="col-xs-6 col-md-6 tleft">
# <h5 class="m-0"><span class="ebiz-vehicle-highprice-label">High Price</span></h5>
# </div>
# <div class="col-xs-6 col-md-6 tright">
# <h4 class="m-0">$<span class="ebiz-vehicle-highprice-value">0</span></h4>
# </div>
# </div>
# <div class="row">
# <div class="col-xs-6 col-md-6 tleft">
# <h5 class="m-0"><span class="ebiz-vehicle-lowprice-label">Low Price</span></h5>
# </div>
# <div class="col-xs-6 col-md-6 tright">
# <h4 class="m-0">$<span class="ebiz-vehicle-lowprice-value">0</span></h4>
# </div>
# </div>
# <div class="row">
# <div class="col-md-12 center">
# <a class="ebiz-vehicle-ebay-link" href="#">
# <img alt="eBay Motors Link" class="lazy" data-lazyload="true" data-src="https://images.ebizautos.media/gallery/ebaylogos/ebaymotors_logo_110_23.png" src="https://images.ebizautos.media/sp.gif"/>
# </a>
# </div>
# </div>
# <div class="row">
# <div class="col-md-12 center">
# <h4 class="m-0"><span class="ebiz-vehicle-call-forprice">Call For Price</span></h4>
# </div>
# </div>
# <div class="row">
# <div class="col-md-12 center">
# <h4 class="m-0"><span class="ebiz-vehicle-salepending">Sale Pending</span></h4>
# </div>
# </div>
# <div class="row">
# <div class="col-md-12 center">
# <h4 class="m-0"><span class="ebiz-vehicle-sold">Sold</span></h4>
# </div>
# </div>
# </div>
# <div class="notifyMePriceAlert-vehicleActions">
# <ul>
# <li><a class="ebiz-vehicle-share" href="javascript: void(0);"><i class="icon-facebook-sign"></i><span>Share</span></a></li>
# <li><a class="ebiz-vehicle-details-link" href="#"><i class="icon-line-eye"></i><span>Details</span></a></li>
# <li><a href="javascript: void(0);"><i class="icon-line2-heart ebiz-vehicle-save-star"></i><span class="ebiz-vehicle-save-label">Save</span></a></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="swiper-slide ebiz-alerted-vehicle-template" style="margin-right: 30px;">
# <div class="swiper-slide-content">
# <a class="ebiz-vehicle-details-link" href="#">
# <img alt="Vehicle Image Thumbnail" class="vehicleImage responsive ebiz-vehicle-photo" src=""/>
# </a>
# <div class="notifyMePriceAlert-vehicleInfo center">
# <h3 class="h4 mt-3">
# <a class="color ebiz-vehicle-details-link" href="#">
# <span class="ebiz-vehicle-year">Year</span>
# <span class="ebiz-vehicle-make">Make</span><br/>
# <span class="ebiz-vehicle-model">Model</span>
# </a>
# </h3>
# </div>
# <div class="notifyMePriceAlert-vehiclePrice clearfix">
# <div class="row">
# <div class="col-xs-12 col-md-12 center">
# <div class="new-price"><i class="icon-long-arrow-down"></i> <h6 class="body-font inline-block m-0">New Price</h6></div>
# </div>
# </div>
# <div class="row">
# <div class="col-xs-6 col-md-6 tleft">
# <h5 class="m-0"><span class="ebiz-vehicle-alerterprice-label">Price</span></h5>
# </div>
# <div class="col-xs-6 col-md-6 tright">
# <h4 class="m-0">$<span class="ebiz-vehicle-aleptedprice-value"></span></h4>
# </div>
# </div>
# </div>
# <div class="notifyMePriceAlert-vehicleActions">
# <ul>
# <li><a class="ebiz-vehicle-share" href="javascript: void(0);"><i class="icon-facebook-sign"></i><span>Share</span></a></li>
# <li><a class="ebiz-vehicle-details-link" href="#"><i class="icon-line-eye"></i><span>Details</span></a></li>
# <li><a class="ebiz-vehicle-delete" href="javascript: void(0);"><i class="icon-trash2"></i><span>Delete</span></a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# <div id="notifyMePriceAlert-container" style="display:none;">
# <div class="alert alert-success notifyMePriceAlert mb-2 mt-3 clearfix">
# <a aria-label="close" class="close" href="#"><i class="icon-line2-close"></i></a>
# <div class="content d-inline">
# <strong>Success!</strong><br/>
#                   The vehicle has been saved. <br/>
# <span class="ebiz-not-loggedin fleft mt-3">However, you are not logged in. <a class="notifyMePriceAlert-launch" data-value="0" href="#">Log in</a> or <a class="notifyMePriceAlert-launch" data-value="0" href="#">Sign up</a> to receive price alerts.</span>
# </div>
# </div>
# </div>
# </div>
# <!-- Footer_InventoryCarfaxSnapshotScript -->
# <!-- Inventory_LeftSearchSlider_JS -->
# <script>
#
# 	var minYear = 2014;
# 	var maxYear; if (2021 == 2014) { maxYear = 2021 + 0.1 } else { maxYear = 2021 };
# 	$('#_minyear').val(minYear);
# 	$('#_minyear-m').val(minYear);
# 	$('#_maxyear').val(maxYear);
# 	$('#_maxyear-m').val(maxYear);
#
#
# 	var minPrice = 10000;
# 	var maxPrice; if ( 10000 == 65000 ) { maxPrice = 65000 + 0.1 } else { maxPrice = 65000 };
# 	var minMiles = 2298;
# 	var maxMiles; if ( 2298 == 98995 ) { maxMiles = 98995 + 0.1 } else { maxMiles = 98995 };
# 	var minMpgCity = 0;
# 	var maxMpgCity; if ( 0 == 43 ) { maxMpgCity = 43 + 0.1 } else { maxMpgCity = 43 };
# 	var minMpgHwy = 0;
# 	var maxMpgHwy; if ( 0 == 41 ) { maxMpgHwy = 41 + 0.1 } else { maxMpgHwy = 41 };
# 	var minTruckSleeperSize = 2147483647;
# 	var maxTruckSleeperSize; if ( 2147483647 == 0 ) { maxTruckSleeperSize = 0 + 0.1 } else { maxTruckSleeperSize = 0 };
#
# 	$('#_minprice').val(minPrice);$('#_minprice-m').val(minPrice);$('#_maxprice').val(maxPrice);$('#_maxprice-m').val(maxPrice);$('#_minmiles').val(minMiles);$('#_minmiles-m').val(minMiles);$('#_maxmiles').val(maxMiles);$('#_maxmiles-m').val(maxMiles);$('#_minmpgcity').val(minMpgCity);$('#_minmpgcity-m').val(minMpgCity);$('#_maxmpgcity').val(maxMpgCity);$('#_maxmpgcity-m').val(maxMpgCity);$('#_minmpghwy').val(minMpgHwy);$('#_minmpghwy-m').val(minMpgHwy);$('#_maxmpghwy').val(maxMpgHwy);$('#_maxmpghwy-m').val(maxMpgHwy);$('#_mintrucksleepersize').val(minTruckSleeperSize);$('#_mintrucksleepersize-m').val(minTruckSleeperSize);$('#_maxtrucksleepersize').val(maxTruckSleeperSize);$('#_maxtrucksleepersize-m').val(maxTruckSleeperSize);
# 	function SubmitYearRangeFilters2(a){var b=$(a.currentTarget).parents("form")[0],c=$("#filtersActionUrl").val(),d="_yearfrom",e="_yearto",f="",g="";c.indexOf("?")!=-1?(g=c.substring(0,c.indexOf("?")+1),f=c.substring(c.indexOf("?")+1)):g=c,f.length>0?f+="&":f="?";var h=$("input[name="+d+"]",b).val(),i=$("input[name="+e+"]",b).val(),j=parseInt(h),k=parseFloat(i);if(f=g+f,isNaN(j)||isNaN(k))if(isNaN(j)){if(isNaN(k))return;f+=e+"="+k}else f+=d+"="+j;else j>k?(j=i,k=h):(j=h,k=i),f+=d+"="+j+"&"+e+"="+k;window.location.href=f};
# 	$(".submitYearRangeButton2").on("click",SubmitYearRangeFilters2)
# </script>
# <script src="https://images.ebizautos.media/Foundation/Controls/-2147482925/js/nouislider.js"></script>
# <script src="https://images.ebizautos.media/foundation/gallery/js/srpsliders.js"></script>
# <script>$(document).ready(function(){$('#slider-years').find('.noUi-handle-lower').attr('aria-label','Years Slider Lower Handle');$('#slider-years').find('.noUi-handle-upper').attr('aria-label','Years Slider Upper Handle');$('#slider-mileage').find('.noUi-handle-lower').attr('aria-label','Mileage Slider Lower Handle');$('#slider-mileage').find('.noUi-handle-upper').attr('aria-label','Mileage Slider Upper Handle');$('#slider-price').find('.noUi-handle-lower').attr('aria-label','Price Slider Lower Handle');$('#slider-price').find('.noUi-handle-upper').attr('aria-label','Price Slider Upper Handle');$('#slider-mpgcity').find('.noUi-handle-lower').attr('aria-label','MPG City Slider Lower Handle');$('#slider-mpgcity').find('.noUi-handle-upper').attr('aria-label','MPG City Slider Upper Handle');$('#slider-mpghwy').find('.noUi-handle-lower').attr('aria-label','MPG Highway Slider Lower Handle');$('#slider-mpghwy').find('.noUi-handle-upper').attr('aria-label','MPG Highway Slider Upper Handle');$('#slider-trucksleepersize').find('.noUi-handle-lower').attr('aria-label','Sleeper Size Slider Lower Handle');$('#slider-trucksleepersize').find('.noUi-handle-upper').attr('aria-label','Sleeper Size Slider Upper Handle')});</script>
# <!-- Footer_Foundation_JS_V2_jQuery_v1.12.0 -->
# <div class="icon-angle-up" id="gotoTop"></div>
# <!-- All Pages Plugins -->
# <script defer="" id="plugins-main" src="https://images.ebizautos.media/Foundation/Controls/-2147482815/js/plugins-main.js"></script>
# <!-- Functions All Pages -->
# <script defer="" id="functions-main" src="https://images.ebizautos.media/Foundation/Controls/-2147482815/js/functions-main.js"></script>
# <!-- Custom Codes Footer Start -->
# <!-- Facebook Pixel Code -->
# <script>
# !function(f,b,e,v,n,t,s){if(f.fbq)return;n=f.fbq=function(){n.callMethod?
# n.callMethod.apply(n,arguments):n.queue.push(arguments)};if(!f._fbq)f._fbq=n;
# n.push=n;n.loaded=!0;n.version='2.0';n.queue=[];t=b.createElement(e);t.async=!0;
# t.src=v;s=b.getElementsByTagName(e)[0];s.parentNode.insertBefore(t,s)}(window,
# document,'script','https://connect.facebook.net/en_US/fbevents.js');
#  fbq('init', '1159625614065569');
#  fbq('track', 'PageView');
#  fbq('track', 'ViewContent');
#  fbq('track', 'AddToCart');
#  fbq('track', 'Purchase');
# </script>
# <noscript>
# <img height="1" src="https://www.facebook.com/tr?id=1159625614065569&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/>
# </noscript>
# <!-- End Facebook Pixel Code -->
# <script>
#     // By placing this code on your website, you authorize CarGurus to access
#     // and use website visitor data to optimize digital advertising performance.
#     var CarGurus = window.CarGurus || {}; window.CarGurus = CarGurus;
#     CarGurus.Partner = window.CarGurus.Partner || {};
#     CarGurus.Partner.Metrics = window.CarGurus.Partner.Metrics || {};
#     CarGurus.Partner.Metrics.Options = window.CarGurus.Partner.Metrics.Options || {};
#     CarGurus.Partner.Metrics.Options.AccessKey = "00000000-0000-0afc-0000-000000044a92";
#     CarGurus.Partner.Metrics.Options.debug = false;
#     (function() {
#       var script = document.createElement('script');
#       script.src = "https://static.cargurus.com/js/api/en_US/2.0/partnermetrics.js";
#       script.async = true;
#       var entry = document.getElementsByTagName('script')[0];
#       entry.parentNode.insertBefore(script, entry);
#     })();
#   </script>
# <noscript>
# <div style="display:inline;">
# <img alt="" height="1" src="https://www.cargurus.com/Cars/api/2.0/recordMetricsImage.action?k=00000000-0000-0afc-0000-000000044a92&amp;x=%7B%22ns%22%3A1%7D" style="border-style:none;" width="1"/>
# </div>
# </noscript>
# <script src="//labels-prod.s3.amazonaws.com/vin_select/38055.js"></script> <script type="text/javascript">
# 	var ci = document.createElement("script");
# 	ci.type = "text/javascript";
# 	ci.src = "//tracking.callmeasurement.com/tracking.js";
# 	ci.async = true;
# 	var first = document.getElementsByTagName("script")[0];
# 	first.parentNode.insertBefore(ci, first);
# </script>
# <script type="text/javascript">
# /* <![CDATA[ */
# var google_conversion_id = 945651261;
# var google_custom_params = window.google_tag_params;
# var google_remarketing_only = true;
# /* ]]> */
# </script>
# <script src="//www.googleadservices.com/pagead/conversion.js" type="text/javascript">
# </script>
# <noscript>
# <div style="display:inline;">
# <img alt="" height="1" src="//googleads.g.doubleclick.net/pagead/viewthroughconversion/945651261/?guid=ON&amp;script=0" style="border-style:none;" width="1">
# </img></div>
# </noscript>
# <script async="" src="https://content-container.edmunds.com/890619.js" type="text/javascript"></script> <!-- Google Code for Remarketing tag -->
# <!-- Remarketing tags may not be associated with personally identifiable information or placed on pages related to sensitive categories. For instructions on adding this tag and more information on the above requirements, read the setup guide: google.com/ads/remarketingsetup -->
# <script type="text/javascript">
# /* <![CDATA[ */
# var google_conversion_id = 995687175;
# var google_conversion_label = "FikICPGp9wQQh_bj2gM";
# var google_custom_params = window.google_tag_params;
# var google_remarketing_only = true;
# /* ]]> */
# </script>
# <script src="//www.googleadservices.com/pagead/conversion.js" type="text/javascript">
# </script>
# <noscript>
# <div style="display:inline;">
# <img alt="" height="1" src="//googleads.g.doubleclick.net/pagead/viewthroughconversion/995687175/?value=0&amp;label=FikICPGp9wQQh_bj2gM&amp;guid=ON&amp;script=0" style="border-style:none;" width="1"/>
# </div>
# </noscript>
# <style>.simpwebchat_srp_item .simp-srp-item-button{padding-left:0!important;padding-right:0!important;z-index:998}</style>
# <script src="https://direct-automecca.dealer.simpsocial.com/srp-chat.js"></script>
# <script language="javascript" src="https://cdn.flickfusion.net/s/c/21927464-674F-486B-D550-EA39EE7B9136/ws.js"></script>
# <!-- Custom Codes Footer End -->
# <!-- Footer_FitVids_JS -->
# <!-- Moved to Main Plugins and Functions -->
# <!-- Swiper_AllOther_JS -->
# <script id="plugins-swiper" src="https://images.ebizautos.media/Foundation/Controls/-2147482818/js/swiper-bundle.js"></script>
# <!-- Footer_PriceAlert_JS_V2 -->
# <script defer="" id="plugins-validate" src="https://images.ebizautos.media/Foundation/Controls/-2147482816/js/jquery.validate.js"></script>
# <script defer="" id="functions-pas-dashboard" src="https://images.ebizautos.media/Foundation/Controls/-2147482816/js/functions-pas-dashboard.js"></script>
# <!-- Footer_SRPInfo_Schema_org -->
# <script type="application/ld+json">
#     []
# </script>
# <script type="application/ld+json">
#     {
#         "@context": "http://schema.org",
#         "@type": "ItemList",
#         "url": "http://www.directautomecca.com/inventory.aspx?_new=true&amp;_used=true&amp;_page=3",
#         "itemListElement": [
#
#         ]
#     }
# </script>
# <!-- Footer_Breadcrumb_Schema_org -->
# <script type="application/ld+json">
# {
#   "@context": "http://schema.org",
#   "@type": "BreadcrumbList",
#   "itemListElement": [
#     {
#     "@type": "ListItem",
#     "position": 1,
#     "item": {
#       "@id": "//www.directautomecca.com/",
#       "name": "Home"
#     }
#   },
#
#     {
#     "@type": "ListItem",
#     "position": 2,
#     "item": {
#       "@id": "https://www.directautomecca.com/inventory.aspx?_new=true&amp;_used=true&amp;_page=3",
#       "name": "All  Cars"
#     }
#   }
#   ]
# }
# </script>
# <!-- HTML_End -->
# <script type="application/ld+json">
# 	{
# 	  "@context": "http://www.schema.org",
# 	  "@type": "AutoDealer",
# 	  "name": "DirectAutomecca.com",
# 	  "url": "http://www.directautomecca.com/",
# 	  "logo": "https://images.ebizautos.media/Foundation/Sites/7725/AccountTemplate/images/logo.png?v2",
# 	  "image": "https://images.ebizautos.media/Foundation/Sites/7725/AccountTemplate/images/dealer-image.jpg",
# 	  "telephone": "+1 508-812-7804",
# 	  "address": {
# 		"@type": "PostalAddress",
# 		"streetAddress": "154 Waverly Street ",
# 		"addressLocality": "Framingham",
# 		"addressRegion": "MA",
# 		"postalCode": "01702",
# 		"addressCountry": "USA"
# 	  },
# 	  "priceRange": "$$",
# 	  "geo": {
# 		"@type": "GeoCoordinates",
# 		"latitude": "42.2785425",
# 		"longitude": "-71.4062965"
# 	  },
# 	  "contactPoint": {
# 		"@type": "ContactPoint",
# 		"telephone": "+1 508-812-7804",
# 		"contactType": "sales"
# 	  },
# 	  "sameAs": [
#         "https://www.facebook.com/DirectAutomecca",
#         "https://www.twitter.com/directautomecca",
#         "https://www.youtube.com/channel/UC6mGIPgsYrrRQfeO-IO8qcg",
#         "https://www.instagram.com/directautomecca",
#         "",
#         ""
#       ]
# 	}
# </script>
# <script>
# $(document).ready(function() {
#     setTimeout(function() {
#         if (window.SpinCarLeadReportUrl) {
#             $('.ebiz-leadform-button').each(function() {
#                 $(this).attr("data-source", $(this).attr("data-source") + "&spurl=" + window.SpinCarLeadReportUrl);
#             });
#             $('.spin-frame').attr("title","Vehicle Spins and Images")
#         } else {
#             console.log("SpinCar not installed.")
#         }
#     }, 1900);
# });
# </script>
# </body>
# </html>

# %%
def parseColumn(soup, html_tag, html_class):
    dataColumn = soup.find_all(html_tag, class_=html_class)
    new_col_list = []
    
    for i in range(0, len(dataColumn)):
        new_col_list.append(dataColumn[i].get_text())
        
    return new_col_list

title = parseColumn(soup_test, 'h2', 'ebiz-vdp-title color m-0')
title
# Out:
# []

# %%
dealerships = {
    'Bostonyan Auto Group': {
        'url': 'https://www.bostonyanautogroup.com/view-inventory',
        'pagination_url': '',
        'dealership_name': 'Bostonyan Auto Group',
        'address': '119 Worcester St',
        'zipcode': '01760',
        'city': 'Natick',
        'state': 'MA'
    },
    'Direct Auto Mecca': {
        'url': 'https://www.directautomecca.com/view-inventory.aspx',
        'pagination_url': 'https://www.directautomecca.com/inventory.aspx?_new=true&_used=true&_page=2',
        'dealership_name': 'Direct Auto Mecca',
        'address': '154 Waverly Street',
        'zipcode': '01760',
        'city': 'Natick',
        'state': 'MA'
    }
}

# %%
pagination_url = dealerships['Direct Auto Mecca']['pagination_url']
page_counter = 2

blah = []

while (True):
    response = requests.get(pagination_url, headers = headers)
    soup = BeautifulSoup(response.text, "html.parser")   
    title = parseColumn(soup, 'h2', 'ebiz-vdp-title color m-0')
    
    if len(title) == 0:
        break;
    else:
        blah.append(get_direct_auto_inventory_data(soup, dealerships[key]))
    
    page_counter += 1
    pagination_url = pagination_url.replace('page=2', f'page={page_counter}')
# Out:
# [nan, 41997, 42397, 42997, 42997, 42997, 43997, 43997, 43997, 44497, 44697, 45000, 45000, 45000, 45000, 45000, 45000, 45597, 45997, 47597, 47697, 47997, 47997, 48697, 48997, 48997, 49497, 49497, 49497, nan, 50000, 50000, 50997, 50997, 51997, 52997, 52997, 52997, 52997, 53997, 55497, nan, 56997, 57997, 57997, 59497, 59497, 59497, 60000, 60997, 65000, 65000]

# %%
blah
# Out:
# [                              title  year           make            models  \
#  0       2019 Chevrolet Express 2500  2019      Chevrolet      Express 2500
#  1                   2020 Ford F-150  2020           Ford             F-150
#  2                2019 Tesla Model 3  2019           None
#  3              2020 GMC Savana 2500  2020            GMC       Savana 2500
#  4                    2015 GMC Yukon  2015            GMC             Yukon
#  5                     2019 Ram 1500  2019            Ram              1500
#  6     2019 Chevrolet Silverado 1500  2019      Chevrolet    Silverado 1500
#  7                2018 Toyota Tundra  2018         Toyota            Tundra
#  8       2019 Chevrolet Express 3500  2019      Chevrolet      Express 3500
#  9     2019 Chevrolet Silverado 1500  2019      Chevrolet    Silverado 1500
#  10             2019 GMC Sierra 1500  2019            GMC       Sierra 1500
#  11               2020 Ford Explorer  2020           Ford          Explorer
#  12               2020 Ford Explorer  2020           Ford          Explorer
#  13                    2019 Ram 1500  2019            Ram              1500
#  14      2020 Chevrolet Express 2500  2020      Chevrolet      Express 2500
#  15      2020 Chevrolet Express 2500  2020      Chevrolet      Express 2500
#  16            2019 Ford Transit-250  2019           Ford       Transit-250
#  17             2020 GMC Sierra 1500  2020            GMC       Sierra 1500
#  18            2020 Ford Transit-250  2020           Ford       Transit-250
#  19           2017 Mercedes-Benz GLC  2017  Mercedes-Benz               GLC
#  20               2019 Dodge Durango  2019          Dodge           Durango
#  21    2020 Chevrolet Silverado 1500  2020      Chevrolet    Silverado 1500
#  22          2019 Ram ProMaster 2500  2019            Ram    ProMaster 2500
#  23            2020 Ford Transit-250  2020           Ford       Transit-250
#  24               2019 Toyota Tundra  2019         Toyota            Tundra
#  25                  2018 Ford F-150  2018           Ford             F-150
#  26    2020 Chevrolet Silverado 1500  2020      Chevrolet    Silverado 1500
#  27    2020 Chevrolet Silverado 1500  2020      Chevrolet    Silverado 1500
#  28                    2020 Ram 1500  2020            Ram              1500
#  29      2020 Chevrolet Express 2500  2020      Chevrolet      Express 2500
#  30                  2021 Ford F-150  2021           Ford             F-150
#  31           2017 GMC Sierra 3500HD  2017            GMC     Sierra 3500HD
#  32                    2021 Ram 2500  2021            Ram              2500
#  33                2019 Ford F-250SD  2019           Ford           F-250SD
#  34                  2019 Ford F-150  2019           Ford             F-150
#  35               2019 Tesla Model 3  2019           None
#  36               2019 Tesla Model 3  2019           None
#  37               2020 Ford Explorer  2020           Ford          Explorer
#  38           2021 Toyota Highlander  2021         Toyota        Highlander
#  39  2017 Chevrolet Silverado 2500HD  2017      Chevrolet  Silverado 2500HD
#  40    2021 Chevrolet Silverado 1500  2021      Chevrolet    Silverado 1500
#  41           2017 GMC Sierra 3500HD  2017            GMC     Sierra 3500HD
#  42                  2019 Ford F-150  2019           Ford             F-150
#  43  2019 Chevrolet Silverado 2500HD  2019      Chevrolet  Silverado 2500HD
#  44                      2019 BMW X6  2019            BMW                X6
#  45          2019 Chevrolet Corvette  2019      Chevrolet          Corvette
#  46           2020 GMC Sierra 2500HD  2020            GMC     Sierra 2500HD
#  47                    2019 Ram 1500  2019            Ram              1500
#  48  2020 Chevrolet Silverado 2500HD  2020      Chevrolet  Silverado 2500HD
#  49  2021 Chevrolet Silverado 2500HD  2021      Chevrolet  Silverado 2500HD
#  50             2020 GMC Sierra 1500  2020            GMC       Sierra 1500
#  51    2021 Chevrolet Silverado 1500  2021      Chevrolet    Silverado 1500
#
#     vehicle_type  vehicle_mileage    price                      exterior_color  \
#  0          None            53070      NaN                        Summit White
#  1          None            18159  41997.0                               Black
#  2          None            43193  42397.0                               White
#  3          None            33590  42997.0                        Summit White
#  4          None            82925  42997.0                Quicksilver Metallic
#  5          None            90755  42997.0              Bright White Clearcoat
#  6          None            34526  43997.0                                Teal
#  7          None            18390  43997.0                               Black
#  8          None            46956  43997.0                        Summit White
#  9          None            30662  44497.0                               White
#  10         None            17058  44697.0                                Teal
#  11         None            16870  45000.0                               Black
#  12         None             6225  45000.0                            Magnetic
#  13         None            43749  45000.0              Bright White Clearcoat
#  14         None            26499  45000.0                        Summit White
#  15         None            23587  45000.0                        Summit White
#  16         None            14258  45000.0                               White
#  17         None            10854  45597.0                                Blue
#  18         None            54000  45997.0                               White
#  19         None            19780  47597.0                               White
#  20         None            38067  47697.0             White Knuckle Clearcoat
#  21         None            25681  47997.0                               Black
#  22         None            49640  47997.0              Bright White Clearcoat
#  23         None            55773  48697.0                               White
#  24         None            26114  48997.0                               White
#  25         None            42415  48997.0                               White
#  26         None            13145  49497.0                               Black
#  27         None            11338  49497.0                                 Red
#  28         None             8210  49497.0     Diamond Black Crystal Pearlcoat
#  29         None            26835      NaN                        Summit White
#  30         None             8277  50000.0                               White
#  31         None            36986  50000.0                        Summit White
#  32         None            12715  50997.0                               Black
#  33         None            78876  50997.0                               White
#  34         None            32152  51997.0                        Ingot Silver
#  35         None            24347  52997.0                               White
#  36         None            29715  52997.0                               Black
#  37         None            14480  52997.0                               White
#  38         None             7559  52997.0                               White
#  39         None            89755  53997.0                 Pepperdust Metallic
#  40         None            15209  55497.0                               White
#  41         None            37148      NaN                        Cardinal Red
#  42         None            11886  56997.0                               White
#  43         None            23342  57997.0               Mosaic Black Metallic
#  44         None            26326  57997.0                       Dark Graphite
#  45         None             2298  59497.0                               Black
#  46         None            36744  59497.0                               White
#  47         None            30222  59497.0  Granite Crystal Metallic Clearcoat
#  48         None            16111  60000.0                               Black
#  49         None            11178  60997.0                               White
#  50         None            20840  65000.0                               White
#  51         None             4098  65000.0                               Black
#
#                                interior_color      transmission  \
#  0                                       Gray   8 Spd Automatic
#  1                          Medium Earth Gray  10 Spd Automatic
#  2                                      White   1 Spd Automatic
#  3                                       Gray   6 Spd Automatic
#  4                                  Jet Black   6 Spd Automatic
#  5                                      Black   8 Spd Automatic
#  6                                      Black   6 Spd Automatic
#  7                                       Gray   6 Spd Automatic
#  8                                       Gray   6 Spd Automatic
#  9                                      Black   6 Spd Automatic
#  10                                     Black   6 Spd Automatic
#  11                                     Black  10 Spd Automatic
#  12                                     Black  10 Spd Automatic
#  13                                     Black   8 Spd Automatic
#  14              Jet Black/Medium Dark Pewter   6 Spd Automatic
#  15                             Medium Pewter   6 Spd Automatic
#  16                                      Gray   6 Spd Automatic
#  17                                     Black   6 Spd Automatic
#  18                                      Gray  10 Spd Automatic
#  19                                     Beige   9 Spd Automatic
#  20                                       Red   8 Spd Automatic
#  21                                     Black   6 Spd Automatic
#  22                                     Black   6 Spd Automatic
#  23                                     Black  10 Spd Automatic
#  24                                     Black   6 Spd Automatic
#  25                                     Black  10 Spd Automatic
#  26                                     Black   6 Spd Automatic
#  27                                     Black   6 Spd Automatic
#  28                                     Black   8 Spd Automatic
#  29                                      Gray   6 Spd Automatic
#  30                                      Gray  10 Spd Automatic
#  31                        Dark Ash/Jet Black   6 Spd Automatic
#  32                                      Gray   8 Spd Automatic
#  33                                      Gray   6 Spd Automatic
#  34                                     Black  10 Spd Automatic
#  35                                     Black   1 Spd Automatic
#  36                                     Black   1 Spd Automatic
#  37                                     Beige  10 Spd Automatic
#  38                                       Red   8 Spd Automatic
#  39                                Cocoa/Dune  10 Spd Automatic
#  40                                     Black   8 Spd Automatic
#  41  Dark Ash With Jet Black Interior Accents  10 Spd Automatic
#  42                                     Black  10 Spd Automatic
#  43                 Jet Black/Medium Ash Gray  10 Spd Automatic
#  44                                     Black   8 Spd Automatic
#  45                                 Jet Black   8 Spd Automatic
#  46                                     Black   6 Spd Automatic
#  47                                     Black   8 Spd Automatic
#  48                                 Jet Black   6 Spd Automatic
#  49                                     Black   6 Spd Automatic
#  50                                     Black  10 Spd Automatic
#  51                                     Black  10 Spd Automatic
#
#                        engine                vin    dealership_name  \
#  0           4.3L V6 Cylinder  1GCWGBFP6K1163996  Direct Auto Mecca
#  1           2.7L V6 Cylinder  1FTEW1EP7LFB20721  Direct Auto Mecca
#  2         0.0 Electric Motor  5YJ3E1EA5KF486458  Direct Auto Mecca
#  3            6.0L 8 CYLINDER  1GTW7AFG2L1182542  Direct Auto Mecca
#  4            6.2L 8 Cylinder  1GKS2CKJ2FR299400  Direct Auto Mecca
#  5            5.7L 8 Cylinder  1C6SRFLT1KN849042  Direct Auto Mecca
#  6            5.3L 8 Cylinder  1GCRYCEF9KZ244145  Direct Auto Mecca
#  7            5.7L 8 Cylinder  5TFUY5F11JX716678  Direct Auto Mecca
#  8            6.0L 8 Cylinder  1GAZGPFGXK1255812  Direct Auto Mecca
#  9            5.3L 8 Cylinder  1GCPYCEF5KZ283399  Direct Auto Mecca
#  10           5.3L 8 Cylinder  1GTU9AEF9KZ269798  Direct Auto Mecca
#  11           2.3L 4 Cylinder  1FMSK8DH8LGA42814  Direct Auto Mecca
#  12           2.3L 4 CYLINDER  1FMSK8DH2LGB50099  Direct Auto Mecca
#  13           5.7L 8 Cylinder  1C6SRFFTXKN726187  Direct Auto Mecca
#  14           6.0L 8 Cylinder  1GCWGAFG1L1166302  Direct Auto Mecca
#  15           6.0L 8 Cylinder  1GCWGAFG1L1229463  Direct Auto Mecca
#  16          3.7L V6 Cylinder  1FTYR1ZM5KKB34787  Direct Auto Mecca
#  17           5.3L 8 Cylinder  1GTU9AEF6LZ379516  Direct Auto Mecca
#  18          3.5L V6 Cylinder  1FTBR1C85LKA07525  Direct Auto Mecca
#  19           2.0L 4 Cylinder  WDC0J4KB1HF155551  Direct Auto Mecca
#  20           5.7L 8 Cylinder  1C4SDJCT3KC664528  Direct Auto Mecca
#  21           5.3L 8 Cylinder  1GCPYCEF8LZ267666  Direct Auto Mecca
#  22          3.6L V6 Cylinder  3C6TRVDG3KE531752  Direct Auto Mecca
#  23          3.5L V6 Cylinder  1FTBR1X85LKA14629  Direct Auto Mecca
#  24           5.7L 8 Cylinder  5TFDY5F18KX835300  Direct Auto Mecca
#  25           5.0L 8 Cylinder  1FTEW1E5XJFC18279  Direct Auto Mecca
#  26           5.3L 8 CYLINDER  1GCPYCEF1LZ165576  Direct Auto Mecca
#  27           5.3L 8 Cylinder  1GCPYCEF2LZ262947  Direct Auto Mecca
#  28           5.7L 8 Cylinder  1C6SRFET7LN119764  Direct Auto Mecca
#  29           6.0L 8 Cylinder  1GCWGBFG8L1156307  Direct Auto Mecca
#  30           5.0L 8 Cylinder  1FTFW1E54MFA18961  Direct Auto Mecca
#  31           6.0L 8 Cylinder  1GD32VCG0HZ247373  Direct Auto Mecca
#  32           6.4L 8 Cylinder  3C6UR5CJ5MG539537  Direct Auto Mecca
#  33           6.7L 8 Cylinder  1FT7W2BT2KEE57141  Direct Auto Mecca
#  34          3.5L V6 Cylinder  1FTEW1E47KFC94180  Direct Auto Mecca
#  35        0.0 Electric Motor  5YJ3E1EB0KF388267  Direct Auto Mecca
#  36        0.0 Electric Motor  5YJ3E1EB6KF432336  Direct Auto Mecca
#  37          3.0L V6 Cylinder  1FM5K8HC1LGB88094  Direct Auto Mecca
#  38          3.5L V6 Cylinder  5TDLZRBH3MS118735  Direct Auto Mecca
#  39           6.6L 8 Cylinder  1GC1KWEY0HF151784  Direct Auto Mecca
#  40           5.3L 8 Cylinder  1GCUYEEDXMZ108307  Direct Auto Mecca
#  41           6.6L 8 Cylinder  1GD32VCY3HF173182  Direct Auto Mecca
#  42          3.5L V6 Cylinder  1FTEW1E40KFD02524  Direct Auto Mecca
#  43           6.6L 8 Cylinder  1GC1KREY7KF249770  Direct Auto Mecca
#  44  3.0L Straight 6 Cylinder  5UXKU2C53K0Z64481  Direct Auto Mecca
#  45           6.2L 8 CYLINDER  1G1YB2D77K5124779  Direct Auto Mecca
#  46           6.0L 8 Cylinder  1GT59ME79LF137089  Direct Auto Mecca
#  47           5.7L 8 Cylinder  1C6SRFHT3KN725878  Direct Auto Mecca
#  48           6.0L 8 Cylinder  1GC1YME77LF226516  Direct Auto Mecca
#  49           6.6L 8 Cylinder  1GC4YME72MF192760  Direct Auto Mecca
#  50           6.2L 8 Cylinder  1GTP9EEL5LZ144700  Direct Auto Mecca
#  51           5.3L 8 Cylinder  1GCUYHED6MZ436969  Direct Auto Mecca
#
#      dealership_address dealership_zipcode dealership_city dealership_state  \
#  0   154 Waverly Street              01760          Natick               MA
#  1   154 Waverly Street              01760          Natick               MA
#  2   154 Waverly Street              01760          Natick               MA
#  3   154 Waverly Street              01760          Natick               MA
#  4   154 Waverly Street              01760          Natick               MA
#  5   154 Waverly Street              01760          Natick               MA
#  6   154 Waverly Street              01760          Natick               MA
#  7   154 Waverly Street              01760          Natick               MA
#  8   154 Waverly Street              01760          Natick               MA
#  9   154 Waverly Street              01760          Natick               MA
#  10  154 Waverly Street              01760          Natick               MA
#  11  154 Waverly Street              01760          Natick               MA
#  12  154 Waverly Street              01760          Natick               MA
#  13  154 Waverly Street              01760          Natick               MA
#  14  154 Waverly Street              01760          Natick               MA
#  15  154 Waverly Street              01760          Natick               MA
#  16  154 Waverly Street              01760          Natick               MA
#  17  154 Waverly Street              01760          Natick               MA
#  18  154 Waverly Street              01760          Natick               MA
#  19  154 Waverly Street              01760          Natick               MA
#  20  154 Waverly Street              01760          Natick               MA
#  21  154 Waverly Street              01760          Natick               MA
#  22  154 Waverly Street              01760          Natick               MA
#  23  154 Waverly Street              01760          Natick               MA
#  24  154 Waverly Street              01760          Natick               MA
#  25  154 Waverly Street              01760          Natick               MA
#  26  154 Waverly Street              01760          Natick               MA
#  27  154 Waverly Street              01760          Natick               MA
#  28  154 Waverly Street              01760          Natick               MA
#  29  154 Waverly Street              01760          Natick               MA
#  30  154 Waverly Street              01760          Natick               MA
#  31  154 Waverly Street              01760          Natick               MA
#  32  154 Waverly Street              01760          Natick               MA
#  33  154 Waverly Street              01760          Natick               MA
#  34  154 Waverly Street              01760          Natick               MA
#  35  154 Waverly Street              01760          Natick               MA
#  36  154 Waverly Street              01760          Natick               MA
#  37  154 Waverly Street              01760          Natick               MA
#  38  154 Waverly Street              01760          Natick               MA
#  39  154 Waverly Street              01760          Natick               MA
#  40  154 Waverly Street              01760          Natick               MA
#  41  154 Waverly Street              01760          Natick               MA
#  42  154 Waverly Street              01760          Natick               MA
#  43  154 Waverly Street              01760          Natick               MA
#  44  154 Waverly Street              01760          Natick               MA
#  45  154 Waverly Street              01760          Natick               MA
#  46  154 Waverly Street              01760          Natick               MA
#  47  154 Waverly Street              01760          Natick               MA
#  48  154 Waverly Street              01760          Natick               MA
#  49  154 Waverly Street              01760          Natick               MA
#  50  154 Waverly Street              01760          Natick               MA
#  51  154 Waverly Street              01760          Natick               MA
#
#                                          inventory_url  \
#  0   https://www.directautomecca.com/view-inventory...
#  1   https://www.directautomecca.com/view-inventory...
#  2   https://www.directautomecca.com/view-inventory...
#  3   https://www.directautomecca.com/view-inventory...
#  4   https://www.directautomecca.com/view-inventory...
#  5   https://www.directautomecca.com/view-inventory...
#  6   https://www.directautomecca.com/view-inventory...
#  7   https://www.directautomecca.com/view-inventory...
#  8   https://www.directautomecca.com/view-inventory...
#  9   https://www.directautomecca.com/view-inventory...
#  10  https://www.directautomecca.com/view-inventory...
#  11  https://www.directautomecca.com/view-inventory...
#  12  https://www.directautomecca.com/view-inventory...
#  13  https://www.directautomecca.com/view-inventory...
#  14  https://www.directautomecca.com/view-inventory...
#  15  https://www.directautomecca.com/view-inventory...
#  16  https://www.directautomecca.com/view-inventory...
#  17  https://www.directautomecca.com/view-inventory...
#  18  https://www.directautomecca.com/view-inventory...
#  19  https://www.directautomecca.com/view-inventory...
#  20  https://www.directautomecca.com/view-inventory...
#  21  https://www.directautomecca.com/view-inventory...
#  22  https://www.directautomecca.com/view-inventory...
#  23  https://www.directautomecca.com/view-inventory...
#  24  https://www.directautomecca.com/view-inventory...
#  25  https://www.directautomecca.com/view-inventory...
#  26  https://www.directautomecca.com/view-inventory...
#  27  https://www.directautomecca.com/view-inventory...
#  28  https://www.directautomecca.com/view-inventory...
#  29  https://www.directautomecca.com/view-inventory...
#  30  https://www.directautomecca.com/view-inventory...
#  31  https://www.directautomecca.com/view-inventory...
#  32  https://www.directautomecca.com/view-inventory...
#  33  https://www.directautomecca.com/view-inventory...
#  34  https://www.directautomecca.com/view-inventory...
#  35  https://www.directautomecca.com/view-inventory...
#  36  https://www.directautomecca.com/view-inventory...
#  37  https://www.directautomecca.com/view-inventory...
#  38  https://www.directautomecca.com/view-inventory...
#  39  https://www.directautomecca.com/view-inventory...
#  40  https://www.directautomecca.com/view-inventory...
#  41  https://www.directautomecca.com/view-inventory...
#  42  https://www.directautomecca.com/view-inventory...
#  43  https://www.directautomecca.com/view-inventory...
#  44  https://www.directautomecca.com/view-inventory...
#  45  https://www.directautomecca.com/view-inventory...
#  46  https://www.directautomecca.com/view-inventory...
#  47  https://www.directautomecca.com/view-inventory...
#  48  https://www.directautomecca.com/view-inventory...
#  49  https://www.directautomecca.com/view-inventory...
#  50  https://www.directautomecca.com/view-inventory...
#  51  https://www.directautomecca.com/view-inventory...
#
#                   scraped_date
#  0  2022-03-04 23:41:21.140222
#  1  2022-03-04 23:41:21.140222
#  2  2022-03-04 23:41:21.140222
#  3  2022-03-04 23:41:21.140222
#  4  2022-03-04 23:41:21.140222
#  5  2022-03-04 23:41:21.140222
#  6  2022-03-04 23:41:21.140222
#  7  2022-03-04 23:41:21.140222
#  8  2022-03-04 23:41:21.140222
#  9  2022-03-04 23:41:21.140222
#  10 2022-03-04 23:41:21.140222
#  11 2022-03-04 23:41:21.140222
#  12 2022-03-04 23:41:21.140222
#  13 2022-03-04 23:41:21.140222
#  14 2022-03-04 23:41:21.140222
#  15 2022-03-04 23:41:21.140222
#  16 2022-03-04 23:41:21.140222
#  17 2022-03-04 23:41:21.140222
#  18 2022-03-04 23:41:21.140222
#  19 2022-03-04 23:41:21.140222
#  20 2022-03-04 23:41:21.140222
#  21 2022-03-04 23:41:21.140222
#  22 2022-03-04 23:41:21.140222
#  23 2022-03-04 23:41:21.140222
#  24 2022-03-04 23:41:21.140222
#  25 2022-03-04 23:41:21.140222
#  26 2022-03-04 23:41:21.140222
#  27 2022-03-04 23:41:21.140222
#  28 2022-03-04 23:41:21.140222
#  29 2022-03-04 23:41:21.140222
#  30 2022-03-04 23:41:21.140222
#  31 2022-03-04 23:41:21.140222
#  32 2022-03-04 23:41:21.140222
#  33 2022-03-04 23:41:21.140222
#  34 2022-03-04 23:41:21.140222
#  35 2022-03-04 23:41:21.140222
#  36 2022-03-04 23:41:21.140222
#  37 2022-03-04 23:41:21.140222
#  38 2022-03-04 23:41:21.140222
#  39 2022-03-04 23:41:21.140222
#  40 2022-03-04 23:41:21.140222
#  41 2022-03-04 23:41:21.140222
#  42 2022-03-04 23:41:21.140222
#  43 2022-03-04 23:41:21.140222
#  44 2022-03-04 23:41:21.140222
#  45 2022-03-04 23:41:21.140222
#  46 2022-03-04 23:41:21.140222
#  47 2022-03-04 23:41:21.140222
#  48 2022-03-04 23:41:21.140222
#  49 2022-03-04 23:41:21.140222
#  50 2022-03-04 23:41:21.140222
#  51 2022-03-04 23:41:21.140222  ]

# %%
pagination_url = dealerships['Direct Auto Mecca']['pagination_url']
page_counter = 2

titles = []

response = requests.get(pagination_url, headers = headers)
soup = BeautifulSoup(response.text, "html.parser")   
title = parseColumn(soup, 'h2', 'ebiz-vdp-title color m-0')

titles.append(title)

page_counter += 1
pagination_url = pagination_url.replace('page=2', f'page={page_counter}')

# %%
titles
# Out:
# [['2019 Chevrolet Express 2500',
#   '2020 Ford F-150',
#   '2019 Tesla Model 3',
#   '2020 GMC Savana 2500',
#   '2015 GMC Yukon',
#   '2019 Ram 1500',
#   '2019 Chevrolet Silverado 1500',
#   '2018 Toyota Tundra',
#   '2019 Chevrolet Express 3500',
#   '2019 Chevrolet Silverado 1500',
#   '2019 GMC Sierra 1500',
#   '2020 Ford Explorer',
#   '2020 Ford Explorer',
#   '2019 Ram 1500',
#   '2020 Chevrolet Express 2500',
#   '2020 Chevrolet Express 2500',
#   '2019 Ford Transit-250',
#   '2020 GMC Sierra 1500',
#   '2020 Ford Transit-250',
#   '2017 Mercedes-Benz GLC',
#   '2019 Dodge Durango',
#   '2020 Chevrolet Silverado 1500',
#   '2019 Ram ProMaster 2500',
#   '2020 Ford Transit-250',
#   '2019 Toyota Tundra',
#   '2018 Ford F-150',
#   '2020 Chevrolet Silverado 1500',
#   '2020 Chevrolet Silverado 1500',
#   '2020 Ram 1500',
#   '2020 Chevrolet Express 2500',
#   '2021 Ford F-150',
#   '2017 GMC Sierra 3500HD',
#   '2021 Ram 2500',
#   '2019 Ford F-250SD',
#   '2019 Ford F-150',
#   '2019 Tesla Model 3',
#   '2019 Tesla Model 3',
#   '2020 Ford Explorer',
#   '2021 Toyota Highlander',
#   '2017 Chevrolet Silverado 2500HD',
#   '2021 Chevrolet Silverado 1500',
#   '2017 GMC Sierra 3500HD',
#   '2019 Ford F-150',
#   '2019 Chevrolet Silverado 2500HD',
#   '2019 BMW X6',
#   '2019 Chevrolet Corvette',
#   '2020 GMC Sierra 2500HD',
#   '2019 Ram 1500',
#   '2020 Chevrolet Silverado 2500HD',
#   '2021 Chevrolet Silverado 2500HD',
#   '2020 GMC Sierra 1500',
#   '2021 Chevrolet Silverado 1500']]

# %%
# conn = sqlite3.connect('cars.db')

# #Creating a cursor object using the cursor() method
# cursor = conn.cursor()

# #Doping EMPLOYEE table if already exists
# cursor.execute("DROP TABLE inventory")

# #Commit your changes in the database
# conn.commit()

# #Closing the connection
# conn.close()

# %%
# Check pagination

https://www.directautomecca.com/inventory.aspx?_new=true&_used=true&_page=2

# %%
conn = sqlite3.connect('cars.db')

# %%
df = pd.read_sql_query("SELECT * from inventory", conn)
df
# Out:
#                                         title  year           make  \
# 0                  2009 Toyota Camry LE Sedan  2009         Toyota
# 1                   2011 BMW X3 xDrive28i SUV  2011            BMW
# 2                    2011 Lexus HS 250h Sedan  2011          Lexus
# 3        2011 Mercedes-Benz ML 350 4MATIC SUV  2011  Mercedes-Benz
# 4    2012 Audi A6 3.0T quattro Prestige Sedan  2012           Audi
# ..                                        ...   ...            ...
# 168                             2019 Ram 1500  2019            Ram
# 169           2020 Chevrolet Silverado 2500HD  2020      Chevrolet
# 170           2021 Chevrolet Silverado 2500HD  2021      Chevrolet
# 171                      2020 GMC Sierra 1500  2020            GMC
# 172             2021 Chevrolet Silverado 1500  2021      Chevrolet
#
#                        models vehicle_type  vehicle_mileage    price  \
# 0                    Camry LE        Sedan           124351   8495.0
# 1                X3 xDrive28i          SUV            98952  13995.0
# 2                     HS 250h        Sedan            92948  13995.0
# 3               ML 350 4MATIC          SUV            98922  14995.0
# 4    A6 3.0T quattro Prestige        Sedan            98933  17995.0
# ..                        ...          ...              ...      ...
# 168                      1500         None            30222  59497.0
# 169          Silverado 2500HD         None            16111  60000.0
# 170          Silverado 2500HD         None            11178  60997.0
# 171               Sierra 1500         None            20840  65000.0
# 172            Silverado 1500         None             4098  65000.0
#
#                          exterior_color        interior_color  \
# 0                Magnetic Gray Metallic                   Ash
# 1                             Jet Black  Black Nevada Leather
# 2                                 Black                 Black
# 3               Obsidian Black Metallic         Black Leather
# 4                                 White                 Brown
# ..                                  ...                   ...
# 168  Granite Crystal Metallic Clearcoat                 Black
# 169                               Black             Jet Black
# 170                               White                 Black
# 171                               White                 Black
# 172                               Black                 Black
#
#          transmission                                  engine  \
# 0           Automatic               2.4L I4 158hp 161ft. lbs.
# 1           Automatic               3.0L I6 240hp 221ft. lbs.
# 2           Automatic        2.4L Hybrid I4 147hp 138ft. lbs.
# 3           Automatic               3.5L V6 268hp 258ft. lbs.
# 4           Automatic  3.0L Supercharged V6 310hp 325ft. lbs.
# ..                ...                                     ...
# 168   8 Spd Automatic                         5.7L 8 Cylinder
# 169   6 Spd Automatic                         6.0L 8 Cylinder
# 170   6 Spd Automatic                         6.6L 8 Cylinder
# 171  10 Spd Automatic                         6.2L 8 Cylinder
# 172  10 Spd Automatic                         5.3L 8 Cylinder
#
#                    vin       dealership_name  dealership_address  \
# 0    4T4BE46K89R114118  Bostonyan Auto Group    119 Worcester St
# 1    5UXWX5C51BL715699  Bostonyan Auto Group    119 Worcester St
# 2    JTHBB1BA0B2044987  Bostonyan Auto Group    119 Worcester St
# 3    4JGBB8GB4BA723044  Bostonyan Auto Group    119 Worcester St
# 4    WAUHGAFC4CN137257  Bostonyan Auto Group    119 Worcester St
# ..                 ...                   ...                 ...
# 168  1C6SRFHT3KN725878     Direct Auto Mecca  154 Waverly Street
# 169  1GC1YME77LF226516     Direct Auto Mecca  154 Waverly Street
# 170  1GC4YME72MF192760     Direct Auto Mecca  154 Waverly Street
# 171  1GTP9EEL5LZ144700     Direct Auto Mecca  154 Waverly Street
# 172  1GCUYHED6MZ436969     Direct Auto Mecca  154 Waverly Street
#
#     dealership_zipcode dealership_city dealership_state  \
# 0                01760          Natick               MA
# 1                01760          Natick               MA
# 2                01760          Natick               MA
# 3                01760          Natick               MA
# 4                01760          Natick               MA
# ..                 ...             ...              ...
# 168              01760          Natick               MA
# 169              01760          Natick               MA
# 170              01760          Natick               MA
# 171              01760          Natick               MA
# 172              01760          Natick               MA
#
#                                          inventory_url  \
# 0    https://www.bostonyanautogroup.com/view-inventory
# 1    https://www.bostonyanautogroup.com/view-inventory
# 2    https://www.bostonyanautogroup.com/view-inventory
# 3    https://www.bostonyanautogroup.com/view-inventory
# 4    https://www.bostonyanautogroup.com/view-inventory
# ..                                                 ...
# 168  https://www.directautomecca.com/view-inventory...
# 169  https://www.directautomecca.com/view-inventory...
# 170  https://www.directautomecca.com/view-inventory...
# 171  https://www.directautomecca.com/view-inventory...
# 172  https://www.directautomecca.com/view-inventory...
#
#                    scraped_date
# 0    2022-03-04 23:43:26.413657
# 1    2022-03-04 23:43:26.413657
# 2    2022-03-04 23:43:26.413657
# 3    2022-03-04 23:43:26.413657
# 4    2022-03-04 23:43:26.413657
# ..                          ...
# 168  2022-03-04 23:43:32.375412
# 169  2022-03-04 23:43:32.375412
# 170  2022-03-04 23:43:32.375412
# 171  2022-03-04 23:43:32.375412
# 172  2022-03-04 23:43:32.375412
#
# [173 rows x 19 columns]

# %%
df.loc[df['dealership_name'] == 'Direct Auto Mecca', :]
# Out:
#                                title  year        make            models  \
# 21             2014 Volkswagen Jetta  2014  Volkswagen             Jetta
# 22            2014 Volkswagen Passat  2014  Volkswagen            Passat
# 23                 2015 Nissan Rogue  2015      Nissan             Rogue
# 24              2019 Chevrolet Spark  2019   Chevrolet             Spark
# 25                 2016 Nissan Rogue  2016      Nissan             Rogue
# ..                               ...   ...         ...               ...
# 168                    2019 Ram 1500  2019         Ram              1500
# 169  2020 Chevrolet Silverado 2500HD  2020   Chevrolet  Silverado 2500HD
# 170  2021 Chevrolet Silverado 2500HD  2021   Chevrolet  Silverado 2500HD
# 171             2020 GMC Sierra 1500  2020         GMC       Sierra 1500
# 172    2021 Chevrolet Silverado 1500  2021   Chevrolet    Silverado 1500
#
#     vehicle_type  vehicle_mileage    price  \
# 21          None            96889  10000.0
# 22          None            68956  13497.0
# 23          None            82552  17597.0
# 24          None            22395  17997.0
# 25          None            84059  18497.0
# ..           ...              ...      ...
# 168         None            30222  59497.0
# 169         None            16111  60000.0
# 170         None            11178  60997.0
# 171         None            20840  65000.0
# 172         None             4098  65000.0
#
#                          exterior_color  \
# 21                               Silver
# 22                               Silver
# 23                          Super Black
# 24                  Silver Ice Metallic
# 25                         Gun Metallic
# ..                                  ...
# 168  Granite Crystal Metallic Clearcoat
# 169                               Black
# 170                               White
# 171                               White
# 172                               Black
#
#                               interior_color      transmission  \
# 21                          Mar Grigalauskas      5 Spd Manual
# 22                                      Gray   6 Spd Automatic
# 23                                     Black               CVT
# 24   Jet Black/Dark Anderson Silver Metallic               CVT
# 25                                  Charcoal               CVT
# ..                                       ...               ...
# 168                                    Black   8 Spd Automatic
# 169                                Jet Black   6 Spd Automatic
# 170                                    Black   6 Spd Automatic
# 171                                    Black  10 Spd Automatic
# 172                                    Black  10 Spd Automatic
#
#               engine                vin    dealership_name  \
# 21   2.0L 4 Cylinder  3VW1K7AJ1EM371670  Direct Auto Mecca
# 22   1.8L 4 Cylinder  1VWAT7A35EC091203  Direct Auto Mecca
# 23   2.5L 4 Cylinder  KNMAT2MV0FP507719  Direct Auto Mecca
# 24   1.4L 4 Cylinder  KL8CF6SA2KC750949  Direct Auto Mecca
# 25   2.5L 4 Cylinder  JN8AT2MV3GW141234  Direct Auto Mecca
# ..               ...                ...                ...
# 168  5.7L 8 Cylinder  1C6SRFHT3KN725878  Direct Auto Mecca
# 169  6.0L 8 Cylinder  1GC1YME77LF226516  Direct Auto Mecca
# 170  6.6L 8 Cylinder  1GC4YME72MF192760  Direct Auto Mecca
# 171  6.2L 8 Cylinder  1GTP9EEL5LZ144700  Direct Auto Mecca
# 172  5.3L 8 Cylinder  1GCUYHED6MZ436969  Direct Auto Mecca
#
#      dealership_address dealership_zipcode dealership_city dealership_state  \
# 21   154 Waverly Street              01760          Natick               MA
# 22   154 Waverly Street              01760          Natick               MA
# 23   154 Waverly Street              01760          Natick               MA
# 24   154 Waverly Street              01760          Natick               MA
# 25   154 Waverly Street              01760          Natick               MA
# ..                  ...                ...             ...              ...
# 168  154 Waverly Street              01760          Natick               MA
# 169  154 Waverly Street              01760          Natick               MA
# 170  154 Waverly Street              01760          Natick               MA
# 171  154 Waverly Street              01760          Natick               MA
# 172  154 Waverly Street              01760          Natick               MA
#
#                                          inventory_url  \
# 21   https://www.directautomecca.com/view-inventory...
# 22   https://www.directautomecca.com/view-inventory...
# 23   https://www.directautomecca.com/view-inventory...
# 24   https://www.directautomecca.com/view-inventory...
# 25   https://www.directautomecca.com/view-inventory...
# ..                                                 ...
# 168  https://www.directautomecca.com/view-inventory...
# 169  https://www.directautomecca.com/view-inventory...
# 170  https://www.directautomecca.com/view-inventory...
# 171  https://www.directautomecca.com/view-inventory...
# 172  https://www.directautomecca.com/view-inventory...
#
#                    scraped_date
# 21   2022-03-04 23:43:29.300674
# 22   2022-03-04 23:43:29.300674
# 23   2022-03-04 23:43:29.300674
# 24   2022-03-04 23:43:29.300674
# 25   2022-03-04 23:43:29.300674
# ..                          ...
# 168  2022-03-04 23:43:32.375412
# 169  2022-03-04 23:43:32.375412
# 170  2022-03-04 23:43:32.375412
# 171  2022-03-04 23:43:32.375412
# 172  2022-03-04 23:43:32.375412
#
# [152 rows x 19 columns]
