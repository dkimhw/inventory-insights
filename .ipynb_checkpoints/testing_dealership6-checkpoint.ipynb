# %%
import parse_inventory as pi
import parse_dealership
import requests
import re
from bs4 import BeautifulSoup
import pandas as pd
from datetime import datetime
import sqlite3
import numpy as np

# %%
headers = {
    'user-agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/56.0.2924.87 Safari/537.36',
}

URL = 'https://avonautobrokers.com/newandusedcars?page=12'
response = requests.get(URL, headers = headers)
soup = BeautifulSoup(response.text, "html.parser")

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <title>
#    Used Cars for Sale Avon MA 02301 Avon Auto Brokers
#   </title>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <meta content="Used Cars, used autos, automobiles, brockton, avon, boston, boston used cars, audi, bmw, mercedes, merecedes-benz, chevrolet, cadillac, chrysler, dodge, ford, acura, kia, hyundai, gmc, hummer, honda, infiniti, infinity, jeep, jaguar, lexus, lincoln, mazda, mitsubishi, mini, cooper, nissan, scion, toyota, land rover, range rover, lr2, lr3, high line used cars, cars, pre-owned, preowned, pre owned, luxury used cars, luxury cars, accord, civic, porsche, certified cars, certified pre owned, service, customer service, randolph, easton, norton, mansfield, taunton, natick, framingham, dover, carver, rockland, attleboro, weymouth, plymouth, stoughton, south easton, north easton, bridgewater, west bridgewater, east bridgewater, falmouth, whitman, abington, norwood, westwood, canton, wellesley, newton, boston, brighton, allston, dorchester, roxbury, car dealer, dealership, car dealers, automobile dealership, automobiles, car dealership, used car dealership, minivan, suv, car, truck, luxury truck, luxury suv" name="keywords"/>
#   <meta content="Used Cars for Sale Avon MA 02301 Avon Auto Brokers" name="description"/>
#   <meta content="hdh0anpUKNYabEZ1QPQBZ5XnHcJ8M56P5UtpyNH70YQ" name="google-site-verification">
#    <meta content="https://imagescdn.dealercarsearch.com/dealerimages/5134/23493/Logo2.png" name="og:image" property="og:image"/>
#    <meta content="https://avonautobrokers.com/newandusedcars" name="og:url" property="og:url"/>
#    <meta content="Used Cars for Sale Avon MA 02301 Avon Auto Brokers" name="og:title" property="og:title"/>
#    <meta content="Used Cars for Sale Avon MA 02301 Avon Auto Brokers" name="og:description" property="og:description"/>
#    <script src="https://webchat.hammer-corp.com/loader.js" type="text/javascript">
#    </script>
#    <!-- Global site tag (gtag.js) - Google Analytics -->
#    <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-188118350-1">
#    </script>
#    <script>
#     window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'UA-188118350-1');
#    </script>
#    <link crossorigin="" href="https://userway.org" rel="preconnect"/>
#    <link href="https://www.google-analytics.com" rel="preconnect"/>
#    <script type="text/javascript">
#     var _userway_config = {
#     position: "5",
#     size: "small",
#     account: "RKc9SJg9ce"
#   };
#    </script>
#    <script async="" src="https://cdn.userway.org/widget.js" type="text/javascript">
#    </script>
#    <script async="" src="https://content-container.edmunds.com/.js" type="text/javascript">
#    </script>
#    <link href="/Dealers/05001_06000/05134_mvc/23493.min.css?v=Vpw2kHZk05VST7MAFHEbFeicA6VQVJDCSO5pEjUuoC8" rel="stylesheet"/>
#    <link href="https://avonautobrokers.com/newandusedcars" rel="canonical"/>
#    <!-- Global site tag (gtag.js) - Google Analytics -->
#    <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-3RNWQYM023">
#    </script>
#    <script>
#     window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#   gtag('config', 'G-3RNWQYM023');
#    </script>
#    <script>
#     (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#   ga('create', 'UA-113563710-1', 'auto', 'Dealer');  ga('Dealer.send', 'pageview');
#    </script>
#    <script src="https://checkout.autofi.com/script.js" type="text/javascript">
#    </script>
#    <!-- Facebook Pixel Code -->
#    <script>
#     !function(f,b,e,v,n,t,s)
# {if(f.fbq)return;n=f.fbq=function(){n.callMethod?
# n.callMethod.apply(n,arguments):n.queue.push(arguments)};
# if(!f._fbq)f._fbq=n;n.push=n;n.loaded=!0;n.version='2.0';
# n.queue=[];t=b.createElement(e);t.async=!0;
# t.src=v;s=b.getElementsByTagName(e)[0];
# s.parentNode.insertBefore(t,s)}(window,document,'script',
# 'https://connect.facebook.net/en_US/fbevents.js');
# fbq('init', '1013190789141789');
# fbq('track', 'PageView');
#    </script>
#    <!-- End Facebook Pixel Code -->
#    <script async="" src="https://content-container.edmunds.com/828233.js" type="text/javascript">
#    </script>
#    <script async="" defer="" src="https://www.carcodesms.com/widgets/125039.js" type="text/javascript">
#    </script>
#   </meta>
#  </head>
#  <body class="listPage newandusedcars-dcs">
#   <header class="s41r_headerWrapper">
#    <div id="topBar">
#     <div class="topHeader container">
#      <div class="s41r_addressPane" id="AddressPane">
#       <div class="ContentPane_135385 AddressAndPhone AddressAndPhone_135385">
#        <div class="AddressPhone_Main">
#         <span class="LabelAddress1">
#          <i class="fas fa-map-marker-alt">
#          </i>
#          159 Memorial Dr. Rte 28
#         </span>
#         <span class="LabelCityStateZip1">
#          Avon, MA 02322
#         </span>
#         <span class="LabelPhone1">
#          <i class="fas fa-phone">
#          </i>
#          <a href="tel:508-584-0577">
#           508-584-0577
#          </a>
#         </span>
#         <div class="location2">
#          <span class="LabelAddress2">
#           <i class="fas fa-map-marker-alt">
#           </i>
#           985 Belmont Street, Rte 123
#          </span>
#          <span class="LabelCityStateZip2">
#           Brockton, MA 02301
#          </span>
#          <span class="LabelPhone2">
#           <i class="fas fa-phone">
#           </i>
#           <a href="tel:508-584-4500">
#            508-584-4500
#           </a>
#          </span>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div class="s41r_SocialMediaPane" id="SocialMediaPane">
#       <div class="ContentPane_135386 SocialMedia SocialMedia_135386">
#        <div class="socialMedia">
#         <a aria-label="Follow Us on Facebook" href="https://www.facebook.com/avonautobrokers" rel="noopener" target="_blank" title="Follow Us on Facebook">
#          <i class="fab fa-facebook-f">
#          </i>
#         </a>
#         <a aria-label="Follow Us on Twitter" href="https://twitter.com/AvonAutoBroker" rel="noopener" target="_blank" title="Follow Us on Twitter">
#          <i class="fab fa-twitter">
#          </i>
#         </a>
#         <a aria-label="Follow Us on YouTube" href="https://www.youtube.com/channel/UCfPjH3kjVpFR6viRq-T1A-w" rel="noopener" target="_blank" title="Follow Us on YouTube">
#          <i class="fab fa-youtube">
#          </i>
#         </a>
#         <a aria-label="Follow Us on Google" href="https://www.google.com/maps/place/Avon+Auto+Brokers/@42.1159778,-71.0324963,17z/data=!3m1!4b1!4m5!3m4!1s0x0:0x2ffb0d3c7e9405a3!8m2!3d42.1159778!4d-71.0303076" rel="noopener" target="_blank" title="Follow Us on Google">
#          <i class="fab fa-google">
#          </i>
#         </a>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="topBarSwitch">
#     <div class="container">
#      <a aria-label="Store Info" href="#">
#       <i class="fas fa-map-marker">
#       </i>
#       <i class="fas fa-phone">
#       </i>
#       <i class="fas fa-envelope">
#       </i>
#       <i class="fas fa-share-alt">
#       </i>
#      </a>
#     </div>
#    </div>
#    <div class="logoWrapper">
#     <a aria-label="Dealer Logo" href="//avonautobrokers.com" id="hlLogo">
#      <img alt="Avon Auto Brokers Logo" class="dealerLogo logo logo_5134 img-fluid" src="https://imagescdn.dealercarsearch.com/dealerimages/5134/23493/Logo2.png" title="Avon Auto Brokers Logo"/>
#     </a>
#     <div class="s41r_headerpane" id="headerPane">
#     </div>
#    </div>
#    <div class="menuWrapper">
#     <div class="container">
#      <nav class="navbar navbar-expand-lg" id="s41r_menu">
#       <button aria-controls="siteNav" aria-expanded="false" aria-label="Toggle navigation" class="siteMenu navbar-toggler" data-target="#siteNav" data-toggle="collapse" type="button">
#        Site Menu
#       </button>
#       <div class="collapse navbar-collapse" id="siteNav">
#        <ul class="navbar-nav">
#         <li class="nav-item">
#          <a class="nav-link" href="/default">
#           <span>
#            Home
#           </span>
#          </a>
#         </li>
#         <li class="nav-item dropdown">
#          <a aria-expanded="false" aria-haspopup="true" class="nav-link dropdown-toggle" data-toggle="dropdown" href="/newandusedcars?clearall=1">
#           <span>
#            Inventory
#           </span>
#          </a>
#          <div class="dropdown-menu">
#           <a class="dropdown-item" href="/newandusedcars?clearall=1">
#            <span>
#             Shop Cars, Trucks, &amp; SUVs
#            </span>
#           </a>
#           <a class="dropdown-item" href="/newandusedcars?clearall=1&amp;pricelow=1&amp;pricehigh=20000">
#            <span>
#             Vehicles Under 20K
#            </span>
#           </a>
#          </div>
#         </li>
#         <li class="nav-item dropdown">
#          <a aria-expanded="false" aria-haspopup="true" class="nav-link dropdown-toggle" data-toggle="dropdown" href="/financing">
#           <span>
#            Financing
#           </span>
#          </a>
#          <div class="dropdown-menu">
#           <a class="dropdown-item" href="/creditapp">
#            <span>
#             Apply Online
#            </span>
#           </a>
#           <a class="dropdown-item" href="/loancalculator">
#            <span>
#             Loan Calculator
#            </span>
#           </a>
#          </div>
#         </li>
#         <li class="nav-item">
#          <a class="nav-link" href="/reviews">
#           <span>
#            Reviews
#           </span>
#          </a>
#         </li>
#         <li class="nav-item dropdown">
#          <a aria-expanded="false" aria-haspopup="true" class="nav-link dropdown-toggle" data-toggle="dropdown" href="/services">
#           <span>
#            Services
#           </span>
#          </a>
#          <div class="dropdown-menu">
#           <a class="dropdown-item" href="/trade">
#            <span>
#             Value Your Trade-In
#            </span>
#           </a>
#           <a class="dropdown-item" href="/locatorservice">
#            <span>
#             Vehicle Finder
#            </span>
#           </a>
#           <a class="dropdown-item" href="/service">
#            <span>
#             Service Center
#            </span>
#           </a>
#           <a class="dropdown-item" href="/extended-warranties">
#            <span>
#             Extended Warranties
#            </span>
#           </a>
#          </div>
#         </li>
#         <li class="nav-item dropdown">
#          <a aria-expanded="false" aria-haspopup="true" class="nav-link dropdown-toggle" data-toggle="dropdown" href="/ourstore">
#           <span>
#            Our Store
#           </span>
#          </a>
#          <div class="dropdown-menu">
#           <a class="dropdown-item" href="/directions">
#            <span>
#             Hours &amp; Map
#            </span>
#           </a>
#           <a class="dropdown-item" href="/aboutus">
#            <span>
#             About Us
#            </span>
#           </a>
#           <a class="dropdown-item" href="/sendcomments">
#            <span>
#             Contact Us
#            </span>
#           </a>
#           <a class="dropdown-item" href="/meetourstaff">
#            <span>
#             Meet Our Staff
#            </span>
#           </a>
#           <a class="dropdown-item" href="/privacy">
#            <span>
#             Privacy Policy
#            </span>
#           </a>
#          </div>
#         </li>
#         <li class="nav-item">
#          <a class="nav-link" href="https://app.consumerfusion.com/review-tool/response/start-page/3587" rel="nofollow" target="_blank">
#           <span>
#            Survey
#           </span>
#          </a>
#         </li>
#        </ul>
#       </div>
#      </nav>
#     </div>
#    </div>
#   </header>
#   <main id="contentWrapper">
#    <section class="titleBarWrapper">
#     <div class="s41r_titleBar container" id="TitleBar">
#      <div class="ContentPane_1188716 HTMLModule HTMLModule_1188716">
#       <h1 class="dealerTitle">
#        Online Showroom from Avon Auto Brokers
#       </h1>
#      </div>
#     </div>
#    </section>
#    <section class="contentWrapper container">
#     <div class="s41r_list clearfix" id="ContentPane">
#      <div class="ContentPane_1189022 HTMLModule HTMLModule_1189022">
#       <div class="edmunds-trade-in" data-display="reduced-height-autocomplete">
#       </div>
#       <br/>
#       <script language="javascript" src="https://cdn.flickfusion.net/s/c/8B43A7A7-EDD1-F2A6-760E-C70B6E2D5727/ws.js">
#       </script>
#       <div ff_client="62ACC7CC-BB25-645D-AC10-054685436B7C" ff_img="https://media.flickfusion.net/videos/global/images/ff_play.png" ff_lp="0" ff_overlay="1" ff_vin="[VIN]" id="ff_link">
#       </div>
#       <!--DIV_SCRIPT_LINEBREAK-->
#       <script language="javascript" src="https://media.flickfusion.net/videos/global/ff_multiple_link_lg_js.php">
#       </script>
#       <style>
#        @import url(https://fonts.googleapis.com/css?family=Lato:400,100,100italic,300,300italic,400italic,700,700italic,900,900italic);
#  	.HolidayBanner {display:inline-block;background: #e000ff; text-align: center; margin: 10px auto; padding:10px; width:100%;}
# 	.HolidayBanner img {max-width: 150px; margin: 0 auto;}
# 	/*** .HolidayBanner img {float:left;} ***FOR NON-RESPONSIVE***/
# 	.HolidayBanner h2 {display: inline-block; font: 900 calc(2.75em + 1.5vw) "Lato"; margin: 0; color: #fff; padding:0 10px; text-align: center;}
# 	.HolidayBanner h2 span {color: #fff;}
# 	.HolidayBanner strong {font: 700 2em "Lato"; margin: 0; color: #fff;}
# 	.HolidayBanner small {display:block; font: 700 2.25em "Lato"; margin: 0; padding-bottom:10px; color: #050505;}
#       </style>
#       <a href="https://avonautobrokers.com/creditapp.aspx?" target="_blank">
#        <div class="HolidayBanner container">
#         <div class="col-sm-12">
#          <h2>
#           30-Second
#           <span>
#            Credit Application!
#           </span>
#          </h2>
#          <small>
#           Click to Learn More
#          </small>
#         </div>
#        </div>
#       </a>
#       <!-- <img src="https://imagescdn.dealercarsearch.com/dealerimages/5134/23493/ConsumerSatisfactionAward2.jpg" alt="Consumer Satisfaction Award" class="img-fluid d-block mx-auto mb-3"/> -->
#      </div>
#      <div class="ContentPane_1453453 HTMLModule HTMLModule_1453453">
#       <!-- <p style="color: whitesmoke">To Select multiple values hold down the shift key</p> -->
#      </div>
#      <div class="ContentPane_1460258 ResponsiveFilterByPrice ResponsiveFilterByPrice_1460258">
#       <div id="filterByPriceWrap">
#        <div class="filter-by-price-price">
#         <a class="btn" href="/newandusedcars?clearall=1&amp;internetpricelow=1&amp;internetpricehigh=10000" target="_top">
#          Under $10,000
#         </a>
#        </div>
#        <div class="filter-by-price-price">
#         <a class="btn" href="/newandusedcars?clearall=1&amp;internetpricelow=10000&amp;internetpricehigh=15000" target="_top">
#          $10,000 - $15,000
#         </a>
#        </div>
#        <div class="filter-by-price-price">
#         <a class="btn" href="/newandusedcars?clearall=1&amp;internetpricelow=15000&amp;internetpricehigh=20000" target="_top">
#          $15,000 - $20,000
#         </a>
#        </div>
#        <div class="filter-by-price-price">
#         <a class="btn" href="/newandusedcars?clearall=1&amp;internetpricelow=20000&amp;internetpricehigh=25000" target="_top">
#          $20,000 - $25,000
#         </a>
#        </div>
#        <div class="filter-by-price-price">
#         <a class="btn" href="/newandusedcars?clearall=1&amp;internetpricelow=25000&amp;internetpricehigh=30000" target="_top">
#          $25,000 - $30,000
#         </a>
#        </div>
#        <div class="filter-by-price-price">
#         <a class="btn" href="/newandusedcars?clearall=1&amp;internetpricelow=30000&amp;internetpricehigh=350000" target="_top">
#          Over $30,000
#         </a>
#        </div>
#       </div>
#      </div>
#      <div class="ContentPane_1189025 ResponsiveInventoryModule11 ResponsiveInventoryModule11_1189025">
#       <div class="i11r" id="vehicles">
#        <div class="inv-loading-overlay d-none">
#        </div>
#        <form action="/InventoryModule/RefreshInventoryModule?pagename=newandusedcars" data-ajax="true" data-ajax-failure="inventoryModuleFormFailure();" data-ajax-method="get" data-ajax-mode="replace-with" data-ajax-success="inventoryModuleFormSuccess()" data-ajax-update="#vehicles" id="filterForm" method="post">
#         <div class="inv-filter-wrap">
#          <button aria-controls="panelRefine" aria-expanded="false" class="btn filterBtn filter-btn-wide" data-target="#panelRefine" data-toggle="collapse" type="button">
#           <i class="fas fa-sliders-h">
#           </i>
#           Filter Vehicles
#          </button>
#          <div class="inv-filterRow collapse show" data-id-to-update="filters" id="panelRefine">
#           <div class="refineSearchWrap">
#            <div class="refineSearch panel-group" id="refineAccordion">
#             <div id="filterFields">
#              <div class="cd-filter-block">
#               <label aria-label="Year">
#                Year
#               </label>
#               <div class="cd-filter-content">
#                <select aria-label="FilterYear" class="selectpicker form-control" data-dropdown-align-right="true" data-selected-text-format="count &gt; 2" id="FilterYear" multiple="" name="year">
#                 <option selected="" value="">
#                  Any
#                 </option>
#                 <option name="year" value="1984">
#                  1984 (1)
#                 </option>
#                 <option name="year" value="1987">
#                  1987 (2)
#                 </option>
#                 <option name="year" value="1996">
#                  1996 (1)
#                 </option>
#                 <option name="year" value="2000">
#                  2000 (1)
#                 </option>
#                 <option name="year" value="2002">
#                  2002 (3)
#                 </option>
#                 <option name="year" value="2004">
#                  2004 (4)
#                 </option>
#                 <option name="year" value="2005">
#                  2005 (2)
#                 </option>
#                 <option name="year" value="2006">
#                  2006 (6)
#                 </option>
#                 <option name="year" value="2007">
#                  2007 (12)
#                 </option>
#                 <option name="year" value="2008">
#                  2008 (10)
#                 </option>
#                 <option name="year" value="2009">
#                  2009 (6)
#                 </option>
#                 <option name="year" value="2010">
#                  2010 (9)
#                 </option>
#                 <option name="year" value="2011">
#                  2011 (20)
#                 </option>
#                 <option name="year" value="2012">
#                  2012 (20)
#                 </option>
#                 <option name="year" value="2013">
#                  2013 (41)
#                 </option>
#                 <option name="year" value="2014">
#                  2014 (41)
#                 </option>
#                 <option name="year" value="2015">
#                  2015 (43)
#                 </option>
#                 <option name="year" value="2016">
#                  2016 (37)
#                 </option>
#                 <option name="year" value="2017">
#                  2017 (23)
#                 </option>
#                 <option name="year" value="2018">
#                  2018 (14)
#                 </option>
#                 <option name="year" value="2019">
#                  2019 (8)
#                 </option>
#                 <option name="year" value="2021">
#                  2021 (1)
#                 </option>
#                </select>
#               </div>
#              </div>
#              <div class="cd-filter-block">
#               <label aria-label="Make">
#                Make
#               </label>
#               <div class="cd-filter-content">
#                <select aria-label="FilterMakeName" class="selectpicker form-control" data-dropdown-align-right="true" data-selected-text-format="count &gt; 2" id="FilterMakeName" multiple="" name="makename">
#                 <option selected="" value="">
#                  Any
#                 </option>
#                 <option name="makename" value="Acura">
#                  Acura (1)
#                 </option>
#                 <option name="makename" value="Aston Martin">
#                  Aston Martin (1)
#                 </option>
#                 <option name="makename" value="Audi">
#                  Audi (38)
#                 </option>
#                 <option name="makename" value="BMW">
#                  BMW (65)
#                 </option>
#                 <option name="makename" value="Bentley">
#                  Bentley (1)
#                 </option>
#                 <option name="makename" value="Cadillac">
#                  Cadillac (17)
#                 </option>
#                 <option name="makename" value="Chevrolet">
#                  Chevrolet (35)
#                 </option>
#                 <option name="makename" value="Dodge">
#                  Dodge (4)
#                 </option>
#                 <option name="makename" value="Ford">
#                  Ford (19)
#                 </option>
#                 <option name="makename" value="GMC">
#                  GMC (1)
#                 </option>
#                 <option name="makename" value="Honda">
#                  Honda (1)
#                 </option>
#                 <option name="makename" value="Infiniti">
#                  Infiniti (2)
#                 </option>
#                 <option name="makename" value="Jaguar">
#                  Jaguar (9)
#                 </option>
#                 <option name="makename" value="Jeep">
#                  Jeep (16)
#                 </option>
#                 <option name="makename" value="Lamborghini">
#                  Lamborghini (2)
#                 </option>
#                 <option name="makename" value="Land Rover">
#                  Land Rover (9)
#                 </option>
#                 <option name="makename" value="Lexus">
#                  Lexus (7)
#                 </option>
#                 <option name="makename" value="Maserati">
#                  Maserati (11)
#                 </option>
#                 <option name="makename" value="Mercedes-Benz">
#                  Mercedes-Benz (42)
#                 </option>
#                 <option name="makename" value="Nissan">
#                  Nissan (3)
#                 </option>
#                 <option name="makename" value="Pontiac">
#                  Pontiac (2)
#                 </option>
#                 <option name="makename" value="Porsche">
#                  Porsche (7)
#                 </option>
#                 <option name="makename" value="RAM">
#                  RAM (2)
#                 </option>
#                 <option name="makename" value="Rolls-Royce">
#                  Rolls-Royce (4)
#                 </option>
#                 <option name="makename" value="Toyota">
#                  Toyota (3)
#                 </option>
#                 <option name="makename" value="Volkswagen">
#                  Volkswagen (3)
#                 </option>
#                </select>
#               </div>
#              </div>
#              <div class="cd-filter-block">
#               <label aria-label="Model">
#                Model
#               </label>
#               <div class="cd-filter-content">
#                <select aria-label="FilterModelName" class="selectpicker form-control" data-dropdown-align-right="true" data-selected-text-format="count &gt; 2" disabled="" id="FilterModelName" multiple="" name="modelname">
#                 <option selected="" value="">
#                  Any
#                 </option>
#                 <option name="modelname" value="1-Series">
#                  1-Series (1)
#                 </option>
#                 <option name="modelname" value="1500">
#                  1500 (2)
#                 </option>
#                 <option name="modelname" value="2-Series">
#                  2-Series (2)
#                 </option>
#                 <option name="modelname" value="3 Series">
#                  3 Series (1)
#                 </option>
#                 <option name="modelname" value="3-Series">
#                  3-Series (15)
#                 </option>
#                 <option name="modelname" value="3-Series Gran Turismo">
#                  3-Series Gran Turismo (1)
#                 </option>
#                 <option name="modelname" value="4-Series">
#                  4-Series (2)
#                 </option>
#                 <option name="modelname" value="4-Series Gran Coupe">
#                  4-Series Gran Coupe (1)
#                 </option>
#                 <option name="modelname" value="5-Series">
#                  5-Series (11)
#                 </option>
#                 <option name="modelname" value="5-Series Gran Turismo">
#                  5-Series Gran Turismo (2)
#                 </option>
#                 <option name="modelname" value="6-Series">
#                  6-Series (7)
#                 </option>
#                 <option name="modelname" value="7-Series">
#                  7-Series (3)
#                 </option>
#                 <option name="modelname" value="911">
#                  911 (1)
#                 </option>
#                 <option name="modelname" value="A3">
#                  A3 (2)
#                 </option>
#                 <option name="modelname" value="A4">
#                  A4 (2)
#                 </option>
#                 <option name="modelname" value="A5">
#                  A5 (7)
#                 </option>
#                 <option name="modelname" value="A6">
#                  A6 (2)
#                 </option>
#                 <option name="modelname" value="A7">
#                  A7 (1)
#                 </option>
#                 <option name="modelname" value="A8">
#                  A8 (2)
#                 </option>
#                 <option name="modelname" value="AMG GT">
#                  AMG GT (1)
#                 </option>
#                 <option name="modelname" value="ATS">
#                  ATS (4)
#                 </option>
#                 <option name="modelname" value="Alpina B7">
#                  Alpina B7 (3)
#                 </option>
#                 <option name="modelname" value="Altima">
#                  Altima (1)
#                 </option>
#                 <option name="modelname" value="Avalanche">
#                  Avalanche (1)
#                 </option>
#                 <option name="modelname" value="Beetle">
#                  Beetle (1)
#                 </option>
#                 <option name="modelname" value="Boxster">
#                  Boxster (1)
#                 </option>
#                 <option name="modelname" value="C-Class">
#                  C-Class (13)
#                 </option>
#                 <option name="modelname" value="CLA-Class">
#                  CLA-Class (2)
#                 </option>
#                 <option name="modelname" value="CR-V">
#                  CR-V (1)
#                 </option>
#                 <option name="modelname" value="CTS">
#                  CTS (2)
#                 </option>
#                 <option name="modelname" value="Camaro">
#                  Camaro (11)
#                 </option>
#                 <option name="modelname" value="Captiva Sport">
#                  Captiva Sport (1)
#                 </option>
#                 <option name="modelname" value="Cayenne Hybrid">
#                  Cayenne Hybrid (1)
#                 </option>
#                 <option name="modelname" value="Challenger">
#                  Challenger (3)
#                 </option>
#                 <option name="modelname" value="Charger">
#                  Charger (1)
#                 </option>
#                 <option name="modelname" value="Continental GT">
#                  Continental GT (1)
#                 </option>
#                 <option name="modelname" value="Corvette">
#                  Corvette (15)
#                 </option>
#                 <option name="modelname" value="DTS">
#                  DTS (2)
#                 </option>
#                 <option name="modelname" value="Discovery Sport">
#                  Discovery Sport (1)
#                 </option>
#                 <option name="modelname" value="E-Class">
#                  E-Class (4)
#                 </option>
#                 <option name="modelname" value="E-Pace">
#                  E-Pace (1)
#                 </option>
#                 <option name="modelname" value="Escalade">
#                  Escalade (6)
#                 </option>
#                 <option name="modelname" value="Escape">
#                  Escape (1)
#                 </option>
#                 <option name="modelname" value="Explorer">
#                  Explorer (1)
#                 </option>
#                 <option name="modelname" value="F-150">
#                  F-150 (2)
#                 </option>
#                 <option name="modelname" value="F-250 SD">
#                  F-250 SD (2)
#                 </option>
#                 <option name="modelname" value="F-350 SD">
#                  F-350 SD (2)
#                 </option>
#                 <option name="modelname" value="F-Pace">
#                  F-Pace (2)
#                 </option>
#                 <option name="modelname" value="F-Type">
#                  F-Type (1)
#                 </option>
#                 <option name="modelname" value="Fiesta">
#                  Fiesta (1)
#                 </option>
#                 <option name="modelname" value="Firebird">
#                  Firebird (1)
#                 </option>
#                 <option name="modelname" value="GL-Class">
#                  GL-Class (5)
#                 </option>
#                 <option name="modelname" value="GLA-Class">
#                  GLA-Class (2)
#                 </option>
#                 <option name="modelname" value="GLK-Class">
#                  GLK-Class (2)
#                 </option>
#                 <option name="modelname" value="GX 460">
#                  GX 460 (1)
#                 </option>
#                 <option name="modelname" value="Gallardo">
#                  Gallardo (1)
#                 </option>
#                 <option name="modelname" value="Ghibli">
#                  Ghibli (8)
#                 </option>
#                 <option name="modelname" value="Ghost">
#                  Ghost (3)
#                 </option>
#                 <option name="modelname" value="Golf GTI">
#                  Golf GTI (1)
#                 </option>
#                 <option name="modelname" value="Grand Cherokee">
#                  Grand Cherokee (8)
#                 </option>
#                 <option name="modelname" value="IS">
#                  IS (3)
#                 </option>
#                 <option name="modelname" value="Jetta Sportwagen">
#                  Jetta Sportwagen (1)
#                 </option>
#                 <option name="modelname" value="LR4">
#                  LR4 (3)
#                 </option>
#                 <option name="modelname" value="M-Class">
#                  M-Class (2)
#                 </option>
#                 <option name="modelname" value="M4">
#                  M4 (2)
#                 </option>
#                 <option name="modelname" value="Murcielago">
#                  Murcielago (1)
#                 </option>
#                 <option name="modelname" value="Mustang">
#                  Mustang (9)
#                 </option>
#                 <option name="modelname" value="Panamera">
#                  Panamera (3)
#                 </option>
#                 <option name="modelname" value="Panamera Hybrid">
#                  Panamera Hybrid (1)
#                 </option>
#                 <option name="modelname" value="Q5">
#                  Q5 (6)
#                 </option>
#                 <option name="modelname" value="Q50">
#                  Q50 (1)
#                 </option>
#                 <option name="modelname" value="Q7">
#                  Q7 (2)
#                 </option>
#                 <option name="modelname" value="QX60">
#                  QX60 (1)
#                 </option>
#                 <option name="modelname" value="Quattroporte">
#                  Quattroporte (3)
#                 </option>
#                 <option name="modelname" value="R8">
#                  R8 (1)
#                 </option>
#                 <option name="modelname" value="RDX">
#                  RDX (1)
#                 </option>
#                 <option name="modelname" value="RS5">
#                  RS5 (1)
#                 </option>
#                 <option name="modelname" value="RX 350">
#                  RX 350 (2)
#                 </option>
#                 <option name="modelname" value="Range Rover Evoque">
#                  Range Rover Evoque (1)
#                 </option>
#                 <option name="modelname" value="Range Rover Sport">
#                  Range Rover Sport (4)
#                 </option>
#                 <option name="modelname" value="S-Class">
#                  S-Class (5)
#                 </option>
#                 <option name="modelname" value="S3">
#                  S3 (2)
#                 </option>
#                 <option name="modelname" value="S4">
#                  S4 (2)
#                 </option>
#                 <option name="modelname" value="S5">
#                  S5 (3)
#                 </option>
#                 <option name="modelname" value="S7">
#                  S7 (2)
#                 </option>
#                 <option name="modelname" value="SC 430">
#                  SC 430 (1)
#                 </option>
#                 <option name="modelname" value="SL-Class">
#                  SL-Class (4)
#                 </option>
#                 <option name="modelname" value="SLK">
#                  SLK (2)
#                 </option>
#                 <option name="modelname" value="SQ5">
#                  SQ5 (2)
#                 </option>
#                 <option name="modelname" value="SRX">
#                  SRX (1)
#                 </option>
#                 <option name="modelname" value="STS">
#                  STS (1)
#                 </option>
#                 <option name="modelname" value="Shelby GT500">
#                  Shelby GT500 (1)
#                 </option>
#                 <option name="modelname" value="Sierra 1500">
#                  Sierra 1500 (1)
#                 </option>
#                 <option name="modelname" value="Silver Spur">
#                  Silver Spur (1)
#                 </option>
#                 <option name="modelname" value="Silverado 1500">
#                  Silverado 1500 (2)
#                 </option>
#                 <option name="modelname" value="Silverado 2500HD">
#                  Silverado 2500HD (1)
#                 </option>
#                 <option name="modelname" value="Solstice">
#                  Solstice (1)
#                 </option>
#                 <option name="modelname" value="Suburban">
#                  Suburban (1)
#                 </option>
#                 <option name="modelname" value="TT">
#                  TT (1)
#                 </option>
#                 <option name="modelname" value="Tacoma">
#                  Tacoma (2)
#                 </option>
#                 <option name="modelname" value="Tahoe">
#                  Tahoe (3)
#                 </option>
#                 <option name="modelname" value="Titan">
#                  Titan (1)
#                 </option>
#                 <option name="modelname" value="V8 Vantage">
#                  V8 Vantage (1)
#                 </option>
#                 <option name="modelname" value="Venza">
#                  Venza (1)
#                 </option>
#                 <option name="modelname" value="Wrangler">
#                  Wrangler (7)
#                 </option>
#                 <option name="modelname" value="Wrangler JK">
#                  Wrangler JK (1)
#                 </option>
#                 <option name="modelname" value="X-Type">
#                  X-Type (2)
#                 </option>
#                 <option name="modelname" value="X1">
#                  X1 (3)
#                 </option>
#                 <option name="modelname" value="X3">
#                  X3 (2)
#                 </option>
#                 <option name="modelname" value="X4">
#                  X4 (2)
#                 </option>
#                 <option name="modelname" value="X5">
#                  X5 (5)
#                 </option>
#                 <option name="modelname" value="X6">
#                  X6 (1)
#                 </option>
#                 <option name="modelname" value="XJ-Series">
#                  XJ-Series (2)
#                 </option>
#                 <option name="modelname" value="XK-Series">
#                  XK-Series (1)
#                 </option>
#                 <option name="modelname" value="XTS">
#                  XTS (1)
#                 </option>
#                 <option name="modelname" value="Z">
#                  Z (1)
#                 </option>
#                 <option name="modelname" value="I8">
#                  I8 (1)
#                 </option>
#                </select>
#               </div>
#              </div>
#              <div class="cd-filter-block">
#               <label aria-label="Trim">
#                Trim
#               </label>
#               <div class="cd-filter-content">
#                <select aria-label="FilterTrimName" class="selectpicker form-control" data-dropdown-align-right="true" data-selected-text-format="count &gt; 2" disabled="" id="FilterTrimName" multiple="" name="trimname">
#                 <option selected="" value="">
#                  Any
#                 </option>
#                 <option name="trimname" value="1.8T Premium">
#                  1.8T Premium (2)
#                 </option>
#                 <option name="trimname" value="135I">
#                  135I (1)
#                 </option>
#                 <option name="trimname" value="1Lt">
#                  1Lt (4)
#                 </option>
#                 <option name="trimname" value="2.0L Premium Plus">
#                  2.0L Premium Plus (1)
#                 </option>
#                 <option name="trimname" value="2.0L Tdi W/Sound/Nav">
#                  2.0L Tdi W/Sound/Nav (1)
#                 </option>
#                 <option name="trimname" value="2.0T Premium Plus">
#                  2.0T Premium Plus (2)
#                 </option>
#                 <option name="trimname" value="2.0T Prestige">
#                  2.0T Prestige (1)
#                 </option>
#                 <option name="trimname" value="2.5 Sv">
#                  2.5 Sv (1)
#                 </option>
#                 <option name="trimname" value="20D Premium">
#                  20D Premium (1)
#                 </option>
#                 <option name="trimname" value="228I Xdrive">
#                  228I Xdrive (2)
#                 </option>
#                 <option name="trimname" value="25T">
#                  25T (1)
#                 </option>
#                 <option name="trimname" value="2D Convertible">
#                  2D Convertible (1)
#                 </option>
#                 <option name="trimname" value="2D Coupe">
#                  2D Coupe (2)
#                 </option>
#                 <option name="trimname" value="2Dr Conv">
#                  2Dr Conv (3)
#                 </option>
#                 <option name="trimname" value="2Dr Conv Sportshift">
#                  2Dr Conv Sportshift (1)
#                 </option>
#                 <option name="trimname" value="2Dr Convertible">
#                  2Dr Convertible (2)
#                 </option>
#                 <option name="trimname" value="2Dr Coupe">
#                  2Dr Coupe (1)
#                 </option>
#                 <option name="trimname" value="2Dr Cpe">
#                  2Dr Cpe (7)
#                 </option>
#                 <option name="trimname" value="2Dr Cpe Auto">
#                  2Dr Cpe Auto (1)
#                 </option>
#                 <option name="trimname" value="2Dr Hatchback Coupe">
#                  2Dr Hatchback Coupe (1)
#                 </option>
#                 <option name="trimname" value="2Ss">
#                  2Ss (1)
#                 </option>
#                 <option name="trimname" value="3.0 Premium Plus">
#                  3.0 Premium Plus (1)
#                 </option>
#                 <option name="trimname" value="3.0 Sedan">
#                  3.0 Sedan (1)
#                 </option>
#                 <option name="trimname" value="3.0I">
#                  3.0I (1)
#                 </option>
#                 <option name="trimname" value="3.0L">
#                  3.0L (1)
#                 </option>
#                 <option name="trimname" value="3.0T Premium Plus">
#                  3.0T Premium Plus (1)
#                 </option>
#                 <option name="trimname" value="3.0T S Line Prestige">
#                  3.0T S Line Prestige (1)
#                 </option>
#                 <option name="trimname" value="320I Xdrive">
#                  320I Xdrive (4)
#                 </option>
#                 <option name="trimname" value="328I">
#                  328I (3)
#                 </option>
#                 <option name="trimname" value="328I Xdrive">
#                  328I Xdrive (3)
#                 </option>
#                 <option name="trimname" value="330I Xdrive">
#                  330I Xdrive (1)
#                 </option>
#                 <option name="trimname" value="335I">
#                  335I (4)
#                 </option>
#                 <option name="trimname" value="335I Xdrive">
#                  335I Xdrive (2)
#                 </option>
#                 <option name="trimname" value="4">
#                  4 (1)
#                 </option>
#                 <option name="trimname" value="4.0T">
#                  4.0T (2)
#                 </option>
#                 <option name="trimname" value="4.2L">
#                  4.2L (1)
#                 </option>
#                 <option name="trimname" value="428I Xdrive">
#                  428I Xdrive (2)
#                 </option>
#                 <option name="trimname" value="430I Xdrive">
#                  430I Xdrive (1)
#                 </option>
#                 <option name="trimname" value="4Dr Sdn">
#                  4Dr Sdn (3)
#                 </option>
#                 <option name="trimname" value="4Dr Sdn 2.5L Rwd">
#                  4Dr Sdn 2.5L Rwd (1)
#                 </option>
#                 <option name="trimname" value="4Dr Sdn 3.0L">
#                  4Dr Sdn 3.0L (1)
#                 </option>
#                 <option name="trimname" value="4Dr Sdn Awd">
#                  4Dr Sdn Awd (2)
#                 </option>
#                 <option name="trimname" value="4Dr Sdn Duoselect">
#                  4Dr Sdn Duoselect (1)
#                 </option>
#                 <option name="trimname" value="4Dr Sdn Ewb">
#                  4Dr Sdn Ewb (1)
#                 </option>
#                 <option name="trimname" value="4Dr Sport Sdn Auto Awd">
#                  4Dr Sport Sdn Auto Awd (1)
#                 </option>
#                 <option name="trimname" value="4Dr Sport Sdn Auto Rwd">
#                  4Dr Sport Sdn Auto Rwd (1)
#                 </option>
#                 <option name="trimname" value="4S">
#                  4S (1)
#                 </option>
#                 <option name="trimname" value="4Wd 4Dr">
#                  4Wd 4Dr (1)
#                 </option>
#                 <option name="trimname" value="5.0L">
#                  5.0L (2)
#                 </option>
#                 <option name="trimname" value="5.5L V8">
#                  5.5L V8 (4)
#                 </option>
#                 <option name="trimname" value="50I">
#                  50I (1)
#                 </option>
#                 <option name="trimname" value="528I">
#                  528I (1)
#                 </option>
#                 <option name="trimname" value="528I Xdrive">
#                  528I Xdrive (4)
#                 </option>
#                 <option name="trimname" value="530I Xdrive">
#                  530I Xdrive (1)
#                 </option>
#                 <option name="trimname" value="535I Xdrive">
#                  535I Xdrive (4)
#                 </option>
#                 <option name="trimname" value="550I">
#                  550I (1)
#                 </option>
#                 <option name="trimname" value="550I Xdrive">
#                  550I Xdrive (2)
#                 </option>
#                 <option name="trimname" value="650Ci">
#                  650Ci (1)
#                 </option>
#                 <option name="trimname" value="650I">
#                  650I (5)
#                 </option>
#                 <option name="trimname" value="650I Xdrive">
#                  650I Xdrive (1)
#                 </option>
#                 <option name="trimname" value="750I">
#                  750I (1)
#                 </option>
#                 <option name="trimname" value="750I Xdrive">
#                  750I Xdrive (1)
#                 </option>
#                 <option name="trimname" value="750Li Xdrive">
#                  750Li Xdrive (4)
#                 </option>
#                 <option name="trimname" value="Amg C 43">
#                  Amg C 43 (2)
#                 </option>
#                 <option name="trimname" value="Amg Gt">
#                  Amg Gt (1)
#                 </option>
#                 <option name="trimname" value="Autobahn">
#                  Autobahn (1)
#                 </option>
#                 <option name="trimname" value="Awd">
#                  Awd (2)
#                 </option>
#                 <option name="trimname" value="Awd 4Dr">
#                  Awd 4Dr (2)
#                 </option>
#                 <option name="trimname" value="Awd W/1Sa">
#                  Awd W/1Sa (1)
#                 </option>
#                 <option name="trimname" value="Backcountry">
#                  Backcountry (1)
#                 </option>
#                 <option name="trimname" value="Big Horn">
#                  Big Horn (1)
#                 </option>
#                 <option name="trimname" value="C 250 Sport">
#                  C 250 Sport (1)
#                 </option>
#                 <option name="trimname" value="C 300">
#                  C 300 (7)
#                 </option>
#                 <option name="trimname" value="C 300 Sport">
#                  C 300 Sport (1)
#                 </option>
#                 <option name="trimname" value="C 400">
#                  C 400 (1)
#                 </option>
#                 <option name="trimname" value="C 63 Amg">
#                  C 63 Amg (1)
#                 </option>
#                 <option name="trimname" value="Cla 250">
#                  Cla 250 (2)
#                 </option>
#                 <option name="trimname" value="E 350">
#                  E 350 (1)
#                 </option>
#                 <option name="trimname" value="E 350 Sport">
#                  E 350 Sport (1)
#                 </option>
#                 <option name="trimname" value="E 400">
#                  E 400 (1)
#                 </option>
#                 <option name="trimname" value="E 63 Amg">
#                  E 63 Amg (1)
#                 </option>
#                 <option name="trimname" value="Ecoboost Premium">
#                  Ecoboost Premium (1)
#                 </option>
#                 <option name="trimname" value="Firebird">
#                  Firebird (1)
#                 </option>
#                 <option name="trimname" value="Gl 450">
#                  Gl 450 (4)
#                 </option>
#                 <option name="trimname" value="Gl 550">
#                  Gl 550 (1)
#                 </option>
#                 <option name="trimname" value="Gla 250">
#                  Gla 250 (2)
#                 </option>
#                 <option name="trimname" value="Glk 350">
#                  Glk 350 (2)
#                 </option>
#                 <option name="trimname" value="Grand Sport 1Lt">
#                  Grand Sport 1Lt (1)
#                 </option>
#                 <option name="trimname" value="Grand Sport 2Lt">
# ...
#             </label>
#             <input aria-labelledby="lblSMSLastName" class="form-control" data-val="true" data-val-required="The Last Name field is required." id="txtSMSLastName" name="LastName" type="text" value=""/>
#             <span class="text-danger field-validation-valid" data-valmsg-for="LastName" data-valmsg-replace="true">
#             </span>
#            </div>
#            <div class="form-group">
#             <label for="MobilePhone" id="lblSMSPhoneNumber">
#              Mobile Phone
#             </label>
#             <input aria-labelledby="lblSMSPhoneNumbere" class="form-control" data-val="true" data-val-regex="ex. ###-###-####" data-val-regex-pattern="^\([0-9]{3}\)\s?[0-9]{3}(-|\s)?[0-9]{4}$|^[0-9]{3}-?[0-9]{3}-?[0-9]{4}$" data-val-required="The Mobile Phone field is required." id="txtSMSPhoneNumber" name="MobilePhone" type="tel" value=""/>
#             <span class="text-danger field-validation-valid" data-valmsg-for="MobilePhone" data-valmsg-replace="true">
#             </span>
#            </div>
#            <div class="form-group">
#             <label for="Comments" id="lblSMSMessage">
#              Comments
#             </label>
#             <textarea aria-labelledby="lblSMSMessage" class="form-control form-textarea" data-val="true" data-val-required="The Comments field is required." id="txtSMSMessage" name="Comments">
# </textarea>
#             <span class="text-danger field-validation-valid" data-valmsg-for="Comments" data-valmsg-replace="true">
#             </span>
#            </div>
#            <input data-val="true" data-val-required="The VehicleId field is required." id="smsModalVehicleId" name="VehicleId" type="hidden" value="0"/>
#            <input data-val="true" data-val-required="The DealerId field is required." id="smsModalDealerId" name="DealerId" type="hidden" value="0"/>
#            <input id="smsModalCssClassPrefixId" name="CssClassPrefix" type="hidden" value="ir11"/>
#            <input id="smsModalYearMakeModel" name="YearMakeModel" type="hidden" value=""/>
#            <input id="smsModalStockNumber" name="StockNumber" type="hidden" value=""/>
#            <div class="contact-disclaimer">
#             <div class="form-group">
#              <div class="form-check">
#               <input aria-label="Contact Consent" class="form-check-input" data-val="true" data-val-range="Please check the box to verify acknowledgement and consent." data-val-range-max="True" data-val-range-min="True" data-val-required="The ContactDisclaimerConsent field is required." id="chkContactDisclaimerConsent" name="ContactDisclaimerConsent" type="checkbox" value="true"/>
#               <label aria-labelledby="chkContactDisclaimerConsent" for="chkContactDisclaimerConsent">
#                <strong>
#                 ACKNOWLEDGMENT AND CONSENT:
#                </strong>
#               </label>
#               <span class="text-danger field-validation-valid" data-valmsg-for="ContactDisclaimerConsent" data-valmsg-replace="true">
#               </span>
#              </div>
#              I hereby consent to receive text messages or phone calls from or on behalf of the dealer or their employees to the mobile phone number I provided above.  By opting in,  I understand that message and data rates may apply.  This acknowledgement constitutes my written consent to receive text messages to my cell phone and phone calls, including communications sent using an auto-dialer or pre-recorded message. You may withdraw your consent at any time by texting "STOP".
#             </div>
#            </div>
#            <div>
#            </div>
#            <div class="modal-footer">
#             <button class="ir11_submitButton btn" id="btnSendSMS">
#              I agree, Send Text
#              <i class="fas fa-spinner fa-spin fa-fw" id="ModalSmsTextFormSpinner" style="display: none">
#              </i>
#             </button>
#             <a href="/privacy" rel="noopener" target="_blank">
#              Privacy Policy
#             </a>
#            </div>
#            <div class="RowIce">
#             <input aria-label="Name" autocomplete="off" class="form-control" name="Name" type="text"/>
#            </div>
#            <input name="__RequestVerificationToken" type="hidden" value="CfDJ8Ps6JMJP4ONGi1LBaHz13Y28Y-R7mX4hFfyKk_O9dNHWKKCE3IJehvOXRoPfSfm5AKY-nweO4h27pK5HoEq_F-AXxpQ8zYyevhF_dlz66cbsxCKKcw_OU4zJcfRNMbfSTrT8RenVz3HDTYd1O7n0wQU"/>
#            <input name="ContactDisclaimerConsent" type="hidden" value="false"/>
#           </form>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div aria-hidden="true" aria-labelledby="pricedropModalLabel" class="modal fade" id="pricedropModal" role="dialog" tabindex="-1">
#        <div class="modal-dialog" role="document">
#         <div class="modal-content">
#          <div class="modal-header">
#           <h5 class="modal-title" id="pricedropModalLabel">
#            Price Drop Notifications
#           </h5>
#           <button aria-label="Close" class="close" data-dismiss="modal" type="button">
#            <span aria-hidden="true">
#             ×
#            </span>
#           </button>
#          </div>
#          <div class="modal-body">
#           <div class="formWrap price-drop-form-wrapper">
#            <div class="alert alert-success price-drop-modal-success" role="alert" style=" display: none">
#             Vehicle Price Watch submitted
#            </div>
#            <form action="/LeadModule/PriceDropSubmitForm?pagename=newandusedcars&amp;modulename=ResponsiveInventoryModule11" data-ajax="true" data-ajax-begin="$('.price-drop-form-button').prop('disabled',true);" data-ajax-complete="$('.price-drop-form-button').prop('disabled',false);" data-ajax-failure="ajaxFailure" data-ajax-loading=".price-drop-form-spinner" data-ajax-method="post" data-ajax-success="priceDropSuccess();formLeadTracking('0', '', 'Price Drop Form');redirect('');" data-recaptcha-id="PriceDropRecaptchaToken" data-recaptcha-site-key="" data-recaptcha-type="Undefined" id="PriceDropSubmitForm" method="post">
#             <div class="form-group">
#              <label class="col-form-label" for="FirstName" id="lblPriceDropFirstName">
#               First Name:
#              </label>
#              <input aria-labelledby="lblPriceDropFirstName" class="txtDropFirstName form-control" data-val="true" data-val-required="Please enter your first name" id="FirstName" name="FirstName" type="text" value=""/>
#              <span class="text-danger field-validation-valid" data-valmsg-for="FirstName" data-valmsg-replace="true">
#              </span>
#             </div>
#             <div class="form-group">
#              <label class="col-form-label" for="LastName" id="lblPriceDropLastName">
#               Last Name:
#              </label>
#              <input aria-labelledby="lblPriceDropLastName" class="txtDropLastName form-control" data-val="true" data-val-required="Please enter your last name" id="LastName" name="LastName" type="text" value=""/>
#              <span class="text-danger field-validation-valid" data-valmsg-for="LastName" data-valmsg-replace="true">
#              </span>
#             </div>
#             <div class="form-group">
#              <label class="col-form-label" for="Email" id="lblPriceDropEmail">
#               Email:
#              </label>
#              <input aria-labelledby="lblPriceDropEmail" class="txtDropEmail form-control" data-other="MobilePhone" data-val="true" data-val-requiredifother="Please enter phone or email" id="Email" name="Email" onchange="$('.txtDropMobilePhone').valid();" placeholder="example@example.com" type="email" value=""/>
#              <span class="text-danger field-validation-valid" data-valmsg-for="Email" data-valmsg-replace="true">
#              </span>
#             </div>
#             <div class="form-group">
#              <label class="col-form-label" for="MobilePhone" id="lblPriceDropMobilePhone">
#               Mobile Phone:
#              </label>
#              <input aria-labelledby="lblPriceDropMobilePhone" class="txtDropMobilePhone form-control" data-other="Email" data-val="true" data-val-regex="ex. ###-###-####" data-val-regex-pattern="^\([0-9]{3}\)\s?[0-9]{3}(-|\s)?[0-9]{4}$|^[0-9]{3}-?[0-9]{3}-?[0-9]{4}$" data-val-requiredifother="Please enter phone or email" id="MobilePhone" name="MobilePhone" onchange="$('.txtDropEmail').valid();" placeholder="###-###-####" type="tel" value=""/>
#              <span class="text-danger field-validation-valid" data-valmsg-for="MobilePhone" data-valmsg-replace="true">
#              </span>
#             </div>
#             <div class="contact-disclaimer">
#              <div class="form-group">
#               <div class="form-check">
#                <input aria-label="Contact Consent" class="form-check-input" data-val="true" data-val-range="Please check the box to verify acknowledgement and consent." data-val-range-max="True" data-val-range-min="True" data-val-required="The ContactDisclaimerConsent field is required." id="chkContactDisclaimerConsent" name="ContactDisclaimerConsent" type="checkbox" value="true"/>
#                <label aria-labelledby="chkContactDisclaimerConsent" for="chkContactDisclaimerConsent">
#                 <strong>
#                  ACKNOWLEDGMENT AND CONSENT:
#                 </strong>
#                </label>
#                <span class="text-danger field-validation-valid" data-valmsg-for="ContactDisclaimerConsent" data-valmsg-replace="true">
#                </span>
#               </div>
#               I hereby consent to receive text messages or phone calls from or on behalf of the dealer or their employees to the mobile phone number I provided above.  By opting in,  I understand that message and data rates may apply.  This acknowledgement constitutes my written consent to receive text messages to my cell phone and phone calls, including communications sent using an auto-dialer or pre-recorded message. You may withdraw your consent at any time by texting "STOP".
#              </div>
#             </div>
#             <div>
#             </div>
#             <button class="btn price-drop-form-button">
#              Submit
#              <i class="fas fa-spinner fa-spin fa-fw price-drop-form-spinner" style="display: none">
#              </i>
#             </button>
#             <input name="CssClassPrefix" type="hidden" value="i01r"/>
#             <input data-val="true" data-val-required="The InventoryId field is required." id="priceDropInventoryId" name="InventoryId" type="hidden" value="0"/>
#             <input data-val="true" data-val-required="The DealerId field is required." id="priceDropDealerId" name="DealerId" type="hidden" value="0"/>
#             <input data-val="true" data-val-required="The PriceType field is required." id="priceDropPriceType" name="PriceType" type="hidden" value="Undefined"/>
#             <input id="priceDropStockNumber" name="StockNumber" type="hidden" value=""/>
#             <div class="RowIce">
#              <input aria-label="Name" autocomplete="off" class="form-control" name="Name" type="text"/>
#             </div>
#             <input name="__RequestVerificationToken" type="hidden" value="CfDJ8Ps6JMJP4ONGi1LBaHz13Y28Y-R7mX4hFfyKk_O9dNHWKKCE3IJehvOXRoPfSfm5AKY-nweO4h27pK5HoEq_F-AXxpQ8zYyevhF_dlz66cbsxCKKcw_OU4zJcfRNMbfSTrT8RenVz3HDTYd1O7n0wQU"/>
#             <input name="ContactDisclaimerConsent" type="hidden" value="false"/>
#            </form>
#           </div>
#          </div>
#          <div class="modal-footer">
#          </div>
#         </div>
#        </div>
#       </div>
#       <script src="https://snapshot.carfax.com/latest/snapshot.js" type="text/javascript">
#       </script>
#      </div>
#     </div>
#    </section>
#   </main>
#   <footer class="footerWrapper">
#    <div class="s41r_footer" id="FooterPane">
#     <div class="ContentPane_202905 HTMLModule HTMLModule_202905">
#      <center>
#       <bbbseal class="bbbseal bbb_1_80_280">
#       </bbbseal>
#       <script type="text/javascript">
#        (function () {
#     var bbb = document.createElement("script");
#     bbb.type = "text/javascript";
#     bbb.async = true;
#     bbb.src = "https://seal-boston.bbb.org/v3/seals/blue-seal-280-80-bbb-56949.js";
#     var s = document.getElementsByTagName("script")[0];
#     s.parentNode.insertBefore(bbb, s);
# })();
#       </script>
#      </center>
#      <br/>
#     </div>
#     <div class="ContentPane_135382 FooterNav FooterNav_135382">
#      <div class="footerNav">
#       <a aria-label="Home" href="/default" target="_top" title="Home">
#        Home
#       </a>
#       <span class="footer-sep">
#        |
#       </span>
#       <a aria-label="About Us" href="/aboutus" target="_top" title="About Us">
#        About Us
#       </a>
#       <span class="footer-sep">
#        |
#       </span>
#       <a aria-label="Contact Us" href="/sendcomments" target="_top" title="Contact Us">
#        Contact Us
#       </a>
#       <span class="footer-sep">
#        |
#       </span>
#       <a aria-label="Privacy" href="/privacy" target="_top" title="Privacy">
#        Privacy Policy
#       </a>
#      </div>
#     </div>
#     <div class="ContentPane_135381 Copyright Copyright_135381">
#      <div class="copyright_main">
#       <div class="dcsLogin">
#        <a href="https://www.dealercarsearch.com" rel="noopener" target="_blank">
#         Dealer Car Search Login
#        </a>
#       </div>
#       <div class="copyright">
#        Copyright 2022        |
#        <a href="/sitemap" rel="noopener" target="_blank">
#         Sitemap
#        </a>
#       </div>
#      </div>
#     </div>
#     <div class="ContentPane_135465 HTMLModule HTMLModule_135465">
#      <script>
#       (function(d, s, id) {
#   var js, cnjs = d.getElementsByTagName('head')[0];
#   if (d.getElementById(id)) return;
#   js = d.createElement(s); js.id = id;
#   js.src = "//app.carnow.com/dealers/carnow_plugin.js?key=0kpjKfsF4KDGw4JvBg5HDJCkElm5jDJeddBi3Ithfxc6siws";
#   cnjs.appendChild(js, cnjs);
#   js.onload = function () { CarNowPlugin.init(); }
# }(document, 'script', 'com-carnow-plugin'));
#      </script>
#      <!---
# <a href="#" onclick="CarNowPlugin.showSmsContactForm(this, 'cncb11_sms_form');return false;" data-name="SRP VDP Text Us" rel="nofollow" title="Click to Text with a representative" class="cn-bar-btn">
# <img src="https://s3.amazonaws.com/customer-custom-images/CarNow_CTA_btn-textus.png"></a>
# --->
#     </div>
#     <div class="ContentPane_135383 SEO SEO_135383">
#      <div class="SeoText" itemscope="" itemtype="http://schema.org/AutoDealer">
#       <span itemprop="name">
#        Avon Auto Brokers
#       </span>
#       <i itemprop="address" itemscope="" itemtype="http://schema.org/PostalAddress">
#        <span itemprop="streetAddress">
#         159 Memorial Dr. Rte 28,
#        </span>
#        <span itemprop="addressLocality">
#         Avon,
#        </span>
#        <span itemprop="addressRegion">
#         MA
#        </span>
#        <span itemprop="postalCode">
#         02322
#        </span>
#       </i>
#       <a href="tel://508-584-0577" itemprop="telephone">
#        508-584-0577
#       </a>
#       <a href="https://avonautobrokers.com" itemprop="url">
#        https://avonautobrokers.com
#       </a>
#       <img alt="Logo" itemprop="logo" src="/Dealers/05001_06000/05134_mvc/images/logo.png"/>
#      </div>
#     </div>
#    </div>
#   </footer>
#   <div class="" id="ChatPane">
#   </div>
#   <a aria-label="Go to top of page" class="top" href="#" title="Go to top of page">
#    <i class="fas fa-chevron-up">
#    </i>
#   </a>
#   <noscript>
#    <img height="1" src="https://www.facebook.com/tr?id=1013190789141789&amp;ev=PageView
# &amp;noscript=1" width="1"/>
#   </noscript>
#   <script src="/Dealers/05001_06000/05134_mvc/23493.min.js?v=JX0hUpZCywZmkHGeHMFrBitU55O6oAUZZpoYnuitWAM" type="text/javascript">
#   </script>
#   <!--
# DEBUG INFORMATION
# =================
#
# Running on DCSPCMS01
# Release Name: Release-82
# Release Definition: new-cms-production-release
# Environment: Prod (Odd)
# Build Definition Id: 83
# Build Definition Name: cms-production-build
# Build Number: cms-production-build_2022.1.26.1
# Build Id: 19064
# Build URI: vstfs:///Build/Build/19064
# Source Branch: refs/heads/master
# Source Branch Name: master
# Source Version: 81676b4f2db95956c9da48fe4b988aab1bc8a3a8
# Requested For: Matthew Ingram
# Build Type: Build
#
# -->
#  </body>
# </html>

# %%
x = pi.parse_subsection_attr(soup, 'aria-label', 'div', 'a', 'c')

# %%
x
# Out:
# []

# %%
if len(x) == 0:
    print('Done')
# Out:
# Done

# %%
len(pi.parse_subsection(soup, 'div', 'span', 'i11r-vehicle', 'vehicleTrim'))
# Out:
# 25

# %%
len(pi.parse_subsection(soup, 'div', 'span', 'i11r-vehicle', 'price-2'))
# Out:
# 25

# %%
pi.convert_to_numeric_type(pi.parse_subsection(soup, 'div', 'p', 'i11r-vehicle', 'i11r_optMileage', 'get_text'))
# Out:
# [93675,
#  98610,
#  69596,
#  77675,
#  56776,
#  72324,
#  88597,
#  51692,
#  82134,
#  61934,
#  66113,
#  71893,
#  34018,
#  73904,
#  51567,
#  78156,
#  67810,
#  66109,
#  57188,
#  43518,
#  76593,
#  77396,
#  55576,
#  86968,
#  82159]

# %%
a = pi.parse_subsection_attr(soup, 'aria-label', 'div', 'a', 'i11r-vehicle')
a
# Out:
# ['2012 BMW 3-Series 328i',
#  '2012 BMW 3-Series 335i xDrive',
#  '2013 BMW 3-Series 335i xDrive',
#  '2014 BMW 3-Series 320i xDrive',
#  '2014 BMW 3-Series 320i xDrive',
#  '2014 BMW 3-Series 320i xDrive',
#  '2014 BMW 3-Series 328i xDrive',
#  '2015 BMW 3-Series 328i xDrive',
#  '2017 BMW 3-Series 320i xDrive',
#  '2018 BMW 3-Series Gran Turismo 330i xDrive',
#  '2014 BMW 4-Series 428i xDrive',
#  '2014 BMW 4-Series 428i xDrive',
#  '2019 BMW 4-Series Gran Coupe 430i xDrive',
#  '2011 BMW 5-Series 550i xDrive',
#  '2013 BMW 5-Series 535i xDrive',
#  '2013 BMW 5-Series 528i',
#  '2014 BMW 5-Series 528i xDrive',
#  '2014 BMW 5-Series 528i xDrive',
#  '2015 BMW 5-Series 535i xDrive',
#  '2015 BMW 5-Series 550i xDrive',
#  '2015 BMW 5-Series 528i xDrive',
#  '2016 BMW 5-Series 535i xDrive',
#  '2016 BMW 5-Series 528i xDrive',
#  '2017 BMW 5-Series 530i xDrive',
#  '2012 BMW 5-Series Gran Turismo 550i']

# %%
dealerships = {
    'Bostonyan Auto Group': {
        'url': 'https://www.bostonyanautogroup.com/view-inventory',
        'pagination_url': '',
        'dealership_name': 'Bostonyan Auto Group',
        'address': '119 Worcester St',
        'zipcode': '01760',
        'city': 'Natick',
        'state': 'MA'
    },
    'Direct Auto Mecca': {
        'url': 'https://www.directautomecca.com/view-inventory.aspx',
        'pagination_url': 'https://www.directautomecca.com/inventory.aspx?_new=true&_used=true&_page=2',
        'dealership_name': 'Direct Auto Mecca',
        'address': '154 Waverly Street',
        'zipcode': '01760',
        'city': 'Natick',
        'state': 'MA'
    },
    'Fafama Auto Sales': {
        'url': 'https://www.fafama.com/used-cars.aspx',
        'pagination_url': 'https://www.fafama.com/inventory.aspx?_used=true&_page=2',
        'dealership_name': 'Fafama Auto Sales',
        'address': '5 Cape Road',
        'zipcode': '01757',
        'city': 'Milford',
        'state': 'MA'
    },
    'Newton Automotive Sales': {
        'url': 'https://www.newtonautoandsales.com/cars-for-sale',
        'pagination_url': 'https://www.newtonautoandsales.com/cars-for-sale?PageNumber=2&Sort=MakeAsc&StockNumber=&Condition=&BodyStyle=&Make=&MaxPrice=&Mileage=&SoldStatus=AllVehicles&StockNumber=',
        'dealership_name': 'Newton Automotive Sales',
        'address': '249 Centre Street',
        'zipcode': '02458',
        'city': 'Newton',
        'state': 'MA'
    },
    'Blasius Boston': {
        'url': 'https://www.blasiusboston.com/used-cars-holliston-ma',
        'pagination_url': 'https://www.blasiusboston.com/used-cars-holliston-ma?page=2',
        'dealership_name': 'Blasius Boston',
        'address': '1286 Washington Street',
        'zipcode': '01746',
        'city': 'Holliston',
        'state': 'MA'
    },
    'Avon Auto Brokers': {
        'url': 'https://avonautobrokers.com/newandusedcars?clearall=1',
        'pagination_url': 'https://avonautobrokers.com/newandusedcars?page=2',
        'dealership_name': 'Avon Auto Brokers',
        'address': '159 Memorial Drive',
        'zipcode': '02322',
        'city': 'Avon',
        'state': 'MA'
    }
}

# %%
c = parse_dealership.get_avon_inventory_data(soup, dealerships['Avon Auto Brokers'])

# %%
c
# Out:
#                                          title  year make  \
# 0                       2012 BMW 3-Series 328i  2012  BMW
# 1                2012 BMW 3-Series 335i xDrive  2012  BMW
# 2                2013 BMW 3-Series 335i xDrive  2013  BMW
# 3                2014 BMW 3-Series 320i xDrive  2014  BMW
# 4                2014 BMW 3-Series 320i xDrive  2014  BMW
# 5                2014 BMW 3-Series 320i xDrive  2014  BMW
# 6                2014 BMW 3-Series 328i xDrive  2014  BMW
# 7                2015 BMW 3-Series 328i xDrive  2015  BMW
# 8                2017 BMW 3-Series 320i xDrive  2017  BMW
# 9   2018 BMW 3-Series Gran Turismo 330i xDrive  2018  BMW
# 10               2014 BMW 4-Series 428i xDrive  2014  BMW
# 11               2014 BMW 4-Series 428i xDrive  2014  BMW
# 12    2019 BMW 4-Series Gran Coupe 430i xDrive  2019  BMW
# 13               2011 BMW 5-Series 550i xDrive  2011  BMW
# 14               2013 BMW 5-Series 535i xDrive  2013  BMW
# 15                      2013 BMW 5-Series 528i  2013  BMW
# 16               2014 BMW 5-Series 528i xDrive  2014  BMW
# 17               2014 BMW 5-Series 528i xDrive  2014  BMW
# 18               2015 BMW 5-Series 535i xDrive  2015  BMW
# 19               2015 BMW 5-Series 550i xDrive  2015  BMW
# 20               2015 BMW 5-Series 528i xDrive  2015  BMW
# 21               2016 BMW 5-Series 535i xDrive  2016  BMW
# 22               2016 BMW 5-Series 528i xDrive  2016  BMW
# 23               2017 BMW 5-Series 530i xDrive  2017  BMW
# 24         2012 BMW 5-Series Gran Turismo 550i  2012  BMW
#
#                            model_trim vehicle_type                  model  \
# 0                       3-Series 328i         None               3-Series
# 1                3-Series 335i xDrive         None               3-Series
# 2                3-Series 335i xDrive         None               3-Series
# 3                3-Series 320i xDrive         None               3-Series
# 4                3-Series 320i xDrive         None               3-Series
# 5                3-Series 320i xDrive         None               3-Series
# 6                3-Series 328i xDrive         None               3-Series
# 7                3-Series 328i xDrive         None               3-Series
# 8                3-Series 320i xDrive         None               3-Series
# 9   3-Series Gran Turismo 330i xDrive         None  3-Series Gran Turismo
# 10               4-Series 428i xDrive         None               4-Series
# 11               4-Series 428i xDrive         None               4-Series
# 12         4-Series Gran  430i xDrive        Coupe    4-Series Gran Coupe
# 13               5-Series 550i xDrive         None               5-Series
# 14               5-Series 535i xDrive         None               5-Series
# 15                      5-Series 528i         None               5-Series
# 16               5-Series 528i xDrive         None               5-Series
# 17               5-Series 528i xDrive         None               5-Series
# 18               5-Series 535i xDrive         None               5-Series
# 19               5-Series 550i xDrive         None               5-Series
# 20               5-Series 528i xDrive         None               5-Series
# 21               5-Series 535i xDrive         None               5-Series
# 22               5-Series 528i xDrive         None               5-Series
# 23               5-Series 530i xDrive         None               5-Series
# 24         5-Series Gran Turismo 550i         None  5-Series Gran Turismo
#
#            trim  vehicle_mileage    price           exterior_color  ...  \
# 0          328i            93675  12995.0  Black Sapphire Metallic  ...
# 1   335i xDrive            98610  17995.0             Alpine White  ...
# 2   335i xDrive            69596  23450.0             Alpine White  ...
# 3   320i xDrive            77675  17888.0  Glacier Silver Metallic  ...
# 4   320i xDrive            56776  19995.0             Alpine White  ...
# 5   320i xDrive            72324  17995.0                Jet Black  ...
# 6   328i xDrive            88597  17495.0             Alpine White  ...
# 7   328i xDrive            51692  23995.0             Alpine White  ...
# 8   320i xDrive            82134  21995.0             Alpine White  ...
# 9   330i xDrive            61934  28888.0             Alpine White  ...
# 10  428i xDrive            66113  28995.0    Estoril Blue Metallic  ...
# 11  428i xDrive            71893  23995.0    Mineral Gray Metallic  ...
# 12  430i xDrive            34018  37888.0             Alpine White  ...
# 13  550i xDrive            73904  18995.0   Dark Graphite Metallic  ...
# 14  535i xDrive            51567  22750.0                Jet Black  ...
# 15         528i            78156  19750.0             Alpine White  ...
# 16  528i xDrive            67810  23750.0             Alpine White  ...
# 17  528i xDrive            66109  22888.0    Carbon Black Metallic  ...
# 18  535i xDrive            57188  24995.0             Alpine White  ...
# 19  550i xDrive            43518  33995.0                Jet Black  ...
# 20  528i xDrive            76593  22995.0   Callisto Gray Metallic  ...
# 21  535i xDrive            77396      NaN                    BLACK  ...
# 22  528i xDrive            55576  28995.0             Alpine White  ...
# 23  530i xDrive            86968  28995.0             Alpine White  ...
# 24         550i            82159  21995.0    Carbon Black Metallic  ...
#
#                              engine        drivetrain                vin  \
# 0            2.0L 4 Cylinder Engine  Rear Wheel Drive  WBA3A5C57CF340369
# 1   3.0L Straight 6 Cylinder Engine   All Wheel Drive  WBAKF9C50CE859077
# 2   3.0L Straight 6 Cylinder Engine   All Wheel Drive  WBA3B9C5XDF585494
# 3                       2.0L 4 Cyl.               AWD  WBA3C3G5XENS71260
# 4            2.0L 4 Cylinder Engine   All Wheel Drive  WBA3C3G58ENS67336
# 5            2.0L 4 Cylinder Engine   All Wheel Drive  WBA3C3C51EP661500
# 6            2.0L 4 Cylinder Engine   All Wheel Drive  WBA3B5G5XENS10733
# 7            2.0L 4 Cylinder Engine   All Wheel Drive  WBA3B5G58FNS14622
# 8            2.0L 4 Cylinder Engine   All Wheel Drive  WBA8E5G54HNU22433
# 9            2.0L 4 Cylinder Engine   All Wheel Drive  WBA8Z9C57JG828833
# 10                      2.0L 4 Cyl.               AWD  WBA3T1C51EPS98345
# 11           2.0L 4 Cylinder Engine   All Wheel Drive  WBA3N9C50EF722399
# 12           2.0L 4 Cylinder Engine   All Wheel Drive  WBA4J3C55KBL07028
# 13           4.4L 8 Cylinder Engine   All Wheel Drive  WBAFU9C55BC784698
# 14  3.0L Straight 6 Cylinder Engine   All Wheel Drive  WBAFU7C55DDU77517
# 15           2.0L 4 Cylinder Engine  Rear Wheel Drive  WBAXG5C59DD232851
# 16           2.0L 4 Cylinder Engine   All Wheel Drive  WBA5A7C55ED616700
# 17           2.0L 4 Cylinder Engine   All Wheel Drive  WBA5A7C52ED616475
# 18  3.0L Straight 6 Cylinder Engine   All Wheel Drive  WBA5B3C50FD543503
# 19           4.4L 8 Cylinder Engine   All Wheel Drive  WBAKP9C55FD693999
# 20           2.0L 4 Cylinder Engine   All Wheel Drive  WBA5A7C55FD624586
# 21   3.0 Straight 6 Cylinder Engine   All Wheel Drive  WBA5B3C50GG260129
# 22           2.0L 4 Cylinder Engine   All Wheel Drive  WBA5A7C57GG644452
# 23           2.0L 4 Cylinder Engine   All Wheel Drive  WBAJA7C38HWA70967
# 24           4.4L 8 Cylinder Engine  Rear Wheel Drive  WBASN4C57CC210202
#
#       dealership_name  dealership_address dealership_zipcode dealership_city  \
# 0   Avon Auto Brokers  159 Memorial Drive              02322            Avon
# 1   Avon Auto Brokers  159 Memorial Drive              02322            Avon
# 2   Avon Auto Brokers  159 Memorial Drive              02322            Avon
# 3   Avon Auto Brokers  159 Memorial Drive              02322            Avon
# 4   Avon Auto Brokers  159 Memorial Drive              02322            Avon
# 5   Avon Auto Brokers  159 Memorial Drive              02322            Avon
# 6   Avon Auto Brokers  159 Memorial Drive              02322            Avon
# 7   Avon Auto Brokers  159 Memorial Drive              02322            Avon
# 8   Avon Auto Brokers  159 Memorial Drive              02322            Avon
# 9   Avon Auto Brokers  159 Memorial Drive              02322            Avon
# 10  Avon Auto Brokers  159 Memorial Drive              02322            Avon
# 11  Avon Auto Brokers  159 Memorial Drive              02322            Avon
# 12  Avon Auto Brokers  159 Memorial Drive              02322            Avon
# 13  Avon Auto Brokers  159 Memorial Drive              02322            Avon
# 14  Avon Auto Brokers  159 Memorial Drive              02322            Avon
# 15  Avon Auto Brokers  159 Memorial Drive              02322            Avon
# 16  Avon Auto Brokers  159 Memorial Drive              02322            Avon
# 17  Avon Auto Brokers  159 Memorial Drive              02322            Avon
# 18  Avon Auto Brokers  159 Memorial Drive              02322            Avon
# 19  Avon Auto Brokers  159 Memorial Drive              02322            Avon
# 20  Avon Auto Brokers  159 Memorial Drive              02322            Avon
# 21  Avon Auto Brokers  159 Memorial Drive              02322            Avon
# 22  Avon Auto Brokers  159 Memorial Drive              02322            Avon
# 23  Avon Auto Brokers  159 Memorial Drive              02322            Avon
# 24  Avon Auto Brokers  159 Memorial Drive              02322            Avon
#
#    dealership_state                                      inventory_url  \
# 0                MA  https://avonautobrokers.com/newandusedcars?cle...
# 1                MA  https://avonautobrokers.com/newandusedcars?cle...
# 2                MA  https://avonautobrokers.com/newandusedcars?cle...
# 3                MA  https://avonautobrokers.com/newandusedcars?cle...
# 4                MA  https://avonautobrokers.com/newandusedcars?cle...
# 5                MA  https://avonautobrokers.com/newandusedcars?cle...
# 6                MA  https://avonautobrokers.com/newandusedcars?cle...
# 7                MA  https://avonautobrokers.com/newandusedcars?cle...
# 8                MA  https://avonautobrokers.com/newandusedcars?cle...
# 9                MA  https://avonautobrokers.com/newandusedcars?cle...
# 10               MA  https://avonautobrokers.com/newandusedcars?cle...
# 11               MA  https://avonautobrokers.com/newandusedcars?cle...
# 12               MA  https://avonautobrokers.com/newandusedcars?cle...
# 13               MA  https://avonautobrokers.com/newandusedcars?cle...
# 14               MA  https://avonautobrokers.com/newandusedcars?cle...
# 15               MA  https://avonautobrokers.com/newandusedcars?cle...
# 16               MA  https://avonautobrokers.com/newandusedcars?cle...
# 17               MA  https://avonautobrokers.com/newandusedcars?cle...
# 18               MA  https://avonautobrokers.com/newandusedcars?cle...
# 19               MA  https://avonautobrokers.com/newandusedcars?cle...
# 20               MA  https://avonautobrokers.com/newandusedcars?cle...
# 21               MA  https://avonautobrokers.com/newandusedcars?cle...
# 22               MA  https://avonautobrokers.com/newandusedcars?cle...
# 23               MA  https://avonautobrokers.com/newandusedcars?cle...
# 24               MA  https://avonautobrokers.com/newandusedcars?cle...
#
#                  scraped_date
# 0  2022-03-14 17:41:02.970459
# 1  2022-03-14 17:41:02.970459
# 2  2022-03-14 17:41:02.970459
# 3  2022-03-14 17:41:02.970459
# 4  2022-03-14 17:41:02.970459
# 5  2022-03-14 17:41:02.970459
# 6  2022-03-14 17:41:02.970459
# 7  2022-03-14 17:41:02.970459
# 8  2022-03-14 17:41:02.970459
# 9  2022-03-14 17:41:02.970459
# 10 2022-03-14 17:41:02.970459
# 11 2022-03-14 17:41:02.970459
# 12 2022-03-14 17:41:02.970459
# 13 2022-03-14 17:41:02.970459
# 14 2022-03-14 17:41:02.970459
# 15 2022-03-14 17:41:02.970459
# 16 2022-03-14 17:41:02.970459
# 17 2022-03-14 17:41:02.970459
# 18 2022-03-14 17:41:02.970459
# 19 2022-03-14 17:41:02.970459
# 20 2022-03-14 17:41:02.970459
# 21 2022-03-14 17:41:02.970459
# 22 2022-03-14 17:41:02.970459
# 23 2022-03-14 17:41:02.970459
# 24 2022-03-14 17:41:02.970459
#
# [25 rows x 22 columns]

# %%
pi.clean_text_data(pi.parse_subsection(soup, 'div', 'p', 'i11r-vehicle', 'i11r_optModel', 'get_text'), 'Model')
# Out:
# ['3-Series',
#  '3-Series',
#  '3-Series',
#  '3-Series',
#  '3-Series',
#  '3-Series',
#  '3-Series',
#  '3-Series',
#  '3-Series',
#  '3-Series Gran Turismo',
#  '4-Series',
#  '4-Series',
#  '4-Series Gran Coupe',
#  '5-Series',
#  '5-Series',
#  '5-Series',
#  '5-Series',
#  '5-Series',
#  '5-Series',
#  '5-Series',
#  '5-Series',
#  '5-Series',
#  '5-Series',
#  '5-Series',
#  '5-Series Gran Turismo']

# %%
pi.parse_subsection(soup, 'div', 'span', 'i11r-vehicle', 'price-2')
# Out:
# ['$12,995',
#  '$17,995',
#  '$23,450',
#  '$17,888',
#  '$19,995',
#  '$17,995',
#  '$17,495',
#  '$23,995',
#  '$21,995',
#  '$28,888',
#  '$28,995',
#  '$23,995',
#  '$37,888',
#  '$18,995',
#  '$22,750',
#  '$19,750',
#  '$23,750',
#  '$22,888',
#  '$24,995',
#  '$33,995',
#  '$22,995',
#  None,
#  '$28,995',
#  '$28,995',
#  '$21,995']

# %%
pi.convert_to_numeric_type(pi.parse_subsection(soup, 'div', 'span', 'i11r-vehicle', 'price-2'))
# Out:
# [12995,
#  17995,
#  23450,
#  17888,
#  19995,
#  17995,
#  17495,
#  23995,
#  21995,
#  28888,
#  28995,
#  23995,
#  37888,
#  18995,
#  22750,
#  19750,
#  23750,
#  22888,
#  24995,
#  33995,
#  22995,
#  nan,
#  28995,
#  28995,
#  21995]

# %%
dealerships = {
    'Bostonyan Auto Group': {
        'url': 'https://www.bostonyanautogroup.com/view-inventory',
        'pagination_url': '',
        'dealership_name': 'Bostonyan Auto Group',
        'address': '119 Worcester St',
        'zipcode': '01760',
        'city': 'Natick',
        'state': 'MA'
    },
    'Direct Auto Mecca': {
        'url': 'https://www.directautomecca.com/view-inventory.aspx',
        'pagination_url': 'https://www.directautomecca.com/inventory.aspx?_new=true&_used=true&_page=2',
        'dealership_name': 'Direct Auto Mecca',
        'address': '154 Waverly Street',
        'zipcode': '01760',
        'city': 'Natick',
        'state': 'MA'
    },
    'Fafama Auto Sales': {
        'url': 'https://www.fafama.com/used-cars.aspx',
        'pagination_url': 'https://www.fafama.com/inventory.aspx?_used=true&_page=2',
        'dealership_name': 'Fafama Auto Sales',
        'address': '5 Cape Road',
        'zipcode': '01757',
        'city': 'Milford',
        'state': 'MA'
    },
    'Newton Automotive Sales': {
        'url': 'https://www.newtonautoandsales.com/cars-for-sale',
        'pagination_url': 'https://www.newtonautoandsales.com/cars-for-sale?PageNumber=2&Sort=MakeAsc&StockNumber=&Condition=&BodyStyle=&Make=&MaxPrice=&Mileage=&SoldStatus=AllVehicles&StockNumber=',
        'dealership_name': 'Newton Automotive Sales',
        'address': '249 Centre Street',
        'zipcode': '02458',
        'city': 'Newton',
        'state': 'MA'
    },
    'Blasius Boston': {
        'url': 'https://www.blasiusboston.com/used-cars-holliston-ma',
        'pagination_url': 'https://www.blasiusboston.com/used-cars-holliston-ma?page=2',
        'dealership_name': 'Blasius Boston',
        'address': '1286 Washington Street',
        'zipcode': '01746',
        'city': 'Holliston',
        'state': 'MA'
    },
    'Avon Auto Brokers': {
        'url': 'https://avonautobrokers.com/newandusedcars?clearall=1',
        'pagination_url': 'https://avonautobrokers.com/newandusedcars?page=2',
        'dealership_name': 'Avon Auto Brokers',
        'address': '159 Memorial Drive',
        'zipcode': '02322',
        'city': 'Avon',
        'state': 'MA'
    }
}

# %%
key = 'Avon Auto Brokers'
c = []

response = requests.get(dealerships[key]['url'], headers = headers)
soup = BeautifulSoup(response.text, "html.parser")
data = parse_dealership.get_avon_inventory_data(soup, dealerships[key])
c.append(data)
# Parse out other pages if there are any available
pagination_url = dealerships[key]['pagination_url']
page_counter = 2

while (True):
    response = requests.get(pagination_url, headers = headers)
    soup_pagination = BeautifulSoup(response.text, "html.parser")   
    title = pi.parse_subsection_attr(soup, 'aria-label', 'div', 'a', 'i11r-vehicle')
    
    print(f'loop: {page_counter}',len(title), ' - ',  pagination_url)

    if len(title) == 0:
        break
    else:
        data = parse_dealership.get_avon_inventory_data(soup_pagination, dealerships[key])
        c.append(data)

    page_counter += 1
    pagination_url = re.sub('page=[0-9]+', f'page={page_counter}', pagination_url)
# Out:
# loop: 2 25  -  https://avonautobrokers.com/newandusedcars?page=2
# loop: 3 25  -  https://avonautobrokers.com/newandusedcars?page=3
# loop: 4 25  -  https://avonautobrokers.com/newandusedcars?page=4
# loop: 5 25  -  https://avonautobrokers.com/newandusedcars?page=5
# loop: 6 25  -  https://avonautobrokers.com/newandusedcars?page=6
# loop: 7 25  -  https://avonautobrokers.com/newandusedcars?page=7
# loop: 8 25  -  https://avonautobrokers.com/newandusedcars?page=8
# loop: 9 25  -  https://avonautobrokers.com/newandusedcars?page=9
# loop: 10 25  -  https://avonautobrokers.com/newandusedcars?page=10
# loop: 11 25  -  https://avonautobrokers.com/newandusedcars?page=11
# loop: 12 25  -  https://avonautobrokers.com/newandusedcars?page=12
# loop: 13 25  -  https://avonautobrokers.com/newandusedcars?page=13
# loop: 14 25  -  https://avonautobrokers.com/newandusedcars?page=14
# loop: 15 25  -  https://avonautobrokers.com/newandusedcars?page=15
# loop: 16 25  -  https://avonautobrokers.com/newandusedcars?page=16
# loop: 17 25  -  https://avonautobrokers.com/newandusedcars?page=17
# loop: 18 25  -  https://avonautobrokers.com/newandusedcars?page=18
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/xb/kngqrs1n3n5474zrpfc02thc0000gn/T/ipykernel_18958/3188344167.py in <module>
#      11
#      12 while (True):
# ---> 13     response = requests.get(pagination_url, headers = headers)
#      14     soup_pagination = BeautifulSoup(response.text, "html.parser")
#      15     title = pi.parse_subsection_attr(soup, 'aria-label', 'div', 'a', 'i11r-vehicle')
#
# ~/opt/anaconda3/envs/dash/lib/python3.9/site-packages/requests/api.py in get(url, params, **kwargs)
#      73     """
#      74
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~/opt/anaconda3/envs/dash/lib/python3.9/site-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~/opt/anaconda3/envs/dash/lib/python3.9/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     527         }
#     528         send_kwargs.update(settings)
# --> 529         resp = self.send(prep, **send_kwargs)
#     530
#     531         return resp
#
# ~/opt/anaconda3/envs/dash/lib/python3.9/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     643
#     644         # Send the request
# --> 645         r = adapter.send(request, **kwargs)
#     646
#     647         # Total elapsed time of the request (approximately)
#
# ~/opt/anaconda3/envs/dash/lib/python3.9/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438         try:
#     439             if not chunked:
# --> 440                 resp = conn.urlopen(
#     441                     method=request.method,
#     442                     url=url,
#
# ~/opt/anaconda3/envs/dash/lib/python3.9/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     701
#     702             # Make the request on the httplib connection object.
# --> 703             httplib_response = self._make_request(
#     704                 conn,
#     705                 method,
#
# ~/opt/anaconda3/envs/dash/lib/python3.9/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     447                     # Python 3 (including for exceptions like SystemExit).
#     448                     # Otherwise it looks like a bug in the code.
# --> 449                     six.raise_from(e, None)
#     450         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~/opt/anaconda3/envs/dash/lib/python3.9/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# ~/opt/anaconda3/envs/dash/lib/python3.9/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     442                 # Python 3
#     443                 try:
# --> 444                     httplib_response = conn.getresponse()
#     445                 except BaseException as e:
#     446                     # Remove the TypeError from the exception chain in
#
# ~/opt/anaconda3/envs/dash/lib/python3.9/http/client.py in getresponse(self)
#    1369         try:
#    1370             try:
# -> 1371                 response.begin()
#    1372             except ConnectionError:
#    1373                 self.close()
#
# ~/opt/anaconda3/envs/dash/lib/python3.9/http/client.py in begin(self)
#     317         # read until we get a non-100 response
#     318         while True:
# --> 319             version, status, reason = self._read_status()
#     320             if status != CONTINUE:
#     321                 break
#
# ~/opt/anaconda3/envs/dash/lib/python3.9/http/client.py in _read_status(self)
#     278
#     279     def _read_status(self):
# --> 280         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     281         if len(line) > _MAXLINE:
#     282             raise LineTooLong("status line")
#
# ~/opt/anaconda3/envs/dash/lib/python3.9/socket.py in readinto(self, b)
#     702         while True:
#     703             try:
# --> 704                 return self._sock.recv_into(b)
#     705             except timeout:
#     706                 self._timeout_occurred = True
#
# ~/opt/anaconda3/envs/dash/lib/python3.9/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# ~/opt/anaconda3/envs/dash/lib/python3.9/ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
TABLE_NAME = 'inventory_staging'
DB_NAME = 'cars.db'

#Connecting to sqlite
conn = sqlite3.connect(DB_NAME)

#Creating a cursor object using the cursor() method
cursor = conn.cursor()

#Doping EMPLOYEE table if already exists
cursor.execute(f"DELETE FROM {TABLE_NAME} WHERE dealership_name = 'Avon Auto Brokers'")

#Commit your changes in the database
conn.commit()

#Closing the connection
conn.close()

# %%
TABLE_NAME = 'inventory_staging'
DB_NAME = 'cars.db'

#Connecting to sqlite
conn = sqlite3.connect(DB_NAME)

#Creating a cursor object using the cursor() method
cursor = conn.cursor()

#Doping EMPLOYEE table if already exists
cursor.execute(f"DELETE FROM {TABLE_NAME} WHERE dealership_name = 'Newton Automotive Sales'")

#Commit your changes in the database
conn.commit()

#Closing the connection
conn.close()

# %%
conn = sqlite3.connect('cars.db')
sql_query = "SELECT dealership_name, count(*) AS num_of_vehicles FROM inventory_staging GROUP BY 1"
result = pd.read_sql_query(sql_query, conn)
result
# Out:
#         dealership_name  num_of_vehicles
# 0        Blasius Boston              289
# 1  Bostonyan Auto Group               18
# 2     Direct Auto Mecca              147
# 3     Fafama Auto Sales              132

# %%
conn = sqlite3.connect('cars.db')
sql_query = "SELECT dealership_name, count(*) AS num_of_vehicles FROM inventory_staging GROUP BY 1"
result = pd.read_sql_query(sql_query, conn)
result
# Out:
#            dealership_name  num_of_vehicles
# 0        Avon Auto Brokers              303
# 1           Blasius Boston              289
# 2     Bostonyan Auto Group               18
# 3        Direct Auto Mecca              147
# 4        Fafama Auto Sales              132
# 5  Newton Automotive Sales               35

# %%
conn = sqlite3.connect('cars.db')
sql_query = "SELECT * FROM inventory_staging WHERE dealership_name = 'Avon Auto Brokers'"
result = pd.read_sql_query(sql_query, conn)
result
#result.to_csv('cars.csv')
# Out:
#                                                 title  year          make  \
# 0                             2013 Acura RDX Tech Pkg  2013         Acura
# 1    2007 Aston Martin V8 Vantage 2dr Conv Sportshift  2007  Aston Martin
# 2                           2015 Audi A3 1.8T Premium  2015          Audi
# 3                           2015 Audi A3 1.8T Premium  2015          Audi
# 4                                2014 Audi A4 Premium  2014          Audi
# ..                                                ...   ...           ...
# 298                      2018 Toyota Tacoma TRD Sport  2018        Toyota
# 299                              2013 Toyota Venza LE  2013        Toyota
# 300       2013 Volkswagen Beetle 2.0L TDI w/Sound/Nav  2013    Volkswagen
# 301                 2017 Volkswagen Golf GTI Autobahn  2017    Volkswagen
# 302              2014 Volkswagen Jetta SportWagen TDI  2014    Volkswagen
#
#                       model_trim vehicle_type             model  \
# 0                   RDX Tech Pkg          SUV               RDX
# 1    V8 tage 2dr Conv Sportshift  Convertible        V8 Vantage
# 2                A3 1.8T Premium        Sedan                A3
# 3                A3 1.8T Premium        Sedan                A3
# 4                     A4 Premium        Sedan                A4
# ..                           ...          ...               ...
# 298             Tacoma TRD Sport        Truck            Tacoma
# 299                     Venza LE        Wagon             Venza
# 300  Beetle 2.0L TDI w/Sound/Nav  Convertible            Beetle
# 301            Golf GTI Autobahn    Hatchback          Golf GTI
# 302         Jetta SportWagen TDI        Wagon  Jetta SportWagen
#
#                      trim  vehicle_mileage    price            exterior_color  \
# 0                Tech Pkg           120771  15995.0  Graphite Luster Metallic
# 1     2dr Conv Sportshift            35137  47995.0            Standard Paint
# 2            1.8T Premium            64060  19495.0           Brilliant Black
# 3            1.8T Premium            52410  19995.0   Florett Silver Metallic
# 4                 Premium            72622  16450.0             Brilliant Red
# ..                    ...              ...      ...                       ...
# 298             TRD Sport            37000  38888.0    Magnetic Gray Metallic
# 299                    LE            99695  16995.0            Attitude Black
# 300  2.0L TDI w/Sound/Nav            68885  22995.0               Candy White
# 301              Autobahn            72712  22995.0    Reflex Silver Metallic
# 302                   TDI            68878  17495.0     Toffee Brown Metallic
#
#      ...                   engine         drivetrain                vin  \
# 0    ...  3.5L V6 Cylinder Engine    All Wheel Drive  5J8TB4H55DL003514
# 1    ...   4.3L 8 Cylinder Engine   Rear Wheel Drive  SCFBF04B47GD06725
# 2    ...   1.8L 4 Cylinder Engine  Front Wheel Drive  WAUACGFF3F1141158
# 3    ...   1.8L 4 Cylinder Engine  Front Wheel Drive  WAUACGFF0F1134555
# 4    ...   2.0L 4 Cylinder Engine    All Wheel Drive  WAUBFAFL6EA071135
# ..   ...                      ...                ...                ...
# 298  ...  3.5L V6 Cylinder Engine   Four Wheel Drive  3TMCZ5AN8JM169515
# 299  ...   2.7L 4 Cylinder Engine    All Wheel Drive  4T3BA3BB2DU039714
# 300  ...   2.0L 4 Cylinder Engine  Front Wheel Drive  3VW5L7AT5DM833386
# 301  ...   2.0L 4 Cylinder Engine  Front Wheel Drive  3VW4T7AU7HM015930
# 302  ...   2.0L 4 Cylinder Engine  Front Wheel Drive  3VWPL7AJ9EM612057
#
#        dealership_name  dealership_address dealership_zipcode dealership_city  \
# 0    Avon Auto Brokers  159 Memorial Drive              02322            Avon
# 1    Avon Auto Brokers  159 Memorial Drive              02322            Avon
# 2    Avon Auto Brokers  159 Memorial Drive              02322            Avon
# 3    Avon Auto Brokers  159 Memorial Drive              02322            Avon
# 4    Avon Auto Brokers  159 Memorial Drive              02322            Avon
# ..                 ...                 ...                ...             ...
# 298  Avon Auto Brokers  159 Memorial Drive              02322            Avon
# 299  Avon Auto Brokers  159 Memorial Drive              02322            Avon
# 300  Avon Auto Brokers  159 Memorial Drive              02322            Avon
# 301  Avon Auto Brokers  159 Memorial Drive              02322            Avon
# 302  Avon Auto Brokers  159 Memorial Drive              02322            Avon
#
#     dealership_state                                      inventory_url  \
# 0                 MA  https://avonautobrokers.com/newandusedcars?cle...
# 1                 MA  https://avonautobrokers.com/newandusedcars?cle...
# 2                 MA  https://avonautobrokers.com/newandusedcars?cle...
# 3                 MA  https://avonautobrokers.com/newandusedcars?cle...
# 4                 MA  https://avonautobrokers.com/newandusedcars?cle...
# ..               ...                                                ...
# 298               MA  https://avonautobrokers.com/newandusedcars?cle...
# 299               MA  https://avonautobrokers.com/newandusedcars?cle...
# 300               MA  https://avonautobrokers.com/newandusedcars?cle...
# 301               MA  https://avonautobrokers.com/newandusedcars?cle...
# 302               MA  https://avonautobrokers.com/newandusedcars?cle...
#
#                    scraped_date
# 0    2022-03-15 17:59:45.972128
# 1    2022-03-15 17:59:45.972128
# 2    2022-03-15 17:59:45.972128
# 3    2022-03-15 17:59:45.972128
# 4    2022-03-15 17:59:45.972128
# ..                          ...
# 298  2022-03-15 17:59:57.188535
# 299  2022-03-15 17:59:57.188535
# 300  2022-03-15 17:59:57.909209
# 301  2022-03-15 17:59:57.909209
# 302  2022-03-15 17:59:57.909209
#
# [303 rows x 22 columns]

# %% [markdown]
# result.isnull().sum()

# %%
pi.clean_text_data(pi.parse_subsection(soup, 'div', 'p', 'i11r-vehicle', 'i11r_optBody', 'get_text'), 'Body Type')
# Out:
# ['Convertible',
#  'Convertible',
#  'Convertible',
#  'Convertible',
#  'Sedan',
#  'Truck',
#  'Coupe',
#  'Hatchback',
#  'Convertible',
#  'Coupe',
#  'Convertible',
#  'SUV',
#  'Sedan',
#  'Sedan',
#  'Sedan',
#  'Sedan',
#  'Truck',
#  'Truck',
#  'Sedan',
#  'Sedan',
#  'Sedan',
#  'Sedan',
#  'Truck',
#  'Truck',
#  'Wagon']

# %%
conn = sqlite3.connect('cars.db')
sql_query = "SELECT * FROM inventory_staging WHERE make is null"
result = pd.read_sql_query(sql_query, conn)
result
# Out:
# Empty DataFrame
# Columns: [title, year, make, model_trim, vehicle_type, model, trim, vehicle_mileage, price, exterior_color, interior_color, transmission, engine, drivetrain, vin, dealership_name, dealership_address, dealership_zipcode, dealership_city, dealership_state, inventory_url, scraped_date]
# Index: []
#
# [0 rows x 22 columns]
